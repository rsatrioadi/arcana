# %%
# %pip install --upgrade py2neo
# %pip install --upgrade openai

# %%
from py2neo import Graph

# %%
from itertools import groupby

# %%
import json


def read_json_file(file_path):
    with open(file_path, 'r') as file:
        data = json.load(file)
    return data


def parse_json(json_string):
  json_dict = json.loads(json_string)
  return json_dict


def dict_to_pretty_json(dictionary):
  pretty_json = json.dumps(dictionary, indent=2)
  return pretty_json


def write_dict_to_json(dictionary, file_path):
  with open(file_path, 'w') as json_file:
    json.dump(dictionary, json_file, indent=2)

# %%
import configparser

def read_ini_file(file_path):
    config = configparser.ConfigParser()
    config.read(file_path)
    ini_dict = {section: dict(config.items(section))
                for section in config.sections()}
    return ini_dict

# %%
from openai import OpenAI

# %%
import re


def remove_java_comments(java_source):
    # Regular expression to match Java comments (both single-line and multi-line)
    pattern = r"(//.*?$)|(/\*.*?\*/)"

    # Remove comments using the regular expression
    java_source_without_comments = re.sub(
        pattern, "", java_source, flags=re.MULTILINE | re.DOTALL)

    return java_source_without_comments

# %%
def sentence(s):
  '''
  Capitalize the first letter of a string `s` and ensures that the string 
  ends with a period (if it's not already a sentence-ending punctuation).
  '''
  t = s.strip()
  if t[-1] in '.?!…~–—':
    return f'{t[0].upper()}{t[1:]}'
  else:
    return f'{t[0].upper()}{t[1:]}.'
  
sentence(' hello world~  ')
# Out:
# 'Hello world~'

# %% [markdown]
# ## Parameters

# %%
# If True: do not call the API, just print the prompts
only_print_prompt = False

# %%
secrets = read_ini_file('secrets.ini')
project_name = secrets['project']['name']
project_name
# Out:
# 'k9mail'

# %%
project_desc = 'an open source email client for Android focused on making it easy to chew through large volumes of email'

# %% [markdown]
# ## Connect to neo4j
#
# To access knowledge graph extracted using javapers which is then loaded to neo4j graph database.

# %%
graph = Graph(secrets['neo4j']['url'], auth=(secrets['neo4j']['username'], secrets['neo4j']['password']))

# %% [markdown]
# ## Connect to openai

# %%
args = dict()

if 'apikey' in secrets['openai']:
  args['api_key'] = secrets['openai']['apikey']
if 'apibase' in secrets['openai']:
  args['base_url'] = secrets['openai']['apibase']
if 'model' in secrets['openai']:
  model = secrets['openai']['model']
else:
  model = "gpt-3.5-turbo"

(args['base_url'], model)

# %%
client = OpenAI(**args)
client.base_url
# Out:
# URL('https://api.openai.com/v1/')

# %%
# test the LLM server---create a completion
completion = client.chat.completions.create(
  model=model,
  messages=[{"role":"user","content":"What is your name?"}],
  temperature=0
)
# print the completion
print(completion.choices[0].message.content)
# Out:
# I am a language model AI created by OpenAI, so I do not have a personal name. You can refer to me as OpenAI or Assistant. How can I assist you today?

# %%
# layers = [
# 	{
# 		"name":"Presentation Layer",
# 		"class_characteristics": [
# 			"contains fields that represent UI objects such as buttons and text fields",
# 			"defines a UI markup template with markers of where to put data from model",
# 		],
# 		"method_characteristics": [
# 			"sets the attribute of UI objects based on information from other objects",
# 			"arranges UI objects in a particular layout",
# 			"observes changes in a data model and updates UI objects accordingly",
# 			"reacts to UI events by creating or invoking data model objects",
# 			"determines how to update a UI view according to the result of data model process result",
# 			"reacts to UI events by deciding what kind of action to initiate and delegates to a command to carry out the action ",
# 			"recognizes domain data and invokes the appropriate UI rendering transformations",
# 			"processes domain data element by element and transforms it into visual representation for the UI",
# 			"assembles model information in a presentation-oriented logical structure for the UI",
# 			"renders a presentation-oriented structure in a UI view markup", 
# 		]
# 	},
# 	{
# 		"name":"Service Layer",
# 		"class_characteristics": [
# 			"establishes a set of avaliable domain operations",
# 			"provides a coarse-grained interface that delegates to/coordinates finer-grained interfaces",
# 		],
# 		"method_characteristics": [
# 			"responds to user input, manipulates model, and causes the view to update appropriately",
# 			"decides which domain logic to run upon an event",
# 			"decides the view with which to display the result of a domain operation",
# 			"encapsulates business logic",
# 			"controls transactions and coordinates responses in the implementation of its operations",
# 			"wraps several calls to a domain model within one method",
# 		]
# 	},
# 	{
# 		"name":"Domain Layer",
# 		"class_characteristics": [
# 			"organizes business logic by procedures where each procedure handles a single request from the presentation",
# 			"handles the business logic for all rows in a database table or view",
# 			"groups data model with behavior that acts on that data",
# 			"represents a tabular data",
# 			"represents a serializable data",
# 			"consists of fields and getters and setters",
# 			"has simple or primitive fields",
# 		],
# 		"method_characteristics": [
# 			"makes calls to the data source",
# 			"represents some meaningful business rules or logic",
# 			"assembles information from multiple domain objects",
# 		]
# 	},
# 	{
# 		"name":"Data Source Layer",
# 		"class_characteristics": [
# 			"represents a single data record",
# 			"acts as a gateway to a data source",
# 			"has a simple interface consisting find, update, insert, and delete methods",
# 			"maintains a list of objects affected by a  transaction and coordinates the writing out of changes",
# 			"maintains an identity map to see which objects are already loaded from the data source",
# 			"wraps a record in a data source, encapsulates the data source access, and adds domain logic on that data",
# 			"is responsible for saving and loading to the data source and also for any domain logic that acts on the data",
# 		],
# 		"method_characteristics": [
# 			"performs conversion from data source-type to in-memory representation",
# 			"contains operations for insert/update/delete to a data source",
# 			"finds information from a data source and returns its representation",
# 			"returns a tabular data",
# 			"bundles changes to a data source as a single transaction",
# 			"performs inconsistency checking before commiting changes to a data source",
# 			"maps an object from the data source to an equivalent model object",
# 		]
# 	},
# ]

# %%
# layers

# %%
# prompt_template = '''Consider the context of an Android Java project "{project_name}": {project_desc}.

# The {class_type} `{class_name}` contains the method `{method_name}`:

# ```java
# {method_src}
# ```

# Which of the following statements could reflect the above method? There can be 0, 1, or more answers. Hint: when you see "domain", think "Android email client" and when you see "data source", it means a database, external file, or equivalent.

# {method_characteristics}

# Think step by step. The last line of your response must only be an array containing statement numbers that are true, e.g., `[1,3]`.
# '''

# %%
prompt1_template = '''Here are the layers in a layered software architecture and their responsibilities:

1. **Presentation Layer**: Manages the user interface, including defining UI elements and their behavior, displays information, reacting to user input, and updating UI views accordingly.
  
2. **Service Layer**: Orchestrates domain operations, encapsulates business logic, selects the appropriate business logic for a user request, and coordinates responses between the presentation and domain layers.

3. **Domain Layer**: Organizes and implements business logic, represents domain data and its behavior, and carries out the necessary computation for responding to user requests.

4. **Data Source Layer**: Communicates with databases, messaging systems, or other sources of data, performs CRUD operations, handles data conversion, and ensures data integrity before committing changes to the data source.

Consider the following Java method from {project_desc}:

```java
{method_src}
```

Reason about whether this method fits with each of the layers above. Think step by step. First, summarize what is the responsibility of the method. Then compare it to the layers above.'''

prompt2 = "In conclusion, state a single layer that you think fits this method the most. Just answer with the name of the layer and nothing else."

# %%
packages = { record['p']['qualifiedName'] for record in graph.run('match (p:Container)-[:contains]->(:Structure) where p.kind="package" return p') }

# %%
len(packages), packages
# Out:
# (38,
#  {'com.fsck.k9',
#   'com.fsck.k9.account',
#   'com.fsck.k9.activity',
#   'com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.loader',
#   'com.fsck.k9.activity.misc',
#   'com.fsck.k9.activity.setup',
#   'com.fsck.k9.autocrypt',
#   'com.fsck.k9.cache',
#   'com.fsck.k9.controller',
#   'com.fsck.k9.crypto',
#   'com.fsck.k9.fragment',
#   'com.fsck.k9.helper',
#   'com.fsck.k9.helper.jsoup',
#   'com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.migrations',
#   'com.fsck.k9.mailstore.util',
#   'com.fsck.k9.message',
#   'com.fsck.k9.message.extractors',
#   'com.fsck.k9.message.html',
#   'com.fsck.k9.message.quote',
#   'com.fsck.k9.message.signature',
#   'com.fsck.k9.notification',
#   'com.fsck.k9.power',
#   'com.fsck.k9.preferences',
#   'com.fsck.k9.provider',
#   'com.fsck.k9.remotecontrol',
#   'com.fsck.k9.search',
#   'com.fsck.k9.service',
#   'com.fsck.k9.setup',
#   'com.fsck.k9.ui',
#   'com.fsck.k9.ui.compose',
#   'com.fsck.k9.ui.crypto',
#   'com.fsck.k9.ui.dialog',
#   'com.fsck.k9.ui.message',
#   'com.fsck.k9.ui.messageview',
#   'com.fsck.k9.view',
#   'com.fsck.k9.widget.list'})

# %%
take_samples = False

# %%
# import random

# if take_samples:
#   num_methods = 0

#   samples = dict()

#   for pkg_name in sorted(list(packages)):

#     classes = [ record['c'] for record in graph.run('MATCH (p:Container)-[:contains]->(c:Structure) '
#                                                                     f'WHERE p.qualifiedName="{pkg_name}" AND p.kind="package" '
#                                                                     'RETURN c') ]
#     top_classes = [c for c in classes if not '$' in c['qualifiedName']]
#     class_samples = random.sample(top_classes, min(len(top_classes),3))
    
#     samples[pkg_name] = dict()
#     for clss in class_samples:

#       class_name = clss['qualifiedName']
#       kind = clss['kind']
#       methods = [ record['m'] for record in graph.run('MATCH (c:Structure)-[:hasScript]->(m:Operation) '
#                                                       f'WHERE c.qualifiedName="{class_name}" AND m.visibility="public" AND m.kind="method" '
#                                                       'return m') ]
#       ok_methods = [m for m in methods if 300<len(m['sourceText'])<3000]
#       method_samples = random.sample(ok_methods, min(len(ok_methods),10))
#       # print(len(method_samples), [(clss['qualifiedName'], m['simpleName']) for m in method_samples])
#       num_methods += len(method_samples)

#       samples[pkg_name][class_name] = method_samples
#   print(samples)

# %%
# if take_samples:
# 	write_dict_to_json(samples, 'k9mail-samples.json')

# %%
# if not take_samples:
# 	samples = read_json_file('k9mail-samples.json')
# samples

# %%
num_methods = 0

samples = dict()

for pkg_name in sorted(list(packages)):
    classes = [ record['c'] for record in graph.run('MATCH (p:Container)-[:contains]->(c:Structure) '
                                                                    f'WHERE p.qualifiedName="{pkg_name}" AND p.kind="package" '
                                                                    'RETURN c') ]
    # top_classes = [c for c in classes if not '$' in c['qualifiedName']]
    # class_samples = random.sample(top_classes, min(len(top_classes),3))
    
    samples[pkg_name] = dict()
    for clss in classes:

      class_name = clss['qualifiedName']
      kind = clss['kind']
      methods = [ record['m'] for record in graph.run('MATCH (c:Structure)-[:hasScript]->(m:Operation) '
                                                      f'WHERE c.qualifiedName="{class_name}" AND m.visibility="public" AND m.kind="method" '
                                                      'return m') ]
    #   ok_methods = [m for m in methods if 300<len(m['sourceText'])<3000]
    #   method_samples = random.sample(ok_methods, min(len(ok_methods),10))
      # print(len(method_samples), [(clss['qualifiedName'], m['simpleName']) for m in method_samples])
      num_methods += len(methods)

      samples[pkg_name][class_name] = methods
# print(samples)
num_methods
# Out:
# 2693

# %%
samples.keys()
# Out:
# dict_keys(['com.fsck.k9', 'com.fsck.k9.account', 'com.fsck.k9.activity', 'com.fsck.k9.activity.compose', 'com.fsck.k9.activity.loader', 'com.fsck.k9.activity.misc', 'com.fsck.k9.activity.setup', 'com.fsck.k9.autocrypt', 'com.fsck.k9.cache', 'com.fsck.k9.controller', 'com.fsck.k9.crypto', 'com.fsck.k9.fragment', 'com.fsck.k9.helper', 'com.fsck.k9.helper.jsoup', 'com.fsck.k9.mailstore', 'com.fsck.k9.mailstore.migrations', 'com.fsck.k9.mailstore.util', 'com.fsck.k9.message', 'com.fsck.k9.message.extractors', 'com.fsck.k9.message.html', 'com.fsck.k9.message.quote', 'com.fsck.k9.message.signature', 'com.fsck.k9.notification', 'com.fsck.k9.power', 'com.fsck.k9.preferences', 'com.fsck.k9.provider', 'com.fsck.k9.remotecontrol', 'com.fsck.k9.search', 'com.fsck.k9.service', 'com.fsck.k9.setup', 'com.fsck.k9.ui', 'com.fsck.k9.ui.compose', 'com.fsck.k9.ui.crypto', 'com.fsck.k9.ui.dialog', 'com.fsck.k9.ui.message', 'com.fsck.k9.ui.messageview', 'com.fsck.k9.view', 'com.fsck.k9.widget.list'])

# %%
samples['com.fsck.k9.ui']
# Out:
# {'com.fsck.k9.ui.EolConvertingEditText': [Node('Operation', kind='method', metaSrc='source code', name='setCharacters(java.lang.CharSequence)', qualifiedName='com.fsck.k9.ui.EolConvertingEditText.setCharacters(java.lang.CharSequence)', simpleName='setCharacters(java.lang.CharSequence)', sourceText='/**\r\n * Sets the string value of the EolConvertingEditText. Any line endings\r\n * in the string will be converted to {@code \\n}.\r\n *\r\n * @param text\r\n */\r\npublic void setCharacters(java.lang.CharSequence text) {\r\n    setText(text.toString().replace("\\r\\n", "\\n"));\r\n}', visibility='public'),
#   Node('Operation', kind='method', metaSrc='source code', name='getCharacters()', qualifiedName='com.fsck.k9.ui.EolConvertingEditText.getCharacters()', simpleName='getCharacters()', sourceText='/**\r\n * Return the text the EolConvertingEditText is displaying.\r\n *\r\n * @return A string with any line endings converted to {@code \\r\\n}.\r\n */\r\npublic java.lang.String getCharacters() {\r\n    return getText().toString().replace("\\n", "\\r\\n");\r\n}', visibility='public')],
#  'com.fsck.k9.ui.ContactBadge$QueryHandler': [],
#  'com.fsck.k9.ui.ContactBadge': [Node('Operation', kind='method', metaSrc='source code', name='assignContactFromEmail(java.lang.String,boolean,android.os.Bundle)', qualifiedName='com.fsck.k9.ui.ContactBadge.assignContactFromEmail(java.lang.String,boolean,android.os.Bundle)', simpleName='assignContactFromEmail(java.lang.String,boolean,android.os.Bundle)', sourceText="/**\r\n * Assign a contact based on an email address. This should only be used when\r\n * the contact's URI is not available, as an extra query will have to be\r\n * performed to lookup the URI based on the email.\r\n *\r\n * @param emailAddress\r\n * \t\tThe email address of the contact.\r\n * @param lazyLookup\r\n * \t\tIf this is true, the lookup query will not be performed\r\n * \t\tuntil this view is clicked.\r\n * @param extras\r\n * \t\tA bundle of extras to populate the contact edit page with if the contact\r\n * \t\tis not found and the user chooses to add the email address to an existing contact or\r\n * \t\tcreate a new contact. Uses the same string constants as those found in\r\n * \t\t{@link android.provider.ContactsContract.Intents.Insert}\r\n */\r\npublic void assignContactFromEmail(java.lang.String emailAddress, boolean lazyLookup, android.os.Bundle extras) {\r\n    contactEmail = emailAddress;\r\n    this.extras = extras;\r\n    if (!lazyLookup) {\r\n        queryHandler.startQuery(com.fsck.k9.ui.ContactBadge.TOKEN_EMAIL_LOOKUP, null, android.net.Uri.withAppendedPath(Email.CONTENT_LOOKUP_URI, android.net.Uri.encode(contactEmail)), com.fsck.k9.ui.ContactBadge.EMAIL_LOOKUP_PROJECTION, null, null, null);\r\n    } else {\r\n        contactUri = null;\r\n        onContactUriChanged();\r\n    }\r\n}", visibility='public'),
#   Node('Operation', kind='method', metaSrc='source code', name='assignContactUri(android.net.Uri)', qualifiedName='com.fsck.k9.ui.ContactBadge.assignContactUri(android.net.Uri)', simpleName='assignContactUri(android.net.Uri)', sourceText="/**\r\n * Assign the contact uri that this ContactBadge should be associated\r\n * with. Note that this is only used for displaying the QuickContact window and\r\n * won't bind the contact's photo for you. Call {@link #setImageDrawable(Drawable)} to set the\r\n * photo.\r\n *\r\n * @param contactUri\r\n * \t\tEither a {@link Contacts#CONTENT_URI} or\r\n * \t\t{@link Contacts#CONTENT_LOOKUP_URI} style URI.\r\n */\r\npublic void assignContactUri(android.net.Uri contactUri) {\r\n    this.contactUri = contactUri;\r\n    contactEmail = null;\r\n    onContactUriChanged();\r\n}", visibility='public'),
#   Node('Operation', kind='method', metaSrc='source code', name='onInitializeAccessibilityNodeInfo(android.view.accessibility.AccessibilityNodeInfo)', qualifiedName='com.fsck.k9.ui.ContactBadge.onInitializeAccessibilityNodeInfo(android.view.accessibility.AccessibilityNodeInfo)', simpleName='onInitializeAccessibilityNodeInfo(android.view.accessibility.AccessibilityNodeInfo)', sourceText='@java.lang.Override\r\npublic void onInitializeAccessibilityNodeInfo(android.view.accessibility.AccessibilityNodeInfo info) {\r\n    super.onInitializeAccessibilityNodeInfo(info);\r\n    info.setClassName(com.fsck.k9.ui.ContactBadge.class.getName());\r\n}', visibility='public'),
#   Node('Operation', kind='method', metaSrc='source code', name='assignContactFromEmail(java.lang.String,boolean)', qualifiedName='com.fsck.k9.ui.ContactBadge.assignContactFromEmail(java.lang.String,boolean)', simpleName='assignContactFromEmail(java.lang.String,boolean)', sourceText="/**\r\n * Assign a contact based on an email address. This should only be used when\r\n * the contact's URI is not available, as an extra query will have to be\r\n * performed to lookup the URI based on the email.\r\n *\r\n * @param emailAddress\r\n * \t\tThe email address of the contact.\r\n * @param lazyLookup\r\n * \t\tIf this is true, the lookup query will not be performed\r\n * \t\tuntil this view is clicked.\r\n */\r\npublic void assignContactFromEmail(java.lang.String emailAddress, boolean lazyLookup) {\r\n    assignContactFromEmail(emailAddress, lazyLookup, null);\r\n}", visibility='public'),
#   Node('Operation', kind='method', metaSrc='source code', name='onInitializeAccessibilityEvent(android.view.accessibility.AccessibilityEvent)', qualifiedName='com.fsck.k9.ui.ContactBadge.onInitializeAccessibilityEvent(android.view.accessibility.AccessibilityEvent)', simpleName='onInitializeAccessibilityEvent(android.view.accessibility.AccessibilityEvent)', sourceText='@java.lang.Override\r\npublic void onInitializeAccessibilityEvent(android.view.accessibility.AccessibilityEvent event) {\r\n    super.onInitializeAccessibilityEvent(event);\r\n    event.setClassName(com.fsck.k9.ui.ContactBadge.class.getName());\r\n}', visibility='public'),
#   Node('Operation', kind='method', metaSrc='source code', name='onClick(android.view.View)', qualifiedName='com.fsck.k9.ui.ContactBadge.onClick(android.view.View)', simpleName='onClick(android.view.View)', sourceText="@java.lang.Override\r\npublic void onClick(android.view.View v) {\r\n    // If contact has been assigned, extras should no longer be null, but do a null check\r\n    // anyway just in case assignContactFromPhone or Email was called with a null bundle or\r\n    // wasn't assigned previously.\r\n    final android.os.Bundle extras = (this.extras == null) ? new android.os.Bundle() : this.extras;\r\n    if (contactUri != null) {\r\n        android.provider.ContactsContract.QuickContact.showQuickContact(getContext(), this, contactUri, QuickContact.MODE_LARGE, null);\r\n    } else if (contactEmail != null) {\r\n        extras.putString(com.fsck.k9.ui.ContactBadge.EXTRA_URI_CONTENT, contactEmail);\r\n        queryHandler.startQuery(com.fsck.k9.ui.ContactBadge.TOKEN_EMAIL_LOOKUP_AND_TRIGGER, extras, android.net.Uri.withAppendedPath(Email.CONTENT_LOOKUP_URI, android.net.Uri.encode(contactEmail)), com.fsck.k9.ui.ContactBadge.EMAIL_LOOKUP_PROJECTION, null, null, null);\r\n    }\r\n}", visibility='public')]}

# %%
only_print_prompt = False

# %%
import time

timestr = time.strftime("%Y%m%d-%H%M%S")
timestr
# Out:
# '20240411-161946'

# %%
with open(f'layerinator-{timestr}.log', 'a') as file:

  results = dict()
  kind = 'class'
  for pkg_name in samples.keys():
    results[pkg_name] = dict()
    for class_name in samples[pkg_name].keys():
      results[pkg_name][class_name] = dict()
      for method in samples[pkg_name][class_name]:
        method_name = method['simpleName']
        results[pkg_name][class_name][method_name] = dict()
        file.write(f"# {pkg_name}, {class_name}, {method_name}")
        file.write("\n\n")
        # file.write(method['sourceText'])
        # file.write("\n")
        # for layer in layers:
        #   print(f'## {layer["name"]}')
        #   print()
        #   prompt = prompt_template.format(
        #       # layer_name=layer["name"],
        #       # layer_responsibility=layer["responsibility"],
        #       method_characteristics="\n".join(
        #           [f"  {i+1}. {layer['method_characteristics'][i]}" for i in range(len(layer["method_characteristics"]))]),
        #       project_name=project_name,
        #       project_desc=project_desc,
        #       class_type=kind,
        #       class_name=class_name,
        #       method_name=method_name,
        #       # method_desc = goals[pkg_name]['classes'][row["c.qualifiedName"]]['methods'][method_name]['description'],
        #       method_src=remove_java_comments(method["sourceText"]))
        prompt1 = prompt1_template.format(
          project_desc=project_desc,
          method_src=method["sourceText"]
        )
        if only_print_prompt:
          file.write(prompt1)
          file.write("\n\n")
        else:
          response = None
          try:
            response = client.chat.completions.create(
                model=model,
                messages=[{
                  "role": "user",
                  "content": prompt1
                }],
                temperature=0)
            ast_message = response.choices[0].message
            
            file.write("[USER]\n\n")
            file.write(prompt1)
            file.write("\n\n")
            file.write("[LLM]\n\n")
            file.write(ast_message.content)
            file.write("\n\n")

            response = client.chat.completions.create(
                model=model,
                messages=[{
                  "role": "user",
                  "content": prompt1
                }, 
                ast_message,
                {
                  "role": "user",
                  "content": prompt2
                }],
                temperature=0)
            answer = response.choices[0].message.content
            
            file.write("[USER]\n\n")
            file.write(prompt2)
            file.write("\n\n")
            file.write("[LLM]\n\n")
            file.write(answer)
            file.write("\n\n")

            # print(answer)
            # results[pkg_name][class_name][method_name][layer['name']] = parse_json(answer.split('\n')[-1])
            results[pkg_name][class_name][method_name]['layer'] = answer
          except:
            answer = None
            file.write(str(response) if response else "no response")
            file.write("\n\n")
            # results[pkg_name][class_name][method_name][layer['name']] = []
            results[pkg_name][class_name][method_name]['layer'] = "undefined"
          # print(answer)
          # print()
        file.write("===============================================\n\n")
        # print(dict_to_pretty_json(results[pkg_name][class_name][method_name]))
        # print()
        # break
      file.write("CLASS RESULT:\n\n")
      file.write(dict_to_pretty_json(results[pkg_name][class_name]))
      file.write("\n\n")
      file.flush()
      # break
    file.write("PACKAGE RESULT:\n\n")
    file.write(dict_to_pretty_json(results[pkg_name]))
    file.write("\n\n")
    # break
  file.write("ALL RESULTS:\n\n")
  file.write(dict_to_pretty_json(results))

# %%
if not only_print_prompt:
  write_dict_to_json(results, f"layerinator-v2/{project_name}-layers-{timestr}.json")

# %%
def count_layer_occurrences(input_dict):
    layer_count = {}

    for method, details in input_dict.items():
        layer = details.get("layer")
        if layer:
            if layer in layer_count:
                layer_count[layer] += 1
            else:
                layer_count[layer] = 1

    return layer_count

# %%
results
# Out:
# {'com.fsck.k9': {'com.fsck.k9.Throttle$MyTimerTask': {'run()': {'layer': 'Service Layer'},
#    'cancel()': {'layer': 'Presentation Layer'}},
#   'com.fsck.k9.PRNGFixes$LinuxPRNGSecureRandomProvider': {},
#   'com.fsck.k9.Throttle': {'cancelScheduledCallback()': {'layer': 'Execution Layer'},
#    'onEvent()': {'layer': 'Service Layer'}},
#   'com.fsck.k9.K9$SplitViewMode': {},
#   'com.fsck.k9.PRNGFixes': {'apply()': {'layer': 'Utility Layer'}},
#   'com.fsck.k9.K9$Intents$EmailReceived': {},
#   'com.fsck.k9.BaseAccount': {'setEmail(java.lang.String)': {'layer': 'Domain Layer'},
#    'getEmail()': {'layer': 'Domain Layer'},
#    'getUuid()': {'layer': 'Domain Layer'},
#    'getDescription()': {'layer': 'Domain Layer'},
#    'setDescription(java.lang.String)': {'layer': 'Domain Layer'}},
#   'com.fsck.k9.AccountStats': {},
#   'com.fsck.k9.K9$Intents$Share': {},
#   'com.fsck.k9.Account$ShowPictures': {},
#   'com.fsck.k9.Throttle$MyTimerTask$HandlerRunnable': {'run()': {'layer': 'Service Layer'}},
#   'com.fsck.k9.K9$NotificationQuickDelete': {},
#   'com.fsck.k9.Account$QuoteStyle': {},
#   'com.fsck.k9.Account$Expunge': {},
#   'com.fsck.k9.K9': {'messageListSenderAboveSubject()': {'layer': 'Presentation Layer'},
#    'setDebug(boolean)': {'layer': 'Service Layer'},
#    'setContactNameColor(int)': {'layer': 'Domain Layer'},
#    'setConfirmDeleteStarred(boolean)': {'layer': 'Service Layer'},
#    'setBackgroundOps(com.fsck.k9.K9$BACKGROUND_OPS)': {'layer': 'Service Layer'},
#    'setNotificationDuringQuietTimeEnabled(boolean)': {'layer': 'Service Layer'},
#    'getSplitViewMode()': {'layer': 'Data Source Layer'},
#    'setAnimations(boolean)': {'layer': 'Presentation Layer'},
#    'setDatabasesUpToDate(boolean)': {'layer': 'Data Source Layer'},
#    'setGesturesEnabled(boolean)': {'layer': 'Service Layer'},
#    'useBackgroundAsUnreadIndicator()': {'layer': 'Service Layer'},
#    'isColorizeMissingContactPictures()': {'layer': 'Domain Layer'},
#    'setMessageViewReturnToList(boolean)': {'layer': 'Domain Layer'},
#    'getOpenPgpSupportSignOnly()': {'layer': 'Domain Layer'},
#    'setPgpInlineDialogCounter(int)': {'layer': 'Domain Layer'},
#    'registerApplicationAware(com.fsck.k9.K9$ApplicationAware)': {'layer': 'Service Layer'},
#    'setNotificationQuickDeleteBehaviour(com.fsck.k9.K9$NotificationQuickDelete)': {'layer': 'Domain Layer'},
#    'setHideUserAgent(boolean)': {'layer': 'Domain Layer'},
#    'setMessageViewArchiveActionVisible(boolean)': {'layer': 'Presentation Layer'},
#    'setLockScreenNotificationVisibility(com.fsck.k9.K9$LockScreenNotificationVisibility)': {'layer': 'Service Layer'},
#    'setMessageListPreviewLines(int)': {'layer': 'Presentation Layer'},
#    'setQuietTimeStarts(java.lang.String)': {'layer': 'Service Layer'},
#    'messageViewShowNext()': {'layer': 'Service Layer'},
#    'setHideTimeZone(boolean)': {'layer': 'Domain Layer'},
#    'isMessageViewCopyActionVisible()': {'layer': 'Service Layer'},
#    'showCorrespondentNames()': {'layer': 'Presentation Layer'},
#    'getPgpSignOnlyDialogCounter()': {'layer': 'Utility Layer'},
#    'save(com.fsck.k9.preferences.StorageEditor)': {'layer': 'Data Source Layer'},
#    'getQuietTimeEnabled()': {'layer': 'Service Layer'},
#    'setSplitViewMode(com.fsck.k9.K9$SplitViewMode)': {'layer': 'Presentation Layer'},
#    'getSortType()': {'layer': 'Domain Layer'},
#    'setMessageViewFixedWidthFont(boolean)': {'layer': 'Presentation Layer'},
#    'setQuietTimeEnabled(boolean)': {'layer': 'Domain Layer'},
#    'getK9ThemeResourceId(com.fsck.k9.K9$Theme)': {'layer': 'Utility Layer'},
#    'getK9ThemeResourceId()': {'layer': 'Utility Layer'},
#    'setMessageViewCopyActionVisible(boolean)': {'layer': 'Presentation Layer'},
#    'getK9Language()': {'layer': 'Data Source Layer'},
#    'getK9MessageViewTheme()': {'layer': 'Domain Layer'},
#    'showContactName()': {'layer': 'Presentation Layer'},
#    'gesturesEnabled()': {'layer': 'Service Layer'},
#    'setShowContactName(boolean)': {'layer': 'Presentation Layer'},
#    'wrapFolderNames()': {'layer': 'Presentation Layer'},
#    'setMessageListSenderAboveSubject(boolean)': {'layer': 'Presentation Layer'},
#    'getLockScreenNotificationVisibility()': {'layer': 'Domain Layer'},
#    'getFontSizes()': {'layer': 'Domain Layer'},
#    'isNotificationDuringQuietTimeEnabled()': {'layer': 'Domain Layer'},
#    'measureAccounts()': {'layer': 'Service Layer'},
#    'useFixedMessageViewTheme()': {'layer': 'Presentation Layer'},
#    'setSortAscending(com.fsck.k9.Account$SortType,boolean)': {'layer': 'Service Layer'},
#    'getBackgroundOps()': {'layer': 'Service Layer'},
#    'setColorizeMissingContactPictures(boolean)': {'layer': 'Service Layer'},
#    'confirmSpam()': {'layer': 'Service Layer'},
#    'areDatabasesUpToDate()': {'layer': 'Data Source Layer'},
#    'isThreadedViewEnabled()': {'layer': 'Domain Layer'},
#    'setWrapFolderNames(boolean)': {'layer': 'Presentation Layer'},
#    'getK9ComposerTheme()': {'layer': 'Service Layer'},
#    'setMessageListCheckboxes(boolean)': {'layer': 'Presentation Layer'},
#    'onCreate()': {'layer': 'Service Layer'},
#    'getQuietTimeStarts()': {'layer': 'Data Source Layer'},
#    'showContactPicture()': {'layer': 'Presentation Layer'},
#    'messageListCheckboxes()': {'layer': 'Presentation Layer'},
#    'setAutofitWidth(boolean)': {'layer': 'Presentation Layer'},
#    'getQuietTimeEnds()': {'layer': 'Domain Layer'},
#    'setMessageViewShowNext(boolean)': {'layer': 'Domain Layer'},
#    'setChangeContactNameColor(boolean)': {'layer': 'Presentation Layer'},
#    'setConfirmDeleteFromNotification(boolean)': {'layer': 'Presentation Layer'},
#    'confirmDeleteStarred()': {'layer': 'Domain Layer'},
#    'setNotificationHideSubject(com.fsck.k9.K9$NotificationHideSubject)': {'layer': 'Service Layer'},
#    'setUseFixedMessageViewTheme(boolean)': {'layer': 'Presentation Layer'},
#    'autofitWidth()': {'layer': 'Presentation Layer'},
#    'hideUserAgent()': {'layer': 'None'},
#    'setMessageViewDeleteActionVisible(boolean)': {'layer': 'Presentation Layer'},
#    'checkCachedDatabaseVersion()': {'layer': 'Data Source Layer'},
#    'isHideSpecialAccounts()': {'layer': 'Service Layer'},
#    'setConfirmMarkAllRead(boolean)': {'layer': 'Service Layer'},
#    'confirmDelete()': {'layer': 'Presentation Layer'},
#    'isMessageViewArchiveActionVisible()': {'layer': 'Domain Layer'},
#    'getContactNameColor()': {'layer': 'Presentation Layer'},
#    'getK9Theme()': {'layer': 'Domain Layer'},
#    'setStartIntegratedInbox(boolean)': {'layer': 'Presentation Layer'},
#    'countSearchMessages()': {'layer': 'Domain Layer'},
#    'setMessageViewMoveActionVisible(boolean)': {'layer': 'Presentation Layer'},
#    'isDebug()': {'layer': 'Utility Layer'},
#    'getNotificationHideSubject()': {'layer': 'Domain Layer'},
#    'setQuietTimeEnds(java.lang.String)': {'layer': 'Domain Layer'},
#    'getPgpInlineDialogCounter()': {'layer': 'Domain Layer'},
#    'setBackgroundOps(java.lang.String)': {'layer': 'Service Layer'},
#    'setConfirmSpam(boolean)': {'layer': 'Service Layer'},
#    'setServicesEnabled(android.content.Context)': {'layer': 'Service Layer'},
#    'setHideSpecialAccounts(boolean)': {'layer': 'Domain Layer'},
#    'isSortAscending(com.fsck.k9.Account$SortType)': {'layer': 'Domain Layer'},
#    'loadPrefs(com.fsck.k9.Preferences)': {'layer': 'Data Source Layer'},
#    'setMessageListStars(boolean)': {'layer': 'Presentation Layer'},
#    'setOpenPgpSupportSignOnly(boolean)': {'layer': 'Service Layer'},
#    'getNotificationQuickDeleteBehaviour()': {'layer': 'Domain Layer'},
#    'showAnimations()': {'layer': 'Service Layer'},
#    'setUseVolumeKeysForListNavigation(boolean)': {'layer': 'Presentation Layer'},
#    'getK9MessageViewThemeSetting()': {'layer': 'Presentation Layer'},
#    'setAttachmentDefaultPath(java.lang.String)': {'layer': 'Domain Layer'},
#    'setPgpSignOnlyDialogCounter(int)': {'layer': 'Domain Layer'},
#    'setThreadedViewEnabled(boolean)': {'layer': 'Domain Layer'},
#    'isMessageViewMoveActionVisible()': {'layer': 'Service Layer'},
#    'confirmDiscardMessage()': {'layer': 'Service Layer'},
#    'setOpenPgpProvider(java.lang.String)': {'layer': 'Domain Layer'},
#    'isMessageViewSpamActionVisible()': {'layer': 'Presentation Layer'},
#    'useVolumeKeysForNavigationEnabled()': {'layer': 'Service Layer'},
#    'isOpenPgpProviderConfigured()': {'layer': 'Service Layer'},
#    'useVolumeKeysForListNavigationEnabled()': {'layer': 'Presentation Layer'},
#    'setK9MessageViewThemeSetting(com.fsck.k9.K9$Theme)': {'layer': 'Presentation Layer'},
#    'messageListPreviewLines()': {'layer': 'Presentation Layer'},
#    'setShowContactPicture(boolean)': {'layer': 'Service Layer'},
#    'setMessageViewSpamActionVisible(boolean)': {'layer': 'Presentation Layer'},
#    'getOpenPgpProvider()': {'layer': 'Service Layer'},
#    'setMeasureAccounts(boolean)': {'layer': 'Service Layer'},
#    'confirmDeleteFromNotification()': {'layer': 'Service Layer'},
#    'setConfirmDelete(boolean)': {'layer': 'Service Layer'},
#    'messageViewFixedWidthFont()': {'layer': 'Presentation Layer'},
#    'isMessageViewDeleteActionVisible()': {'layer': 'Domain Layer'},
#    'messageListStars()': {'layer': 'Service Layer'},
#    'changeContactNameColor()': {'layer': 'None'},
#    'startIntegratedInbox()': {'layer': 'Service Layer'},
#    'setSortType(com.fsck.k9.Account$SortType)': {'layer': 'Domain Layer'},
#    'setK9ComposerThemeSetting(com.fsck.k9.K9$Theme)': {'layer': 'Presentation Layer'},
#    'hideTimeZone()': {'layer': 'Utility Layer'},
#    'getK9ComposerThemeSetting()': {'layer': 'Data Source Layer'},
#    'setConfirmDiscardMessage(boolean)': {'layer': 'Presentation Layer'},
#    'getAttachmentDefaultPath()': {'layer': 'Data Source Layer'},
#    'saveSettingsAsync()': {'layer': 'Service Layer'},
#    'setCountSearchMessages(boolean)': {'layer': 'Service Layer'},
#    'isQuietTime()': {'layer': 'Domain Layer'},
#    'setK9Language(java.lang.String)': {'layer': 'Domain Layer'},
#    'setUseBackgroundAsUnreadIndicator(boolean)': {'layer': 'Service Layer'},
#    'setUseVolumeKeysForNavigation(boolean)': {'layer': 'Service Layer'},
#    'setShowCorrespondentNames(boolean)': {'layer': 'Presentation Layer'},
#    'setK9Theme(com.fsck.k9.K9$Theme)': {'layer': 'Presentation Layer'},
#    'messageViewReturnToList()': {'layer': 'Service Layer'},
#    'confirmMarkAllRead()': {'layer': 'Service Layer'}},
#   'com.fsck.k9.EmailAddressValidator': {'fixText(java.lang.CharSequence)': {'layer': 'Domain Layer'},
#    'isValid(java.lang.CharSequence)': {'layer': 'Domain Layer'},
#    'isValidAddressOnly(java.lang.CharSequence)': {'layer': 'Domain Layer'}},
#   'com.fsck.k9.Account$SortType': {'isDefaultAscending()': {'layer': 'Domain Layer'},
#    'getToast(boolean)': {'layer': 'Presentation Layer'}},
#   'com.fsck.k9.Globals': {'getContext()': {'layer': 'Utility Layer'}},
#   'com.fsck.k9.FontSizes': {'getMessageViewContentAsPercent()': {'layer': 'Presentation Layer'},
#    'getMessageViewDate()': {'layer': 'Domain Layer'},
#    'getFolderStatus()': {'layer': 'Domain Layer'},
#    'setMessageViewContentAsPercent(int)': {'layer': 'Presentation Layer'},
#    'getMessageViewBCC()': {'layer': 'Domain Layer'},
#    'setMessageViewSubject(int)': {'layer': 'Domain Layer'},
#    'setMessageListPreview(int)': {'layer': 'Domain Layer'},
#    'getMessageViewAdditionalHeaders()': {'layer': 'Domain Layer'},
#    'getMessageListDate()': {'layer': 'Domain Layer'},
#    'getMessageViewCC()': {'layer': 'Domain Layer'},
#    'setMessageListDate(int)': {'layer': 'Domain Layer'},
#    'setMessageViewTo(int)': {'layer': 'Domain Layer'},
#    'getMessageComposeInput()': {'layer': 'Domain Layer'},
#    'getMessageViewSubject()': {'layer': 'Domain Layer'},
#    'setMessageListSender(int)': {'layer': 'Domain Layer'},
#    'getMessageViewSender()': {'layer': 'Domain Layer'},
#    'load(com.fsck.k9.preferences.Storage)': {'layer': 'Data Source Layer'},
#    'setAccountDescription(int)': {'layer': 'Domain Layer'},
#    'setAccountName(int)': {'layer': 'Domain Layer'},
#    'setMessageViewSender(int)': {'layer': 'Domain Layer'},
#    'setMessageListSubject(int)': {'layer': 'Domain Layer'},
#    'getMessageListPreview()': {'layer': 'Presentation Layer'},
#    'getMessageListSender()': {'layer': 'Domain Layer'},
#    'setMessageViewBCC(int)': {'layer': 'Domain Layer'},
#    'setViewTextSize(android.widget.TextView,int)': {'layer': 'Presentation Layer'},
#    'setMessageViewAdditionalHeaders(int)': {'layer': 'Domain Layer'},
#    'setFolderName(int)': {'layer': 'Domain Layer'},
#    'getMessageViewTo()': {'layer': 'Domain Layer'},
#    'getAccountDescription()': {'layer': 'Domain Layer'},
#    'getMessageListSubject()': {'layer': 'Domain Layer'},
#    'setMessageComposeInput(int)': {'layer': 'Presentation Layer'},
#    'setMessageViewDate(int)': {'layer': 'Domain Layer'},
#    'save(com.fsck.k9.preferences.StorageEditor)': {'layer': 'Data Source Layer'},
#    'getAccountName()': {'layer': 'Domain Layer'},
#    'getFolderName()': {'layer': 'Domain Layer'},
#    'setMessageViewCC(int)': {'layer': 'Domain Layer'},
#    'setFolderStatus(int)': {'layer': 'Domain Layer'}},
#   'com.fsck.k9.NotificationSetting': {'isRingEnabled()': {'layer': 'Domain Layer'},
#    'isVibrateEnabled()': {'layer': 'Domain Layer'},
#    'isLedEnabled()': {'layer': 'Domain Layer'},
#    'setLed(boolean)': {'layer': 'Domain Layer'},
#    'setVibratePattern(int)': {'layer': 'Domain Layer'},
#    'getVibrateTimes()': {'layer': 'Domain Layer'},
#    'setRingEnabled(boolean)': {'layer': 'Domain Layer'},
#    'getLedColor()': {'layer': 'Domain Layer'},
#    'getRingtone()': {'layer': 'Domain Layer'},
#    'setVibrate(boolean)': {'layer': 'Domain Layer'},
#    'getVibration(int,int)': {'layer': 'Utility Layer'},
#    'getVibration()': {'layer': 'Data Source Layer'},
#    'setVibrateTimes(int)': {'layer': 'Domain Layer'},
#    'getVibratePattern()': {'layer': 'Domain Layer'},
#    'setLedColor(int)': {'layer': 'Presentation Layer'},
#    'setRingtone(java.lang.String)': {'layer': 'Domain Layer'}},
#   'com.fsck.k9.K9$NotificationHideSubject': {},
#   'com.fsck.k9.K9$BACKGROUND_OPS': {},
#   'com.fsck.k9.Preferences': {'setDefaultAccount(com.fsck.k9.Account)': {'layer': 'Data Source Layer'},
#    'getAvailableAccounts()': {'layer': 'Service Layer'},
#    'loadAccounts()': {'layer': 'Domain Layer'},
#    'getAccounts()': {'layer': 'Data Source Layer'},
#    'newAccount()': {'layer': 'Domain Layer'},
#    'getAccount(java.lang.String)': {'layer': 'Domain Layer'},
#    'getPreferences(android.content.Context)': {'layer': 'Data Source Layer'},
#    'deleteAccount(com.fsck.k9.Account)': {'layer': 'Service Layer'},
#    'getStorage()': {'layer': 'Data Source Layer'},
#    'getDefaultAccount()': {'layer': 'Domain Layer'}},
#   'com.fsck.k9.Account$FolderMode': {},
#   'com.fsck.k9.Clock': {'getTime()': {'layer': 'Utility Layer'}},
#   'com.fsck.k9.Account': {'getLocalStore()': {'layer': 'Data Source Layer'},
#    'addCertificate(com.fsck.k9.activity.setup.AccountSetupCheckSettings$CheckDirection,java.security.cert.X509Certificate)': {'layer': 'Data Source Layer'},
#    'setDisplayCount(int)': {'layer': 'Domain Layer'},
#    'isReplyAfterQuote()': {'layer': 'Domain Layer'},
#    'getIdentities()': {'layer': 'Domain Layer'},
#    'setSignatureBeforeQuotedText(boolean)': {'layer': 'Domain Layer'},
#    'setIdleRefreshMinutes(int)': {'layer': 'Domain Layer'},
#    'goToUnreadMessageSearch()': {'layer': 'Service Layer'},
#    'setSortType(com.fsck.k9.Account$SortType)': {'layer': 'Domain Layer'},
#    'setFolderTargetMode(com.fsck.k9.Account$FolderMode)': {'layer': 'Domain Layer'},
#    'getStoreUri()': {'layer': 'Domain Layer'},
#    'getMaxPushFolders()': {'layer': 'Domain Layer'},
#    'setEnabled(boolean)': {'layer': 'Domain Layer'},
#    'setExpungePolicy(com.fsck.k9.Account$Expunge)': {'layer': 'Domain Layer'},
#    'limitToDisplayableFolders(com.fsck.k9.search.LocalSearch)': {'layer': 'Service Layer'},
#    'hasDraftsFolder()': {'layer': 'Domain Layer'},
#    'setArchiveFolderName(java.lang.String)': {'layer': 'Domain Layer'},
#    'getSearchableFolders()': {'layer': 'Domain Layer'},
#    'isSortAscending(com.fsck.k9.Account$SortType)': {'layer': 'Domain Layer'},
#    'setInboxFolderName(java.lang.String)': {'layer': 'Domain Layer'},
#    'setTransportUri(java.lang.String)': {'layer': 'Domain Layer'},
#    'getFolderSyncMode()': {'layer': 'Domain Layer'},
#    'setNotifyContactsMailOnly(boolean)': {'layer': 'Domain Layer'},
#    'setSyncRemoteDeletions(boolean)': {'layer': 'Domain Layer'},
#    'setFolderPushMode(com.fsck.k9.Account$FolderMode)': {'layer': 'Service Layer'},
#    'getAlwaysBcc()': {'layer': 'Domain Layer'},
#    'setDraftsFolderName(java.lang.String)': {'layer': 'Domain Layer'},
#    'setSubscribedFoldersOnly(boolean)': {'layer': 'Domain Layer'},
#    'setMessageFormat(com.fsck.k9.Account$MessageFormat)': {'layer': 'Domain Layer'},
#    'getLastSelectedFolderName()': {'layer': 'Domain Layer'},
#    'getQuotePrefix()': {'layer': 'Domain Layer'},
#    'getStats(android.content.Context)': {'layer': 'Service Layer'},
#    'getSpamFolderName()': {'layer': 'Domain Layer'},
#    'syncRemoteDeletions()': {'layer': 'Service Layer'},
#    'save(com.fsck.k9.Preferences)': {'layer': 'Data Source Layer'},
#    'useCompression(com.fsck.k9.mail.NetworkType)': {'layer': 'Data Source Layer'},
#    'setSpamFolderName(java.lang.String)': {'layer': 'Domain Layer'},
#    'setAutomaticCheckIntervalMinutes(int)': {'layer': 'Domain Layer'},
#    'setGoToUnreadMessageSearch(boolean)': {'layer': 'Domain Layer'},
#    'setShowPictures(com.fsck.k9.Account$ShowPictures)': {'layer': 'Domain Layer'},
#    'setQuotePrefix(java.lang.String)': {'layer': 'Domain Layer'},
#    'hashCode()': {'layer': 'Domain Layer'},
#    'getRemoteSearchNumResults()': {'layer': 'Domain Layer'},
#    'setFolderDisplayMode(com.fsck.k9.Account$FolderMode)': {'layer': 'Domain Layer'},
#    'isRemoteSearchFullText()': {'layer': 'Domain Layer'},
#    'isSearchByDateCapable()': {'layer': 'Domain Layer'},
#    'getAccountNumber()': {'layer': 'Domain Layer'},
#    'isPushPollOnConnect()': {'layer': 'Domain Layer'},
#    'getOutboxFolderName()': {'layer': 'Data Source Layer'},
#    'getFolderPushMode()': {'layer': 'Domain Layer'},
#    'setSentFolderName(java.lang.String)': {'layer': 'Domain Layer'},
#    'setChipColor(int)': {'layer': 'Domain Layer'},
#    'getLatestOldMessageSeenTime()': {'layer': 'Domain Layer'},
#    'findIdentity(com.fsck.k9.mail.Address)': {'layer': 'Domain Layer'},
#    'setEmail(java.lang.String)': {'layer': 'Domain Layer'},
#    'setSortAscending(com.fsck.k9.Account$SortType,boolean)': {'layer': 'Domain Layer'},
#    'getName()': {'layer': 'Domain Layer'},
#    'generateColorChip(boolean,boolean)': {'layer': 'Domain Layer'},
#    'isAnIdentity(com.fsck.k9.mail.Address)': {'layer': 'Domain Layer'},
#    'getFolderUnreadCount(android.content.Context,java.lang.String)': {'layer': 'Data Source Layer'},
#    'getEmail()': {'layer': 'Domain Layer'},
#    'subscribedFoldersOnly()': {'layer': 'Domain Layer'},
#    'hasArchiveFolder()': {'layer': 'Domain Layer'},
#    'setFolderNotifyNewMailMode(com.fsck.k9.Account$FolderMode)': {'layer': 'Domain Layer'},
#    'setReplyAfterQuote(boolean)': {'layer': 'Domain Layer'},
#    'setLastSelectedFolderName(java.lang.String)': {'layer': 'Domain Layer'},
#    'getAutomaticCheckIntervalMinutes()': {'layer': 'Domain Layer'},
#    'getSignatureUse()': {'layer': 'Domain Layer'},
#    'setRingNotified(boolean)': {'layer': 'Domain Layer'},
#    'getMessageFormat()': {'layer': 'Domain Layer'},
#    'isNotifyNewMail()': {'layer': 'Domain Layer'},
#    'setStripSignature(boolean)': {'layer': 'Domain Layer'},
#    'setMarkMessageAsReadOnView(boolean)': {'layer': 'Domain Layer'},
#    'isDefaultQuotedTextShown()': {'layer': 'Domain Layer'},
#    'getEarliestPollDate()': {'layer': 'Service Layer'},
#    'setRemoteSearchFullText(boolean)': {'layer': 'Domain Layer'},
#    'generateAccountNumber(com.fsck.k9.Preferences)': {'layer': 'Service Layer'},
#    'setMessageReadReceipt(boolean)': {'layer': 'Domain Layer'},
#    'setCompression(com.fsck.k9.mail.NetworkType,boolean)': {'layer': 'Data Source Layer'},
#    'setDefaultQuotedTextShown(boolean)': {'layer': 'Domain Layer'},
#    'isStripSignature()': {'layer': 'Domain Layer'},
#    'setQuoteStyle(com.fsck.k9.Account$QuoteStyle)': {'layer': 'Domain Layer'},
#    'isAnIdentity(com.fsck.k9.mail.Address[])': {'layer': 'Domain Layer'},
#    'isEnabled()': {'layer': 'Domain Layer'},
#    'setSearchableFolders(com.fsck.k9.Account$Searchable)': {'layer': 'Domain Layer'},
#    'isSignatureBeforeQuotedText()': {'layer': 'Domain Layer'},
#    'isNotifyContactsMailOnly()': {'layer': 'Domain Layer'},
#    'getFolderNotifyNewMailMode()': {'layer': 'Domain Layer'},
#    'setName(java.lang.String)': {'layer': 'Domain Layer'},
#    'setIdentities(java.util.List)': {'layer': 'Domain Layer'},
#    'allowRemoteSearch()': {'layer': 'Domain Layer'},
#    'setSignatureUse(boolean)': {'layer': 'Domain Layer'},
#    'getRemoteStore()': {'layer': 'Service Layer'},
#    'hasTrashFolder()': {'layer': 'Domain Layer'},
#    'deleteCertificate(java.lang.String,int,com.fsck.k9.activity.setup.AccountSetupCheckSettings$CheckDirection)': {'layer': 'Data Source Layer'},
#    'getLocalStorageProviderId()': {'layer': 'Domain Layer'},
#    'setAutoExpandFolderName(java.lang.String)': {'layer': 'Domain Layer'},
#    'hasSpamFolder()': {'layer': 'Domain Layer'},
#    'setMaximumAutoDownloadMessageSize(int)': {'layer': 'Service Layer'},
#    'getQuoteStyle()': {'layer': 'Domain Layer'},
#    'getSignature()': {'layer': 'Domain Layer'},
#    'getInboxFolderName()': {'layer': 'Domain Layer'},
#    'setRemoteSearchNumResults(int)': {'layer': 'Domain Layer'},
#    'excludeSpecialFolders(com.fsck.k9.search.LocalSearch)': {'layer': 'Service Layer'},
#    'setPushPollOnConnect(boolean)': {'layer': 'Domain Layer'},
#    'getTrashFolderName()': {'layer': 'Domain Layer'},
#    'toString()': {'layer': 'Domain Layer'},
#    'getArchiveFolderName()': {'layer': 'Domain Layer'},
#    'getDescription()': {'layer': 'Domain Layer'},
#    'getAutoExpandFolderName()': {'layer': 'Domain Layer'},
#    'setMaximumPolledMessageAge(int)': {'layer': 'Domain Layer'},
#    'setLocalStorageProviderId(java.lang.String)': {'layer': 'Data Source Layer'},
#    'hasSentFolder()': {'layer': 'Domain Layer'},
#    'getMaximumAutoDownloadMessageSize()': {'layer': 'Domain Layer'},
#    'getSortType()': {'layer': 'Domain Layer'},
#    'setDescription(java.lang.String)': {'layer': 'Domain Layer'},
#    'getChipColor()': {'layer': 'Domain Layer'},
#    'getDeletePolicy()': {'layer': 'Domain Layer'},
#    'isMarkMessageAsReadOnView()': {'layer': 'Domain Layer'},
#    'setDeletePolicy(com.fsck.k9.Account$DeletePolicy)': {'layer': 'Domain Layer'},
#    'isRingNotified()': {'layer': 'Domain Layer'},
#    'getDisplayCount()': {'layer': 'Presentation Layer'},
#    'isAlwaysShowCcBcc()': {'layer': 'Domain Layer'},
#    'getDraftsFolderName()': {'layer': 'Domain Layer'},
#    'getExpungePolicy()': {'layer': 'Domain Layer'},
#    'getShowPictures()': {'layer': 'Domain Layer'},
#    'setCryptoKey(long)': {'layer': 'Domain Layer'},
#    'isSpecialFolder(java.lang.String)': {'layer': 'Domain Layer'},
#    'setNotifySelfNewMail(boolean)': {'layer': 'Domain Layer'},
#    'move(com.fsck.k9.Preferences,boolean)': {'layer': 'Data Source Layer'},
#    'getNotificationSetting()': {'layer': 'Domain Layer'},
#    'getSentFolderName()': {'layer': 'Domain Layer'},
#    'setNotifyNewMail(boolean)': {'layer': 'Domain Layer'},
#    'setFolderSyncMode(com.fsck.k9.Account$FolderMode)': {'layer': 'Domain Layer'},
#    'setAlwaysBcc(java.lang.String)': {'layer': 'Domain Layer'},
#    'setShowOngoing(boolean)': {'layer': 'Domain Layer'},
#    'setAlwaysShowCcBcc(boolean)': {'layer': 'Domain Layer'},
#    'getIdleRefreshMinutes()': {'layer': 'Domain Layer'},
#    'isNotifySelfNewMail()': {'layer': 'Domain Layer'},
#    'setAllowRemoteSearch(boolean)': {'layer': 'Domain Layer'},
#    'isShowOngoing()': {'layer': 'Domain Layer'},
#    'getCryptoKey()': {'layer': 'Domain Layer'},
#    'setStoreUri(java.lang.String)': {'layer': 'Domain Layer'},
#    'getFolderTargetMode()': {'layer': 'Domain Layer'},
#    'getTransportUri()': {'layer': 'Domain Layer'},
#    'setSignature(java.lang.String)': {'layer': 'Domain Layer'},
#    'getFolderDisplayMode()': {'layer': 'Domain Layer'},
#    'equals(java.lang.Object)': {'layer': 'Domain Layer'},
#    'setLatestOldMessageSeenTime(long)': {'layer': 'Domain Layer'},
#    'excludeUnwantedFolders(com.fsck.k9.search.LocalSearch)': {'layer': 'Service Layer'},
#    'getIdentity(int)': {'layer': 'Domain Layer'},
#    'getMaximumPolledMessageAge()': {'layer': 'Domain Layer'},
#    'isAvailable(android.content.Context)': {'layer': 'Service Layer'},
#    'getUuid()': {'layer': 'Domain Layer'},
#    'setTrashFolderName(java.lang.String)': {'layer': 'Domain Layer'},
#    'setMaxPushFolders(int)': {'layer': 'Domain Layer'},
#    'isMessageReadReceiptAlways()': {'layer': 'Domain Layer'}},
#   'com.fsck.k9.K9$Intents': {},
#   'com.fsck.k9.Account$MessageFormat': {},
#   'com.fsck.k9.K9$ApplicationAware': {'initializeComponent(android.app.Application)': {'layer': 'Service Layer'}},
#   'com.fsck.k9.Identity': {'getDescription()': {'layer': 'Domain Layer'},
#    'setSignature(java.lang.String)': {'layer': 'Domain Layer'},
#    'setEmail(java.lang.String)': {'layer': 'Domain Layer'},
#    'getSignatureUse()': {'layer': 'Domain Layer'},
#    'getSignature()': {'layer': 'Domain Layer'},
#    'getName()': {'layer': 'Domain Layer'},
#    'setDescription(java.lang.String)': {'layer': 'Domain Layer'},
#    'setReplyTo(java.lang.String)': {'layer': 'Domain Layer'},
#    'getReplyTo()': {'layer': 'Domain Layer'},
#    'setName(java.lang.String)': {'layer': 'Domain Layer'},
#    'toString()': {'layer': 'Domain Layer'},
#    'getEmail()': {'layer': 'Domain Layer'},
#    'setSignatureUse(boolean)': {'layer': 'Domain Layer'}},
#   'com.fsck.k9.Account$Searchable': {},
#   'com.fsck.k9.K9$LockScreenNotificationVisibility': {},
#   'com.fsck.k9.PRNGFixes$LinuxPRNGSecureRandom': {},
#   'com.fsck.k9.K9$Theme': {},
#   'com.fsck.k9.Account$DeletePolicy': {'preferenceString()': {'layer': 'Domain Layer'},
#    'fromInt(int)': {'layer': 'Domain Layer'}}},
#  'com.fsck.k9.account': {'com.fsck.k9.account.AccountCreator': {'getDefaultDeletePolicy(com.fsck.k9.mail.ServerSettings.Type)': {'layer': 'Service Layer'},
#    'getDefaultPort(com.fsck.k9.mail.ConnectionSecurity,com.fsck.k9.mail.ServerSettings.Type)': {'layer': 'Service Layer'}}},
#  'com.fsck.k9.activity': {'com.fsck.k9.activity.FolderList$FolderListAdapter': {'getFilter()': {'layer': 'Presentation Layer'},
#    'getCount()': {'layer': 'Domain Layer'},
#    'getFolder(java.lang.String)': {'layer': 'Service Layer'},
#    'isEnabled(int)': {'layer': 'Presentation Layer'},
#    'getItemView(int,android.view.View,android.view.ViewGroup)': {'layer': 'Presentation Layer'},
#    'getView(int,android.view.View,android.view.ViewGroup)': {'layer': 'Presentation Layer'},
#    'areAllItemsEnabled()': {'layer': 'Presentation Layer'},
#    'isItemSelectable(int)': {'layer': 'Domain Layer'},
#    'getFolderIndex(java.lang.String)': {'layer': 'Data Source Layer'},
#    'setFilter(android.widget.Filter)': {'layer': 'Domain Layer'},
#    'getItem(int)': {'layer': 'Data Source Layer'},
#    'getItemId(int)': {'layer': 'Data Source Layer'},
#    'getItem(long)': {'layer': 'Data Source Layer'},
#    'hasStableIds()': {'layer': 'Presentation Layer'}},
#   'com.fsck.k9.activity.Accounts$AccountsHandler': {'progress(boolean)': {'layer': 'Presentation Layer'},
#    'dataChanged()': {'layer': 'Presentation Layer'},
#    'accountSizeChanged(com.fsck.k9.Account,long,long)': {'layer': 'Presentation Layer'},
#    'refreshTitle()': {'layer': 'Presentation Layer'},
#    'progress(int)': {'layer': 'Presentation Layer'},
#    'workingAccount(com.fsck.k9.Account,int)': {'layer': 'Presentation Layer'}},
#   'com.fsck.k9.activity.MessageCompose': {'showContactPicker(int)': {'layer': 'Presentation Layer'},
#    'onOptionsItemSelected(android.view.MenuItem)': {'layer': 'Presentation Layer'},
#    'onRecipientsChanged()': {'layer': 'Domain Layer'},
#    'onMessageBuildCancel()': {'layer': 'Presentation Layer'},
#    'saveDraftEventually()': {'layer': 'Domain Layer'},
#    'onClick(android.view.View)': {'layer': 'Presentation Layer'},
#    'onPrepareOptionsMenu(android.view.Menu)': {'layer': 'Presentation Layer'},
#    'onAttachmentRemoved()': {'layer': 'Domain Layer'},
#    'onCreate(android.os.Bundle)': {'layer': 'Presentation Layer'},
#    'onProgressCancel(com.fsck.k9.fragment.ProgressDialogFragment)': {'layer': 'Presentation Layer'},
#    'onOpenPgpClickDisable()': {'layer': 'Service Layer'},
#    'performSendAfterChecks()': {'layer': 'Service Layer'},
#    'onAttachmentAdded()': {'layer': 'Domain Layer'},
#    'onRetainNonConfigurationInstance()': {'layer': 'Presentation Layer'},
#    'loadLocalMessageForDisplay(com.fsck.k9.mailstore.MessageViewInfo,com.fsck.k9.activity.MessageCompose$Action)': {'layer': 'Service Layer'},
#    'onFocusChange(android.view.View,boolean)': {'layer': 'Presentation Layer'},
#    'updateMessageFormat()': {'layer': 'Domain Layer'},
#    'onCreateOptionsMenu(android.view.Menu)': {'layer': 'Presentation Layer'},
#    'onOpenPgpSignOnlyChange(boolean)': {'layer': 'Presentation Layer'},
#    'onMessageBuildSuccess(com.fsck.k9.mail.internet.MimeMessage,boolean)': {'layer': 'Service Layer'},
#    'onDestroy()': {'layer': 'Presentation Layer'},
#    'launchUserInteractionPendingIntent(android.app.PendingIntent,int)': {'layer': 'Presentation Layer'},
#    'onCreateDialog(int)': {'layer': 'Presentation Layer'},
#    'onPause()': {'layer': 'Presentation Layer'},
#    'onMessageBuildException(com.fsck.k9.mail.MessagingException)': {'layer': 'Presentation Layer'},
#    'onBackPressed()': {'layer': 'Presentation Layer'},
#    'loadQuotedTextForEdit()': {'layer': 'Domain Layer'},
#    'onProgressCancel(com.fsck.k9.fragment.AttachmentDownloadDialogFragment)': {'layer': 'Presentation Layer'},
#    'onMessageBuildReturnPendingIntent(android.app.PendingIntent,int)': {'layer': 'Presentation Layer'},
#    'onOpenPgpInlineChange(boolean)': {'layer': 'Presentation Layer'}},
#   'com.fsck.k9.activity.Accounts$ExportAsyncTask': {},
#   'com.fsck.k9.activity.MessageInfoHolder': {'equals(java.lang.Object)': {'layer': 'Domain Layer'},
#    'hashCode()': {'layer': 'Domain Layer'}},
#   'com.fsck.k9.activity.Search': {'onStop()': {'layer': 'Presentation Layer'},
#    'onStart()': {'layer': 'Presentation Layer'},
#    'isActive()': {'layer': 'Presentation Layer'},
#    'setActive(boolean)': {'layer': 'Service Layer'}},
#   'com.fsck.k9.activity.Accounts$ImportAsyncTask': {},
#   'com.fsck.k9.activity.ColorPickerDialog$OnColorChangedListener': {'colorChanged(int)': {'layer': 'Presentation Layer'}},
#   'com.fsck.k9.activity.K9PreferenceActivity': {'onCreate(android.os.Bundle)': {'layer': 'Presentation Layer'}},
#   'com.fsck.k9.activity.MessageList$StorageListenerImplementation': {'onUnmount(java.lang.String)': {'layer': 'Presentation Layer'},
#    'onMount(java.lang.String)': {'layer': 'Domain Layer'}},
#   'com.fsck.k9.activity.K9Activity': {'dispatchTouchEvent(android.view.MotionEvent)': {'layer': 'Presentation Layer'},
#    'setupGestureDetector(com.fsck.k9.activity.misc.SwipeGestureDetector$OnSwipeGestureListener)': {'layer': 'Presentation Layer'},
#    'onCreate(android.os.Bundle)': {'layer': 'Presentation Layer'}},
#   'com.fsck.k9.activity.K9ActivityCommon': {'getThemeBackgroundColor()': {'layer': 'Data Source Layer'},
#    'newInstance(android.app.Activity)': {'layer': 'Presentation Layer'},
#    'setupGestureDetector(com.fsck.k9.activity.misc.SwipeGestureDetector$OnSwipeGestureListener)': {'layer': 'Presentation Layer'},
#    'preDispatchTouchEvent(android.view.MotionEvent)': {'layer': 'Presentation Layer'},
#    'setLanguage(android.content.Context,java.lang.String)': {'layer': 'Presentation Layer'}},
#   'com.fsck.k9.activity.AccountList': {'onResume()': {'layer': 'Presentation Layer'},
#    'onItemClick(android.widget.AdapterView,android.view.View,int,long)': {'layer': 'Presentation Layer'},
#    'populateListView(java.util.List)': {'layer': 'Presentation Layer'},
#    'onCreate(android.os.Bundle)': {'layer': 'Presentation Layer'}},
#   'com.fsck.k9.activity.LauncherShortcuts': {'onCreate(android.os.Bundle)': {'layer': 'Presentation Layer'}},
#   'com.fsck.k9.activity.Accounts$PasswordPromptDialog': {'onTextChanged(java.lang.CharSequence,int,int,int)': {'layer': 'Presentation Layer'},
#    'afterTextChanged(android.text.Editable)': {'layer': 'Presentation Layer'},
#    'restore(android.app.Activity)': {'layer': 'Service Layer'},
#    'show(com.fsck.k9.activity.Accounts)': {'layer': 'Presentation Layer'},
#    'retain()': {'layer': 'Presentation Layer'},
#    'beforeTextChanged(java.lang.CharSequence,int,int,int)': {'layer': 'Presentation Layer'}},
#   'com.fsck.k9.activity.Accounts$AccountClickListener': {'onClick(android.view.View)': {'layer': 'Presentation Layer'}},
#   'com.fsck.k9.activity.AccountList$LoadAccounts': {},
#   'com.fsck.k9.activity.ColorPickerDialog': {'setColor(int)': {'layer': 'Presentation Layer'}},
#   'com.fsck.k9.activity.ChooseFolder': {'onOptionsItemSelected(android.view.MenuItem)': {'layer': 'Presentation Layer'},
#    'onCreateOptionsMenu(android.view.Menu)': {'layer': 'Presentation Layer'},
#    'onCreate(android.os.Bundle)': {'layer': 'Presentation Layer'}},
#   'com.fsck.k9.activity.EditIdentity': {'onCreate(android.os.Bundle)': {'layer': 'Presentation Layer'},
#    'onSaveInstanceState(android.os.Bundle)': {'layer': 'Presentation Layer'},
#    'onBackPressed()': {'layer': 'Presentation Layer'}},
#   'com.fsck.k9.activity.Accounts$ListImportContentsAsyncTask': {},
#   'com.fsck.k9.activity.MessageCompose$Action': {'getTitleResource()': {'layer': 'Presentation Layer'}},
#   'com.fsck.k9.activity.UnreadWidgetConfiguration': {'onActivityResult(int,int,android.content.Intent)': {'layer': 'Presentation Layer'},
#    'getWidgetProperties(android.content.Context,int)': {'layer': 'Data Source Layer'},
#    'deleteWidgetConfiguration(android.content.Context,int)': {'layer': 'Data Source Layer'},
#    'onOptionsItemSelected(android.view.MenuItem)': {'layer': 'Presentation Layer'},
#    'onCreate(android.os.Bundle)': {'layer': 'Presentation Layer'},
#    'onCreateOptionsMenu(android.view.Menu)': {'layer': 'Presentation Layer'}},
#   'com.fsck.k9.activity.EmailAddressList': {'onItemClick(android.widget.AdapterView,android.view.View,int,long)': {'layer': 'Presentation Layer'},
#    'onCreate(android.os.Bundle)': {'layer': 'Presentation Layer'}},
#   'com.fsck.k9.activity.K9PreferenceActivity$PreferenceChangeListener': {'onPreferenceChange(android.preference.Preference,java.lang.Object)': {'layer': 'Presentation Layer'}},
#   'com.fsck.k9.activity.MessageCompose$SendMessageTask': {},
#   'com.fsck.k9.activity.AccountList$AccountsAdapter$AccountViewHolder': {},
#   'com.fsck.k9.activity.Accounts$AccountsAdapter': {'getView(int,android.view.View,android.view.ViewGroup)': {'layer': 'Presentation Layer'}},
#   'com.fsck.k9.activity.AccountList$AccountsAdapter': {'getView(int,android.view.View,android.view.ViewGroup)': {'layer': 'Presentation Layer'}},
#   'com.fsck.k9.activity.FolderList$FolderClickListener': {'onClick(android.view.View)': {'layer': 'Presentation Layer'}},
#   'com.fsck.k9.activity.Accounts': {'onItemLongClick(android.widget.AdapterView,android.view.View,int,long)': {'layer': 'Presentation Layer'},
#    'onPrepareDialog(int,android.app.Dialog)': {'layer': 'Presentation Layer'},
#    'onExport(boolean,com.fsck.k9.Account)': {'layer': 'Presentation Layer'},
#    'onCreateDialog(int)': {'layer': 'Presentation Layer'},
#    'onCreate(android.os.Bundle)': {'layer': 'Presentation Layer'},
#    'listAccounts(android.content.Context)': {'layer': 'Presentation Layer'},
#    'onResume()': {'layer': 'Presentation Layer'},
#    'onCreateContextMenu(android.view.ContextMenu,android.view.View,android.view.ContextMenu.ContextMenuInfo)': {'layer': 'Presentation Layer'},
#    'onItemClick(android.widget.AdapterView,android.view.View,int,long)': {'layer': 'Presentation Layer'},
#    'onCreateOptionsMenu(android.view.Menu)': {'layer': 'Presentation Layer'},
#    'onPause()': {'layer': 'Service Layer'},
#    'importSettings(android.content.Context)': {'layer': 'Presentation Layer'},
#    'setProgress(boolean)': {'layer': 'Presentation Layer'},
#    'onContextItemSelected(android.view.MenuItem)': {'layer': 'Presentation Layer'},
#    'onExport(android.content.Intent)': {'layer': 'Service Layer'},
#    'onRetainNonConfigurationInstance()': {'layer': 'Presentation Layer'},
#    'createUnreadSearch(android.content.Context,com.fsck.k9.BaseAccount)': {'layer': 'Service Layer'},
#    'onSaveInstanceState(android.os.Bundle)': {'layer': 'Presentation Layer'},
#    'onOptionsItemSelected(android.view.MenuItem)': {'layer': 'Presentation Layer'}},
#   'com.fsck.k9.activity.MessageLoaderHelper': {'asyncRestartMessageCryptoProcessing()': {'layer': 'Service Layer'},
#    'onDestroyChangingConfigurations()': {'layer': 'Presentation Layer'},
#    'onDestroy()': {'layer': 'Presentation Layer'},
#    'asyncStartOrResumeLoadingMessage(com.fsck.k9.activity.MessageReference,android.os.Parcelable)': {'layer': 'Service Layer'},
#    'asyncReloadMessage()': {'layer': 'Presentation Layer'},
#    'downloadCompleteMessage()': {'layer': 'Presentation Layer'},
#    'onActivityResult(int,int,android.content.Intent)': {'layer': 'Service Layer'}},
#   'com.fsck.k9.activity.Accounts$SetPasswordsAsyncTask': {},
#   'com.fsck.k9.activity.ConfirmationDialog': {'create(android.app.Activity,int,int,java.lang.String,int,int,java.lang.Runnable)': {'layer': 'Presentation Layer'},
#    'create(android.app.Activity,int,int,java.lang.String,int,int,java.lang.Runnable,java.lang.Runnable)': {'layer': 'Presentation Layer'},
#    'create(android.app.Activity,int,int,int,int,int,java.lang.Runnable)': {'layer': 'Presentation Layer'}},
#   'com.fsck.k9.activity.AlternateRecipientAdapter$AlternateRecipientListener': {'onRecipientChange(com.fsck.k9.view.RecipientSelectView$Recipient,com.fsck.k9.view.RecipientSelectView$Recipient)': {'layer': 'Domain Layer'},
#    'onRecipientRemove(com.fsck.k9.view.RecipientSelectView$Recipient)': {'layer': 'Presentation Layer'}},
#   'com.fsck.k9.activity.FolderList$FolderListHandler': {'accountSizeChanged(long,long)': {'layer': 'Presentation Layer'},
#    'workingAccount(int)': {'layer': 'Presentation Layer'},
#    'progress(boolean)': {'layer': 'Presentation Layer'},
#    'dataChanged()': {'layer': 'Presentation Layer'},
#    'newFolders(java.util.List)': {'layer': 'Presentation Layer'},
#    'folderLoading(java.lang.String,boolean)': {'layer': 'Presentation Layer'},
#    'refreshTitle()': {'layer': 'Presentation Layer'}},
#   'com.fsck.k9.activity.K9ListActivity': {'setupGestureDetector(com.fsck.k9.activity.misc.SwipeGestureDetector$OnSwipeGestureListener)': {'layer': 'Presentation Layer'},
#    'onCreate(android.os.Bundle)': {'layer': 'Presentation Layer'},
#    'onResume()': {'layer': 'Presentation Layer'},
#    'onKeyUp(int,android.view.KeyEvent)': {'layer': 'Presentation Layer'},
#    'onKeyDown(int,android.view.KeyEvent)': {'layer': 'Presentation Layer'},
#    'dispatchTouchEvent(android.view.MotionEvent)': {'layer': 'Presentation Layer'}},
#   'com.fsck.k9.activity.ChooseFolder$ChooseFolderHandler': {'handleMessage(android.os.Message)': {'layer': 'Presentation Layer'},
#    'progress(boolean)': {'layer': 'Presentation Layer'},
#    'setSelectedFolder(int)': {'layer': 'Service Layer'}},
#   'com.fsck.k9.activity.ActivityListener': {'searchStats(com.fsck.k9.AccountStats)': {'layer': 'Presentation Layer'},
#    'synchronizeMailboxFailed(com.fsck.k9.Account,java.lang.String,java.lang.String)': {'layer': 'Service Layer'},
#    'synchronizeMailboxStarted(com.fsck.k9.Account,java.lang.String)': {'layer': 'Service Layer'},
#    'sendPendingMessagesCompleted(com.fsck.k9.Account)': {'layer': 'Service Layer'},
#    'pendingCommandStarted(com.fsck.k9.Account,java.lang.String)': {'layer': 'Service Layer'},
#    'sendPendingMessagesFailed(com.fsck.k9.Account)': {'layer': 'Service Layer'},
#    'getFolderTotal()': {'layer': 'Domain Layer'},
#    'pendingCommandCompleted(com.fsck.k9.Account,java.lang.String)': {'layer': 'Service Layer'},
#    'pendingCommandsProcessing(com.fsck.k9.Account)': {'layer': 'Service Layer'},
#    'getFolderCompleted()': {'layer': 'Domain Layer'},
#    'synchronizeMailboxHeadersProgress(com.fsck.k9.Account,java.lang.String,int,int)': {'layer': 'Domain Layer'},
#    'synchronizeMailboxHeadersFinished(com.fsck.k9.Account,java.lang.String,int,int)': {'layer': 'Service Layer'},
#    'folderStatusChanged(com.fsck.k9.Account,java.lang.String,int)': {'layer': 'Service Layer'},
#    'synchronizeMailboxFinished(com.fsck.k9.Account,java.lang.String,int,int)': {'layer': 'Domain Layer'},
#    'synchronizeMailboxHeadersStarted(com.fsck.k9.Account,java.lang.String)': {'layer': 'Service Layer'},
#    'systemStatusChanged()': {'layer': 'Presentation Layer'},
#    'onPause(android.content.Context)': {'layer': 'Data Source Layer'},
#    'sendPendingMessagesStarted(com.fsck.k9.Account)': {'layer': 'Domain Layer'},
#    'informUserOfStatus()': {'layer': 'Presentation Layer'},
#    'synchronizeMailboxProgress(com.fsck.k9.Account,java.lang.String,int,int)': {'layer': 'Service Layer'},
#    'getOperation(android.content.Context)': {'layer': 'Presentation Layer'},
#    'onResume(android.content.Context)': {'layer': 'Presentation Layer'},
#    'pendingCommandsFinished(com.fsck.k9.Account)': {'layer': 'Service Layer'}},
#   'com.fsck.k9.activity.NotificationDeleteConfirmation': {'onPrepareDialog(int,android.app.Dialog)': {'layer': 'Presentation Layer'},
#    'onCreateDialog(int)': {'layer': 'Presentation Layer'},
#    'getIntent(android.content.Context,java.util.List)': {'layer': 'Service Layer'},
#    'getIntent(android.content.Context,com.fsck.k9.activity.MessageReference)': {'layer': 'Service Layer'},
#    'onCreate(android.os.Bundle)': {'layer': 'Presentation Layer'}},
#   'com.fsck.k9.activity.ChooseIdentity': {'onCreate(android.os.Bundle)': {'layer': 'Presentation Layer'},
#    'onResume()': {'layer': 'Presentation Layer'}},
#   'com.fsck.k9.activity.UpgradeDatabases': {'onCreate(android.os.Bundle)': {'layer': 'Presentation Layer'},
#    'actionUpgradeDatabases(android.content.Context,android.content.Intent)': {'layer': 'Service Layer'},
#    'onResume()': {'layer': 'Service Layer'},
#    'onPause()': {'layer': 'Presentation Layer'}},
#   'com.fsck.k9.activity.Accounts$AccountsImportedDialog': {},
#   'com.fsck.k9.activity.Accounts$ImportSelectionDialog': {'restore(android.app.Activity)': {'layer': 'Presentation Layer'},
#    'show(com.fsck.k9.activity.Accounts)': {'layer': 'Presentation Layer'},
#    'show(com.fsck.k9.activity.Accounts,android.util.SparseBooleanArray)': {'layer': 'Presentation Layer'},
#    'retain()': {'layer': 'Presentation Layer'}},
#   'com.fsck.k9.activity.AlternateRecipientAdapter': {'getItemId(int)': {'layer': 'Presentation Layer'},
#    'getCount()': {'layer': 'Domain Layer'},
#    'bindItemView(android.view.View,com.fsck.k9.view.RecipientSelectView$Recipient)': {'layer': 'Presentation Layer'},
#    'setCurrentRecipient(com.fsck.k9.view.RecipientSelectView$Recipient)': {'layer': 'Domain Layer'},
#    'getItem(int)': {'layer': 'Domain Layer'},
#    'bindHeaderView(android.view.View,com.fsck.k9.view.RecipientSelectView$Recipient)': {'layer': 'Presentation Layer'},
#    'isEnabled(int)': {'layer': 'Presentation Layer'},
#    'setShowAdvancedInfo(boolean)': {'layer': 'Domain Layer'},
#    'getView(int,android.view.View,android.view.ViewGroup)': {'layer': 'Presentation Layer'},
#    'setAlternateRecipientInfo(java.util.List)': {'layer': 'Domain Layer'},
#    'newView(android.view.ViewGroup)': {'layer': 'Presentation Layer'}},
#   'com.fsck.k9.activity.MessageLoaderHelper$MessageLoaderCallbacks': {'onDownloadErrorNetworkError()': {'layer': 'Service Layer'},
#    'onMessageDataLoadFinished(com.fsck.k9.mailstore.LocalMessage)': {'layer': 'Service Layer'},
#    'onMessageDataLoadFailed()': {'layer': 'Service Layer'},
#    'onMessageViewInfoLoadFailed(com.fsck.k9.mailstore.MessageViewInfo)': {'layer': 'Presentation Layer'},
#    'startIntentSenderForMessageLoaderHelper(android.content.IntentSender,int,android.content.Intent,int,int,int)': {'layer': 'Service Layer'},
#    'onDownloadErrorMessageNotFound()': {'layer': 'Service Layer'},
#    'onMessageViewInfoLoadFinished(com.fsck.k9.mailstore.MessageViewInfo)': {'layer': 'Domain Layer'},
#    'setLoadingProgress(int,int)': {'layer': 'Presentation Layer'}},
#   'com.fsck.k9.activity.K9ActivityCommon$K9ActivityMagic': {'setupGestureDetector(com.fsck.k9.activity.misc.SwipeGestureDetector$OnSwipeGestureListener)': {'layer': 'Presentation Layer'}},
#   'com.fsck.k9.activity.MessageList$DisplayMode': {},
#   'com.fsck.k9.activity.UpgradeDatabases$UpgradeDatabaseBroadcastReceiver': {'onReceive(android.content.Context,android.content.Intent)': {'layer': 'Presentation Layer'}},
#   'com.fsck.k9.activity.AlternateRecipientAdapter$RecipientTokenHolder': {'setShowAsHeader(boolean)': {'layer': 'Presentation Layer'}},
#   'com.fsck.k9.activity.FolderList': {'onOptionsItemSelected(android.view.MenuItem)': {'layer': 'Presentation Layer'},
#    'onCreateOptionsMenu(android.view.Menu)': {'layer': 'Presentation Layer'},
#    'onKeyDown(int,android.view.KeyEvent)': {'layer': 'Presentation Layer'},
#    'onNewIntent(android.content.Intent)': {'layer': 'Data Source Layer'},
#    'onResume()': {'layer': 'Service Layer'},
#    'onCreateContextMenu(android.view.ContextMenu,android.view.View,android.view.ContextMenu.ContextMenuInfo)': {'layer': 'Presentation Layer'},
#    'onCreate(android.os.Bundle)': {'layer': 'Presentation Layer'},
#    'onSearchRequested()': {'layer': 'Presentation Layer'},
#    'actionHandleAccountIntent(android.content.Context,com.fsck.k9.Account,boolean)': {'layer': 'Service Layer'},
#    'onContextItemSelected(android.view.MenuItem)': {'layer': 'Presentation Layer'},
#    'onRetainNonConfigurationInstance()': {'layer': 'Data Source Layer'},
#    'actionHandleAccount(android.content.Context,com.fsck.k9.Account)': {'layer': 'Service Layer'},
#    'onPause()': {'layer': 'Presentation Layer'}},
#   'com.fsck.k9.activity.Accounts$SimpleDialog': {'restore(android.app.Activity)': {'layer': 'Presentation Layer'},
#    'retain()': {'layer': 'Presentation Layer'},
#    'show(com.fsck.k9.activity.Accounts)': {'layer': 'Presentation Layer'}},
#   'com.fsck.k9.activity.FolderList$FolderViewHolder': {},
#   'com.fsck.k9.activity.MessageReferenceHelper': {'toMessageReferenceList(java.util.List)': {'layer': 'Domain Layer'},
#    'toMessageReferenceStringList(java.util.List)': {'layer': 'Domain Layer'}},
#   'com.fsck.k9.activity.MessageReference': {'toIdentityString()': {'layer': 'Domain Layer'},
#    'withModifiedUid(java.lang.String)': {'layer': 'Domain Layer'},
#    'equals(java.lang.String,java.lang.String,java.lang.String)': {'layer': 'Domain Layer'},
#    'equals(java.lang.Object)': {'layer': 'Domain Layer'},
#    'hashCode()': {'layer': 'Domain Layer'},
#    'withModifiedFlag(com.fsck.k9.mail.Flag)': {'layer': 'Domain Layer'},
#    'getAccountUuid()': {'layer': 'Domain Layer'},
#    'getUid()': {'layer': 'Domain Layer'},
#    'parse(java.lang.String)': {'layer': 'Domain Layer'},
#    'getFlag()': {'layer': 'Domain Layer'},
#    'toString()': {'layer': 'Domain Layer'},
#    'getFolderName()': {'layer': 'Domain Layer'}},
#   'com.fsck.k9.activity.ManageIdentities': {'onContextItemSelected(android.view.MenuItem)': {'layer': 'Presentation Layer'},
#    'onResume()': {'layer': 'Presentation Layer'},
#    'onCreateOptionsMenu(android.view.Menu)': {'layer': 'Presentation Layer'},
#    'onCreateContextMenu(android.view.ContextMenu,android.view.View,android.view.ContextMenu.ContextMenuInfo)': {'layer': 'Presentation Layer'},
#    'onOptionsItemSelected(android.view.MenuItem)': {'layer': 'Presentation Layer'},
#    'onBackPressed()': {'layer': 'Presentation Layer'}},
#   'com.fsck.k9.activity.ChooseAccount': {},
#   'com.fsck.k9.activity.FolderList$FolderListAdapter$FolderListFilter': {'getSearchTerm()': {'layer': 'Domain Layer'}},
#   'com.fsck.k9.activity.FolderListFilter': {'invalidate()': {'layer': 'Domain Layer'}},
#   'com.fsck.k9.activity.Accounts$ACCOUNT_LOCATION': {},
#   'com.fsck.k9.activity.MessageList': {'shortcutIntent(android.content.Context,java.lang.String)': {'layer': 'Presentation Layer'},
# ...
#    'getMimeType()': {'layer': 'Data Source Layer'},
#    'hasResolvedActivities()': {'layer': 'Domain Layer'},
#    'containsFileUri()': {'layer': 'Data Source Layer'}},
#   'com.fsck.k9.ui.messageview.MessageContainerView$OnRenderingFinishedListener': {'onLoadFinished()': {'layer': 'Data Source Layer'}},
#   'com.fsck.k9.ui.messageview.DownloadImageTask': {},
#   'com.fsck.k9.ui.messageview.MessageContainerView': {'hasHiddenExternalImages()': {'layer': 'Domain Layer'},
#    'onCreateContextMenu(android.view.ContextMenu,android.view.View,android.view.ContextMenu.ContextMenuInfo)': {'layer': 'Presentation Layer'},
#    'refreshAttachmentThumbnail(com.fsck.k9.mailstore.AttachmentViewInfo)': {'layer': 'Domain Layer'},
#    'enableAttachmentButtons()': {'layer': 'Presentation Layer'},
#    'renderAttachments(com.fsck.k9.mailstore.MessageViewInfo)': {'layer': 'Presentation Layer'},
#    'displayMessageViewContainer(com.fsck.k9.mailstore.MessageViewInfo,com.fsck.k9.ui.messageview.MessageContainerView$OnRenderingFinishedListener,boolean,boolean,com.fsck.k9.ui.messageview.AttachmentViewCallback)': {'layer': 'Presentation Layer'},
#    'onFinishInflate()': {'layer': 'Presentation Layer'},
#    'showPictures()': {'layer': 'Presentation Layer'},
#    'enableAttachmentButtons(com.fsck.k9.mailstore.AttachmentViewInfo)': {'layer': 'Presentation Layer'},
#    'disableAttachmentButtons()': {'layer': 'Presentation Layer'},
#    'resetView()': {'layer': 'Presentation Layer'},
#    'onSaveInstanceState()': {'layer': 'Presentation Layer'},
#    'disableAttachmentButtons(com.fsck.k9.mailstore.AttachmentViewInfo)': {'layer': 'Presentation Layer'},
#    'onRestoreInstanceState(android.os.Parcelable)': {'layer': 'Presentation Layer'},
#    'onLayoutChanged()': {'layer': 'Presentation Layer'},
#    'beginSelectingText()': {'layer': 'Presentation Layer'},
#    'zoom(android.view.KeyEvent)': {'layer': 'Presentation Layer'}},
#   'com.fsck.k9.ui.messageview.CryptoInfoDialog': {'onCreateDialog(android.os.Bundle)': {'layer': 'Presentation Layer'},
#    'newInstance(com.fsck.k9.view.MessageCryptoDisplayStatus,boolean)': {'layer': 'Presentation Layer'}},
#   'com.fsck.k9.ui.messageview.AttachmentView': {'enableButtons()': {'layer': 'Presentation Layer'},
#    'setAttachment(com.fsck.k9.mailstore.AttachmentViewInfo)': {'layer': 'Domain Layer'},
#    'disableButtons()': {'layer': 'Presentation Layer'},
#    'setCallback(com.fsck.k9.ui.messageview.AttachmentViewCallback)': {'layer': 'Presentation Layer'},
#    'onLongClick(android.view.View)': {'layer': 'Presentation Layer'},
#    'onClick(android.view.View)': {'layer': 'Presentation Layer'},
#    'refreshThumbnail()': {'layer': 'Presentation Layer'},
#    'getAttachment()': {'layer': 'Domain Layer'}},
#   'com.fsck.k9.ui.messageview.AttachmentController$SaveAttachmentAsyncTask': {},
#   'com.fsck.k9.ui.messageview.MessageCryptoPresenter': {'onActivityResult(int,int,android.content.Intent)': {'layer': 'Presentation Layer'},
#    'onCryptoClick()': {'layer': 'Presentation Layer'},
#    'onSaveInstanceState(android.os.Bundle)': {'layer': 'Presentation Layer'},
#    'maybeHandleShowMessage(com.fsck.k9.ui.messageview.MessageTopView,com.fsck.k9.Account,com.fsck.k9.mailstore.MessageViewInfo)': {'layer': 'Presentation Layer'},
#    'onResume()': {'layer': 'Presentation Layer'},
#    'getDecryptionResultForReply()': {'layer': 'Domain Layer'},
#    'onClickShowMessageOverrideWarning()': {'layer': 'Presentation Layer'},
#    'onClickShowCryptoKey()': {'layer': 'Presentation Layer'},
#    'onClickRetryCryptoOperation()': {'layer': 'Presentation Layer'},
#    'onClickConfigureProvider()': {'layer': 'Presentation Layer'},
#    'onClickShowCryptoWarningDetails()': {'layer': 'Presentation Layer'}}},
#  'com.fsck.k9.view': {'com.fsck.k9.view.MessageHeader$OnLayoutChangedListener': {'onLayoutChanged()': {'layer': 'Presentation Layer'}},
#   'com.fsck.k9.view.RecipientSelectView$RecipientCryptoStatus': {},
#   'com.fsck.k9.view.MessageHeader$HeaderEntry': {},
#   'com.fsck.k9.view.RecipientSelectView$RecipientTokenSpan': {},
#   'com.fsck.k9.view.HighlightDialogFragment': {'onDismiss(android.content.DialogInterface)': {'layer': 'Presentation Layer'},
#    'onStart()': {'layer': 'Presentation Layer'}},
#   'com.fsck.k9.view.RecipientSelectView$RecipientTokenViewHolder': {},
#   'com.fsck.k9.view.CryptoModeSelector$CryptoStatusSelectedListener': {'onCryptoStatusSelected(com.fsck.k9.view.CryptoModeSelector$CryptoModeSelectorState)': {'layer': 'Service Layer'}},
#   'com.fsck.k9.view.ViewSwitcher': {'setFirstInAnimation(android.view.animation.Animation)': {'layer': 'Presentation Layer'},
#    'onAnimationStart(android.view.animation.Animation)': {'layer': 'Presentation Layer'},
#    'setSecondOutAnimation(android.view.animation.Animation)': {'layer': 'Presentation Layer'},
#    'getSecondInAnimation()': {'layer': 'Presentation Layer'},
#    'showSecondView()': {'layer': 'Presentation Layer'},
#    'setOnSwitchCompleteListener(com.fsck.k9.view.ViewSwitcher$OnSwitchCompleteListener)': {'layer': 'Presentation Layer'},
#    'showFirstView()': {'layer': 'Presentation Layer'},
#    'getFirstInAnimation()': {'layer': 'Presentation Layer'},
#    'getmFirstOutAnimation()': {'layer': 'Presentation Layer'},
#    'setFirstOutAnimation(android.view.animation.Animation)': {'layer': 'Presentation Layer'},
#    'getSecondOutAnimation()': {'layer': 'Presentation Layer'},
#    'setSecondInAnimation(android.view.animation.Animation)': {'layer': 'Presentation Layer'},
#    'onAnimationEnd(android.view.animation.Animation)': {'layer': 'Presentation Layer'},
#    'onAnimationRepeat(android.view.animation.Animation)': {'layer': 'Presentation Layer'}},
#   'com.fsck.k9.view.NonLockingScrollView': {'onInterceptTouchEvent(android.view.MotionEvent)': {'layer': 'Presentation Layer'},
#    'requestChildFocus(android.view.View,android.view.View)': {'layer': 'Presentation Layer'}},
#   'com.fsck.k9.view.MessageCryptoDisplayStatus': {'isUnencryptedSigned()': {'layer': 'Domain Layer'},
#    'fromResultAnnotation(com.fsck.k9.mailstore.CryptoResultAnnotation)': {'layer': 'Service Layer'},
#    'hasAssociatedKey()': {'layer': 'Domain Layer'}},
#   'com.fsck.k9.view.MessageWebView': {'emulateShiftHeld()': {'layer': 'Presentation Layer'},
#    'displayHtmlContentWithInlineAttachments(java.lang.String,com.fsck.k9.mailstore.AttachmentResolver,com.fsck.k9.view.MessageWebView$OnPageFinishedListener)': {'layer': 'Service Layer'},
#    'blockNetworkData(boolean)': {'layer': 'Data Source Layer'},
#    'configure()': {'layer': 'Presentation Layer'}},
#   'com.fsck.k9.view.MessageHeader': {'setCryptoStatus(com.fsck.k9.view.MessageCryptoDisplayStatus)': {'layer': 'Presentation Layer'},
#    'onShowAdditionalHeaders()': {'layer': 'Presentation Layer'},
#    'populate(com.fsck.k9.mail.Message,com.fsck.k9.Account)': {'layer': 'Presentation Layer'},
#    'setOnCryptoClickListener(com.fsck.k9.ui.messageview.OnCryptoClickListener)': {'layer': 'Presentation Layer'},
#    'onSaveInstanceState()': {'layer': 'Presentation Layer'},
#    'showSubjectLine()': {'layer': 'Presentation Layer'},
#    'additionalHeadersVisible()': {'layer': 'Presentation Layer'},
#    'onClick(android.view.View)': {'layer': 'Presentation Layer'},
#    'onLongClick(android.view.View)': {'layer': 'Presentation Layer'},
#    'hideCryptoStatus()': {'layer': 'Presentation Layer'},
#    'setOnFlagListener(android.view.View.OnClickListener)': {'layer': 'Presentation Layer'},
#    'createMessage(int)': {'layer': 'Presentation Layer'},
#    'setOnLayoutChangedListener(com.fsck.k9.view.MessageHeader$OnLayoutChangedListener)': {'layer': 'Presentation Layer'},
#    'shouldShowSender(com.fsck.k9.mail.Message)': {'layer': 'Domain Layer'},
#    'onRestoreInstanceState(android.os.Parcelable)': {'layer': 'Presentation Layer'},
#    'setCryptoStatusDisabled()': {'layer': 'Presentation Layer'},
#    'setCryptoStatusLoading()': {'layer': 'Presentation Layer'}},
#   'com.fsck.k9.view.ClientCertificateSpinner': {'setAlias(java.lang.String)': {'layer': 'Domain Layer'},
#    'getAlias()': {'layer': 'Presentation Layer'},
#    'chooseCertificate()': {'layer': 'Service Layer'},
#    'setOnClientCertificateChangedListener(com.fsck.k9.view.ClientCertificateSpinner$OnClientCertificateChangedListener)': {'layer': 'Presentation Layer'}},
#   'com.fsck.k9.view.CryptoModeSelector$CryptoModeSelectorState': {},
#   'com.fsck.k9.view.K9WebViewClient': {'newInstance(com.fsck.k9.mailstore.AttachmentResolver)': {'layer': 'Data Source Layer'},
#    'onPageFinished(android.webkit.WebView,java.lang.String)': {'layer': 'Presentation Layer'},
#    'setOnPageFinishedListener(com.fsck.k9.view.MessageWebView$OnPageFinishedListener)': {'layer': 'Presentation Layer'},
#    'shouldOverrideUrlLoading(android.webkit.WebView,java.lang.String)': {'layer': 'Presentation Layer'}},
#   'com.fsck.k9.view.MessageWebView$OnPageFinishedListener': {'onPageFinished()': {'layer': 'Presentation Layer'}},
#   'com.fsck.k9.view.ClientCertificateSpinner$OnClientCertificateChangedListener': {'onClientCertificateChanged(java.lang.String)': {'layer': 'Domain Layer'}},
#   'com.fsck.k9.view.MessageTitleView': {'showSubjectInMessageHeader()': {'layer': 'Presentation Layer'},
#    'setMessageHeader(com.fsck.k9.view.MessageHeader)': {'layer': 'Domain Layer'},
#    'onDraw(android.graphics.Canvas)': {'layer': 'Presentation Layer'}},
#   'com.fsck.k9.view.K9WebViewClient$LollipopWebViewClient': {'shouldInterceptRequest(android.webkit.WebView,android.webkit.WebResourceRequest)': {'layer': 'Data Source Layer'}},
#   'com.fsck.k9.view.K9WebViewClient$PreLollipopWebViewClient': {'shouldInterceptRequest(android.webkit.WebView,java.lang.String)': {'layer': 'Data Source Layer'}},
#   'com.fsck.k9.view.RecipientSelectView$Recipient': {'equals(java.lang.Object)': {'layer': 'Domain Layer'},
#    'getDisplayNameOrUnknown(android.content.Context)': {'layer': 'Domain Layer'},
#    'setCryptoStatus(com.fsck.k9.view.RecipientSelectView$RecipientCryptoStatus)': {'layer': 'Presentation Layer'},
#    'getContactLookupUri()': {'layer': 'Data Source Layer'},
#    'isValidEmailAddress()': {'layer': 'Domain Layer'},
#    'getDisplayNameOrAddress()': {'layer': 'Domain Layer'},
#    'getCryptoStatus()': {'layer': 'Domain Layer'},
#    'getNameOrUnknown(android.content.Context)': {'layer': 'Domain Layer'}},
#   'com.fsck.k9.view.FoldableLinearLayout': {'addView(android.view.View)': {'layer': 'Presentation Layer'}},
#   'com.fsck.k9.view.RecipientSelectView$TokenListener': {'onTokenChanged(java.lang.Object)': {'layer': 'Domain Layer'}},
#   'com.fsck.k9.view.ToolableViewAnimator': {'setDisplayedChildId(int)': {'layer': 'Presentation Layer'},
#    'setDisplayedChild(int,boolean)': {'layer': 'Presentation Layer'},
#    'setDisplayedChild(int)': {'layer': 'Presentation Layer'},
#    'addView(android.view.View,int,android.view.ViewGroup$LayoutParams)': {'layer': 'Presentation Layer'},
#    'getDisplayedChildId()': {'layer': 'Presentation Layer'}},
#   'com.fsck.k9.view.ViewSwitcher$OnSwitchCompleteListener': {'onSwitchComplete(int)': {'layer': 'Presentation Layer'}},
#   'com.fsck.k9.view.NonLockingScrollView$HierarchyTreeChangeListener': {'onChildViewRemoved(android.view.View,android.view.View)': {'layer': 'Presentation Layer'},
#    'onChildViewAdded(android.view.View,android.view.View)': {'layer': 'Presentation Layer'}},
#   'com.fsck.k9.view.RigidWebView': {},
#   'com.fsck.k9.view.MessageCryptoStatusView': {'setCryptoDisplayStatus(com.fsck.k9.view.MessageCryptoDisplayStatus)': {'layer': 'Presentation Layer'}},
#   'com.fsck.k9.view.FoldableLinearLayout$SavedState': {'writeToParcel(android.os.Parcel,int)': {'layer': 'Domain Layer'}},
#   'com.fsck.k9.view.LinearViewAnimator': {'setUpInAnimation(android.view.animation.Animation)': {'layer': 'Presentation Layer'},
#    'setUpOutAnimation(android.content.Context,int)': {'layer': 'Presentation Layer'},
#    'setDownInAnimation(android.view.animation.Animation)': {'layer': 'Presentation Layer'},
#    'setUpInAnimation(android.content.Context,int)': {'layer': 'Presentation Layer'},
#    'setDownOutAnimation(android.content.Context,int)': {'layer': 'Presentation Layer'},
#    'setUpOutAnimation(android.view.animation.Animation)': {'layer': 'Presentation Layer'},
#    'setDownOutAnimation(android.view.animation.Animation)': {'layer': 'Presentation Layer'},
#    'setDownInAnimation(android.content.Context,int)': {'layer': 'Presentation Layer'},
#    'setDisplayedChild(int)': {'layer': 'Presentation Layer'},
#    'setDisplayedChild(int,boolean)': {'layer': 'Presentation Layer'}},
#   'com.fsck.k9.view.MessageHeader$SavedState': {'writeToParcel(android.os.Parcel,int)': {'layer': 'Data Source Layer'}},
#   'com.fsck.k9.view.ThemeUtils': {'getStyledColor(android.content.res.Resources.Theme,int)': {'layer': 'Presentation Layer'},
#    'getStyledColor(android.content.Context,int)': {'layer': 'Presentation Layer'}},
#   'com.fsck.k9.view.RecipientSelectView': {'onLoaderReset(android.content.Loader)': {'layer': 'Presentation Layer'},
#    'hasUncompletedText()': {'layer': 'Domain Layer'},
#    'onLoadFinished(android.content.Loader,java.util.List)': {'layer': 'Presentation Layer'},
#    'setCryptoProvider(java.lang.String,boolean)': {'layer': 'Domain Layer'},
#    'setLoaderManager(android.app.LoaderManager)': {'layer': 'Service Layer'},
#    'setShowCryptoEnabled(boolean)': {'layer': 'Domain Layer'},
#    'onTouchEvent(android.view.MotionEvent)': {'layer': 'Presentation Layer'},
#    'addRecipients(com.fsck.k9.view.RecipientSelectView$Recipient[])': {'layer': 'Domain Layer'},
#    'showDropDown()': {'layer': 'Presentation Layer'},
#    'onCreateLoader(int,android.os.Bundle)': {'layer': 'Presentation Layer'},
#    'postShowAlternatesPopup(java.util.List)': {'layer': 'Presentation Layer'},
#    'setTokenListener(com.fsck.k9.view.RecipientSelectView$TokenListener)': {'layer': 'Presentation Layer'},
#    'getAddresses()': {'layer': 'Service Layer'},
#    'performCompletion()': {'layer': 'Presentation Layer'},
#    'onKeyDown(int,android.view.KeyEvent)': {'layer': 'Presentation Layer'},
#    'isEmpty()': {'layer': 'Domain Layer'},
#    'onFocusChanged(boolean,int,android.graphics.Rect)': {'layer': 'Presentation Layer'},
#    'onRecipientRemove(com.fsck.k9.view.RecipientSelectView$Recipient)': {'layer': 'Presentation Layer'},
#    'showAlternatesPopup(java.util.List)': {'layer': 'Presentation Layer'},
#    'onRecipientChange(com.fsck.k9.view.RecipientSelectView$Recipient,com.fsck.k9.view.RecipientSelectView$Recipient)': {'layer': 'Presentation Layer'},
#    'tryPerformCompletion()': {'layer': 'Presentation Layer'}},
#   'com.fsck.k9.view.CryptoModeSelector': {'setCryptoStatusListener(com.fsck.k9.view.CryptoModeSelector$CryptoStatusSelectedListener)': {'layer': 'Presentation Layer'},
#    'setCryptoStatus(com.fsck.k9.view.CryptoModeSelector$CryptoModeSelectorState)': {'layer': 'Domain Layer'}},
#   'com.fsck.k9.view.ColorChip': {'drawable()': {'layer': 'Domain Layer'}}},
#  'com.fsck.k9.widget.list': {'com.fsck.k9.widget.list.MessageListWidgetProvider': {'onReceive(android.content.Context,android.content.Intent)': {'layer': 'Service Layer'},
#    'onUpdate(android.content.Context,android.appwidget.AppWidgetManager,int[])': {'layer': 'Presentation Layer'},
#    'triggerMessageListWidgetUpdate(android.content.Context)': {'layer': 'Service Layer'}},
#   'com.fsck.k9.widget.list.MessageListWidgetService': {'onGetViewFactory(android.content.Intent)': {'layer': 'Service Layer'}},
#   'com.fsck.k9.widget.list.MessageListRemoteViewFactory$MailItem': {},
#   'com.fsck.k9.widget.list.MessageListRemoteViewFactory': {'getLoadingView()': {'layer': 'Presentation Layer'},
#    'getItemId(int)': {'layer': 'Data Source Layer'},
#    'getCount()': {'layer': 'Domain Layer'},
#    'onDestroy()': {'layer': 'Presentation Layer'},
#    'hasStableIds()': {'layer': 'Presentation Layer'},
#    'onCreate()': {'layer': 'Presentation Layer'},
#    'getViewTypeCount()': {'layer': 'Presentation Layer'},
#    'onDataSetChanged()': {'layer': 'Presentation Layer'},
#    'getViewAt(int)': {'layer': 'Presentation Layer'}}}}

# %%
for package in results:
	for clss in results[package]:
		results[package][clss]['layers'] = count_layer_occurrences(results[package][clss])

results
# Out:
# {'com.fsck.k9': {'com.fsck.k9.Throttle$MyTimerTask': {'run()': {'layer': 'Service Layer'},
#    'cancel()': {'layer': 'Presentation Layer'},
#    'layers': {'Service Layer': 1, 'Presentation Layer': 1}},
#   'com.fsck.k9.PRNGFixes$LinuxPRNGSecureRandomProvider': {'layers': {}},
#   'com.fsck.k9.Throttle': {'cancelScheduledCallback()': {'layer': 'Execution Layer'},
#    'onEvent()': {'layer': 'Service Layer'},
#    'layers': {'Execution Layer': 1, 'Service Layer': 1}},
#   'com.fsck.k9.K9$SplitViewMode': {'layers': {}},
#   'com.fsck.k9.PRNGFixes': {'apply()': {'layer': 'Utility Layer'},
#    'layers': {'Utility Layer': 1}},
#   'com.fsck.k9.K9$Intents$EmailReceived': {'layers': {}},
#   'com.fsck.k9.BaseAccount': {'setEmail(java.lang.String)': {'layer': 'Domain Layer'},
#    'getEmail()': {'layer': 'Domain Layer'},
#    'getUuid()': {'layer': 'Domain Layer'},
#    'getDescription()': {'layer': 'Domain Layer'},
#    'setDescription(java.lang.String)': {'layer': 'Domain Layer'},
#    'layers': {'Domain Layer': 5}},
#   'com.fsck.k9.AccountStats': {'layers': {}},
#   'com.fsck.k9.K9$Intents$Share': {'layers': {}},
#   'com.fsck.k9.Account$ShowPictures': {'layers': {}},
#   'com.fsck.k9.Throttle$MyTimerTask$HandlerRunnable': {'run()': {'layer': 'Service Layer'},
#    'layers': {'Service Layer': 1}},
#   'com.fsck.k9.K9$NotificationQuickDelete': {'layers': {}},
#   'com.fsck.k9.Account$QuoteStyle': {'layers': {}},
#   'com.fsck.k9.Account$Expunge': {'layers': {}},
#   'com.fsck.k9.K9': {'messageListSenderAboveSubject()': {'layer': 'Presentation Layer'},
#    'setDebug(boolean)': {'layer': 'Service Layer'},
#    'setContactNameColor(int)': {'layer': 'Domain Layer'},
#    'setConfirmDeleteStarred(boolean)': {'layer': 'Service Layer'},
#    'setBackgroundOps(com.fsck.k9.K9$BACKGROUND_OPS)': {'layer': 'Service Layer'},
#    'setNotificationDuringQuietTimeEnabled(boolean)': {'layer': 'Service Layer'},
#    'getSplitViewMode()': {'layer': 'Data Source Layer'},
#    'setAnimations(boolean)': {'layer': 'Presentation Layer'},
#    'setDatabasesUpToDate(boolean)': {'layer': 'Data Source Layer'},
#    'setGesturesEnabled(boolean)': {'layer': 'Service Layer'},
#    'useBackgroundAsUnreadIndicator()': {'layer': 'Service Layer'},
#    'isColorizeMissingContactPictures()': {'layer': 'Domain Layer'},
#    'setMessageViewReturnToList(boolean)': {'layer': 'Domain Layer'},
#    'getOpenPgpSupportSignOnly()': {'layer': 'Domain Layer'},
#    'setPgpInlineDialogCounter(int)': {'layer': 'Domain Layer'},
#    'registerApplicationAware(com.fsck.k9.K9$ApplicationAware)': {'layer': 'Service Layer'},
#    'setNotificationQuickDeleteBehaviour(com.fsck.k9.K9$NotificationQuickDelete)': {'layer': 'Domain Layer'},
#    'setHideUserAgent(boolean)': {'layer': 'Domain Layer'},
#    'setMessageViewArchiveActionVisible(boolean)': {'layer': 'Presentation Layer'},
#    'setLockScreenNotificationVisibility(com.fsck.k9.K9$LockScreenNotificationVisibility)': {'layer': 'Service Layer'},
#    'setMessageListPreviewLines(int)': {'layer': 'Presentation Layer'},
#    'setQuietTimeStarts(java.lang.String)': {'layer': 'Service Layer'},
#    'messageViewShowNext()': {'layer': 'Service Layer'},
#    'setHideTimeZone(boolean)': {'layer': 'Domain Layer'},
#    'isMessageViewCopyActionVisible()': {'layer': 'Service Layer'},
#    'showCorrespondentNames()': {'layer': 'Presentation Layer'},
#    'getPgpSignOnlyDialogCounter()': {'layer': 'Utility Layer'},
#    'save(com.fsck.k9.preferences.StorageEditor)': {'layer': 'Data Source Layer'},
#    'getQuietTimeEnabled()': {'layer': 'Service Layer'},
#    'setSplitViewMode(com.fsck.k9.K9$SplitViewMode)': {'layer': 'Presentation Layer'},
#    'getSortType()': {'layer': 'Domain Layer'},
#    'setMessageViewFixedWidthFont(boolean)': {'layer': 'Presentation Layer'},
#    'setQuietTimeEnabled(boolean)': {'layer': 'Domain Layer'},
#    'getK9ThemeResourceId(com.fsck.k9.K9$Theme)': {'layer': 'Utility Layer'},
#    'getK9ThemeResourceId()': {'layer': 'Utility Layer'},
#    'setMessageViewCopyActionVisible(boolean)': {'layer': 'Presentation Layer'},
#    'getK9Language()': {'layer': 'Data Source Layer'},
#    'getK9MessageViewTheme()': {'layer': 'Domain Layer'},
#    'showContactName()': {'layer': 'Presentation Layer'},
#    'gesturesEnabled()': {'layer': 'Service Layer'},
#    'setShowContactName(boolean)': {'layer': 'Presentation Layer'},
#    'wrapFolderNames()': {'layer': 'Presentation Layer'},
#    'setMessageListSenderAboveSubject(boolean)': {'layer': 'Presentation Layer'},
#    'getLockScreenNotificationVisibility()': {'layer': 'Domain Layer'},
#    'getFontSizes()': {'layer': 'Domain Layer'},
#    'isNotificationDuringQuietTimeEnabled()': {'layer': 'Domain Layer'},
#    'measureAccounts()': {'layer': 'Service Layer'},
#    'useFixedMessageViewTheme()': {'layer': 'Presentation Layer'},
#    'setSortAscending(com.fsck.k9.Account$SortType,boolean)': {'layer': 'Service Layer'},
#    'getBackgroundOps()': {'layer': 'Service Layer'},
#    'setColorizeMissingContactPictures(boolean)': {'layer': 'Service Layer'},
#    'confirmSpam()': {'layer': 'Service Layer'},
#    'areDatabasesUpToDate()': {'layer': 'Data Source Layer'},
#    'isThreadedViewEnabled()': {'layer': 'Domain Layer'},
#    'setWrapFolderNames(boolean)': {'layer': 'Presentation Layer'},
#    'getK9ComposerTheme()': {'layer': 'Service Layer'},
#    'setMessageListCheckboxes(boolean)': {'layer': 'Presentation Layer'},
#    'onCreate()': {'layer': 'Service Layer'},
#    'getQuietTimeStarts()': {'layer': 'Data Source Layer'},
#    'showContactPicture()': {'layer': 'Presentation Layer'},
#    'messageListCheckboxes()': {'layer': 'Presentation Layer'},
#    'setAutofitWidth(boolean)': {'layer': 'Presentation Layer'},
#    'getQuietTimeEnds()': {'layer': 'Domain Layer'},
#    'setMessageViewShowNext(boolean)': {'layer': 'Domain Layer'},
#    'setChangeContactNameColor(boolean)': {'layer': 'Presentation Layer'},
#    'setConfirmDeleteFromNotification(boolean)': {'layer': 'Presentation Layer'},
#    'confirmDeleteStarred()': {'layer': 'Domain Layer'},
#    'setNotificationHideSubject(com.fsck.k9.K9$NotificationHideSubject)': {'layer': 'Service Layer'},
#    'setUseFixedMessageViewTheme(boolean)': {'layer': 'Presentation Layer'},
#    'autofitWidth()': {'layer': 'Presentation Layer'},
#    'hideUserAgent()': {'layer': 'None'},
#    'setMessageViewDeleteActionVisible(boolean)': {'layer': 'Presentation Layer'},
#    'checkCachedDatabaseVersion()': {'layer': 'Data Source Layer'},
#    'isHideSpecialAccounts()': {'layer': 'Service Layer'},
#    'setConfirmMarkAllRead(boolean)': {'layer': 'Service Layer'},
#    'confirmDelete()': {'layer': 'Presentation Layer'},
#    'isMessageViewArchiveActionVisible()': {'layer': 'Domain Layer'},
#    'getContactNameColor()': {'layer': 'Presentation Layer'},
#    'getK9Theme()': {'layer': 'Domain Layer'},
#    'setStartIntegratedInbox(boolean)': {'layer': 'Presentation Layer'},
#    'countSearchMessages()': {'layer': 'Domain Layer'},
#    'setMessageViewMoveActionVisible(boolean)': {'layer': 'Presentation Layer'},
#    'isDebug()': {'layer': 'Utility Layer'},
#    'getNotificationHideSubject()': {'layer': 'Domain Layer'},
#    'setQuietTimeEnds(java.lang.String)': {'layer': 'Domain Layer'},
#    'getPgpInlineDialogCounter()': {'layer': 'Domain Layer'},
#    'setBackgroundOps(java.lang.String)': {'layer': 'Service Layer'},
#    'setConfirmSpam(boolean)': {'layer': 'Service Layer'},
#    'setServicesEnabled(android.content.Context)': {'layer': 'Service Layer'},
#    'setHideSpecialAccounts(boolean)': {'layer': 'Domain Layer'},
#    'isSortAscending(com.fsck.k9.Account$SortType)': {'layer': 'Domain Layer'},
#    'loadPrefs(com.fsck.k9.Preferences)': {'layer': 'Data Source Layer'},
#    'setMessageListStars(boolean)': {'layer': 'Presentation Layer'},
#    'setOpenPgpSupportSignOnly(boolean)': {'layer': 'Service Layer'},
#    'getNotificationQuickDeleteBehaviour()': {'layer': 'Domain Layer'},
#    'showAnimations()': {'layer': 'Service Layer'},
#    'setUseVolumeKeysForListNavigation(boolean)': {'layer': 'Presentation Layer'},
#    'getK9MessageViewThemeSetting()': {'layer': 'Presentation Layer'},
#    'setAttachmentDefaultPath(java.lang.String)': {'layer': 'Domain Layer'},
#    'setPgpSignOnlyDialogCounter(int)': {'layer': 'Domain Layer'},
#    'setThreadedViewEnabled(boolean)': {'layer': 'Domain Layer'},
#    'isMessageViewMoveActionVisible()': {'layer': 'Service Layer'},
#    'confirmDiscardMessage()': {'layer': 'Service Layer'},
#    'setOpenPgpProvider(java.lang.String)': {'layer': 'Domain Layer'},
#    'isMessageViewSpamActionVisible()': {'layer': 'Presentation Layer'},
#    'useVolumeKeysForNavigationEnabled()': {'layer': 'Service Layer'},
#    'isOpenPgpProviderConfigured()': {'layer': 'Service Layer'},
#    'useVolumeKeysForListNavigationEnabled()': {'layer': 'Presentation Layer'},
#    'setK9MessageViewThemeSetting(com.fsck.k9.K9$Theme)': {'layer': 'Presentation Layer'},
#    'messageListPreviewLines()': {'layer': 'Presentation Layer'},
#    'setShowContactPicture(boolean)': {'layer': 'Service Layer'},
#    'setMessageViewSpamActionVisible(boolean)': {'layer': 'Presentation Layer'},
#    'getOpenPgpProvider()': {'layer': 'Service Layer'},
#    'setMeasureAccounts(boolean)': {'layer': 'Service Layer'},
#    'confirmDeleteFromNotification()': {'layer': 'Service Layer'},
#    'setConfirmDelete(boolean)': {'layer': 'Service Layer'},
#    'messageViewFixedWidthFont()': {'layer': 'Presentation Layer'},
#    'isMessageViewDeleteActionVisible()': {'layer': 'Domain Layer'},
#    'messageListStars()': {'layer': 'Service Layer'},
#    'changeContactNameColor()': {'layer': 'None'},
#    'startIntegratedInbox()': {'layer': 'Service Layer'},
#    'setSortType(com.fsck.k9.Account$SortType)': {'layer': 'Domain Layer'},
#    'setK9ComposerThemeSetting(com.fsck.k9.K9$Theme)': {'layer': 'Presentation Layer'},
#    'hideTimeZone()': {'layer': 'Utility Layer'},
#    'getK9ComposerThemeSetting()': {'layer': 'Data Source Layer'},
#    'setConfirmDiscardMessage(boolean)': {'layer': 'Presentation Layer'},
#    'getAttachmentDefaultPath()': {'layer': 'Data Source Layer'},
#    'saveSettingsAsync()': {'layer': 'Service Layer'},
#    'setCountSearchMessages(boolean)': {'layer': 'Service Layer'},
#    'isQuietTime()': {'layer': 'Domain Layer'},
#    'setK9Language(java.lang.String)': {'layer': 'Domain Layer'},
#    'setUseBackgroundAsUnreadIndicator(boolean)': {'layer': 'Service Layer'},
#    'setUseVolumeKeysForNavigation(boolean)': {'layer': 'Service Layer'},
#    'setShowCorrespondentNames(boolean)': {'layer': 'Presentation Layer'},
#    'setK9Theme(com.fsck.k9.K9$Theme)': {'layer': 'Presentation Layer'},
#    'messageViewReturnToList()': {'layer': 'Service Layer'},
#    'confirmMarkAllRead()': {'layer': 'Service Layer'},
#    'layers': {'Presentation Layer': 40,
#     'Service Layer': 45,
#     'Domain Layer': 35,
#     'Data Source Layer': 10,
#     'Utility Layer': 5,
#     'None': 2}},
#   'com.fsck.k9.EmailAddressValidator': {'fixText(java.lang.CharSequence)': {'layer': 'Domain Layer'},
#    'isValid(java.lang.CharSequence)': {'layer': 'Domain Layer'},
#    'isValidAddressOnly(java.lang.CharSequence)': {'layer': 'Domain Layer'},
#    'layers': {'Domain Layer': 3}},
#   'com.fsck.k9.Account$SortType': {'isDefaultAscending()': {'layer': 'Domain Layer'},
#    'getToast(boolean)': {'layer': 'Presentation Layer'},
#    'layers': {'Domain Layer': 1, 'Presentation Layer': 1}},
#   'com.fsck.k9.Globals': {'getContext()': {'layer': 'Utility Layer'},
#    'layers': {'Utility Layer': 1}},
#   'com.fsck.k9.FontSizes': {'getMessageViewContentAsPercent()': {'layer': 'Presentation Layer'},
#    'getMessageViewDate()': {'layer': 'Domain Layer'},
#    'getFolderStatus()': {'layer': 'Domain Layer'},
#    'setMessageViewContentAsPercent(int)': {'layer': 'Presentation Layer'},
#    'getMessageViewBCC()': {'layer': 'Domain Layer'},
#    'setMessageViewSubject(int)': {'layer': 'Domain Layer'},
#    'setMessageListPreview(int)': {'layer': 'Domain Layer'},
#    'getMessageViewAdditionalHeaders()': {'layer': 'Domain Layer'},
#    'getMessageListDate()': {'layer': 'Domain Layer'},
#    'getMessageViewCC()': {'layer': 'Domain Layer'},
#    'setMessageListDate(int)': {'layer': 'Domain Layer'},
#    'setMessageViewTo(int)': {'layer': 'Domain Layer'},
#    'getMessageComposeInput()': {'layer': 'Domain Layer'},
#    'getMessageViewSubject()': {'layer': 'Domain Layer'},
#    'setMessageListSender(int)': {'layer': 'Domain Layer'},
#    'getMessageViewSender()': {'layer': 'Domain Layer'},
#    'load(com.fsck.k9.preferences.Storage)': {'layer': 'Data Source Layer'},
#    'setAccountDescription(int)': {'layer': 'Domain Layer'},
#    'setAccountName(int)': {'layer': 'Domain Layer'},
#    'setMessageViewSender(int)': {'layer': 'Domain Layer'},
#    'setMessageListSubject(int)': {'layer': 'Domain Layer'},
#    'getMessageListPreview()': {'layer': 'Presentation Layer'},
#    'getMessageListSender()': {'layer': 'Domain Layer'},
#    'setMessageViewBCC(int)': {'layer': 'Domain Layer'},
#    'setViewTextSize(android.widget.TextView,int)': {'layer': 'Presentation Layer'},
#    'setMessageViewAdditionalHeaders(int)': {'layer': 'Domain Layer'},
#    'setFolderName(int)': {'layer': 'Domain Layer'},
#    'getMessageViewTo()': {'layer': 'Domain Layer'},
#    'getAccountDescription()': {'layer': 'Domain Layer'},
#    'getMessageListSubject()': {'layer': 'Domain Layer'},
#    'setMessageComposeInput(int)': {'layer': 'Presentation Layer'},
#    'setMessageViewDate(int)': {'layer': 'Domain Layer'},
#    'save(com.fsck.k9.preferences.StorageEditor)': {'layer': 'Data Source Layer'},
#    'getAccountName()': {'layer': 'Domain Layer'},
#    'getFolderName()': {'layer': 'Domain Layer'},
#    'setMessageViewCC(int)': {'layer': 'Domain Layer'},
#    'setFolderStatus(int)': {'layer': 'Domain Layer'},
#    'layers': {'Presentation Layer': 5,
#     'Domain Layer': 30,
#     'Data Source Layer': 2}},
#   'com.fsck.k9.NotificationSetting': {'isRingEnabled()': {'layer': 'Domain Layer'},
#    'isVibrateEnabled()': {'layer': 'Domain Layer'},
#    'isLedEnabled()': {'layer': 'Domain Layer'},
#    'setLed(boolean)': {'layer': 'Domain Layer'},
#    'setVibratePattern(int)': {'layer': 'Domain Layer'},
#    'getVibrateTimes()': {'layer': 'Domain Layer'},
#    'setRingEnabled(boolean)': {'layer': 'Domain Layer'},
#    'getLedColor()': {'layer': 'Domain Layer'},
#    'getRingtone()': {'layer': 'Domain Layer'},
#    'setVibrate(boolean)': {'layer': 'Domain Layer'},
#    'getVibration(int,int)': {'layer': 'Utility Layer'},
#    'getVibration()': {'layer': 'Data Source Layer'},
#    'setVibrateTimes(int)': {'layer': 'Domain Layer'},
#    'getVibratePattern()': {'layer': 'Domain Layer'},
#    'setLedColor(int)': {'layer': 'Presentation Layer'},
#    'setRingtone(java.lang.String)': {'layer': 'Domain Layer'},
#    'layers': {'Domain Layer': 13,
#     'Utility Layer': 1,
#     'Data Source Layer': 1,
#     'Presentation Layer': 1}},
#   'com.fsck.k9.K9$NotificationHideSubject': {'layers': {}},
#   'com.fsck.k9.K9$BACKGROUND_OPS': {'layers': {}},
#   'com.fsck.k9.Preferences': {'setDefaultAccount(com.fsck.k9.Account)': {'layer': 'Data Source Layer'},
#    'getAvailableAccounts()': {'layer': 'Service Layer'},
#    'loadAccounts()': {'layer': 'Domain Layer'},
#    'getAccounts()': {'layer': 'Data Source Layer'},
#    'newAccount()': {'layer': 'Domain Layer'},
#    'getAccount(java.lang.String)': {'layer': 'Domain Layer'},
#    'getPreferences(android.content.Context)': {'layer': 'Data Source Layer'},
#    'deleteAccount(com.fsck.k9.Account)': {'layer': 'Service Layer'},
#    'getStorage()': {'layer': 'Data Source Layer'},
#    'getDefaultAccount()': {'layer': 'Domain Layer'},
#    'layers': {'Data Source Layer': 4, 'Service Layer': 2, 'Domain Layer': 4}},
#   'com.fsck.k9.Account$FolderMode': {'layers': {}},
#   'com.fsck.k9.Clock': {'getTime()': {'layer': 'Utility Layer'},
#    'layers': {'Utility Layer': 1}},
#   'com.fsck.k9.Account': {'getLocalStore()': {'layer': 'Data Source Layer'},
#    'addCertificate(com.fsck.k9.activity.setup.AccountSetupCheckSettings$CheckDirection,java.security.cert.X509Certificate)': {'layer': 'Data Source Layer'},
#    'setDisplayCount(int)': {'layer': 'Domain Layer'},
#    'isReplyAfterQuote()': {'layer': 'Domain Layer'},
#    'getIdentities()': {'layer': 'Domain Layer'},
#    'setSignatureBeforeQuotedText(boolean)': {'layer': 'Domain Layer'},
#    'setIdleRefreshMinutes(int)': {'layer': 'Domain Layer'},
#    'goToUnreadMessageSearch()': {'layer': 'Service Layer'},
#    'setSortType(com.fsck.k9.Account$SortType)': {'layer': 'Domain Layer'},
#    'setFolderTargetMode(com.fsck.k9.Account$FolderMode)': {'layer': 'Domain Layer'},
#    'getStoreUri()': {'layer': 'Domain Layer'},
#    'getMaxPushFolders()': {'layer': 'Domain Layer'},
#    'setEnabled(boolean)': {'layer': 'Domain Layer'},
#    'setExpungePolicy(com.fsck.k9.Account$Expunge)': {'layer': 'Domain Layer'},
#    'limitToDisplayableFolders(com.fsck.k9.search.LocalSearch)': {'layer': 'Service Layer'},
#    'hasDraftsFolder()': {'layer': 'Domain Layer'},
#    'setArchiveFolderName(java.lang.String)': {'layer': 'Domain Layer'},
#    'getSearchableFolders()': {'layer': 'Domain Layer'},
#    'isSortAscending(com.fsck.k9.Account$SortType)': {'layer': 'Domain Layer'},
#    'setInboxFolderName(java.lang.String)': {'layer': 'Domain Layer'},
#    'setTransportUri(java.lang.String)': {'layer': 'Domain Layer'},
#    'getFolderSyncMode()': {'layer': 'Domain Layer'},
#    'setNotifyContactsMailOnly(boolean)': {'layer': 'Domain Layer'},
#    'setSyncRemoteDeletions(boolean)': {'layer': 'Domain Layer'},
#    'setFolderPushMode(com.fsck.k9.Account$FolderMode)': {'layer': 'Service Layer'},
#    'getAlwaysBcc()': {'layer': 'Domain Layer'},
#    'setDraftsFolderName(java.lang.String)': {'layer': 'Domain Layer'},
#    'setSubscribedFoldersOnly(boolean)': {'layer': 'Domain Layer'},
#    'setMessageFormat(com.fsck.k9.Account$MessageFormat)': {'layer': 'Domain Layer'},
#    'getLastSelectedFolderName()': {'layer': 'Domain Layer'},
#    'getQuotePrefix()': {'layer': 'Domain Layer'},
#    'getStats(android.content.Context)': {'layer': 'Service Layer'},
#    'getSpamFolderName()': {'layer': 'Domain Layer'},
#    'syncRemoteDeletions()': {'layer': 'Service Layer'},
#    'save(com.fsck.k9.Preferences)': {'layer': 'Data Source Layer'},
#    'useCompression(com.fsck.k9.mail.NetworkType)': {'layer': 'Data Source Layer'},
#    'setSpamFolderName(java.lang.String)': {'layer': 'Domain Layer'},
#    'setAutomaticCheckIntervalMinutes(int)': {'layer': 'Domain Layer'},
#    'setGoToUnreadMessageSearch(boolean)': {'layer': 'Domain Layer'},
#    'setShowPictures(com.fsck.k9.Account$ShowPictures)': {'layer': 'Domain Layer'},
#    'setQuotePrefix(java.lang.String)': {'layer': 'Domain Layer'},
#    'hashCode()': {'layer': 'Domain Layer'},
#    'getRemoteSearchNumResults()': {'layer': 'Domain Layer'},
#    'setFolderDisplayMode(com.fsck.k9.Account$FolderMode)': {'layer': 'Domain Layer'},
#    'isRemoteSearchFullText()': {'layer': 'Domain Layer'},
#    'isSearchByDateCapable()': {'layer': 'Domain Layer'},
#    'getAccountNumber()': {'layer': 'Domain Layer'},
#    'isPushPollOnConnect()': {'layer': 'Domain Layer'},
#    'getOutboxFolderName()': {'layer': 'Data Source Layer'},
#    'getFolderPushMode()': {'layer': 'Domain Layer'},
#    'setSentFolderName(java.lang.String)': {'layer': 'Domain Layer'},
#    'setChipColor(int)': {'layer': 'Domain Layer'},
#    'getLatestOldMessageSeenTime()': {'layer': 'Domain Layer'},
#    'findIdentity(com.fsck.k9.mail.Address)': {'layer': 'Domain Layer'},
#    'setEmail(java.lang.String)': {'layer': 'Domain Layer'},
#    'setSortAscending(com.fsck.k9.Account$SortType,boolean)': {'layer': 'Domain Layer'},
#    'getName()': {'layer': 'Domain Layer'},
#    'generateColorChip(boolean,boolean)': {'layer': 'Domain Layer'},
#    'isAnIdentity(com.fsck.k9.mail.Address)': {'layer': 'Domain Layer'},
#    'getFolderUnreadCount(android.content.Context,java.lang.String)': {'layer': 'Data Source Layer'},
#    'getEmail()': {'layer': 'Domain Layer'},
#    'subscribedFoldersOnly()': {'layer': 'Domain Layer'},
#    'hasArchiveFolder()': {'layer': 'Domain Layer'},
#    'setFolderNotifyNewMailMode(com.fsck.k9.Account$FolderMode)': {'layer': 'Domain Layer'},
#    'setReplyAfterQuote(boolean)': {'layer': 'Domain Layer'},
#    'setLastSelectedFolderName(java.lang.String)': {'layer': 'Domain Layer'},
#    'getAutomaticCheckIntervalMinutes()': {'layer': 'Domain Layer'},
#    'getSignatureUse()': {'layer': 'Domain Layer'},
#    'setRingNotified(boolean)': {'layer': 'Domain Layer'},
#    'getMessageFormat()': {'layer': 'Domain Layer'},
#    'isNotifyNewMail()': {'layer': 'Domain Layer'},
#    'setStripSignature(boolean)': {'layer': 'Domain Layer'},
#    'setMarkMessageAsReadOnView(boolean)': {'layer': 'Domain Layer'},
#    'isDefaultQuotedTextShown()': {'layer': 'Domain Layer'},
#    'getEarliestPollDate()': {'layer': 'Service Layer'},
#    'setRemoteSearchFullText(boolean)': {'layer': 'Domain Layer'},
#    'generateAccountNumber(com.fsck.k9.Preferences)': {'layer': 'Service Layer'},
#    'setMessageReadReceipt(boolean)': {'layer': 'Domain Layer'},
#    'setCompression(com.fsck.k9.mail.NetworkType,boolean)': {'layer': 'Data Source Layer'},
#    'setDefaultQuotedTextShown(boolean)': {'layer': 'Domain Layer'},
#    'isStripSignature()': {'layer': 'Domain Layer'},
#    'setQuoteStyle(com.fsck.k9.Account$QuoteStyle)': {'layer': 'Domain Layer'},
#    'isAnIdentity(com.fsck.k9.mail.Address[])': {'layer': 'Domain Layer'},
#    'isEnabled()': {'layer': 'Domain Layer'},
#    'setSearchableFolders(com.fsck.k9.Account$Searchable)': {'layer': 'Domain Layer'},
#    'isSignatureBeforeQuotedText()': {'layer': 'Domain Layer'},
#    'isNotifyContactsMailOnly()': {'layer': 'Domain Layer'},
#    'getFolderNotifyNewMailMode()': {'layer': 'Domain Layer'},
#    'setName(java.lang.String)': {'layer': 'Domain Layer'},
#    'setIdentities(java.util.List)': {'layer': 'Domain Layer'},
#    'allowRemoteSearch()': {'layer': 'Domain Layer'},
#    'setSignatureUse(boolean)': {'layer': 'Domain Layer'},
#    'getRemoteStore()': {'layer': 'Service Layer'},
#    'hasTrashFolder()': {'layer': 'Domain Layer'},
#    'deleteCertificate(java.lang.String,int,com.fsck.k9.activity.setup.AccountSetupCheckSettings$CheckDirection)': {'layer': 'Data Source Layer'},
#    'getLocalStorageProviderId()': {'layer': 'Domain Layer'},
#    'setAutoExpandFolderName(java.lang.String)': {'layer': 'Domain Layer'},
#    'hasSpamFolder()': {'layer': 'Domain Layer'},
#    'setMaximumAutoDownloadMessageSize(int)': {'layer': 'Service Layer'},
#    'getQuoteStyle()': {'layer': 'Domain Layer'},
#    'getSignature()': {'layer': 'Domain Layer'},
#    'getInboxFolderName()': {'layer': 'Domain Layer'},
#    'setRemoteSearchNumResults(int)': {'layer': 'Domain Layer'},
#    'excludeSpecialFolders(com.fsck.k9.search.LocalSearch)': {'layer': 'Service Layer'},
#    'setPushPollOnConnect(boolean)': {'layer': 'Domain Layer'},
#    'getTrashFolderName()': {'layer': 'Domain Layer'},
#    'toString()': {'layer': 'Domain Layer'},
#    'getArchiveFolderName()': {'layer': 'Domain Layer'},
#    'getDescription()': {'layer': 'Domain Layer'},
#    'getAutoExpandFolderName()': {'layer': 'Domain Layer'},
#    'setMaximumPolledMessageAge(int)': {'layer': 'Domain Layer'},
#    'setLocalStorageProviderId(java.lang.String)': {'layer': 'Data Source Layer'},
#    'hasSentFolder()': {'layer': 'Domain Layer'},
#    'getMaximumAutoDownloadMessageSize()': {'layer': 'Domain Layer'},
#    'getSortType()': {'layer': 'Domain Layer'},
#    'setDescription(java.lang.String)': {'layer': 'Domain Layer'},
#    'getChipColor()': {'layer': 'Domain Layer'},
#    'getDeletePolicy()': {'layer': 'Domain Layer'},
#    'isMarkMessageAsReadOnView()': {'layer': 'Domain Layer'},
#    'setDeletePolicy(com.fsck.k9.Account$DeletePolicy)': {'layer': 'Domain Layer'},
#    'isRingNotified()': {'layer': 'Domain Layer'},
#    'getDisplayCount()': {'layer': 'Presentation Layer'},
#    'isAlwaysShowCcBcc()': {'layer': 'Domain Layer'},
#    'getDraftsFolderName()': {'layer': 'Domain Layer'},
#    'getExpungePolicy()': {'layer': 'Domain Layer'},
#    'getShowPictures()': {'layer': 'Domain Layer'},
#    'setCryptoKey(long)': {'layer': 'Domain Layer'},
#    'isSpecialFolder(java.lang.String)': {'layer': 'Domain Layer'},
#    'setNotifySelfNewMail(boolean)': {'layer': 'Domain Layer'},
#    'move(com.fsck.k9.Preferences,boolean)': {'layer': 'Data Source Layer'},
#    'getNotificationSetting()': {'layer': 'Domain Layer'},
#    'getSentFolderName()': {'layer': 'Domain Layer'},
#    'setNotifyNewMail(boolean)': {'layer': 'Domain Layer'},
#    'setFolderSyncMode(com.fsck.k9.Account$FolderMode)': {'layer': 'Domain Layer'},
#    'setAlwaysBcc(java.lang.String)': {'layer': 'Domain Layer'},
#    'setShowOngoing(boolean)': {'layer': 'Domain Layer'},
#    'setAlwaysShowCcBcc(boolean)': {'layer': 'Domain Layer'},
#    'getIdleRefreshMinutes()': {'layer': 'Domain Layer'},
#    'isNotifySelfNewMail()': {'layer': 'Domain Layer'},
#    'setAllowRemoteSearch(boolean)': {'layer': 'Domain Layer'},
#    'isShowOngoing()': {'layer': 'Domain Layer'},
#    'getCryptoKey()': {'layer': 'Domain Layer'},
#    'setStoreUri(java.lang.String)': {'layer': 'Domain Layer'},
#    'getFolderTargetMode()': {'layer': 'Domain Layer'},
#    'getTransportUri()': {'layer': 'Domain Layer'},
#    'setSignature(java.lang.String)': {'layer': 'Domain Layer'},
#    'getFolderDisplayMode()': {'layer': 'Domain Layer'},
#    'equals(java.lang.Object)': {'layer': 'Domain Layer'},
#    'setLatestOldMessageSeenTime(long)': {'layer': 'Domain Layer'},
#    'excludeUnwantedFolders(com.fsck.k9.search.LocalSearch)': {'layer': 'Service Layer'},
#    'getIdentity(int)': {'layer': 'Domain Layer'},
#    'getMaximumPolledMessageAge()': {'layer': 'Domain Layer'},
#    'isAvailable(android.content.Context)': {'layer': 'Service Layer'},
#    'getUuid()': {'layer': 'Domain Layer'},
#    'setTrashFolderName(java.lang.String)': {'layer': 'Domain Layer'},
#    'setMaxPushFolders(int)': {'layer': 'Domain Layer'},
#    'isMessageReadReceiptAlways()': {'layer': 'Domain Layer'},
#    'layers': {'Data Source Layer': 10,
#     'Domain Layer': 134,
#     'Service Layer': 12,
#     'Presentation Layer': 1}},
#   'com.fsck.k9.K9$Intents': {'layers': {}},
#   'com.fsck.k9.Account$MessageFormat': {'layers': {}},
#   'com.fsck.k9.K9$ApplicationAware': {'initializeComponent(android.app.Application)': {'layer': 'Service Layer'},
#    'layers': {'Service Layer': 1}},
#   'com.fsck.k9.Identity': {'getDescription()': {'layer': 'Domain Layer'},
#    'setSignature(java.lang.String)': {'layer': 'Domain Layer'},
#    'setEmail(java.lang.String)': {'layer': 'Domain Layer'},
#    'getSignatureUse()': {'layer': 'Domain Layer'},
#    'getSignature()': {'layer': 'Domain Layer'},
#    'getName()': {'layer': 'Domain Layer'},
#    'setDescription(java.lang.String)': {'layer': 'Domain Layer'},
#    'setReplyTo(java.lang.String)': {'layer': 'Domain Layer'},
#    'getReplyTo()': {'layer': 'Domain Layer'},
#    'setName(java.lang.String)': {'layer': 'Domain Layer'},
#    'toString()': {'layer': 'Domain Layer'},
#    'getEmail()': {'layer': 'Domain Layer'},
#    'setSignatureUse(boolean)': {'layer': 'Domain Layer'},
#    'layers': {'Domain Layer': 13}},
#   'com.fsck.k9.Account$Searchable': {'layers': {}},
#   'com.fsck.k9.K9$LockScreenNotificationVisibility': {'layers': {}},
#   'com.fsck.k9.PRNGFixes$LinuxPRNGSecureRandom': {'layers': {}},
#   'com.fsck.k9.K9$Theme': {'layers': {}},
#   'com.fsck.k9.Account$DeletePolicy': {'preferenceString()': {'layer': 'Domain Layer'},
#    'fromInt(int)': {'layer': 'Domain Layer'},
#    'layers': {'Domain Layer': 2}}},
#  'com.fsck.k9.account': {'com.fsck.k9.account.AccountCreator': {'getDefaultDeletePolicy(com.fsck.k9.mail.ServerSettings.Type)': {'layer': 'Service Layer'},
#    'getDefaultPort(com.fsck.k9.mail.ConnectionSecurity,com.fsck.k9.mail.ServerSettings.Type)': {'layer': 'Service Layer'},
#    'layers': {'Service Layer': 2}}},
#  'com.fsck.k9.activity': {'com.fsck.k9.activity.FolderList$FolderListAdapter': {'getFilter()': {'layer': 'Presentation Layer'},
#    'getCount()': {'layer': 'Domain Layer'},
#    'getFolder(java.lang.String)': {'layer': 'Service Layer'},
#    'isEnabled(int)': {'layer': 'Presentation Layer'},
#    'getItemView(int,android.view.View,android.view.ViewGroup)': {'layer': 'Presentation Layer'},
#    'getView(int,android.view.View,android.view.ViewGroup)': {'layer': 'Presentation Layer'},
#    'areAllItemsEnabled()': {'layer': 'Presentation Layer'},
#    'isItemSelectable(int)': {'layer': 'Domain Layer'},
#    'getFolderIndex(java.lang.String)': {'layer': 'Data Source Layer'},
#    'setFilter(android.widget.Filter)': {'layer': 'Domain Layer'},
#    'getItem(int)': {'layer': 'Data Source Layer'},
#    'getItemId(int)': {'layer': 'Data Source Layer'},
#    'getItem(long)': {'layer': 'Data Source Layer'},
#    'hasStableIds()': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 6,
#     'Domain Layer': 3,
#     'Service Layer': 1,
#     'Data Source Layer': 4}},
#   'com.fsck.k9.activity.Accounts$AccountsHandler': {'progress(boolean)': {'layer': 'Presentation Layer'},
#    'dataChanged()': {'layer': 'Presentation Layer'},
#    'accountSizeChanged(com.fsck.k9.Account,long,long)': {'layer': 'Presentation Layer'},
#    'refreshTitle()': {'layer': 'Presentation Layer'},
#    'progress(int)': {'layer': 'Presentation Layer'},
#    'workingAccount(com.fsck.k9.Account,int)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 6}},
#   'com.fsck.k9.activity.MessageCompose': {'showContactPicker(int)': {'layer': 'Presentation Layer'},
#    'onOptionsItemSelected(android.view.MenuItem)': {'layer': 'Presentation Layer'},
#    'onRecipientsChanged()': {'layer': 'Domain Layer'},
#    'onMessageBuildCancel()': {'layer': 'Presentation Layer'},
#    'saveDraftEventually()': {'layer': 'Domain Layer'},
#    'onClick(android.view.View)': {'layer': 'Presentation Layer'},
#    'onPrepareOptionsMenu(android.view.Menu)': {'layer': 'Presentation Layer'},
#    'onAttachmentRemoved()': {'layer': 'Domain Layer'},
#    'onCreate(android.os.Bundle)': {'layer': 'Presentation Layer'},
#    'onProgressCancel(com.fsck.k9.fragment.ProgressDialogFragment)': {'layer': 'Presentation Layer'},
#    'onOpenPgpClickDisable()': {'layer': 'Service Layer'},
#    'performSendAfterChecks()': {'layer': 'Service Layer'},
#    'onAttachmentAdded()': {'layer': 'Domain Layer'},
#    'onRetainNonConfigurationInstance()': {'layer': 'Presentation Layer'},
#    'loadLocalMessageForDisplay(com.fsck.k9.mailstore.MessageViewInfo,com.fsck.k9.activity.MessageCompose$Action)': {'layer': 'Service Layer'},
#    'onFocusChange(android.view.View,boolean)': {'layer': 'Presentation Layer'},
#    'updateMessageFormat()': {'layer': 'Domain Layer'},
#    'onCreateOptionsMenu(android.view.Menu)': {'layer': 'Presentation Layer'},
#    'onOpenPgpSignOnlyChange(boolean)': {'layer': 'Presentation Layer'},
#    'onMessageBuildSuccess(com.fsck.k9.mail.internet.MimeMessage,boolean)': {'layer': 'Service Layer'},
#    'onDestroy()': {'layer': 'Presentation Layer'},
#    'launchUserInteractionPendingIntent(android.app.PendingIntent,int)': {'layer': 'Presentation Layer'},
#    'onCreateDialog(int)': {'layer': 'Presentation Layer'},
#    'onPause()': {'layer': 'Presentation Layer'},
#    'onMessageBuildException(com.fsck.k9.mail.MessagingException)': {'layer': 'Presentation Layer'},
#    'onBackPressed()': {'layer': 'Presentation Layer'},
#    'loadQuotedTextForEdit()': {'layer': 'Domain Layer'},
#    'onProgressCancel(com.fsck.k9.fragment.AttachmentDownloadDialogFragment)': {'layer': 'Presentation Layer'},
#    'onMessageBuildReturnPendingIntent(android.app.PendingIntent,int)': {'layer': 'Presentation Layer'},
#    'onOpenPgpInlineChange(boolean)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 20,
#     'Domain Layer': 6,
#     'Service Layer': 4}},
#   'com.fsck.k9.activity.Accounts$ExportAsyncTask': {'layers': {}},
#   'com.fsck.k9.activity.MessageInfoHolder': {'equals(java.lang.Object)': {'layer': 'Domain Layer'},
#    'hashCode()': {'layer': 'Domain Layer'},
#    'layers': {'Domain Layer': 2}},
#   'com.fsck.k9.activity.Search': {'onStop()': {'layer': 'Presentation Layer'},
#    'onStart()': {'layer': 'Presentation Layer'},
#    'isActive()': {'layer': 'Presentation Layer'},
#    'setActive(boolean)': {'layer': 'Service Layer'},
#    'layers': {'Presentation Layer': 3, 'Service Layer': 1}},
#   'com.fsck.k9.activity.Accounts$ImportAsyncTask': {'layers': {}},
#   'com.fsck.k9.activity.ColorPickerDialog$OnColorChangedListener': {'colorChanged(int)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 1}},
#   'com.fsck.k9.activity.K9PreferenceActivity': {'onCreate(android.os.Bundle)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 1}},
#   'com.fsck.k9.activity.MessageList$StorageListenerImplementation': {'onUnmount(java.lang.String)': {'layer': 'Presentation Layer'},
#    'onMount(java.lang.String)': {'layer': 'Domain Layer'},
#    'layers': {'Presentation Layer': 1, 'Domain Layer': 1}},
#   'com.fsck.k9.activity.K9Activity': {'dispatchTouchEvent(android.view.MotionEvent)': {'layer': 'Presentation Layer'},
#    'setupGestureDetector(com.fsck.k9.activity.misc.SwipeGestureDetector$OnSwipeGestureListener)': {'layer': 'Presentation Layer'},
#    'onCreate(android.os.Bundle)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 3}},
#   'com.fsck.k9.activity.K9ActivityCommon': {'getThemeBackgroundColor()': {'layer': 'Data Source Layer'},
#    'newInstance(android.app.Activity)': {'layer': 'Presentation Layer'},
#    'setupGestureDetector(com.fsck.k9.activity.misc.SwipeGestureDetector$OnSwipeGestureListener)': {'layer': 'Presentation Layer'},
#    'preDispatchTouchEvent(android.view.MotionEvent)': {'layer': 'Presentation Layer'},
#    'setLanguage(android.content.Context,java.lang.String)': {'layer': 'Presentation Layer'},
#    'layers': {'Data Source Layer': 1, 'Presentation Layer': 4}},
#   'com.fsck.k9.activity.AccountList': {'onResume()': {'layer': 'Presentation Layer'},
#    'onItemClick(android.widget.AdapterView,android.view.View,int,long)': {'layer': 'Presentation Layer'},
#    'populateListView(java.util.List)': {'layer': 'Presentation Layer'},
#    'onCreate(android.os.Bundle)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 4}},
#   'com.fsck.k9.activity.LauncherShortcuts': {'onCreate(android.os.Bundle)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 1}},
#   'com.fsck.k9.activity.Accounts$PasswordPromptDialog': {'onTextChanged(java.lang.CharSequence,int,int,int)': {'layer': 'Presentation Layer'},
#    'afterTextChanged(android.text.Editable)': {'layer': 'Presentation Layer'},
#    'restore(android.app.Activity)': {'layer': 'Service Layer'},
#    'show(com.fsck.k9.activity.Accounts)': {'layer': 'Presentation Layer'},
#    'retain()': {'layer': 'Presentation Layer'},
#    'beforeTextChanged(java.lang.CharSequence,int,int,int)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 5, 'Service Layer': 1}},
#   'com.fsck.k9.activity.Accounts$AccountClickListener': {'onClick(android.view.View)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 1}},
#   'com.fsck.k9.activity.AccountList$LoadAccounts': {'layers': {}},
#   'com.fsck.k9.activity.ColorPickerDialog': {'setColor(int)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 1}},
#   'com.fsck.k9.activity.ChooseFolder': {'onOptionsItemSelected(android.view.MenuItem)': {'layer': 'Presentation Layer'},
#    'onCreateOptionsMenu(android.view.Menu)': {'layer': 'Presentation Layer'},
#    'onCreate(android.os.Bundle)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 3}},
#   'com.fsck.k9.activity.EditIdentity': {'onCreate(android.os.Bundle)': {'layer': 'Presentation Layer'},
#    'onSaveInstanceState(android.os.Bundle)': {'layer': 'Presentation Layer'},
#    'onBackPressed()': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 3}},
#   'com.fsck.k9.activity.Accounts$ListImportContentsAsyncTask': {'layers': {}},
#   'com.fsck.k9.activity.MessageCompose$Action': {'getTitleResource()': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 1}},
#   'com.fsck.k9.activity.UnreadWidgetConfiguration': {'onActivityResult(int,int,android.content.Intent)': {'layer': 'Presentation Layer'},
#    'getWidgetProperties(android.content.Context,int)': {'layer': 'Data Source Layer'},
#    'deleteWidgetConfiguration(android.content.Context,int)': {'layer': 'Data Source Layer'},
#    'onOptionsItemSelected(android.view.MenuItem)': {'layer': 'Presentation Layer'},
#    'onCreate(android.os.Bundle)': {'layer': 'Presentation Layer'},
#    'onCreateOptionsMenu(android.view.Menu)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 4, 'Data Source Layer': 2}},
#   'com.fsck.k9.activity.EmailAddressList': {'onItemClick(android.widget.AdapterView,android.view.View,int,long)': {'layer': 'Presentation Layer'},
#    'onCreate(android.os.Bundle)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 2}},
#   'com.fsck.k9.activity.K9PreferenceActivity$PreferenceChangeListener': {'onPreferenceChange(android.preference.Preference,java.lang.Object)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 1}},
#   'com.fsck.k9.activity.MessageCompose$SendMessageTask': {'layers': {}},
#   'com.fsck.k9.activity.AccountList$AccountsAdapter$AccountViewHolder': {'layers': {}},
#   'com.fsck.k9.activity.Accounts$AccountsAdapter': {'getView(int,android.view.View,android.view.ViewGroup)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 1}},
#   'com.fsck.k9.activity.AccountList$AccountsAdapter': {'getView(int,android.view.View,android.view.ViewGroup)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 1}},
#   'com.fsck.k9.activity.FolderList$FolderClickListener': {'onClick(android.view.View)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 1}},
#   'com.fsck.k9.activity.Accounts': {'onItemLongClick(android.widget.AdapterView,android.view.View,int,long)': {'layer': 'Presentation Layer'},
#    'onPrepareDialog(int,android.app.Dialog)': {'layer': 'Presentation Layer'},
#    'onExport(boolean,com.fsck.k9.Account)': {'layer': 'Presentation Layer'},
#    'onCreateDialog(int)': {'layer': 'Presentation Layer'},
#    'onCreate(android.os.Bundle)': {'layer': 'Presentation Layer'},
#    'listAccounts(android.content.Context)': {'layer': 'Presentation Layer'},
#    'onResume()': {'layer': 'Presentation Layer'},
#    'onCreateContextMenu(android.view.ContextMenu,android.view.View,android.view.ContextMenu.ContextMenuInfo)': {'layer': 'Presentation Layer'},
#    'onItemClick(android.widget.AdapterView,android.view.View,int,long)': {'layer': 'Presentation Layer'},
#    'onCreateOptionsMenu(android.view.Menu)': {'layer': 'Presentation Layer'},
#    'onPause()': {'layer': 'Service Layer'},
#    'importSettings(android.content.Context)': {'layer': 'Presentation Layer'},
#    'setProgress(boolean)': {'layer': 'Presentation Layer'},
#    'onContextItemSelected(android.view.MenuItem)': {'layer': 'Presentation Layer'},
#    'onExport(android.content.Intent)': {'layer': 'Service Layer'},
#    'onRetainNonConfigurationInstance()': {'layer': 'Presentation Layer'},
#    'createUnreadSearch(android.content.Context,com.fsck.k9.BaseAccount)': {'layer': 'Service Layer'},
#    'onSaveInstanceState(android.os.Bundle)': {'layer': 'Presentation Layer'},
#    'onOptionsItemSelected(android.view.MenuItem)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 16, 'Service Layer': 3}},
#   'com.fsck.k9.activity.MessageLoaderHelper': {'asyncRestartMessageCryptoProcessing()': {'layer': 'Service Layer'},
#    'onDestroyChangingConfigurations()': {'layer': 'Presentation Layer'},
#    'onDestroy()': {'layer': 'Presentation Layer'},
#    'asyncStartOrResumeLoadingMessage(com.fsck.k9.activity.MessageReference,android.os.Parcelable)': {'layer': 'Service Layer'},
#    'asyncReloadMessage()': {'layer': 'Presentation Layer'},
#    'downloadCompleteMessage()': {'layer': 'Presentation Layer'},
#    'onActivityResult(int,int,android.content.Intent)': {'layer': 'Service Layer'},
#    'layers': {'Service Layer': 3, 'Presentation Layer': 4}},
#   'com.fsck.k9.activity.Accounts$SetPasswordsAsyncTask': {'layers': {}},
#   'com.fsck.k9.activity.ConfirmationDialog': {'create(android.app.Activity,int,int,java.lang.String,int,int,java.lang.Runnable)': {'layer': 'Presentation Layer'},
#    'create(android.app.Activity,int,int,java.lang.String,int,int,java.lang.Runnable,java.lang.Runnable)': {'layer': 'Presentation Layer'},
#    'create(android.app.Activity,int,int,int,int,int,java.lang.Runnable)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 3}},
#   'com.fsck.k9.activity.AlternateRecipientAdapter$AlternateRecipientListener': {'onRecipientChange(com.fsck.k9.view.RecipientSelectView$Recipient,com.fsck.k9.view.RecipientSelectView$Recipient)': {'layer': 'Domain Layer'},
#    'onRecipientRemove(com.fsck.k9.view.RecipientSelectView$Recipient)': {'layer': 'Presentation Layer'},
#    'layers': {'Domain Layer': 1, 'Presentation Layer': 1}},
#   'com.fsck.k9.activity.FolderList$FolderListHandler': {'accountSizeChanged(long,long)': {'layer': 'Presentation Layer'},
#    'workingAccount(int)': {'layer': 'Presentation Layer'},
#    'progress(boolean)': {'layer': 'Presentation Layer'},
#    'dataChanged()': {'layer': 'Presentation Layer'},
#    'newFolders(java.util.List)': {'layer': 'Presentation Layer'},
#    'folderLoading(java.lang.String,boolean)': {'layer': 'Presentation Layer'},
#    'refreshTitle()': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 7}},
#   'com.fsck.k9.activity.K9ListActivity': {'setupGestureDetector(com.fsck.k9.activity.misc.SwipeGestureDetector$OnSwipeGestureListener)': {'layer': 'Presentation Layer'},
#    'onCreate(android.os.Bundle)': {'layer': 'Presentation Layer'},
#    'onResume()': {'layer': 'Presentation Layer'},
#    'onKeyUp(int,android.view.KeyEvent)': {'layer': 'Presentation Layer'},
#    'onKeyDown(int,android.view.KeyEvent)': {'layer': 'Presentation Layer'},
#    'dispatchTouchEvent(android.view.MotionEvent)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 6}},
#   'com.fsck.k9.activity.ChooseFolder$ChooseFolderHandler': {'handleMessage(android.os.Message)': {'layer': 'Presentation Layer'},
#    'progress(boolean)': {'layer': 'Presentation Layer'},
#    'setSelectedFolder(int)': {'layer': 'Service Layer'},
#    'layers': {'Presentation Layer': 2, 'Service Layer': 1}},
#   'com.fsck.k9.activity.ActivityListener': {'searchStats(com.fsck.k9.AccountStats)': {'layer': 'Presentation Layer'},
#    'synchronizeMailboxFailed(com.fsck.k9.Account,java.lang.String,java.lang.String)': {'layer': 'Service Layer'},
#    'synchronizeMailboxStarted(com.fsck.k9.Account,java.lang.String)': {'layer': 'Service Layer'},
#    'sendPendingMessagesCompleted(com.fsck.k9.Account)': {'layer': 'Service Layer'},
#    'pendingCommandStarted(com.fsck.k9.Account,java.lang.String)': {'layer': 'Service Layer'},
#    'sendPendingMessagesFailed(com.fsck.k9.Account)': {'layer': 'Service Layer'},
#    'getFolderTotal()': {'layer': 'Domain Layer'},
#    'pendingCommandCompleted(com.fsck.k9.Account,java.lang.String)': {'layer': 'Service Layer'},
#    'pendingCommandsProcessing(com.fsck.k9.Account)': {'layer': 'Service Layer'},
#    'getFolderCompleted()': {'layer': 'Domain Layer'},
#    'synchronizeMailboxHeadersProgress(com.fsck.k9.Account,java.lang.String,int,int)': {'layer': 'Domain Layer'},
#    'synchronizeMailboxHeadersFinished(com.fsck.k9.Account,java.lang.String,int,int)': {'layer': 'Service Layer'},
#    'folderStatusChanged(com.fsck.k9.Account,java.lang.String,int)': {'layer': 'Service Layer'},
#    'synchronizeMailboxFinished(com.fsck.k9.Account,java.lang.String,int,int)': {'layer': 'Domain Layer'},
#    'synchronizeMailboxHeadersStarted(com.fsck.k9.Account,java.lang.String)': {'layer': 'Service Layer'},
#    'systemStatusChanged()': {'layer': 'Presentation Layer'},
#    'onPause(android.content.Context)': {'layer': 'Data Source Layer'},
#    'sendPendingMessagesStarted(com.fsck.k9.Account)': {'layer': 'Domain Layer'},
#    'informUserOfStatus()': {'layer': 'Presentation Layer'},
#    'synchronizeMailboxProgress(com.fsck.k9.Account,java.lang.String,int,int)': {'layer': 'Service Layer'},
#    'getOperation(android.content.Context)': {'layer': 'Presentation Layer'},
#    'onResume(android.content.Context)': {'layer': 'Presentation Layer'},
#    'pendingCommandsFinished(com.fsck.k9.Account)': {'layer': 'Service Layer'},
#    'layers': {'Presentation Layer': 5,
#     'Service Layer': 12,
#     'Domain Layer': 5,
#     'Data Source Layer': 1}},
#   'com.fsck.k9.activity.NotificationDeleteConfirmation': {'onPrepareDialog(int,android.app.Dialog)': {'layer': 'Presentation Layer'},
#    'onCreateDialog(int)': {'layer': 'Presentation Layer'},
#    'getIntent(android.content.Context,java.util.List)': {'layer': 'Service Layer'},
#    'getIntent(android.content.Context,com.fsck.k9.activity.MessageReference)': {'layer': 'Service Layer'},
#    'onCreate(android.os.Bundle)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 3, 'Service Layer': 2}},
#   'com.fsck.k9.activity.ChooseIdentity': {'onCreate(android.os.Bundle)': {'layer': 'Presentation Layer'},
#    'onResume()': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 2}},
#   'com.fsck.k9.activity.UpgradeDatabases': {'onCreate(android.os.Bundle)': {'layer': 'Presentation Layer'},
#    'actionUpgradeDatabases(android.content.Context,android.content.Intent)': {'layer': 'Service Layer'},
#    'onResume()': {'layer': 'Service Layer'},
#    'onPause()': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 2, 'Service Layer': 2}},
#   'com.fsck.k9.activity.Accounts$AccountsImportedDialog': {'layers': {}},
#   'com.fsck.k9.activity.Accounts$ImportSelectionDialog': {'restore(android.app.Activity)': {'layer': 'Presentation Layer'},
#    'show(com.fsck.k9.activity.Accounts)': {'layer': 'Presentation Layer'},
#    'show(com.fsck.k9.activity.Accounts,android.util.SparseBooleanArray)': {'layer': 'Presentation Layer'},
#    'retain()': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 4}},
#   'com.fsck.k9.activity.AlternateRecipientAdapter': {'getItemId(int)': {'layer': 'Presentation Layer'},
#    'getCount()': {'layer': 'Domain Layer'},
#    'bindItemView(android.view.View,com.fsck.k9.view.RecipientSelectView$Recipient)': {'layer': 'Presentation Layer'},
#    'setCurrentRecipient(com.fsck.k9.view.RecipientSelectView$Recipient)': {'layer': 'Domain Layer'},
#    'getItem(int)': {'layer': 'Domain Layer'},
#    'bindHeaderView(android.view.View,com.fsck.k9.view.RecipientSelectView$Recipient)': {'layer': 'Presentation Layer'},
#    'isEnabled(int)': {'layer': 'Presentation Layer'},
#    'setShowAdvancedInfo(boolean)': {'layer': 'Domain Layer'},
#    'getView(int,android.view.View,android.view.ViewGroup)': {'layer': 'Presentation Layer'},
#    'setAlternateRecipientInfo(java.util.List)': {'layer': 'Domain Layer'},
#    'newView(android.view.ViewGroup)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 6, 'Domain Layer': 5}},
#   'com.fsck.k9.activity.MessageLoaderHelper$MessageLoaderCallbacks': {'onDownloadErrorNetworkError()': {'layer': 'Service Layer'},
#    'onMessageDataLoadFinished(com.fsck.k9.mailstore.LocalMessage)': {'layer': 'Service Layer'},
#    'onMessageDataLoadFailed()': {'layer': 'Service Layer'},
#    'onMessageViewInfoLoadFailed(com.fsck.k9.mailstore.MessageViewInfo)': {'layer': 'Presentation Layer'},
#    'startIntentSenderForMessageLoaderHelper(android.content.IntentSender,int,android.content.Intent,int,int,int)': {'layer': 'Service Layer'},
#    'onDownloadErrorMessageNotFound()': {'layer': 'Service Layer'},
#    'onMessageViewInfoLoadFinished(com.fsck.k9.mailstore.MessageViewInfo)': {'layer': 'Domain Layer'},
#    'setLoadingProgress(int,int)': {'layer': 'Presentation Layer'},
#    'layers': {'Service Layer': 5, 'Presentation Layer': 2, 'Domain Layer': 1}},
#   'com.fsck.k9.activity.K9ActivityCommon$K9ActivityMagic': {'setupGestureDetector(com.fsck.k9.activity.misc.SwipeGestureDetector$OnSwipeGestureListener)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 1}},
#   'com.fsck.k9.activity.MessageList$DisplayMode': {'layers': {}},
#   'com.fsck.k9.activity.UpgradeDatabases$UpgradeDatabaseBroadcastReceiver': {'onReceive(android.content.Context,android.content.Intent)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 1}},
# ...
#    'zoom(android.view.KeyEvent)': {'layer': 'Presentation Layer'},
#    'layers': {'Domain Layer': 2, 'Presentation Layer': 15}},
#   'com.fsck.k9.ui.messageview.CryptoInfoDialog': {'onCreateDialog(android.os.Bundle)': {'layer': 'Presentation Layer'},
#    'newInstance(com.fsck.k9.view.MessageCryptoDisplayStatus,boolean)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 2}},
#   'com.fsck.k9.ui.messageview.AttachmentView': {'enableButtons()': {'layer': 'Presentation Layer'},
#    'setAttachment(com.fsck.k9.mailstore.AttachmentViewInfo)': {'layer': 'Domain Layer'},
#    'disableButtons()': {'layer': 'Presentation Layer'},
#    'setCallback(com.fsck.k9.ui.messageview.AttachmentViewCallback)': {'layer': 'Presentation Layer'},
#    'onLongClick(android.view.View)': {'layer': 'Presentation Layer'},
#    'onClick(android.view.View)': {'layer': 'Presentation Layer'},
#    'refreshThumbnail()': {'layer': 'Presentation Layer'},
#    'getAttachment()': {'layer': 'Domain Layer'},
#    'layers': {'Presentation Layer': 6, 'Domain Layer': 2}},
#   'com.fsck.k9.ui.messageview.AttachmentController$SaveAttachmentAsyncTask': {'layers': {}},
#   'com.fsck.k9.ui.messageview.MessageCryptoPresenter': {'onActivityResult(int,int,android.content.Intent)': {'layer': 'Presentation Layer'},
#    'onCryptoClick()': {'layer': 'Presentation Layer'},
#    'onSaveInstanceState(android.os.Bundle)': {'layer': 'Presentation Layer'},
#    'maybeHandleShowMessage(com.fsck.k9.ui.messageview.MessageTopView,com.fsck.k9.Account,com.fsck.k9.mailstore.MessageViewInfo)': {'layer': 'Presentation Layer'},
#    'onResume()': {'layer': 'Presentation Layer'},
#    'getDecryptionResultForReply()': {'layer': 'Domain Layer'},
#    'onClickShowMessageOverrideWarning()': {'layer': 'Presentation Layer'},
#    'onClickShowCryptoKey()': {'layer': 'Presentation Layer'},
#    'onClickRetryCryptoOperation()': {'layer': 'Presentation Layer'},
#    'onClickConfigureProvider()': {'layer': 'Presentation Layer'},
#    'onClickShowCryptoWarningDetails()': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 10, 'Domain Layer': 1}}},
#  'com.fsck.k9.view': {'com.fsck.k9.view.MessageHeader$OnLayoutChangedListener': {'onLayoutChanged()': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 1}},
#   'com.fsck.k9.view.RecipientSelectView$RecipientCryptoStatus': {'layers': {}},
#   'com.fsck.k9.view.MessageHeader$HeaderEntry': {'layers': {}},
#   'com.fsck.k9.view.RecipientSelectView$RecipientTokenSpan': {'layers': {}},
#   'com.fsck.k9.view.HighlightDialogFragment': {'onDismiss(android.content.DialogInterface)': {'layer': 'Presentation Layer'},
#    'onStart()': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 2}},
#   'com.fsck.k9.view.RecipientSelectView$RecipientTokenViewHolder': {'layers': {}},
#   'com.fsck.k9.view.CryptoModeSelector$CryptoStatusSelectedListener': {'onCryptoStatusSelected(com.fsck.k9.view.CryptoModeSelector$CryptoModeSelectorState)': {'layer': 'Service Layer'},
#    'layers': {'Service Layer': 1}},
#   'com.fsck.k9.view.ViewSwitcher': {'setFirstInAnimation(android.view.animation.Animation)': {'layer': 'Presentation Layer'},
#    'onAnimationStart(android.view.animation.Animation)': {'layer': 'Presentation Layer'},
#    'setSecondOutAnimation(android.view.animation.Animation)': {'layer': 'Presentation Layer'},
#    'getSecondInAnimation()': {'layer': 'Presentation Layer'},
#    'showSecondView()': {'layer': 'Presentation Layer'},
#    'setOnSwitchCompleteListener(com.fsck.k9.view.ViewSwitcher$OnSwitchCompleteListener)': {'layer': 'Presentation Layer'},
#    'showFirstView()': {'layer': 'Presentation Layer'},
#    'getFirstInAnimation()': {'layer': 'Presentation Layer'},
#    'getmFirstOutAnimation()': {'layer': 'Presentation Layer'},
#    'setFirstOutAnimation(android.view.animation.Animation)': {'layer': 'Presentation Layer'},
#    'getSecondOutAnimation()': {'layer': 'Presentation Layer'},
#    'setSecondInAnimation(android.view.animation.Animation)': {'layer': 'Presentation Layer'},
#    'onAnimationEnd(android.view.animation.Animation)': {'layer': 'Presentation Layer'},
#    'onAnimationRepeat(android.view.animation.Animation)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 14}},
#   'com.fsck.k9.view.NonLockingScrollView': {'onInterceptTouchEvent(android.view.MotionEvent)': {'layer': 'Presentation Layer'},
#    'requestChildFocus(android.view.View,android.view.View)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 2}},
#   'com.fsck.k9.view.MessageCryptoDisplayStatus': {'isUnencryptedSigned()': {'layer': 'Domain Layer'},
#    'fromResultAnnotation(com.fsck.k9.mailstore.CryptoResultAnnotation)': {'layer': 'Service Layer'},
#    'hasAssociatedKey()': {'layer': 'Domain Layer'},
#    'layers': {'Domain Layer': 2, 'Service Layer': 1}},
#   'com.fsck.k9.view.MessageWebView': {'emulateShiftHeld()': {'layer': 'Presentation Layer'},
#    'displayHtmlContentWithInlineAttachments(java.lang.String,com.fsck.k9.mailstore.AttachmentResolver,com.fsck.k9.view.MessageWebView$OnPageFinishedListener)': {'layer': 'Service Layer'},
#    'blockNetworkData(boolean)': {'layer': 'Data Source Layer'},
#    'configure()': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 2,
#     'Service Layer': 1,
#     'Data Source Layer': 1}},
#   'com.fsck.k9.view.MessageHeader': {'setCryptoStatus(com.fsck.k9.view.MessageCryptoDisplayStatus)': {'layer': 'Presentation Layer'},
#    'onShowAdditionalHeaders()': {'layer': 'Presentation Layer'},
#    'populate(com.fsck.k9.mail.Message,com.fsck.k9.Account)': {'layer': 'Presentation Layer'},
#    'setOnCryptoClickListener(com.fsck.k9.ui.messageview.OnCryptoClickListener)': {'layer': 'Presentation Layer'},
#    'onSaveInstanceState()': {'layer': 'Presentation Layer'},
#    'showSubjectLine()': {'layer': 'Presentation Layer'},
#    'additionalHeadersVisible()': {'layer': 'Presentation Layer'},
#    'onClick(android.view.View)': {'layer': 'Presentation Layer'},
#    'onLongClick(android.view.View)': {'layer': 'Presentation Layer'},
#    'hideCryptoStatus()': {'layer': 'Presentation Layer'},
#    'setOnFlagListener(android.view.View.OnClickListener)': {'layer': 'Presentation Layer'},
#    'createMessage(int)': {'layer': 'Presentation Layer'},
#    'setOnLayoutChangedListener(com.fsck.k9.view.MessageHeader$OnLayoutChangedListener)': {'layer': 'Presentation Layer'},
#    'shouldShowSender(com.fsck.k9.mail.Message)': {'layer': 'Domain Layer'},
#    'onRestoreInstanceState(android.os.Parcelable)': {'layer': 'Presentation Layer'},
#    'setCryptoStatusDisabled()': {'layer': 'Presentation Layer'},
#    'setCryptoStatusLoading()': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 16, 'Domain Layer': 1}},
#   'com.fsck.k9.view.ClientCertificateSpinner': {'setAlias(java.lang.String)': {'layer': 'Domain Layer'},
#    'getAlias()': {'layer': 'Presentation Layer'},
#    'chooseCertificate()': {'layer': 'Service Layer'},
#    'setOnClientCertificateChangedListener(com.fsck.k9.view.ClientCertificateSpinner$OnClientCertificateChangedListener)': {'layer': 'Presentation Layer'},
#    'layers': {'Domain Layer': 1, 'Presentation Layer': 2, 'Service Layer': 1}},
#   'com.fsck.k9.view.CryptoModeSelector$CryptoModeSelectorState': {'layers': {}},
#   'com.fsck.k9.view.K9WebViewClient': {'newInstance(com.fsck.k9.mailstore.AttachmentResolver)': {'layer': 'Data Source Layer'},
#    'onPageFinished(android.webkit.WebView,java.lang.String)': {'layer': 'Presentation Layer'},
#    'setOnPageFinishedListener(com.fsck.k9.view.MessageWebView$OnPageFinishedListener)': {'layer': 'Presentation Layer'},
#    'shouldOverrideUrlLoading(android.webkit.WebView,java.lang.String)': {'layer': 'Presentation Layer'},
#    'layers': {'Data Source Layer': 1, 'Presentation Layer': 3}},
#   'com.fsck.k9.view.MessageWebView$OnPageFinishedListener': {'onPageFinished()': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 1}},
#   'com.fsck.k9.view.ClientCertificateSpinner$OnClientCertificateChangedListener': {'onClientCertificateChanged(java.lang.String)': {'layer': 'Domain Layer'},
#    'layers': {'Domain Layer': 1}},
#   'com.fsck.k9.view.MessageTitleView': {'showSubjectInMessageHeader()': {'layer': 'Presentation Layer'},
#    'setMessageHeader(com.fsck.k9.view.MessageHeader)': {'layer': 'Domain Layer'},
#    'onDraw(android.graphics.Canvas)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 2, 'Domain Layer': 1}},
#   'com.fsck.k9.view.K9WebViewClient$LollipopWebViewClient': {'shouldInterceptRequest(android.webkit.WebView,android.webkit.WebResourceRequest)': {'layer': 'Data Source Layer'},
#    'layers': {'Data Source Layer': 1}},
#   'com.fsck.k9.view.K9WebViewClient$PreLollipopWebViewClient': {'shouldInterceptRequest(android.webkit.WebView,java.lang.String)': {'layer': 'Data Source Layer'},
#    'layers': {'Data Source Layer': 1}},
#   'com.fsck.k9.view.RecipientSelectView$Recipient': {'equals(java.lang.Object)': {'layer': 'Domain Layer'},
#    'getDisplayNameOrUnknown(android.content.Context)': {'layer': 'Domain Layer'},
#    'setCryptoStatus(com.fsck.k9.view.RecipientSelectView$RecipientCryptoStatus)': {'layer': 'Presentation Layer'},
#    'getContactLookupUri()': {'layer': 'Data Source Layer'},
#    'isValidEmailAddress()': {'layer': 'Domain Layer'},
#    'getDisplayNameOrAddress()': {'layer': 'Domain Layer'},
#    'getCryptoStatus()': {'layer': 'Domain Layer'},
#    'getNameOrUnknown(android.content.Context)': {'layer': 'Domain Layer'},
#    'layers': {'Domain Layer': 6,
#     'Presentation Layer': 1,
#     'Data Source Layer': 1}},
#   'com.fsck.k9.view.FoldableLinearLayout': {'addView(android.view.View)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 1}},
#   'com.fsck.k9.view.RecipientSelectView$TokenListener': {'onTokenChanged(java.lang.Object)': {'layer': 'Domain Layer'},
#    'layers': {'Domain Layer': 1}},
#   'com.fsck.k9.view.ToolableViewAnimator': {'setDisplayedChildId(int)': {'layer': 'Presentation Layer'},
#    'setDisplayedChild(int,boolean)': {'layer': 'Presentation Layer'},
#    'setDisplayedChild(int)': {'layer': 'Presentation Layer'},
#    'addView(android.view.View,int,android.view.ViewGroup$LayoutParams)': {'layer': 'Presentation Layer'},
#    'getDisplayedChildId()': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 5}},
#   'com.fsck.k9.view.ViewSwitcher$OnSwitchCompleteListener': {'onSwitchComplete(int)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 1}},
#   'com.fsck.k9.view.NonLockingScrollView$HierarchyTreeChangeListener': {'onChildViewRemoved(android.view.View,android.view.View)': {'layer': 'Presentation Layer'},
#    'onChildViewAdded(android.view.View,android.view.View)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 2}},
#   'com.fsck.k9.view.RigidWebView': {'layers': {}},
#   'com.fsck.k9.view.MessageCryptoStatusView': {'setCryptoDisplayStatus(com.fsck.k9.view.MessageCryptoDisplayStatus)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 1}},
#   'com.fsck.k9.view.FoldableLinearLayout$SavedState': {'writeToParcel(android.os.Parcel,int)': {'layer': 'Domain Layer'},
#    'layers': {'Domain Layer': 1}},
#   'com.fsck.k9.view.LinearViewAnimator': {'setUpInAnimation(android.view.animation.Animation)': {'layer': 'Presentation Layer'},
#    'setUpOutAnimation(android.content.Context,int)': {'layer': 'Presentation Layer'},
#    'setDownInAnimation(android.view.animation.Animation)': {'layer': 'Presentation Layer'},
#    'setUpInAnimation(android.content.Context,int)': {'layer': 'Presentation Layer'},
#    'setDownOutAnimation(android.content.Context,int)': {'layer': 'Presentation Layer'},
#    'setUpOutAnimation(android.view.animation.Animation)': {'layer': 'Presentation Layer'},
#    'setDownOutAnimation(android.view.animation.Animation)': {'layer': 'Presentation Layer'},
#    'setDownInAnimation(android.content.Context,int)': {'layer': 'Presentation Layer'},
#    'setDisplayedChild(int)': {'layer': 'Presentation Layer'},
#    'setDisplayedChild(int,boolean)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 10}},
#   'com.fsck.k9.view.MessageHeader$SavedState': {'writeToParcel(android.os.Parcel,int)': {'layer': 'Data Source Layer'},
#    'layers': {'Data Source Layer': 1}},
#   'com.fsck.k9.view.ThemeUtils': {'getStyledColor(android.content.res.Resources.Theme,int)': {'layer': 'Presentation Layer'},
#    'getStyledColor(android.content.Context,int)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 2}},
#   'com.fsck.k9.view.RecipientSelectView': {'onLoaderReset(android.content.Loader)': {'layer': 'Presentation Layer'},
#    'hasUncompletedText()': {'layer': 'Domain Layer'},
#    'onLoadFinished(android.content.Loader,java.util.List)': {'layer': 'Presentation Layer'},
#    'setCryptoProvider(java.lang.String,boolean)': {'layer': 'Domain Layer'},
#    'setLoaderManager(android.app.LoaderManager)': {'layer': 'Service Layer'},
#    'setShowCryptoEnabled(boolean)': {'layer': 'Domain Layer'},
#    'onTouchEvent(android.view.MotionEvent)': {'layer': 'Presentation Layer'},
#    'addRecipients(com.fsck.k9.view.RecipientSelectView$Recipient[])': {'layer': 'Domain Layer'},
#    'showDropDown()': {'layer': 'Presentation Layer'},
#    'onCreateLoader(int,android.os.Bundle)': {'layer': 'Presentation Layer'},
#    'postShowAlternatesPopup(java.util.List)': {'layer': 'Presentation Layer'},
#    'setTokenListener(com.fsck.k9.view.RecipientSelectView$TokenListener)': {'layer': 'Presentation Layer'},
#    'getAddresses()': {'layer': 'Service Layer'},
#    'performCompletion()': {'layer': 'Presentation Layer'},
#    'onKeyDown(int,android.view.KeyEvent)': {'layer': 'Presentation Layer'},
#    'isEmpty()': {'layer': 'Domain Layer'},
#    'onFocusChanged(boolean,int,android.graphics.Rect)': {'layer': 'Presentation Layer'},
#    'onRecipientRemove(com.fsck.k9.view.RecipientSelectView$Recipient)': {'layer': 'Presentation Layer'},
#    'showAlternatesPopup(java.util.List)': {'layer': 'Presentation Layer'},
#    'onRecipientChange(com.fsck.k9.view.RecipientSelectView$Recipient,com.fsck.k9.view.RecipientSelectView$Recipient)': {'layer': 'Presentation Layer'},
#    'tryPerformCompletion()': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 14,
#     'Domain Layer': 5,
#     'Service Layer': 2}},
#   'com.fsck.k9.view.CryptoModeSelector': {'setCryptoStatusListener(com.fsck.k9.view.CryptoModeSelector$CryptoStatusSelectedListener)': {'layer': 'Presentation Layer'},
#    'setCryptoStatus(com.fsck.k9.view.CryptoModeSelector$CryptoModeSelectorState)': {'layer': 'Domain Layer'},
#    'layers': {'Presentation Layer': 1, 'Domain Layer': 1}},
#   'com.fsck.k9.view.ColorChip': {'drawable()': {'layer': 'Domain Layer'},
#    'layers': {'Domain Layer': 1}}},
#  'com.fsck.k9.widget.list': {'com.fsck.k9.widget.list.MessageListWidgetProvider': {'onReceive(android.content.Context,android.content.Intent)': {'layer': 'Service Layer'},
#    'onUpdate(android.content.Context,android.appwidget.AppWidgetManager,int[])': {'layer': 'Presentation Layer'},
#    'triggerMessageListWidgetUpdate(android.content.Context)': {'layer': 'Service Layer'},
#    'layers': {'Service Layer': 2, 'Presentation Layer': 1}},
#   'com.fsck.k9.widget.list.MessageListWidgetService': {'onGetViewFactory(android.content.Intent)': {'layer': 'Service Layer'},
#    'layers': {'Service Layer': 1}},
#   'com.fsck.k9.widget.list.MessageListRemoteViewFactory$MailItem': {'layers': {}},
#   'com.fsck.k9.widget.list.MessageListRemoteViewFactory': {'getLoadingView()': {'layer': 'Presentation Layer'},
#    'getItemId(int)': {'layer': 'Data Source Layer'},
#    'getCount()': {'layer': 'Domain Layer'},
#    'onDestroy()': {'layer': 'Presentation Layer'},
#    'hasStableIds()': {'layer': 'Presentation Layer'},
#    'onCreate()': {'layer': 'Presentation Layer'},
#    'getViewTypeCount()': {'layer': 'Presentation Layer'},
#    'onDataSetChanged()': {'layer': 'Presentation Layer'},
#    'getViewAt(int)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 7,
#     'Data Source Layer': 1,
#     'Domain Layer': 1}}}}

# %%
def sum_layer_counts(input_dicts):
    layer_count = {}

    for class_name, details in input_dicts.items():
        layers = details.get("layers", {})
        for layer, count in layers.items():
            if layer in layer_count:
                layer_count[layer] += count
            else:
                layer_count[layer] = count

    return layer_count

# %%
for package in results:
	results[package]['layers'] = sum_layer_counts(results[package])

results
# Out:
# {'com.fsck.k9': {'com.fsck.k9.Throttle$MyTimerTask': {'run()': {'layer': 'Service Layer'},
#    'cancel()': {'layer': 'Presentation Layer'},
#    'layers': {'Service Layer': 1, 'Presentation Layer': 1}},
#   'com.fsck.k9.PRNGFixes$LinuxPRNGSecureRandomProvider': {'layers': {}},
#   'com.fsck.k9.Throttle': {'cancelScheduledCallback()': {'layer': 'Execution Layer'},
#    'onEvent()': {'layer': 'Service Layer'},
#    'layers': {'Execution Layer': 1, 'Service Layer': 1}},
#   'com.fsck.k9.K9$SplitViewMode': {'layers': {}},
#   'com.fsck.k9.PRNGFixes': {'apply()': {'layer': 'Utility Layer'},
#    'layers': {'Utility Layer': 1}},
#   'com.fsck.k9.K9$Intents$EmailReceived': {'layers': {}},
#   'com.fsck.k9.BaseAccount': {'setEmail(java.lang.String)': {'layer': 'Domain Layer'},
#    'getEmail()': {'layer': 'Domain Layer'},
#    'getUuid()': {'layer': 'Domain Layer'},
#    'getDescription()': {'layer': 'Domain Layer'},
#    'setDescription(java.lang.String)': {'layer': 'Domain Layer'},
#    'layers': {'Domain Layer': 5}},
#   'com.fsck.k9.AccountStats': {'layers': {}},
#   'com.fsck.k9.K9$Intents$Share': {'layers': {}},
#   'com.fsck.k9.Account$ShowPictures': {'layers': {}},
#   'com.fsck.k9.Throttle$MyTimerTask$HandlerRunnable': {'run()': {'layer': 'Service Layer'},
#    'layers': {'Service Layer': 1}},
#   'com.fsck.k9.K9$NotificationQuickDelete': {'layers': {}},
#   'com.fsck.k9.Account$QuoteStyle': {'layers': {}},
#   'com.fsck.k9.Account$Expunge': {'layers': {}},
#   'com.fsck.k9.K9': {'messageListSenderAboveSubject()': {'layer': 'Presentation Layer'},
#    'setDebug(boolean)': {'layer': 'Service Layer'},
#    'setContactNameColor(int)': {'layer': 'Domain Layer'},
#    'setConfirmDeleteStarred(boolean)': {'layer': 'Service Layer'},
#    'setBackgroundOps(com.fsck.k9.K9$BACKGROUND_OPS)': {'layer': 'Service Layer'},
#    'setNotificationDuringQuietTimeEnabled(boolean)': {'layer': 'Service Layer'},
#    'getSplitViewMode()': {'layer': 'Data Source Layer'},
#    'setAnimations(boolean)': {'layer': 'Presentation Layer'},
#    'setDatabasesUpToDate(boolean)': {'layer': 'Data Source Layer'},
#    'setGesturesEnabled(boolean)': {'layer': 'Service Layer'},
#    'useBackgroundAsUnreadIndicator()': {'layer': 'Service Layer'},
#    'isColorizeMissingContactPictures()': {'layer': 'Domain Layer'},
#    'setMessageViewReturnToList(boolean)': {'layer': 'Domain Layer'},
#    'getOpenPgpSupportSignOnly()': {'layer': 'Domain Layer'},
#    'setPgpInlineDialogCounter(int)': {'layer': 'Domain Layer'},
#    'registerApplicationAware(com.fsck.k9.K9$ApplicationAware)': {'layer': 'Service Layer'},
#    'setNotificationQuickDeleteBehaviour(com.fsck.k9.K9$NotificationQuickDelete)': {'layer': 'Domain Layer'},
#    'setHideUserAgent(boolean)': {'layer': 'Domain Layer'},
#    'setMessageViewArchiveActionVisible(boolean)': {'layer': 'Presentation Layer'},
#    'setLockScreenNotificationVisibility(com.fsck.k9.K9$LockScreenNotificationVisibility)': {'layer': 'Service Layer'},
#    'setMessageListPreviewLines(int)': {'layer': 'Presentation Layer'},
#    'setQuietTimeStarts(java.lang.String)': {'layer': 'Service Layer'},
#    'messageViewShowNext()': {'layer': 'Service Layer'},
#    'setHideTimeZone(boolean)': {'layer': 'Domain Layer'},
#    'isMessageViewCopyActionVisible()': {'layer': 'Service Layer'},
#    'showCorrespondentNames()': {'layer': 'Presentation Layer'},
#    'getPgpSignOnlyDialogCounter()': {'layer': 'Utility Layer'},
#    'save(com.fsck.k9.preferences.StorageEditor)': {'layer': 'Data Source Layer'},
#    'getQuietTimeEnabled()': {'layer': 'Service Layer'},
#    'setSplitViewMode(com.fsck.k9.K9$SplitViewMode)': {'layer': 'Presentation Layer'},
#    'getSortType()': {'layer': 'Domain Layer'},
#    'setMessageViewFixedWidthFont(boolean)': {'layer': 'Presentation Layer'},
#    'setQuietTimeEnabled(boolean)': {'layer': 'Domain Layer'},
#    'getK9ThemeResourceId(com.fsck.k9.K9$Theme)': {'layer': 'Utility Layer'},
#    'getK9ThemeResourceId()': {'layer': 'Utility Layer'},
#    'setMessageViewCopyActionVisible(boolean)': {'layer': 'Presentation Layer'},
#    'getK9Language()': {'layer': 'Data Source Layer'},
#    'getK9MessageViewTheme()': {'layer': 'Domain Layer'},
#    'showContactName()': {'layer': 'Presentation Layer'},
#    'gesturesEnabled()': {'layer': 'Service Layer'},
#    'setShowContactName(boolean)': {'layer': 'Presentation Layer'},
#    'wrapFolderNames()': {'layer': 'Presentation Layer'},
#    'setMessageListSenderAboveSubject(boolean)': {'layer': 'Presentation Layer'},
#    'getLockScreenNotificationVisibility()': {'layer': 'Domain Layer'},
#    'getFontSizes()': {'layer': 'Domain Layer'},
#    'isNotificationDuringQuietTimeEnabled()': {'layer': 'Domain Layer'},
#    'measureAccounts()': {'layer': 'Service Layer'},
#    'useFixedMessageViewTheme()': {'layer': 'Presentation Layer'},
#    'setSortAscending(com.fsck.k9.Account$SortType,boolean)': {'layer': 'Service Layer'},
#    'getBackgroundOps()': {'layer': 'Service Layer'},
#    'setColorizeMissingContactPictures(boolean)': {'layer': 'Service Layer'},
#    'confirmSpam()': {'layer': 'Service Layer'},
#    'areDatabasesUpToDate()': {'layer': 'Data Source Layer'},
#    'isThreadedViewEnabled()': {'layer': 'Domain Layer'},
#    'setWrapFolderNames(boolean)': {'layer': 'Presentation Layer'},
#    'getK9ComposerTheme()': {'layer': 'Service Layer'},
#    'setMessageListCheckboxes(boolean)': {'layer': 'Presentation Layer'},
#    'onCreate()': {'layer': 'Service Layer'},
#    'getQuietTimeStarts()': {'layer': 'Data Source Layer'},
#    'showContactPicture()': {'layer': 'Presentation Layer'},
#    'messageListCheckboxes()': {'layer': 'Presentation Layer'},
#    'setAutofitWidth(boolean)': {'layer': 'Presentation Layer'},
#    'getQuietTimeEnds()': {'layer': 'Domain Layer'},
#    'setMessageViewShowNext(boolean)': {'layer': 'Domain Layer'},
#    'setChangeContactNameColor(boolean)': {'layer': 'Presentation Layer'},
#    'setConfirmDeleteFromNotification(boolean)': {'layer': 'Presentation Layer'},
#    'confirmDeleteStarred()': {'layer': 'Domain Layer'},
#    'setNotificationHideSubject(com.fsck.k9.K9$NotificationHideSubject)': {'layer': 'Service Layer'},
#    'setUseFixedMessageViewTheme(boolean)': {'layer': 'Presentation Layer'},
#    'autofitWidth()': {'layer': 'Presentation Layer'},
#    'hideUserAgent()': {'layer': 'None'},
#    'setMessageViewDeleteActionVisible(boolean)': {'layer': 'Presentation Layer'},
#    'checkCachedDatabaseVersion()': {'layer': 'Data Source Layer'},
#    'isHideSpecialAccounts()': {'layer': 'Service Layer'},
#    'setConfirmMarkAllRead(boolean)': {'layer': 'Service Layer'},
#    'confirmDelete()': {'layer': 'Presentation Layer'},
#    'isMessageViewArchiveActionVisible()': {'layer': 'Domain Layer'},
#    'getContactNameColor()': {'layer': 'Presentation Layer'},
#    'getK9Theme()': {'layer': 'Domain Layer'},
#    'setStartIntegratedInbox(boolean)': {'layer': 'Presentation Layer'},
#    'countSearchMessages()': {'layer': 'Domain Layer'},
#    'setMessageViewMoveActionVisible(boolean)': {'layer': 'Presentation Layer'},
#    'isDebug()': {'layer': 'Utility Layer'},
#    'getNotificationHideSubject()': {'layer': 'Domain Layer'},
#    'setQuietTimeEnds(java.lang.String)': {'layer': 'Domain Layer'},
#    'getPgpInlineDialogCounter()': {'layer': 'Domain Layer'},
#    'setBackgroundOps(java.lang.String)': {'layer': 'Service Layer'},
#    'setConfirmSpam(boolean)': {'layer': 'Service Layer'},
#    'setServicesEnabled(android.content.Context)': {'layer': 'Service Layer'},
#    'setHideSpecialAccounts(boolean)': {'layer': 'Domain Layer'},
#    'isSortAscending(com.fsck.k9.Account$SortType)': {'layer': 'Domain Layer'},
#    'loadPrefs(com.fsck.k9.Preferences)': {'layer': 'Data Source Layer'},
#    'setMessageListStars(boolean)': {'layer': 'Presentation Layer'},
#    'setOpenPgpSupportSignOnly(boolean)': {'layer': 'Service Layer'},
#    'getNotificationQuickDeleteBehaviour()': {'layer': 'Domain Layer'},
#    'showAnimations()': {'layer': 'Service Layer'},
#    'setUseVolumeKeysForListNavigation(boolean)': {'layer': 'Presentation Layer'},
#    'getK9MessageViewThemeSetting()': {'layer': 'Presentation Layer'},
#    'setAttachmentDefaultPath(java.lang.String)': {'layer': 'Domain Layer'},
#    'setPgpSignOnlyDialogCounter(int)': {'layer': 'Domain Layer'},
#    'setThreadedViewEnabled(boolean)': {'layer': 'Domain Layer'},
#    'isMessageViewMoveActionVisible()': {'layer': 'Service Layer'},
#    'confirmDiscardMessage()': {'layer': 'Service Layer'},
#    'setOpenPgpProvider(java.lang.String)': {'layer': 'Domain Layer'},
#    'isMessageViewSpamActionVisible()': {'layer': 'Presentation Layer'},
#    'useVolumeKeysForNavigationEnabled()': {'layer': 'Service Layer'},
#    'isOpenPgpProviderConfigured()': {'layer': 'Service Layer'},
#    'useVolumeKeysForListNavigationEnabled()': {'layer': 'Presentation Layer'},
#    'setK9MessageViewThemeSetting(com.fsck.k9.K9$Theme)': {'layer': 'Presentation Layer'},
#    'messageListPreviewLines()': {'layer': 'Presentation Layer'},
#    'setShowContactPicture(boolean)': {'layer': 'Service Layer'},
#    'setMessageViewSpamActionVisible(boolean)': {'layer': 'Presentation Layer'},
#    'getOpenPgpProvider()': {'layer': 'Service Layer'},
#    'setMeasureAccounts(boolean)': {'layer': 'Service Layer'},
#    'confirmDeleteFromNotification()': {'layer': 'Service Layer'},
#    'setConfirmDelete(boolean)': {'layer': 'Service Layer'},
#    'messageViewFixedWidthFont()': {'layer': 'Presentation Layer'},
#    'isMessageViewDeleteActionVisible()': {'layer': 'Domain Layer'},
#    'messageListStars()': {'layer': 'Service Layer'},
#    'changeContactNameColor()': {'layer': 'None'},
#    'startIntegratedInbox()': {'layer': 'Service Layer'},
#    'setSortType(com.fsck.k9.Account$SortType)': {'layer': 'Domain Layer'},
#    'setK9ComposerThemeSetting(com.fsck.k9.K9$Theme)': {'layer': 'Presentation Layer'},
#    'hideTimeZone()': {'layer': 'Utility Layer'},
#    'getK9ComposerThemeSetting()': {'layer': 'Data Source Layer'},
#    'setConfirmDiscardMessage(boolean)': {'layer': 'Presentation Layer'},
#    'getAttachmentDefaultPath()': {'layer': 'Data Source Layer'},
#    'saveSettingsAsync()': {'layer': 'Service Layer'},
#    'setCountSearchMessages(boolean)': {'layer': 'Service Layer'},
#    'isQuietTime()': {'layer': 'Domain Layer'},
#    'setK9Language(java.lang.String)': {'layer': 'Domain Layer'},
#    'setUseBackgroundAsUnreadIndicator(boolean)': {'layer': 'Service Layer'},
#    'setUseVolumeKeysForNavigation(boolean)': {'layer': 'Service Layer'},
#    'setShowCorrespondentNames(boolean)': {'layer': 'Presentation Layer'},
#    'setK9Theme(com.fsck.k9.K9$Theme)': {'layer': 'Presentation Layer'},
#    'messageViewReturnToList()': {'layer': 'Service Layer'},
#    'confirmMarkAllRead()': {'layer': 'Service Layer'},
#    'layers': {'Presentation Layer': 40,
#     'Service Layer': 45,
#     'Domain Layer': 35,
#     'Data Source Layer': 10,
#     'Utility Layer': 5,
#     'None': 2}},
#   'com.fsck.k9.EmailAddressValidator': {'fixText(java.lang.CharSequence)': {'layer': 'Domain Layer'},
#    'isValid(java.lang.CharSequence)': {'layer': 'Domain Layer'},
#    'isValidAddressOnly(java.lang.CharSequence)': {'layer': 'Domain Layer'},
#    'layers': {'Domain Layer': 3}},
#   'com.fsck.k9.Account$SortType': {'isDefaultAscending()': {'layer': 'Domain Layer'},
#    'getToast(boolean)': {'layer': 'Presentation Layer'},
#    'layers': {'Domain Layer': 1, 'Presentation Layer': 1}},
#   'com.fsck.k9.Globals': {'getContext()': {'layer': 'Utility Layer'},
#    'layers': {'Utility Layer': 1}},
#   'com.fsck.k9.FontSizes': {'getMessageViewContentAsPercent()': {'layer': 'Presentation Layer'},
#    'getMessageViewDate()': {'layer': 'Domain Layer'},
#    'getFolderStatus()': {'layer': 'Domain Layer'},
#    'setMessageViewContentAsPercent(int)': {'layer': 'Presentation Layer'},
#    'getMessageViewBCC()': {'layer': 'Domain Layer'},
#    'setMessageViewSubject(int)': {'layer': 'Domain Layer'},
#    'setMessageListPreview(int)': {'layer': 'Domain Layer'},
#    'getMessageViewAdditionalHeaders()': {'layer': 'Domain Layer'},
#    'getMessageListDate()': {'layer': 'Domain Layer'},
#    'getMessageViewCC()': {'layer': 'Domain Layer'},
#    'setMessageListDate(int)': {'layer': 'Domain Layer'},
#    'setMessageViewTo(int)': {'layer': 'Domain Layer'},
#    'getMessageComposeInput()': {'layer': 'Domain Layer'},
#    'getMessageViewSubject()': {'layer': 'Domain Layer'},
#    'setMessageListSender(int)': {'layer': 'Domain Layer'},
#    'getMessageViewSender()': {'layer': 'Domain Layer'},
#    'load(com.fsck.k9.preferences.Storage)': {'layer': 'Data Source Layer'},
#    'setAccountDescription(int)': {'layer': 'Domain Layer'},
#    'setAccountName(int)': {'layer': 'Domain Layer'},
#    'setMessageViewSender(int)': {'layer': 'Domain Layer'},
#    'setMessageListSubject(int)': {'layer': 'Domain Layer'},
#    'getMessageListPreview()': {'layer': 'Presentation Layer'},
#    'getMessageListSender()': {'layer': 'Domain Layer'},
#    'setMessageViewBCC(int)': {'layer': 'Domain Layer'},
#    'setViewTextSize(android.widget.TextView,int)': {'layer': 'Presentation Layer'},
#    'setMessageViewAdditionalHeaders(int)': {'layer': 'Domain Layer'},
#    'setFolderName(int)': {'layer': 'Domain Layer'},
#    'getMessageViewTo()': {'layer': 'Domain Layer'},
#    'getAccountDescription()': {'layer': 'Domain Layer'},
#    'getMessageListSubject()': {'layer': 'Domain Layer'},
#    'setMessageComposeInput(int)': {'layer': 'Presentation Layer'},
#    'setMessageViewDate(int)': {'layer': 'Domain Layer'},
#    'save(com.fsck.k9.preferences.StorageEditor)': {'layer': 'Data Source Layer'},
#    'getAccountName()': {'layer': 'Domain Layer'},
#    'getFolderName()': {'layer': 'Domain Layer'},
#    'setMessageViewCC(int)': {'layer': 'Domain Layer'},
#    'setFolderStatus(int)': {'layer': 'Domain Layer'},
#    'layers': {'Presentation Layer': 5,
#     'Domain Layer': 30,
#     'Data Source Layer': 2}},
#   'com.fsck.k9.NotificationSetting': {'isRingEnabled()': {'layer': 'Domain Layer'},
#    'isVibrateEnabled()': {'layer': 'Domain Layer'},
#    'isLedEnabled()': {'layer': 'Domain Layer'},
#    'setLed(boolean)': {'layer': 'Domain Layer'},
#    'setVibratePattern(int)': {'layer': 'Domain Layer'},
#    'getVibrateTimes()': {'layer': 'Domain Layer'},
#    'setRingEnabled(boolean)': {'layer': 'Domain Layer'},
#    'getLedColor()': {'layer': 'Domain Layer'},
#    'getRingtone()': {'layer': 'Domain Layer'},
#    'setVibrate(boolean)': {'layer': 'Domain Layer'},
#    'getVibration(int,int)': {'layer': 'Utility Layer'},
#    'getVibration()': {'layer': 'Data Source Layer'},
#    'setVibrateTimes(int)': {'layer': 'Domain Layer'},
#    'getVibratePattern()': {'layer': 'Domain Layer'},
#    'setLedColor(int)': {'layer': 'Presentation Layer'},
#    'setRingtone(java.lang.String)': {'layer': 'Domain Layer'},
#    'layers': {'Domain Layer': 13,
#     'Utility Layer': 1,
#     'Data Source Layer': 1,
#     'Presentation Layer': 1}},
#   'com.fsck.k9.K9$NotificationHideSubject': {'layers': {}},
#   'com.fsck.k9.K9$BACKGROUND_OPS': {'layers': {}},
#   'com.fsck.k9.Preferences': {'setDefaultAccount(com.fsck.k9.Account)': {'layer': 'Data Source Layer'},
#    'getAvailableAccounts()': {'layer': 'Service Layer'},
#    'loadAccounts()': {'layer': 'Domain Layer'},
#    'getAccounts()': {'layer': 'Data Source Layer'},
#    'newAccount()': {'layer': 'Domain Layer'},
#    'getAccount(java.lang.String)': {'layer': 'Domain Layer'},
#    'getPreferences(android.content.Context)': {'layer': 'Data Source Layer'},
#    'deleteAccount(com.fsck.k9.Account)': {'layer': 'Service Layer'},
#    'getStorage()': {'layer': 'Data Source Layer'},
#    'getDefaultAccount()': {'layer': 'Domain Layer'},
#    'layers': {'Data Source Layer': 4, 'Service Layer': 2, 'Domain Layer': 4}},
#   'com.fsck.k9.Account$FolderMode': {'layers': {}},
#   'com.fsck.k9.Clock': {'getTime()': {'layer': 'Utility Layer'},
#    'layers': {'Utility Layer': 1}},
#   'com.fsck.k9.Account': {'getLocalStore()': {'layer': 'Data Source Layer'},
#    'addCertificate(com.fsck.k9.activity.setup.AccountSetupCheckSettings$CheckDirection,java.security.cert.X509Certificate)': {'layer': 'Data Source Layer'},
#    'setDisplayCount(int)': {'layer': 'Domain Layer'},
#    'isReplyAfterQuote()': {'layer': 'Domain Layer'},
#    'getIdentities()': {'layer': 'Domain Layer'},
#    'setSignatureBeforeQuotedText(boolean)': {'layer': 'Domain Layer'},
#    'setIdleRefreshMinutes(int)': {'layer': 'Domain Layer'},
#    'goToUnreadMessageSearch()': {'layer': 'Service Layer'},
#    'setSortType(com.fsck.k9.Account$SortType)': {'layer': 'Domain Layer'},
#    'setFolderTargetMode(com.fsck.k9.Account$FolderMode)': {'layer': 'Domain Layer'},
#    'getStoreUri()': {'layer': 'Domain Layer'},
#    'getMaxPushFolders()': {'layer': 'Domain Layer'},
#    'setEnabled(boolean)': {'layer': 'Domain Layer'},
#    'setExpungePolicy(com.fsck.k9.Account$Expunge)': {'layer': 'Domain Layer'},
#    'limitToDisplayableFolders(com.fsck.k9.search.LocalSearch)': {'layer': 'Service Layer'},
#    'hasDraftsFolder()': {'layer': 'Domain Layer'},
#    'setArchiveFolderName(java.lang.String)': {'layer': 'Domain Layer'},
#    'getSearchableFolders()': {'layer': 'Domain Layer'},
#    'isSortAscending(com.fsck.k9.Account$SortType)': {'layer': 'Domain Layer'},
#    'setInboxFolderName(java.lang.String)': {'layer': 'Domain Layer'},
#    'setTransportUri(java.lang.String)': {'layer': 'Domain Layer'},
#    'getFolderSyncMode()': {'layer': 'Domain Layer'},
#    'setNotifyContactsMailOnly(boolean)': {'layer': 'Domain Layer'},
#    'setSyncRemoteDeletions(boolean)': {'layer': 'Domain Layer'},
#    'setFolderPushMode(com.fsck.k9.Account$FolderMode)': {'layer': 'Service Layer'},
#    'getAlwaysBcc()': {'layer': 'Domain Layer'},
#    'setDraftsFolderName(java.lang.String)': {'layer': 'Domain Layer'},
#    'setSubscribedFoldersOnly(boolean)': {'layer': 'Domain Layer'},
#    'setMessageFormat(com.fsck.k9.Account$MessageFormat)': {'layer': 'Domain Layer'},
#    'getLastSelectedFolderName()': {'layer': 'Domain Layer'},
#    'getQuotePrefix()': {'layer': 'Domain Layer'},
#    'getStats(android.content.Context)': {'layer': 'Service Layer'},
#    'getSpamFolderName()': {'layer': 'Domain Layer'},
#    'syncRemoteDeletions()': {'layer': 'Service Layer'},
#    'save(com.fsck.k9.Preferences)': {'layer': 'Data Source Layer'},
#    'useCompression(com.fsck.k9.mail.NetworkType)': {'layer': 'Data Source Layer'},
#    'setSpamFolderName(java.lang.String)': {'layer': 'Domain Layer'},
#    'setAutomaticCheckIntervalMinutes(int)': {'layer': 'Domain Layer'},
#    'setGoToUnreadMessageSearch(boolean)': {'layer': 'Domain Layer'},
#    'setShowPictures(com.fsck.k9.Account$ShowPictures)': {'layer': 'Domain Layer'},
#    'setQuotePrefix(java.lang.String)': {'layer': 'Domain Layer'},
#    'hashCode()': {'layer': 'Domain Layer'},
#    'getRemoteSearchNumResults()': {'layer': 'Domain Layer'},
#    'setFolderDisplayMode(com.fsck.k9.Account$FolderMode)': {'layer': 'Domain Layer'},
#    'isRemoteSearchFullText()': {'layer': 'Domain Layer'},
#    'isSearchByDateCapable()': {'layer': 'Domain Layer'},
#    'getAccountNumber()': {'layer': 'Domain Layer'},
#    'isPushPollOnConnect()': {'layer': 'Domain Layer'},
#    'getOutboxFolderName()': {'layer': 'Data Source Layer'},
#    'getFolderPushMode()': {'layer': 'Domain Layer'},
#    'setSentFolderName(java.lang.String)': {'layer': 'Domain Layer'},
#    'setChipColor(int)': {'layer': 'Domain Layer'},
#    'getLatestOldMessageSeenTime()': {'layer': 'Domain Layer'},
#    'findIdentity(com.fsck.k9.mail.Address)': {'layer': 'Domain Layer'},
#    'setEmail(java.lang.String)': {'layer': 'Domain Layer'},
#    'setSortAscending(com.fsck.k9.Account$SortType,boolean)': {'layer': 'Domain Layer'},
#    'getName()': {'layer': 'Domain Layer'},
#    'generateColorChip(boolean,boolean)': {'layer': 'Domain Layer'},
#    'isAnIdentity(com.fsck.k9.mail.Address)': {'layer': 'Domain Layer'},
#    'getFolderUnreadCount(android.content.Context,java.lang.String)': {'layer': 'Data Source Layer'},
#    'getEmail()': {'layer': 'Domain Layer'},
#    'subscribedFoldersOnly()': {'layer': 'Domain Layer'},
#    'hasArchiveFolder()': {'layer': 'Domain Layer'},
#    'setFolderNotifyNewMailMode(com.fsck.k9.Account$FolderMode)': {'layer': 'Domain Layer'},
#    'setReplyAfterQuote(boolean)': {'layer': 'Domain Layer'},
#    'setLastSelectedFolderName(java.lang.String)': {'layer': 'Domain Layer'},
#    'getAutomaticCheckIntervalMinutes()': {'layer': 'Domain Layer'},
#    'getSignatureUse()': {'layer': 'Domain Layer'},
#    'setRingNotified(boolean)': {'layer': 'Domain Layer'},
#    'getMessageFormat()': {'layer': 'Domain Layer'},
#    'isNotifyNewMail()': {'layer': 'Domain Layer'},
#    'setStripSignature(boolean)': {'layer': 'Domain Layer'},
#    'setMarkMessageAsReadOnView(boolean)': {'layer': 'Domain Layer'},
#    'isDefaultQuotedTextShown()': {'layer': 'Domain Layer'},
#    'getEarliestPollDate()': {'layer': 'Service Layer'},
#    'setRemoteSearchFullText(boolean)': {'layer': 'Domain Layer'},
#    'generateAccountNumber(com.fsck.k9.Preferences)': {'layer': 'Service Layer'},
#    'setMessageReadReceipt(boolean)': {'layer': 'Domain Layer'},
#    'setCompression(com.fsck.k9.mail.NetworkType,boolean)': {'layer': 'Data Source Layer'},
#    'setDefaultQuotedTextShown(boolean)': {'layer': 'Domain Layer'},
#    'isStripSignature()': {'layer': 'Domain Layer'},
#    'setQuoteStyle(com.fsck.k9.Account$QuoteStyle)': {'layer': 'Domain Layer'},
#    'isAnIdentity(com.fsck.k9.mail.Address[])': {'layer': 'Domain Layer'},
#    'isEnabled()': {'layer': 'Domain Layer'},
#    'setSearchableFolders(com.fsck.k9.Account$Searchable)': {'layer': 'Domain Layer'},
#    'isSignatureBeforeQuotedText()': {'layer': 'Domain Layer'},
#    'isNotifyContactsMailOnly()': {'layer': 'Domain Layer'},
#    'getFolderNotifyNewMailMode()': {'layer': 'Domain Layer'},
#    'setName(java.lang.String)': {'layer': 'Domain Layer'},
#    'setIdentities(java.util.List)': {'layer': 'Domain Layer'},
#    'allowRemoteSearch()': {'layer': 'Domain Layer'},
#    'setSignatureUse(boolean)': {'layer': 'Domain Layer'},
#    'getRemoteStore()': {'layer': 'Service Layer'},
#    'hasTrashFolder()': {'layer': 'Domain Layer'},
#    'deleteCertificate(java.lang.String,int,com.fsck.k9.activity.setup.AccountSetupCheckSettings$CheckDirection)': {'layer': 'Data Source Layer'},
#    'getLocalStorageProviderId()': {'layer': 'Domain Layer'},
#    'setAutoExpandFolderName(java.lang.String)': {'layer': 'Domain Layer'},
#    'hasSpamFolder()': {'layer': 'Domain Layer'},
#    'setMaximumAutoDownloadMessageSize(int)': {'layer': 'Service Layer'},
#    'getQuoteStyle()': {'layer': 'Domain Layer'},
#    'getSignature()': {'layer': 'Domain Layer'},
#    'getInboxFolderName()': {'layer': 'Domain Layer'},
#    'setRemoteSearchNumResults(int)': {'layer': 'Domain Layer'},
#    'excludeSpecialFolders(com.fsck.k9.search.LocalSearch)': {'layer': 'Service Layer'},
#    'setPushPollOnConnect(boolean)': {'layer': 'Domain Layer'},
#    'getTrashFolderName()': {'layer': 'Domain Layer'},
#    'toString()': {'layer': 'Domain Layer'},
#    'getArchiveFolderName()': {'layer': 'Domain Layer'},
#    'getDescription()': {'layer': 'Domain Layer'},
#    'getAutoExpandFolderName()': {'layer': 'Domain Layer'},
#    'setMaximumPolledMessageAge(int)': {'layer': 'Domain Layer'},
#    'setLocalStorageProviderId(java.lang.String)': {'layer': 'Data Source Layer'},
#    'hasSentFolder()': {'layer': 'Domain Layer'},
#    'getMaximumAutoDownloadMessageSize()': {'layer': 'Domain Layer'},
#    'getSortType()': {'layer': 'Domain Layer'},
#    'setDescription(java.lang.String)': {'layer': 'Domain Layer'},
#    'getChipColor()': {'layer': 'Domain Layer'},
#    'getDeletePolicy()': {'layer': 'Domain Layer'},
#    'isMarkMessageAsReadOnView()': {'layer': 'Domain Layer'},
#    'setDeletePolicy(com.fsck.k9.Account$DeletePolicy)': {'layer': 'Domain Layer'},
#    'isRingNotified()': {'layer': 'Domain Layer'},
#    'getDisplayCount()': {'layer': 'Presentation Layer'},
#    'isAlwaysShowCcBcc()': {'layer': 'Domain Layer'},
#    'getDraftsFolderName()': {'layer': 'Domain Layer'},
#    'getExpungePolicy()': {'layer': 'Domain Layer'},
#    'getShowPictures()': {'layer': 'Domain Layer'},
#    'setCryptoKey(long)': {'layer': 'Domain Layer'},
#    'isSpecialFolder(java.lang.String)': {'layer': 'Domain Layer'},
#    'setNotifySelfNewMail(boolean)': {'layer': 'Domain Layer'},
#    'move(com.fsck.k9.Preferences,boolean)': {'layer': 'Data Source Layer'},
#    'getNotificationSetting()': {'layer': 'Domain Layer'},
#    'getSentFolderName()': {'layer': 'Domain Layer'},
#    'setNotifyNewMail(boolean)': {'layer': 'Domain Layer'},
#    'setFolderSyncMode(com.fsck.k9.Account$FolderMode)': {'layer': 'Domain Layer'},
#    'setAlwaysBcc(java.lang.String)': {'layer': 'Domain Layer'},
#    'setShowOngoing(boolean)': {'layer': 'Domain Layer'},
#    'setAlwaysShowCcBcc(boolean)': {'layer': 'Domain Layer'},
#    'getIdleRefreshMinutes()': {'layer': 'Domain Layer'},
#    'isNotifySelfNewMail()': {'layer': 'Domain Layer'},
#    'setAllowRemoteSearch(boolean)': {'layer': 'Domain Layer'},
#    'isShowOngoing()': {'layer': 'Domain Layer'},
#    'getCryptoKey()': {'layer': 'Domain Layer'},
#    'setStoreUri(java.lang.String)': {'layer': 'Domain Layer'},
#    'getFolderTargetMode()': {'layer': 'Domain Layer'},
#    'getTransportUri()': {'layer': 'Domain Layer'},
#    'setSignature(java.lang.String)': {'layer': 'Domain Layer'},
#    'getFolderDisplayMode()': {'layer': 'Domain Layer'},
#    'equals(java.lang.Object)': {'layer': 'Domain Layer'},
#    'setLatestOldMessageSeenTime(long)': {'layer': 'Domain Layer'},
#    'excludeUnwantedFolders(com.fsck.k9.search.LocalSearch)': {'layer': 'Service Layer'},
#    'getIdentity(int)': {'layer': 'Domain Layer'},
#    'getMaximumPolledMessageAge()': {'layer': 'Domain Layer'},
#    'isAvailable(android.content.Context)': {'layer': 'Service Layer'},
#    'getUuid()': {'layer': 'Domain Layer'},
#    'setTrashFolderName(java.lang.String)': {'layer': 'Domain Layer'},
#    'setMaxPushFolders(int)': {'layer': 'Domain Layer'},
#    'isMessageReadReceiptAlways()': {'layer': 'Domain Layer'},
#    'layers': {'Data Source Layer': 10,
#     'Domain Layer': 134,
#     'Service Layer': 12,
#     'Presentation Layer': 1}},
#   'com.fsck.k9.K9$Intents': {'layers': {}},
#   'com.fsck.k9.Account$MessageFormat': {'layers': {}},
#   'com.fsck.k9.K9$ApplicationAware': {'initializeComponent(android.app.Application)': {'layer': 'Service Layer'},
#    'layers': {'Service Layer': 1}},
#   'com.fsck.k9.Identity': {'getDescription()': {'layer': 'Domain Layer'},
#    'setSignature(java.lang.String)': {'layer': 'Domain Layer'},
#    'setEmail(java.lang.String)': {'layer': 'Domain Layer'},
#    'getSignatureUse()': {'layer': 'Domain Layer'},
#    'getSignature()': {'layer': 'Domain Layer'},
#    'getName()': {'layer': 'Domain Layer'},
#    'setDescription(java.lang.String)': {'layer': 'Domain Layer'},
#    'setReplyTo(java.lang.String)': {'layer': 'Domain Layer'},
#    'getReplyTo()': {'layer': 'Domain Layer'},
#    'setName(java.lang.String)': {'layer': 'Domain Layer'},
#    'toString()': {'layer': 'Domain Layer'},
#    'getEmail()': {'layer': 'Domain Layer'},
#    'setSignatureUse(boolean)': {'layer': 'Domain Layer'},
#    'layers': {'Domain Layer': 13}},
#   'com.fsck.k9.Account$Searchable': {'layers': {}},
#   'com.fsck.k9.K9$LockScreenNotificationVisibility': {'layers': {}},
#   'com.fsck.k9.PRNGFixes$LinuxPRNGSecureRandom': {'layers': {}},
#   'com.fsck.k9.K9$Theme': {'layers': {}},
#   'com.fsck.k9.Account$DeletePolicy': {'preferenceString()': {'layer': 'Domain Layer'},
#    'fromInt(int)': {'layer': 'Domain Layer'},
#    'layers': {'Domain Layer': 2}},
#   'layers': {'Service Layer': 63,
#    'Presentation Layer': 49,
#    'Execution Layer': 1,
#    'Utility Layer': 9,
#    'Domain Layer': 240,
#    'Data Source Layer': 27,
#    'None': 2}},
#  'com.fsck.k9.account': {'com.fsck.k9.account.AccountCreator': {'getDefaultDeletePolicy(com.fsck.k9.mail.ServerSettings.Type)': {'layer': 'Service Layer'},
#    'getDefaultPort(com.fsck.k9.mail.ConnectionSecurity,com.fsck.k9.mail.ServerSettings.Type)': {'layer': 'Service Layer'},
#    'layers': {'Service Layer': 2}},
#   'layers': {'Service Layer': 2}},
#  'com.fsck.k9.activity': {'com.fsck.k9.activity.FolderList$FolderListAdapter': {'getFilter()': {'layer': 'Presentation Layer'},
#    'getCount()': {'layer': 'Domain Layer'},
#    'getFolder(java.lang.String)': {'layer': 'Service Layer'},
#    'isEnabled(int)': {'layer': 'Presentation Layer'},
#    'getItemView(int,android.view.View,android.view.ViewGroup)': {'layer': 'Presentation Layer'},
#    'getView(int,android.view.View,android.view.ViewGroup)': {'layer': 'Presentation Layer'},
#    'areAllItemsEnabled()': {'layer': 'Presentation Layer'},
#    'isItemSelectable(int)': {'layer': 'Domain Layer'},
#    'getFolderIndex(java.lang.String)': {'layer': 'Data Source Layer'},
#    'setFilter(android.widget.Filter)': {'layer': 'Domain Layer'},
#    'getItem(int)': {'layer': 'Data Source Layer'},
#    'getItemId(int)': {'layer': 'Data Source Layer'},
#    'getItem(long)': {'layer': 'Data Source Layer'},
#    'hasStableIds()': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 6,
#     'Domain Layer': 3,
#     'Service Layer': 1,
#     'Data Source Layer': 4}},
#   'com.fsck.k9.activity.Accounts$AccountsHandler': {'progress(boolean)': {'layer': 'Presentation Layer'},
#    'dataChanged()': {'layer': 'Presentation Layer'},
#    'accountSizeChanged(com.fsck.k9.Account,long,long)': {'layer': 'Presentation Layer'},
#    'refreshTitle()': {'layer': 'Presentation Layer'},
#    'progress(int)': {'layer': 'Presentation Layer'},
#    'workingAccount(com.fsck.k9.Account,int)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 6}},
#   'com.fsck.k9.activity.MessageCompose': {'showContactPicker(int)': {'layer': 'Presentation Layer'},
#    'onOptionsItemSelected(android.view.MenuItem)': {'layer': 'Presentation Layer'},
#    'onRecipientsChanged()': {'layer': 'Domain Layer'},
#    'onMessageBuildCancel()': {'layer': 'Presentation Layer'},
#    'saveDraftEventually()': {'layer': 'Domain Layer'},
#    'onClick(android.view.View)': {'layer': 'Presentation Layer'},
#    'onPrepareOptionsMenu(android.view.Menu)': {'layer': 'Presentation Layer'},
#    'onAttachmentRemoved()': {'layer': 'Domain Layer'},
#    'onCreate(android.os.Bundle)': {'layer': 'Presentation Layer'},
#    'onProgressCancel(com.fsck.k9.fragment.ProgressDialogFragment)': {'layer': 'Presentation Layer'},
#    'onOpenPgpClickDisable()': {'layer': 'Service Layer'},
#    'performSendAfterChecks()': {'layer': 'Service Layer'},
#    'onAttachmentAdded()': {'layer': 'Domain Layer'},
#    'onRetainNonConfigurationInstance()': {'layer': 'Presentation Layer'},
#    'loadLocalMessageForDisplay(com.fsck.k9.mailstore.MessageViewInfo,com.fsck.k9.activity.MessageCompose$Action)': {'layer': 'Service Layer'},
#    'onFocusChange(android.view.View,boolean)': {'layer': 'Presentation Layer'},
#    'updateMessageFormat()': {'layer': 'Domain Layer'},
#    'onCreateOptionsMenu(android.view.Menu)': {'layer': 'Presentation Layer'},
#    'onOpenPgpSignOnlyChange(boolean)': {'layer': 'Presentation Layer'},
#    'onMessageBuildSuccess(com.fsck.k9.mail.internet.MimeMessage,boolean)': {'layer': 'Service Layer'},
#    'onDestroy()': {'layer': 'Presentation Layer'},
#    'launchUserInteractionPendingIntent(android.app.PendingIntent,int)': {'layer': 'Presentation Layer'},
#    'onCreateDialog(int)': {'layer': 'Presentation Layer'},
#    'onPause()': {'layer': 'Presentation Layer'},
#    'onMessageBuildException(com.fsck.k9.mail.MessagingException)': {'layer': 'Presentation Layer'},
#    'onBackPressed()': {'layer': 'Presentation Layer'},
#    'loadQuotedTextForEdit()': {'layer': 'Domain Layer'},
#    'onProgressCancel(com.fsck.k9.fragment.AttachmentDownloadDialogFragment)': {'layer': 'Presentation Layer'},
#    'onMessageBuildReturnPendingIntent(android.app.PendingIntent,int)': {'layer': 'Presentation Layer'},
#    'onOpenPgpInlineChange(boolean)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 20,
#     'Domain Layer': 6,
#     'Service Layer': 4}},
#   'com.fsck.k9.activity.Accounts$ExportAsyncTask': {'layers': {}},
#   'com.fsck.k9.activity.MessageInfoHolder': {'equals(java.lang.Object)': {'layer': 'Domain Layer'},
#    'hashCode()': {'layer': 'Domain Layer'},
#    'layers': {'Domain Layer': 2}},
#   'com.fsck.k9.activity.Search': {'onStop()': {'layer': 'Presentation Layer'},
#    'onStart()': {'layer': 'Presentation Layer'},
#    'isActive()': {'layer': 'Presentation Layer'},
#    'setActive(boolean)': {'layer': 'Service Layer'},
#    'layers': {'Presentation Layer': 3, 'Service Layer': 1}},
#   'com.fsck.k9.activity.Accounts$ImportAsyncTask': {'layers': {}},
#   'com.fsck.k9.activity.ColorPickerDialog$OnColorChangedListener': {'colorChanged(int)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 1}},
#   'com.fsck.k9.activity.K9PreferenceActivity': {'onCreate(android.os.Bundle)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 1}},
#   'com.fsck.k9.activity.MessageList$StorageListenerImplementation': {'onUnmount(java.lang.String)': {'layer': 'Presentation Layer'},
#    'onMount(java.lang.String)': {'layer': 'Domain Layer'},
#    'layers': {'Presentation Layer': 1, 'Domain Layer': 1}},
#   'com.fsck.k9.activity.K9Activity': {'dispatchTouchEvent(android.view.MotionEvent)': {'layer': 'Presentation Layer'},
#    'setupGestureDetector(com.fsck.k9.activity.misc.SwipeGestureDetector$OnSwipeGestureListener)': {'layer': 'Presentation Layer'},
#    'onCreate(android.os.Bundle)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 3}},
#   'com.fsck.k9.activity.K9ActivityCommon': {'getThemeBackgroundColor()': {'layer': 'Data Source Layer'},
#    'newInstance(android.app.Activity)': {'layer': 'Presentation Layer'},
#    'setupGestureDetector(com.fsck.k9.activity.misc.SwipeGestureDetector$OnSwipeGestureListener)': {'layer': 'Presentation Layer'},
#    'preDispatchTouchEvent(android.view.MotionEvent)': {'layer': 'Presentation Layer'},
#    'setLanguage(android.content.Context,java.lang.String)': {'layer': 'Presentation Layer'},
#    'layers': {'Data Source Layer': 1, 'Presentation Layer': 4}},
#   'com.fsck.k9.activity.AccountList': {'onResume()': {'layer': 'Presentation Layer'},
#    'onItemClick(android.widget.AdapterView,android.view.View,int,long)': {'layer': 'Presentation Layer'},
#    'populateListView(java.util.List)': {'layer': 'Presentation Layer'},
#    'onCreate(android.os.Bundle)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 4}},
#   'com.fsck.k9.activity.LauncherShortcuts': {'onCreate(android.os.Bundle)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 1}},
#   'com.fsck.k9.activity.Accounts$PasswordPromptDialog': {'onTextChanged(java.lang.CharSequence,int,int,int)': {'layer': 'Presentation Layer'},
#    'afterTextChanged(android.text.Editable)': {'layer': 'Presentation Layer'},
#    'restore(android.app.Activity)': {'layer': 'Service Layer'},
#    'show(com.fsck.k9.activity.Accounts)': {'layer': 'Presentation Layer'},
#    'retain()': {'layer': 'Presentation Layer'},
#    'beforeTextChanged(java.lang.CharSequence,int,int,int)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 5, 'Service Layer': 1}},
#   'com.fsck.k9.activity.Accounts$AccountClickListener': {'onClick(android.view.View)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 1}},
#   'com.fsck.k9.activity.AccountList$LoadAccounts': {'layers': {}},
#   'com.fsck.k9.activity.ColorPickerDialog': {'setColor(int)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 1}},
#   'com.fsck.k9.activity.ChooseFolder': {'onOptionsItemSelected(android.view.MenuItem)': {'layer': 'Presentation Layer'},
#    'onCreateOptionsMenu(android.view.Menu)': {'layer': 'Presentation Layer'},
#    'onCreate(android.os.Bundle)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 3}},
#   'com.fsck.k9.activity.EditIdentity': {'onCreate(android.os.Bundle)': {'layer': 'Presentation Layer'},
#    'onSaveInstanceState(android.os.Bundle)': {'layer': 'Presentation Layer'},
#    'onBackPressed()': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 3}},
#   'com.fsck.k9.activity.Accounts$ListImportContentsAsyncTask': {'layers': {}},
#   'com.fsck.k9.activity.MessageCompose$Action': {'getTitleResource()': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 1}},
#   'com.fsck.k9.activity.UnreadWidgetConfiguration': {'onActivityResult(int,int,android.content.Intent)': {'layer': 'Presentation Layer'},
#    'getWidgetProperties(android.content.Context,int)': {'layer': 'Data Source Layer'},
#    'deleteWidgetConfiguration(android.content.Context,int)': {'layer': 'Data Source Layer'},
#    'onOptionsItemSelected(android.view.MenuItem)': {'layer': 'Presentation Layer'},
#    'onCreate(android.os.Bundle)': {'layer': 'Presentation Layer'},
#    'onCreateOptionsMenu(android.view.Menu)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 4, 'Data Source Layer': 2}},
#   'com.fsck.k9.activity.EmailAddressList': {'onItemClick(android.widget.AdapterView,android.view.View,int,long)': {'layer': 'Presentation Layer'},
#    'onCreate(android.os.Bundle)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 2}},
#   'com.fsck.k9.activity.K9PreferenceActivity$PreferenceChangeListener': {'onPreferenceChange(android.preference.Preference,java.lang.Object)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 1}},
#   'com.fsck.k9.activity.MessageCompose$SendMessageTask': {'layers': {}},
#   'com.fsck.k9.activity.AccountList$AccountsAdapter$AccountViewHolder': {'layers': {}},
#   'com.fsck.k9.activity.Accounts$AccountsAdapter': {'getView(int,android.view.View,android.view.ViewGroup)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 1}},
#   'com.fsck.k9.activity.AccountList$AccountsAdapter': {'getView(int,android.view.View,android.view.ViewGroup)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 1}},
#   'com.fsck.k9.activity.FolderList$FolderClickListener': {'onClick(android.view.View)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 1}},
#   'com.fsck.k9.activity.Accounts': {'onItemLongClick(android.widget.AdapterView,android.view.View,int,long)': {'layer': 'Presentation Layer'},
#    'onPrepareDialog(int,android.app.Dialog)': {'layer': 'Presentation Layer'},
#    'onExport(boolean,com.fsck.k9.Account)': {'layer': 'Presentation Layer'},
#    'onCreateDialog(int)': {'layer': 'Presentation Layer'},
#    'onCreate(android.os.Bundle)': {'layer': 'Presentation Layer'},
#    'listAccounts(android.content.Context)': {'layer': 'Presentation Layer'},
#    'onResume()': {'layer': 'Presentation Layer'},
#    'onCreateContextMenu(android.view.ContextMenu,android.view.View,android.view.ContextMenu.ContextMenuInfo)': {'layer': 'Presentation Layer'},
#    'onItemClick(android.widget.AdapterView,android.view.View,int,long)': {'layer': 'Presentation Layer'},
#    'onCreateOptionsMenu(android.view.Menu)': {'layer': 'Presentation Layer'},
#    'onPause()': {'layer': 'Service Layer'},
#    'importSettings(android.content.Context)': {'layer': 'Presentation Layer'},
#    'setProgress(boolean)': {'layer': 'Presentation Layer'},
#    'onContextItemSelected(android.view.MenuItem)': {'layer': 'Presentation Layer'},
#    'onExport(android.content.Intent)': {'layer': 'Service Layer'},
#    'onRetainNonConfigurationInstance()': {'layer': 'Presentation Layer'},
#    'createUnreadSearch(android.content.Context,com.fsck.k9.BaseAccount)': {'layer': 'Service Layer'},
#    'onSaveInstanceState(android.os.Bundle)': {'layer': 'Presentation Layer'},
#    'onOptionsItemSelected(android.view.MenuItem)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 16, 'Service Layer': 3}},
#   'com.fsck.k9.activity.MessageLoaderHelper': {'asyncRestartMessageCryptoProcessing()': {'layer': 'Service Layer'},
#    'onDestroyChangingConfigurations()': {'layer': 'Presentation Layer'},
#    'onDestroy()': {'layer': 'Presentation Layer'},
#    'asyncStartOrResumeLoadingMessage(com.fsck.k9.activity.MessageReference,android.os.Parcelable)': {'layer': 'Service Layer'},
#    'asyncReloadMessage()': {'layer': 'Presentation Layer'},
#    'downloadCompleteMessage()': {'layer': 'Presentation Layer'},
#    'onActivityResult(int,int,android.content.Intent)': {'layer': 'Service Layer'},
#    'layers': {'Service Layer': 3, 'Presentation Layer': 4}},
#   'com.fsck.k9.activity.Accounts$SetPasswordsAsyncTask': {'layers': {}},
#   'com.fsck.k9.activity.ConfirmationDialog': {'create(android.app.Activity,int,int,java.lang.String,int,int,java.lang.Runnable)': {'layer': 'Presentation Layer'},
#    'create(android.app.Activity,int,int,java.lang.String,int,int,java.lang.Runnable,java.lang.Runnable)': {'layer': 'Presentation Layer'},
#    'create(android.app.Activity,int,int,int,int,int,java.lang.Runnable)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 3}},
#   'com.fsck.k9.activity.AlternateRecipientAdapter$AlternateRecipientListener': {'onRecipientChange(com.fsck.k9.view.RecipientSelectView$Recipient,com.fsck.k9.view.RecipientSelectView$Recipient)': {'layer': 'Domain Layer'},
#    'onRecipientRemove(com.fsck.k9.view.RecipientSelectView$Recipient)': {'layer': 'Presentation Layer'},
#    'layers': {'Domain Layer': 1, 'Presentation Layer': 1}},
#   'com.fsck.k9.activity.FolderList$FolderListHandler': {'accountSizeChanged(long,long)': {'layer': 'Presentation Layer'},
#    'workingAccount(int)': {'layer': 'Presentation Layer'},
#    'progress(boolean)': {'layer': 'Presentation Layer'},
#    'dataChanged()': {'layer': 'Presentation Layer'},
#    'newFolders(java.util.List)': {'layer': 'Presentation Layer'},
#    'folderLoading(java.lang.String,boolean)': {'layer': 'Presentation Layer'},
#    'refreshTitle()': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 7}},
#   'com.fsck.k9.activity.K9ListActivity': {'setupGestureDetector(com.fsck.k9.activity.misc.SwipeGestureDetector$OnSwipeGestureListener)': {'layer': 'Presentation Layer'},
#    'onCreate(android.os.Bundle)': {'layer': 'Presentation Layer'},
#    'onResume()': {'layer': 'Presentation Layer'},
#    'onKeyUp(int,android.view.KeyEvent)': {'layer': 'Presentation Layer'},
#    'onKeyDown(int,android.view.KeyEvent)': {'layer': 'Presentation Layer'},
#    'dispatchTouchEvent(android.view.MotionEvent)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 6}},
#   'com.fsck.k9.activity.ChooseFolder$ChooseFolderHandler': {'handleMessage(android.os.Message)': {'layer': 'Presentation Layer'},
#    'progress(boolean)': {'layer': 'Presentation Layer'},
#    'setSelectedFolder(int)': {'layer': 'Service Layer'},
#    'layers': {'Presentation Layer': 2, 'Service Layer': 1}},
#   'com.fsck.k9.activity.ActivityListener': {'searchStats(com.fsck.k9.AccountStats)': {'layer': 'Presentation Layer'},
#    'synchronizeMailboxFailed(com.fsck.k9.Account,java.lang.String,java.lang.String)': {'layer': 'Service Layer'},
#    'synchronizeMailboxStarted(com.fsck.k9.Account,java.lang.String)': {'layer': 'Service Layer'},
#    'sendPendingMessagesCompleted(com.fsck.k9.Account)': {'layer': 'Service Layer'},
#    'pendingCommandStarted(com.fsck.k9.Account,java.lang.String)': {'layer': 'Service Layer'},
#    'sendPendingMessagesFailed(com.fsck.k9.Account)': {'layer': 'Service Layer'},
#    'getFolderTotal()': {'layer': 'Domain Layer'},
#    'pendingCommandCompleted(com.fsck.k9.Account,java.lang.String)': {'layer': 'Service Layer'},
#    'pendingCommandsProcessing(com.fsck.k9.Account)': {'layer': 'Service Layer'},
#    'getFolderCompleted()': {'layer': 'Domain Layer'},
#    'synchronizeMailboxHeadersProgress(com.fsck.k9.Account,java.lang.String,int,int)': {'layer': 'Domain Layer'},
#    'synchronizeMailboxHeadersFinished(com.fsck.k9.Account,java.lang.String,int,int)': {'layer': 'Service Layer'},
#    'folderStatusChanged(com.fsck.k9.Account,java.lang.String,int)': {'layer': 'Service Layer'},
#    'synchronizeMailboxFinished(com.fsck.k9.Account,java.lang.String,int,int)': {'layer': 'Domain Layer'},
#    'synchronizeMailboxHeadersStarted(com.fsck.k9.Account,java.lang.String)': {'layer': 'Service Layer'},
#    'systemStatusChanged()': {'layer': 'Presentation Layer'},
#    'onPause(android.content.Context)': {'layer': 'Data Source Layer'},
#    'sendPendingMessagesStarted(com.fsck.k9.Account)': {'layer': 'Domain Layer'},
#    'informUserOfStatus()': {'layer': 'Presentation Layer'},
#    'synchronizeMailboxProgress(com.fsck.k9.Account,java.lang.String,int,int)': {'layer': 'Service Layer'},
#    'getOperation(android.content.Context)': {'layer': 'Presentation Layer'},
#    'onResume(android.content.Context)': {'layer': 'Presentation Layer'},
#    'pendingCommandsFinished(com.fsck.k9.Account)': {'layer': 'Service Layer'},
#    'layers': {'Presentation Layer': 5,
#     'Service Layer': 12,
#     'Domain Layer': 5,
#     'Data Source Layer': 1}},
#   'com.fsck.k9.activity.NotificationDeleteConfirmation': {'onPrepareDialog(int,android.app.Dialog)': {'layer': 'Presentation Layer'},
#    'onCreateDialog(int)': {'layer': 'Presentation Layer'},
#    'getIntent(android.content.Context,java.util.List)': {'layer': 'Service Layer'},
#    'getIntent(android.content.Context,com.fsck.k9.activity.MessageReference)': {'layer': 'Service Layer'},
#    'onCreate(android.os.Bundle)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 3, 'Service Layer': 2}},
#   'com.fsck.k9.activity.ChooseIdentity': {'onCreate(android.os.Bundle)': {'layer': 'Presentation Layer'},
#    'onResume()': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 2}},
#   'com.fsck.k9.activity.UpgradeDatabases': {'onCreate(android.os.Bundle)': {'layer': 'Presentation Layer'},
#    'actionUpgradeDatabases(android.content.Context,android.content.Intent)': {'layer': 'Service Layer'},
#    'onResume()': {'layer': 'Service Layer'},
#    'onPause()': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 2, 'Service Layer': 2}},
#   'com.fsck.k9.activity.Accounts$AccountsImportedDialog': {'layers': {}},
#   'com.fsck.k9.activity.Accounts$ImportSelectionDialog': {'restore(android.app.Activity)': {'layer': 'Presentation Layer'},
#    'show(com.fsck.k9.activity.Accounts)': {'layer': 'Presentation Layer'},
#    'show(com.fsck.k9.activity.Accounts,android.util.SparseBooleanArray)': {'layer': 'Presentation Layer'},
#    'retain()': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 4}},
#   'com.fsck.k9.activity.AlternateRecipientAdapter': {'getItemId(int)': {'layer': 'Presentation Layer'},
#    'getCount()': {'layer': 'Domain Layer'},
#    'bindItemView(android.view.View,com.fsck.k9.view.RecipientSelectView$Recipient)': {'layer': 'Presentation Layer'},
#    'setCurrentRecipient(com.fsck.k9.view.RecipientSelectView$Recipient)': {'layer': 'Domain Layer'},
#    'getItem(int)': {'layer': 'Domain Layer'},
#    'bindHeaderView(android.view.View,com.fsck.k9.view.RecipientSelectView$Recipient)': {'layer': 'Presentation Layer'},
#    'isEnabled(int)': {'layer': 'Presentation Layer'},
#    'setShowAdvancedInfo(boolean)': {'layer': 'Domain Layer'},
#    'getView(int,android.view.View,android.view.ViewGroup)': {'layer': 'Presentation Layer'},
#    'setAlternateRecipientInfo(java.util.List)': {'layer': 'Domain Layer'},
#    'newView(android.view.ViewGroup)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 6, 'Domain Layer': 5}},
#   'com.fsck.k9.activity.MessageLoaderHelper$MessageLoaderCallbacks': {'onDownloadErrorNetworkError()': {'layer': 'Service Layer'},
#    'onMessageDataLoadFinished(com.fsck.k9.mailstore.LocalMessage)': {'layer': 'Service Layer'},
#    'onMessageDataLoadFailed()': {'layer': 'Service Layer'},
#    'onMessageViewInfoLoadFailed(com.fsck.k9.mailstore.MessageViewInfo)': {'layer': 'Presentation Layer'},
#    'startIntentSenderForMessageLoaderHelper(android.content.IntentSender,int,android.content.Intent,int,int,int)': {'layer': 'Service Layer'},
#    'onDownloadErrorMessageNotFound()': {'layer': 'Service Layer'},
#    'onMessageViewInfoLoadFinished(com.fsck.k9.mailstore.MessageViewInfo)': {'layer': 'Domain Layer'},
#    'setLoadingProgress(int,int)': {'layer': 'Presentation Layer'},
#    'layers': {'Service Layer': 5, 'Presentation Layer': 2, 'Domain Layer': 1}},
#   'com.fsck.k9.activity.K9ActivityCommon$K9ActivityMagic': {'setupGestureDetector(com.fsck.k9.activity.misc.SwipeGestureDetector$OnSwipeGestureListener)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 1}},
#   'com.fsck.k9.activity.MessageList$DisplayMode': {'layers': {}},
# ...
#    'layers': {'Presentation Layer': 2}},
#   'com.fsck.k9.ui.messageview.AttachmentView': {'enableButtons()': {'layer': 'Presentation Layer'},
#    'setAttachment(com.fsck.k9.mailstore.AttachmentViewInfo)': {'layer': 'Domain Layer'},
#    'disableButtons()': {'layer': 'Presentation Layer'},
#    'setCallback(com.fsck.k9.ui.messageview.AttachmentViewCallback)': {'layer': 'Presentation Layer'},
#    'onLongClick(android.view.View)': {'layer': 'Presentation Layer'},
#    'onClick(android.view.View)': {'layer': 'Presentation Layer'},
#    'refreshThumbnail()': {'layer': 'Presentation Layer'},
#    'getAttachment()': {'layer': 'Domain Layer'},
#    'layers': {'Presentation Layer': 6, 'Domain Layer': 2}},
#   'com.fsck.k9.ui.messageview.AttachmentController$SaveAttachmentAsyncTask': {'layers': {}},
#   'com.fsck.k9.ui.messageview.MessageCryptoPresenter': {'onActivityResult(int,int,android.content.Intent)': {'layer': 'Presentation Layer'},
#    'onCryptoClick()': {'layer': 'Presentation Layer'},
#    'onSaveInstanceState(android.os.Bundle)': {'layer': 'Presentation Layer'},
#    'maybeHandleShowMessage(com.fsck.k9.ui.messageview.MessageTopView,com.fsck.k9.Account,com.fsck.k9.mailstore.MessageViewInfo)': {'layer': 'Presentation Layer'},
#    'onResume()': {'layer': 'Presentation Layer'},
#    'getDecryptionResultForReply()': {'layer': 'Domain Layer'},
#    'onClickShowMessageOverrideWarning()': {'layer': 'Presentation Layer'},
#    'onClickShowCryptoKey()': {'layer': 'Presentation Layer'},
#    'onClickRetryCryptoOperation()': {'layer': 'Presentation Layer'},
#    'onClickConfigureProvider()': {'layer': 'Presentation Layer'},
#    'onClickShowCryptoWarningDetails()': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 10, 'Domain Layer': 1}},
#   'layers': {'Domain Layer': 25,
#    'Presentation Layer': 98,
#    'Service Layer': 13,
#    'Data Source Layer': 5}},
#  'com.fsck.k9.view': {'com.fsck.k9.view.MessageHeader$OnLayoutChangedListener': {'onLayoutChanged()': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 1}},
#   'com.fsck.k9.view.RecipientSelectView$RecipientCryptoStatus': {'layers': {}},
#   'com.fsck.k9.view.MessageHeader$HeaderEntry': {'layers': {}},
#   'com.fsck.k9.view.RecipientSelectView$RecipientTokenSpan': {'layers': {}},
#   'com.fsck.k9.view.HighlightDialogFragment': {'onDismiss(android.content.DialogInterface)': {'layer': 'Presentation Layer'},
#    'onStart()': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 2}},
#   'com.fsck.k9.view.RecipientSelectView$RecipientTokenViewHolder': {'layers': {}},
#   'com.fsck.k9.view.CryptoModeSelector$CryptoStatusSelectedListener': {'onCryptoStatusSelected(com.fsck.k9.view.CryptoModeSelector$CryptoModeSelectorState)': {'layer': 'Service Layer'},
#    'layers': {'Service Layer': 1}},
#   'com.fsck.k9.view.ViewSwitcher': {'setFirstInAnimation(android.view.animation.Animation)': {'layer': 'Presentation Layer'},
#    'onAnimationStart(android.view.animation.Animation)': {'layer': 'Presentation Layer'},
#    'setSecondOutAnimation(android.view.animation.Animation)': {'layer': 'Presentation Layer'},
#    'getSecondInAnimation()': {'layer': 'Presentation Layer'},
#    'showSecondView()': {'layer': 'Presentation Layer'},
#    'setOnSwitchCompleteListener(com.fsck.k9.view.ViewSwitcher$OnSwitchCompleteListener)': {'layer': 'Presentation Layer'},
#    'showFirstView()': {'layer': 'Presentation Layer'},
#    'getFirstInAnimation()': {'layer': 'Presentation Layer'},
#    'getmFirstOutAnimation()': {'layer': 'Presentation Layer'},
#    'setFirstOutAnimation(android.view.animation.Animation)': {'layer': 'Presentation Layer'},
#    'getSecondOutAnimation()': {'layer': 'Presentation Layer'},
#    'setSecondInAnimation(android.view.animation.Animation)': {'layer': 'Presentation Layer'},
#    'onAnimationEnd(android.view.animation.Animation)': {'layer': 'Presentation Layer'},
#    'onAnimationRepeat(android.view.animation.Animation)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 14}},
#   'com.fsck.k9.view.NonLockingScrollView': {'onInterceptTouchEvent(android.view.MotionEvent)': {'layer': 'Presentation Layer'},
#    'requestChildFocus(android.view.View,android.view.View)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 2}},
#   'com.fsck.k9.view.MessageCryptoDisplayStatus': {'isUnencryptedSigned()': {'layer': 'Domain Layer'},
#    'fromResultAnnotation(com.fsck.k9.mailstore.CryptoResultAnnotation)': {'layer': 'Service Layer'},
#    'hasAssociatedKey()': {'layer': 'Domain Layer'},
#    'layers': {'Domain Layer': 2, 'Service Layer': 1}},
#   'com.fsck.k9.view.MessageWebView': {'emulateShiftHeld()': {'layer': 'Presentation Layer'},
#    'displayHtmlContentWithInlineAttachments(java.lang.String,com.fsck.k9.mailstore.AttachmentResolver,com.fsck.k9.view.MessageWebView$OnPageFinishedListener)': {'layer': 'Service Layer'},
#    'blockNetworkData(boolean)': {'layer': 'Data Source Layer'},
#    'configure()': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 2,
#     'Service Layer': 1,
#     'Data Source Layer': 1}},
#   'com.fsck.k9.view.MessageHeader': {'setCryptoStatus(com.fsck.k9.view.MessageCryptoDisplayStatus)': {'layer': 'Presentation Layer'},
#    'onShowAdditionalHeaders()': {'layer': 'Presentation Layer'},
#    'populate(com.fsck.k9.mail.Message,com.fsck.k9.Account)': {'layer': 'Presentation Layer'},
#    'setOnCryptoClickListener(com.fsck.k9.ui.messageview.OnCryptoClickListener)': {'layer': 'Presentation Layer'},
#    'onSaveInstanceState()': {'layer': 'Presentation Layer'},
#    'showSubjectLine()': {'layer': 'Presentation Layer'},
#    'additionalHeadersVisible()': {'layer': 'Presentation Layer'},
#    'onClick(android.view.View)': {'layer': 'Presentation Layer'},
#    'onLongClick(android.view.View)': {'layer': 'Presentation Layer'},
#    'hideCryptoStatus()': {'layer': 'Presentation Layer'},
#    'setOnFlagListener(android.view.View.OnClickListener)': {'layer': 'Presentation Layer'},
#    'createMessage(int)': {'layer': 'Presentation Layer'},
#    'setOnLayoutChangedListener(com.fsck.k9.view.MessageHeader$OnLayoutChangedListener)': {'layer': 'Presentation Layer'},
#    'shouldShowSender(com.fsck.k9.mail.Message)': {'layer': 'Domain Layer'},
#    'onRestoreInstanceState(android.os.Parcelable)': {'layer': 'Presentation Layer'},
#    'setCryptoStatusDisabled()': {'layer': 'Presentation Layer'},
#    'setCryptoStatusLoading()': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 16, 'Domain Layer': 1}},
#   'com.fsck.k9.view.ClientCertificateSpinner': {'setAlias(java.lang.String)': {'layer': 'Domain Layer'},
#    'getAlias()': {'layer': 'Presentation Layer'},
#    'chooseCertificate()': {'layer': 'Service Layer'},
#    'setOnClientCertificateChangedListener(com.fsck.k9.view.ClientCertificateSpinner$OnClientCertificateChangedListener)': {'layer': 'Presentation Layer'},
#    'layers': {'Domain Layer': 1, 'Presentation Layer': 2, 'Service Layer': 1}},
#   'com.fsck.k9.view.CryptoModeSelector$CryptoModeSelectorState': {'layers': {}},
#   'com.fsck.k9.view.K9WebViewClient': {'newInstance(com.fsck.k9.mailstore.AttachmentResolver)': {'layer': 'Data Source Layer'},
#    'onPageFinished(android.webkit.WebView,java.lang.String)': {'layer': 'Presentation Layer'},
#    'setOnPageFinishedListener(com.fsck.k9.view.MessageWebView$OnPageFinishedListener)': {'layer': 'Presentation Layer'},
#    'shouldOverrideUrlLoading(android.webkit.WebView,java.lang.String)': {'layer': 'Presentation Layer'},
#    'layers': {'Data Source Layer': 1, 'Presentation Layer': 3}},
#   'com.fsck.k9.view.MessageWebView$OnPageFinishedListener': {'onPageFinished()': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 1}},
#   'com.fsck.k9.view.ClientCertificateSpinner$OnClientCertificateChangedListener': {'onClientCertificateChanged(java.lang.String)': {'layer': 'Domain Layer'},
#    'layers': {'Domain Layer': 1}},
#   'com.fsck.k9.view.MessageTitleView': {'showSubjectInMessageHeader()': {'layer': 'Presentation Layer'},
#    'setMessageHeader(com.fsck.k9.view.MessageHeader)': {'layer': 'Domain Layer'},
#    'onDraw(android.graphics.Canvas)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 2, 'Domain Layer': 1}},
#   'com.fsck.k9.view.K9WebViewClient$LollipopWebViewClient': {'shouldInterceptRequest(android.webkit.WebView,android.webkit.WebResourceRequest)': {'layer': 'Data Source Layer'},
#    'layers': {'Data Source Layer': 1}},
#   'com.fsck.k9.view.K9WebViewClient$PreLollipopWebViewClient': {'shouldInterceptRequest(android.webkit.WebView,java.lang.String)': {'layer': 'Data Source Layer'},
#    'layers': {'Data Source Layer': 1}},
#   'com.fsck.k9.view.RecipientSelectView$Recipient': {'equals(java.lang.Object)': {'layer': 'Domain Layer'},
#    'getDisplayNameOrUnknown(android.content.Context)': {'layer': 'Domain Layer'},
#    'setCryptoStatus(com.fsck.k9.view.RecipientSelectView$RecipientCryptoStatus)': {'layer': 'Presentation Layer'},
#    'getContactLookupUri()': {'layer': 'Data Source Layer'},
#    'isValidEmailAddress()': {'layer': 'Domain Layer'},
#    'getDisplayNameOrAddress()': {'layer': 'Domain Layer'},
#    'getCryptoStatus()': {'layer': 'Domain Layer'},
#    'getNameOrUnknown(android.content.Context)': {'layer': 'Domain Layer'},
#    'layers': {'Domain Layer': 6,
#     'Presentation Layer': 1,
#     'Data Source Layer': 1}},
#   'com.fsck.k9.view.FoldableLinearLayout': {'addView(android.view.View)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 1}},
#   'com.fsck.k9.view.RecipientSelectView$TokenListener': {'onTokenChanged(java.lang.Object)': {'layer': 'Domain Layer'},
#    'layers': {'Domain Layer': 1}},
#   'com.fsck.k9.view.ToolableViewAnimator': {'setDisplayedChildId(int)': {'layer': 'Presentation Layer'},
#    'setDisplayedChild(int,boolean)': {'layer': 'Presentation Layer'},
#    'setDisplayedChild(int)': {'layer': 'Presentation Layer'},
#    'addView(android.view.View,int,android.view.ViewGroup$LayoutParams)': {'layer': 'Presentation Layer'},
#    'getDisplayedChildId()': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 5}},
#   'com.fsck.k9.view.ViewSwitcher$OnSwitchCompleteListener': {'onSwitchComplete(int)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 1}},
#   'com.fsck.k9.view.NonLockingScrollView$HierarchyTreeChangeListener': {'onChildViewRemoved(android.view.View,android.view.View)': {'layer': 'Presentation Layer'},
#    'onChildViewAdded(android.view.View,android.view.View)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 2}},
#   'com.fsck.k9.view.RigidWebView': {'layers': {}},
#   'com.fsck.k9.view.MessageCryptoStatusView': {'setCryptoDisplayStatus(com.fsck.k9.view.MessageCryptoDisplayStatus)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 1}},
#   'com.fsck.k9.view.FoldableLinearLayout$SavedState': {'writeToParcel(android.os.Parcel,int)': {'layer': 'Domain Layer'},
#    'layers': {'Domain Layer': 1}},
#   'com.fsck.k9.view.LinearViewAnimator': {'setUpInAnimation(android.view.animation.Animation)': {'layer': 'Presentation Layer'},
#    'setUpOutAnimation(android.content.Context,int)': {'layer': 'Presentation Layer'},
#    'setDownInAnimation(android.view.animation.Animation)': {'layer': 'Presentation Layer'},
#    'setUpInAnimation(android.content.Context,int)': {'layer': 'Presentation Layer'},
#    'setDownOutAnimation(android.content.Context,int)': {'layer': 'Presentation Layer'},
#    'setUpOutAnimation(android.view.animation.Animation)': {'layer': 'Presentation Layer'},
#    'setDownOutAnimation(android.view.animation.Animation)': {'layer': 'Presentation Layer'},
#    'setDownInAnimation(android.content.Context,int)': {'layer': 'Presentation Layer'},
#    'setDisplayedChild(int)': {'layer': 'Presentation Layer'},
#    'setDisplayedChild(int,boolean)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 10}},
#   'com.fsck.k9.view.MessageHeader$SavedState': {'writeToParcel(android.os.Parcel,int)': {'layer': 'Data Source Layer'},
#    'layers': {'Data Source Layer': 1}},
#   'com.fsck.k9.view.ThemeUtils': {'getStyledColor(android.content.res.Resources.Theme,int)': {'layer': 'Presentation Layer'},
#    'getStyledColor(android.content.Context,int)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 2}},
#   'com.fsck.k9.view.RecipientSelectView': {'onLoaderReset(android.content.Loader)': {'layer': 'Presentation Layer'},
#    'hasUncompletedText()': {'layer': 'Domain Layer'},
#    'onLoadFinished(android.content.Loader,java.util.List)': {'layer': 'Presentation Layer'},
#    'setCryptoProvider(java.lang.String,boolean)': {'layer': 'Domain Layer'},
#    'setLoaderManager(android.app.LoaderManager)': {'layer': 'Service Layer'},
#    'setShowCryptoEnabled(boolean)': {'layer': 'Domain Layer'},
#    'onTouchEvent(android.view.MotionEvent)': {'layer': 'Presentation Layer'},
#    'addRecipients(com.fsck.k9.view.RecipientSelectView$Recipient[])': {'layer': 'Domain Layer'},
#    'showDropDown()': {'layer': 'Presentation Layer'},
#    'onCreateLoader(int,android.os.Bundle)': {'layer': 'Presentation Layer'},
#    'postShowAlternatesPopup(java.util.List)': {'layer': 'Presentation Layer'},
#    'setTokenListener(com.fsck.k9.view.RecipientSelectView$TokenListener)': {'layer': 'Presentation Layer'},
#    'getAddresses()': {'layer': 'Service Layer'},
#    'performCompletion()': {'layer': 'Presentation Layer'},
#    'onKeyDown(int,android.view.KeyEvent)': {'layer': 'Presentation Layer'},
#    'isEmpty()': {'layer': 'Domain Layer'},
#    'onFocusChanged(boolean,int,android.graphics.Rect)': {'layer': 'Presentation Layer'},
#    'onRecipientRemove(com.fsck.k9.view.RecipientSelectView$Recipient)': {'layer': 'Presentation Layer'},
#    'showAlternatesPopup(java.util.List)': {'layer': 'Presentation Layer'},
#    'onRecipientChange(com.fsck.k9.view.RecipientSelectView$Recipient,com.fsck.k9.view.RecipientSelectView$Recipient)': {'layer': 'Presentation Layer'},
#    'tryPerformCompletion()': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 14,
#     'Domain Layer': 5,
#     'Service Layer': 2}},
#   'com.fsck.k9.view.CryptoModeSelector': {'setCryptoStatusListener(com.fsck.k9.view.CryptoModeSelector$CryptoStatusSelectedListener)': {'layer': 'Presentation Layer'},
#    'setCryptoStatus(com.fsck.k9.view.CryptoModeSelector$CryptoModeSelectorState)': {'layer': 'Domain Layer'},
#    'layers': {'Presentation Layer': 1, 'Domain Layer': 1}},
#   'com.fsck.k9.view.ColorChip': {'drawable()': {'layer': 'Domain Layer'},
#    'layers': {'Domain Layer': 1}},
#   'layers': {'Presentation Layer': 83,
#    'Service Layer': 6,
#    'Domain Layer': 21,
#    'Data Source Layer': 6}},
#  'com.fsck.k9.widget.list': {'com.fsck.k9.widget.list.MessageListWidgetProvider': {'onReceive(android.content.Context,android.content.Intent)': {'layer': 'Service Layer'},
#    'onUpdate(android.content.Context,android.appwidget.AppWidgetManager,int[])': {'layer': 'Presentation Layer'},
#    'triggerMessageListWidgetUpdate(android.content.Context)': {'layer': 'Service Layer'},
#    'layers': {'Service Layer': 2, 'Presentation Layer': 1}},
#   'com.fsck.k9.widget.list.MessageListWidgetService': {'onGetViewFactory(android.content.Intent)': {'layer': 'Service Layer'},
#    'layers': {'Service Layer': 1}},
#   'com.fsck.k9.widget.list.MessageListRemoteViewFactory$MailItem': {'layers': {}},
#   'com.fsck.k9.widget.list.MessageListRemoteViewFactory': {'getLoadingView()': {'layer': 'Presentation Layer'},
#    'getItemId(int)': {'layer': 'Data Source Layer'},
#    'getCount()': {'layer': 'Domain Layer'},
#    'onDestroy()': {'layer': 'Presentation Layer'},
#    'hasStableIds()': {'layer': 'Presentation Layer'},
#    'onCreate()': {'layer': 'Presentation Layer'},
#    'getViewTypeCount()': {'layer': 'Presentation Layer'},
#    'onDataSetChanged()': {'layer': 'Presentation Layer'},
#    'getViewAt(int)': {'layer': 'Presentation Layer'},
#    'layers': {'Presentation Layer': 7,
#     'Data Source Layer': 1,
#     'Domain Layer': 1}},
#   'layers': {'Service Layer': 3,
#    'Presentation Layer': 8,
#    'Data Source Layer': 1,
#    'Domain Layer': 1}}}

# %%
write_dict_to_json(results, f"layerinator-v2/{project_name}-layers-recap-{timestr}.json")

# %%
rows = []

for package in results:
	for clss in [c for c in results[package] if c != 'layers']:
		for method in [m for m in results[package][clss] if m != 'layers']:
			rows.append((package,clss,method,results[package][clss][method]['layer']))

rows
# Out:
# [('com.fsck.k9', 'com.fsck.k9.Throttle$MyTimerTask', 'run()', 'Service Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Throttle$MyTimerTask',
#   'cancel()',
#   'Presentation Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Throttle',
#   'cancelScheduledCallback()',
#   'Execution Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.Throttle', 'onEvent()', 'Service Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.PRNGFixes', 'apply()', 'Utility Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.BaseAccount',
#   'setEmail(java.lang.String)',
#   'Domain Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.BaseAccount', 'getEmail()', 'Domain Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.BaseAccount', 'getUuid()', 'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.BaseAccount',
#   'getDescription()',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.BaseAccount',
#   'setDescription(java.lang.String)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Throttle$MyTimerTask$HandlerRunnable',
#   'run()',
#   'Service Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'messageListSenderAboveSubject()',
#   'Presentation Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.K9', 'setDebug(boolean)', 'Service Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.K9', 'setContactNameColor(int)', 'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'setConfirmDeleteStarred(boolean)',
#   'Service Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'setBackgroundOps(com.fsck.k9.K9$BACKGROUND_OPS)',
#   'Service Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'setNotificationDuringQuietTimeEnabled(boolean)',
#   'Service Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.K9', 'getSplitViewMode()', 'Data Source Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'setAnimations(boolean)',
#   'Presentation Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'setDatabasesUpToDate(boolean)',
#   'Data Source Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'setGesturesEnabled(boolean)',
#   'Service Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'useBackgroundAsUnreadIndicator()',
#   'Service Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'isColorizeMissingContactPictures()',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'setMessageViewReturnToList(boolean)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'getOpenPgpSupportSignOnly()',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'setPgpInlineDialogCounter(int)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'registerApplicationAware(com.fsck.k9.K9$ApplicationAware)',
#   'Service Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'setNotificationQuickDeleteBehaviour(com.fsck.k9.K9$NotificationQuickDelete)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'setHideUserAgent(boolean)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'setMessageViewArchiveActionVisible(boolean)',
#   'Presentation Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'setLockScreenNotificationVisibility(com.fsck.k9.K9$LockScreenNotificationVisibility)',
#   'Service Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'setMessageListPreviewLines(int)',
#   'Presentation Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'setQuietTimeStarts(java.lang.String)',
#   'Service Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.K9', 'messageViewShowNext()', 'Service Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.K9', 'setHideTimeZone(boolean)', 'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'isMessageViewCopyActionVisible()',
#   'Service Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'showCorrespondentNames()',
#   'Presentation Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'getPgpSignOnlyDialogCounter()',
#   'Utility Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'save(com.fsck.k9.preferences.StorageEditor)',
#   'Data Source Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.K9', 'getQuietTimeEnabled()', 'Service Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'setSplitViewMode(com.fsck.k9.K9$SplitViewMode)',
#   'Presentation Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.K9', 'getSortType()', 'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'setMessageViewFixedWidthFont(boolean)',
#   'Presentation Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'setQuietTimeEnabled(boolean)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'getK9ThemeResourceId(com.fsck.k9.K9$Theme)',
#   'Utility Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.K9', 'getK9ThemeResourceId()', 'Utility Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'setMessageViewCopyActionVisible(boolean)',
#   'Presentation Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.K9', 'getK9Language()', 'Data Source Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.K9', 'getK9MessageViewTheme()', 'Domain Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.K9', 'showContactName()', 'Presentation Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.K9', 'gesturesEnabled()', 'Service Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'setShowContactName(boolean)',
#   'Presentation Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.K9', 'wrapFolderNames()', 'Presentation Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'setMessageListSenderAboveSubject(boolean)',
#   'Presentation Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'getLockScreenNotificationVisibility()',
#   'Domain Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.K9', 'getFontSizes()', 'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'isNotificationDuringQuietTimeEnabled()',
#   'Domain Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.K9', 'measureAccounts()', 'Service Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'useFixedMessageViewTheme()',
#   'Presentation Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'setSortAscending(com.fsck.k9.Account$SortType,boolean)',
#   'Service Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.K9', 'getBackgroundOps()', 'Service Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'setColorizeMissingContactPictures(boolean)',
#   'Service Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.K9', 'confirmSpam()', 'Service Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'areDatabasesUpToDate()',
#   'Data Source Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.K9', 'isThreadedViewEnabled()', 'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'setWrapFolderNames(boolean)',
#   'Presentation Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.K9', 'getK9ComposerTheme()', 'Service Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'setMessageListCheckboxes(boolean)',
#   'Presentation Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.K9', 'onCreate()', 'Service Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'getQuietTimeStarts()',
#   'Data Source Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'showContactPicture()',
#   'Presentation Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'messageListCheckboxes()',
#   'Presentation Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'setAutofitWidth(boolean)',
#   'Presentation Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.K9', 'getQuietTimeEnds()', 'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'setMessageViewShowNext(boolean)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'setChangeContactNameColor(boolean)',
#   'Presentation Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'setConfirmDeleteFromNotification(boolean)',
#   'Presentation Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.K9', 'confirmDeleteStarred()', 'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'setNotificationHideSubject(com.fsck.k9.K9$NotificationHideSubject)',
#   'Service Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'setUseFixedMessageViewTheme(boolean)',
#   'Presentation Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.K9', 'autofitWidth()', 'Presentation Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.K9', 'hideUserAgent()', 'None'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'setMessageViewDeleteActionVisible(boolean)',
#   'Presentation Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'checkCachedDatabaseVersion()',
#   'Data Source Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.K9', 'isHideSpecialAccounts()', 'Service Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'setConfirmMarkAllRead(boolean)',
#   'Service Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.K9', 'confirmDelete()', 'Presentation Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'isMessageViewArchiveActionVisible()',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'getContactNameColor()',
#   'Presentation Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.K9', 'getK9Theme()', 'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'setStartIntegratedInbox(boolean)',
#   'Presentation Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.K9', 'countSearchMessages()', 'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'setMessageViewMoveActionVisible(boolean)',
#   'Presentation Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.K9', 'isDebug()', 'Utility Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'getNotificationHideSubject()',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'setQuietTimeEnds(java.lang.String)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'getPgpInlineDialogCounter()',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'setBackgroundOps(java.lang.String)',
#   'Service Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.K9', 'setConfirmSpam(boolean)', 'Service Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'setServicesEnabled(android.content.Context)',
#   'Service Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'setHideSpecialAccounts(boolean)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'isSortAscending(com.fsck.k9.Account$SortType)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'loadPrefs(com.fsck.k9.Preferences)',
#   'Data Source Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'setMessageListStars(boolean)',
#   'Presentation Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'setOpenPgpSupportSignOnly(boolean)',
#   'Service Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'getNotificationQuickDeleteBehaviour()',
#   'Domain Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.K9', 'showAnimations()', 'Service Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'setUseVolumeKeysForListNavigation(boolean)',
#   'Presentation Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'getK9MessageViewThemeSetting()',
#   'Presentation Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'setAttachmentDefaultPath(java.lang.String)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'setPgpSignOnlyDialogCounter(int)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'setThreadedViewEnabled(boolean)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'isMessageViewMoveActionVisible()',
#   'Service Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.K9', 'confirmDiscardMessage()', 'Service Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'setOpenPgpProvider(java.lang.String)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'isMessageViewSpamActionVisible()',
#   'Presentation Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'useVolumeKeysForNavigationEnabled()',
#   'Service Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'isOpenPgpProviderConfigured()',
#   'Service Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'useVolumeKeysForListNavigationEnabled()',
#   'Presentation Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'setK9MessageViewThemeSetting(com.fsck.k9.K9$Theme)',
#   'Presentation Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'messageListPreviewLines()',
#   'Presentation Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'setShowContactPicture(boolean)',
#   'Service Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'setMessageViewSpamActionVisible(boolean)',
#   'Presentation Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.K9', 'getOpenPgpProvider()', 'Service Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'setMeasureAccounts(boolean)',
#   'Service Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'confirmDeleteFromNotification()',
#   'Service Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'setConfirmDelete(boolean)',
#   'Service Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'messageViewFixedWidthFont()',
#   'Presentation Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'isMessageViewDeleteActionVisible()',
#   'Domain Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.K9', 'messageListStars()', 'Service Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.K9', 'changeContactNameColor()', 'None'),
#  ('com.fsck.k9', 'com.fsck.k9.K9', 'startIntegratedInbox()', 'Service Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'setSortType(com.fsck.k9.Account$SortType)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'setK9ComposerThemeSetting(com.fsck.k9.K9$Theme)',
#   'Presentation Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.K9', 'hideTimeZone()', 'Utility Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'getK9ComposerThemeSetting()',
#   'Data Source Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'setConfirmDiscardMessage(boolean)',
#   'Presentation Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'getAttachmentDefaultPath()',
#   'Data Source Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.K9', 'saveSettingsAsync()', 'Service Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'setCountSearchMessages(boolean)',
#   'Service Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.K9', 'isQuietTime()', 'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'setK9Language(java.lang.String)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'setUseBackgroundAsUnreadIndicator(boolean)',
#   'Service Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'setUseVolumeKeysForNavigation(boolean)',
#   'Service Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'setShowCorrespondentNames(boolean)',
#   'Presentation Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'setK9Theme(com.fsck.k9.K9$Theme)',
#   'Presentation Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9',
#   'messageViewReturnToList()',
#   'Service Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.K9', 'confirmMarkAllRead()', 'Service Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.EmailAddressValidator',
#   'fixText(java.lang.CharSequence)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.EmailAddressValidator',
#   'isValid(java.lang.CharSequence)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.EmailAddressValidator',
#   'isValidAddressOnly(java.lang.CharSequence)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account$SortType',
#   'isDefaultAscending()',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account$SortType',
#   'getToast(boolean)',
#   'Presentation Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.Globals', 'getContext()', 'Utility Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.FontSizes',
#   'getMessageViewContentAsPercent()',
#   'Presentation Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.FontSizes',
#   'getMessageViewDate()',
#   'Domain Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.FontSizes', 'getFolderStatus()', 'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.FontSizes',
#   'setMessageViewContentAsPercent(int)',
#   'Presentation Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.FontSizes',
#   'getMessageViewBCC()',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.FontSizes',
#   'setMessageViewSubject(int)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.FontSizes',
#   'setMessageListPreview(int)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.FontSizes',
#   'getMessageViewAdditionalHeaders()',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.FontSizes',
#   'getMessageListDate()',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.FontSizes',
#   'getMessageViewCC()',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.FontSizes',
#   'setMessageListDate(int)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.FontSizes',
#   'setMessageViewTo(int)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.FontSizes',
#   'getMessageComposeInput()',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.FontSizes',
#   'getMessageViewSubject()',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.FontSizes',
#   'setMessageListSender(int)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.FontSizes',
#   'getMessageViewSender()',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.FontSizes',
#   'load(com.fsck.k9.preferences.Storage)',
#   'Data Source Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.FontSizes',
#   'setAccountDescription(int)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.FontSizes',
#   'setAccountName(int)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.FontSizes',
#   'setMessageViewSender(int)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.FontSizes',
#   'setMessageListSubject(int)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.FontSizes',
#   'getMessageListPreview()',
#   'Presentation Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.FontSizes',
#   'getMessageListSender()',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.FontSizes',
#   'setMessageViewBCC(int)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.FontSizes',
#   'setViewTextSize(android.widget.TextView,int)',
#   'Presentation Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.FontSizes',
#   'setMessageViewAdditionalHeaders(int)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.FontSizes',
#   'setFolderName(int)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.FontSizes',
#   'getMessageViewTo()',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.FontSizes',
#   'getAccountDescription()',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.FontSizes',
#   'getMessageListSubject()',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.FontSizes',
#   'setMessageComposeInput(int)',
#   'Presentation Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.FontSizes',
#   'setMessageViewDate(int)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.FontSizes',
#   'save(com.fsck.k9.preferences.StorageEditor)',
#   'Data Source Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.FontSizes', 'getAccountName()', 'Domain Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.FontSizes', 'getFolderName()', 'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.FontSizes',
#   'setMessageViewCC(int)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.FontSizes',
#   'setFolderStatus(int)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.NotificationSetting',
#   'isRingEnabled()',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.NotificationSetting',
#   'isVibrateEnabled()',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.NotificationSetting',
#   'isLedEnabled()',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.NotificationSetting',
#   'setLed(boolean)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.NotificationSetting',
#   'setVibratePattern(int)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.NotificationSetting',
#   'getVibrateTimes()',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.NotificationSetting',
#   'setRingEnabled(boolean)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.NotificationSetting',
#   'getLedColor()',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.NotificationSetting',
#   'getRingtone()',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.NotificationSetting',
#   'setVibrate(boolean)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.NotificationSetting',
#   'getVibration(int,int)',
#   'Utility Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.NotificationSetting',
#   'getVibration()',
#   'Data Source Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.NotificationSetting',
#   'setVibrateTimes(int)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.NotificationSetting',
#   'getVibratePattern()',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.NotificationSetting',
#   'setLedColor(int)',
#   'Presentation Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.NotificationSetting',
#   'setRingtone(java.lang.String)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Preferences',
#   'setDefaultAccount(com.fsck.k9.Account)',
#   'Data Source Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Preferences',
#   'getAvailableAccounts()',
#   'Service Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.Preferences', 'loadAccounts()', 'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Preferences',
#   'getAccounts()',
#   'Data Source Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.Preferences', 'newAccount()', 'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Preferences',
#   'getAccount(java.lang.String)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Preferences',
#   'getPreferences(android.content.Context)',
#   'Data Source Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Preferences',
#   'deleteAccount(com.fsck.k9.Account)',
#   'Service Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Preferences',
#   'getStorage()',
#   'Data Source Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Preferences',
#   'getDefaultAccount()',
#   'Domain Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.Clock', 'getTime()', 'Utility Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'getLocalStore()',
#   'Data Source Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'addCertificate(com.fsck.k9.activity.setup.AccountSetupCheckSettings$CheckDirection,java.security.cert.X509Certificate)',
#   'Data Source Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'setDisplayCount(int)',
#   'Domain Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.Account', 'isReplyAfterQuote()', 'Domain Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.Account', 'getIdentities()', 'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'setSignatureBeforeQuotedText(boolean)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'setIdleRefreshMinutes(int)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'goToUnreadMessageSearch()',
#   'Service Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'setSortType(com.fsck.k9.Account$SortType)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'setFolderTargetMode(com.fsck.k9.Account$FolderMode)',
#   'Domain Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.Account', 'getStoreUri()', 'Domain Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.Account', 'getMaxPushFolders()', 'Domain Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.Account', 'setEnabled(boolean)', 'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'setExpungePolicy(com.fsck.k9.Account$Expunge)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'limitToDisplayableFolders(com.fsck.k9.search.LocalSearch)',
#   'Service Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.Account', 'hasDraftsFolder()', 'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'setArchiveFolderName(java.lang.String)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'getSearchableFolders()',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'isSortAscending(com.fsck.k9.Account$SortType)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'setInboxFolderName(java.lang.String)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'setTransportUri(java.lang.String)',
#   'Domain Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.Account', 'getFolderSyncMode()', 'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'setNotifyContactsMailOnly(boolean)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'setSyncRemoteDeletions(boolean)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'setFolderPushMode(com.fsck.k9.Account$FolderMode)',
#   'Service Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.Account', 'getAlwaysBcc()', 'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'setDraftsFolderName(java.lang.String)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'setSubscribedFoldersOnly(boolean)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'setMessageFormat(com.fsck.k9.Account$MessageFormat)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'getLastSelectedFolderName()',
#   'Domain Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.Account', 'getQuotePrefix()', 'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'getStats(android.content.Context)',
#   'Service Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.Account', 'getSpamFolderName()', 'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'syncRemoteDeletions()',
#   'Service Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'save(com.fsck.k9.Preferences)',
#   'Data Source Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'useCompression(com.fsck.k9.mail.NetworkType)',
#   'Data Source Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'setSpamFolderName(java.lang.String)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'setAutomaticCheckIntervalMinutes(int)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'setGoToUnreadMessageSearch(boolean)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'setShowPictures(com.fsck.k9.Account$ShowPictures)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'setQuotePrefix(java.lang.String)',
#   'Domain Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.Account', 'hashCode()', 'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'getRemoteSearchNumResults()',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'setFolderDisplayMode(com.fsck.k9.Account$FolderMode)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'isRemoteSearchFullText()',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'isSearchByDateCapable()',
#   'Domain Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.Account', 'getAccountNumber()', 'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'isPushPollOnConnect()',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'getOutboxFolderName()',
#   'Data Source Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.Account', 'getFolderPushMode()', 'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'setSentFolderName(java.lang.String)',
#   'Domain Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.Account', 'setChipColor(int)', 'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'getLatestOldMessageSeenTime()',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'findIdentity(com.fsck.k9.mail.Address)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'setEmail(java.lang.String)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'setSortAscending(com.fsck.k9.Account$SortType,boolean)',
#   'Domain Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.Account', 'getName()', 'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'generateColorChip(boolean,boolean)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'isAnIdentity(com.fsck.k9.mail.Address)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'getFolderUnreadCount(android.content.Context,java.lang.String)',
#   'Data Source Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.Account', 'getEmail()', 'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'subscribedFoldersOnly()',
#   'Domain Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.Account', 'hasArchiveFolder()', 'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'setFolderNotifyNewMailMode(com.fsck.k9.Account$FolderMode)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'setReplyAfterQuote(boolean)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'setLastSelectedFolderName(java.lang.String)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'getAutomaticCheckIntervalMinutes()',
#   'Domain Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.Account', 'getSignatureUse()', 'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'setRingNotified(boolean)',
#   'Domain Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.Account', 'getMessageFormat()', 'Domain Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.Account', 'isNotifyNewMail()', 'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'setStripSignature(boolean)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'setMarkMessageAsReadOnView(boolean)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'isDefaultQuotedTextShown()',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'getEarliestPollDate()',
#   'Service Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'setRemoteSearchFullText(boolean)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'generateAccountNumber(com.fsck.k9.Preferences)',
#   'Service Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'setMessageReadReceipt(boolean)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'setCompression(com.fsck.k9.mail.NetworkType,boolean)',
#   'Data Source Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'setDefaultQuotedTextShown(boolean)',
#   'Domain Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.Account', 'isStripSignature()', 'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'setQuoteStyle(com.fsck.k9.Account$QuoteStyle)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'isAnIdentity(com.fsck.k9.mail.Address[])',
#   'Domain Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.Account', 'isEnabled()', 'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'setSearchableFolders(com.fsck.k9.Account$Searchable)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'isSignatureBeforeQuotedText()',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'isNotifyContactsMailOnly()',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'getFolderNotifyNewMailMode()',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'setName(java.lang.String)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'setIdentities(java.util.List)',
#   'Domain Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.Account', 'allowRemoteSearch()', 'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'setSignatureUse(boolean)',
#   'Domain Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.Account', 'getRemoteStore()', 'Service Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.Account', 'hasTrashFolder()', 'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'deleteCertificate(java.lang.String,int,com.fsck.k9.activity.setup.AccountSetupCheckSettings$CheckDirection)',
#   'Data Source Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'getLocalStorageProviderId()',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'setAutoExpandFolderName(java.lang.String)',
#   'Domain Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.Account', 'hasSpamFolder()', 'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'setMaximumAutoDownloadMessageSize(int)',
#   'Service Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.Account', 'getQuoteStyle()', 'Domain Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.Account', 'getSignature()', 'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'getInboxFolderName()',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'setRemoteSearchNumResults(int)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'excludeSpecialFolders(com.fsck.k9.search.LocalSearch)',
#   'Service Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'setPushPollOnConnect(boolean)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'getTrashFolderName()',
#   'Domain Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.Account', 'toString()', 'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'getArchiveFolderName()',
#   'Domain Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.Account', 'getDescription()', 'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'getAutoExpandFolderName()',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'setMaximumPolledMessageAge(int)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'setLocalStorageProviderId(java.lang.String)',
#   'Data Source Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.Account', 'hasSentFolder()', 'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'getMaximumAutoDownloadMessageSize()',
#   'Domain Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.Account', 'getSortType()', 'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'setDescription(java.lang.String)',
#   'Domain Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.Account', 'getChipColor()', 'Domain Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.Account', 'getDeletePolicy()', 'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'isMarkMessageAsReadOnView()',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'setDeletePolicy(com.fsck.k9.Account$DeletePolicy)',
#   'Domain Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.Account', 'isRingNotified()', 'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'getDisplayCount()',
#   'Presentation Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.Account', 'isAlwaysShowCcBcc()', 'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'getDraftsFolderName()',
#   'Domain Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.Account', 'getExpungePolicy()', 'Domain Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.Account', 'getShowPictures()', 'Domain Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.Account', 'setCryptoKey(long)', 'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'isSpecialFolder(java.lang.String)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'setNotifySelfNewMail(boolean)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'move(com.fsck.k9.Preferences,boolean)',
#   'Data Source Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'getNotificationSetting()',
#   'Domain Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.Account', 'getSentFolderName()', 'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'setNotifyNewMail(boolean)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'setFolderSyncMode(com.fsck.k9.Account$FolderMode)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'setAlwaysBcc(java.lang.String)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'setShowOngoing(boolean)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'setAlwaysShowCcBcc(boolean)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'getIdleRefreshMinutes()',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'isNotifySelfNewMail()',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'setAllowRemoteSearch(boolean)',
#   'Domain Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.Account', 'isShowOngoing()', 'Domain Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.Account', 'getCryptoKey()', 'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'setStoreUri(java.lang.String)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'getFolderTargetMode()',
#   'Domain Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.Account', 'getTransportUri()', 'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'setSignature(java.lang.String)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'getFolderDisplayMode()',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'equals(java.lang.Object)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'setLatestOldMessageSeenTime(long)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'excludeUnwantedFolders(com.fsck.k9.search.LocalSearch)',
#   'Service Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.Account', 'getIdentity(int)', 'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'getMaximumPolledMessageAge()',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'isAvailable(android.content.Context)',
#   'Service Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.Account', 'getUuid()', 'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'setTrashFolderName(java.lang.String)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'setMaxPushFolders(int)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'isMessageReadReceiptAlways()',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.K9$ApplicationAware',
#   'initializeComponent(android.app.Application)',
#   'Service Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.Identity', 'getDescription()', 'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Identity',
#   'setSignature(java.lang.String)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Identity',
#   'setEmail(java.lang.String)',
#   'Domain Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.Identity', 'getSignatureUse()', 'Domain Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.Identity', 'getSignature()', 'Domain Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.Identity', 'getName()', 'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Identity',
#   'setDescription(java.lang.String)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Identity',
#   'setReplyTo(java.lang.String)',
#   'Domain Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.Identity', 'getReplyTo()', 'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Identity',
#   'setName(java.lang.String)',
#   'Domain Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.Identity', 'toString()', 'Domain Layer'),
#  ('com.fsck.k9', 'com.fsck.k9.Identity', 'getEmail()', 'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Identity',
#   'setSignatureUse(boolean)',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account$DeletePolicy',
#   'preferenceString()',
#   'Domain Layer'),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account$DeletePolicy',
#   'fromInt(int)',
#   'Domain Layer'),
#  ('com.fsck.k9.account',
#   'com.fsck.k9.account.AccountCreator',
#   'getDefaultDeletePolicy(com.fsck.k9.mail.ServerSettings.Type)',
#   'Service Layer'),
#  ('com.fsck.k9.account',
#   'com.fsck.k9.account.AccountCreator',
#   'getDefaultPort(com.fsck.k9.mail.ConnectionSecurity,com.fsck.k9.mail.ServerSettings.Type)',
#   'Service Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.FolderList$FolderListAdapter',
#   'getFilter()',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.FolderList$FolderListAdapter',
#   'getCount()',
#   'Domain Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.FolderList$FolderListAdapter',
#   'getFolder(java.lang.String)',
#   'Service Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.FolderList$FolderListAdapter',
#   'isEnabled(int)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.FolderList$FolderListAdapter',
#   'getItemView(int,android.view.View,android.view.ViewGroup)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.FolderList$FolderListAdapter',
#   'getView(int,android.view.View,android.view.ViewGroup)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.FolderList$FolderListAdapter',
#   'areAllItemsEnabled()',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.FolderList$FolderListAdapter',
#   'isItemSelectable(int)',
#   'Domain Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.FolderList$FolderListAdapter',
#   'getFolderIndex(java.lang.String)',
#   'Data Source Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.FolderList$FolderListAdapter',
#   'setFilter(android.widget.Filter)',
#   'Domain Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.FolderList$FolderListAdapter',
#   'getItem(int)',
#   'Data Source Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.FolderList$FolderListAdapter',
#   'getItemId(int)',
#   'Data Source Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.FolderList$FolderListAdapter',
#   'getItem(long)',
#   'Data Source Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.FolderList$FolderListAdapter',
#   'hasStableIds()',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.Accounts$AccountsHandler',
#   'progress(boolean)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.Accounts$AccountsHandler',
#   'dataChanged()',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.Accounts$AccountsHandler',
#   'accountSizeChanged(com.fsck.k9.Account,long,long)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.Accounts$AccountsHandler',
#   'refreshTitle()',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.Accounts$AccountsHandler',
#   'progress(int)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.Accounts$AccountsHandler',
#   'workingAccount(com.fsck.k9.Account,int)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageCompose',
#   'showContactPicker(int)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageCompose',
#   'onOptionsItemSelected(android.view.MenuItem)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageCompose',
#   'onRecipientsChanged()',
#   'Domain Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageCompose',
#   'onMessageBuildCancel()',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageCompose',
#   'saveDraftEventually()',
#   'Domain Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageCompose',
#   'onClick(android.view.View)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageCompose',
#   'onPrepareOptionsMenu(android.view.Menu)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageCompose',
#   'onAttachmentRemoved()',
#   'Domain Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageCompose',
#   'onCreate(android.os.Bundle)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageCompose',
#   'onProgressCancel(com.fsck.k9.fragment.ProgressDialogFragment)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageCompose',
#   'onOpenPgpClickDisable()',
#   'Service Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageCompose',
#   'performSendAfterChecks()',
#   'Service Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageCompose',
#   'onAttachmentAdded()',
#   'Domain Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageCompose',
#   'onRetainNonConfigurationInstance()',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageCompose',
#   'loadLocalMessageForDisplay(com.fsck.k9.mailstore.MessageViewInfo,com.fsck.k9.activity.MessageCompose$Action)',
#   'Service Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageCompose',
#   'onFocusChange(android.view.View,boolean)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageCompose',
#   'updateMessageFormat()',
#   'Domain Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageCompose',
#   'onCreateOptionsMenu(android.view.Menu)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageCompose',
#   'onOpenPgpSignOnlyChange(boolean)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageCompose',
#   'onMessageBuildSuccess(com.fsck.k9.mail.internet.MimeMessage,boolean)',
#   'Service Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageCompose',
#   'onDestroy()',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageCompose',
#   'launchUserInteractionPendingIntent(android.app.PendingIntent,int)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageCompose',
#   'onCreateDialog(int)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageCompose',
#   'onPause()',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageCompose',
#   'onMessageBuildException(com.fsck.k9.mail.MessagingException)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageCompose',
#   'onBackPressed()',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageCompose',
#   'loadQuotedTextForEdit()',
#   'Domain Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageCompose',
#   'onProgressCancel(com.fsck.k9.fragment.AttachmentDownloadDialogFragment)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageCompose',
#   'onMessageBuildReturnPendingIntent(android.app.PendingIntent,int)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageCompose',
#   'onOpenPgpInlineChange(boolean)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageInfoHolder',
#   'equals(java.lang.Object)',
#   'Domain Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageInfoHolder',
#   'hashCode()',
#   'Domain Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.Search',
#   'onStop()',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.Search',
#   'onStart()',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.Search',
#   'isActive()',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.Search',
#   'setActive(boolean)',
#   'Service Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.ColorPickerDialog$OnColorChangedListener',
#   'colorChanged(int)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.K9PreferenceActivity',
#   'onCreate(android.os.Bundle)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageList$StorageListenerImplementation',
#   'onUnmount(java.lang.String)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageList$StorageListenerImplementation',
#   'onMount(java.lang.String)',
#   'Domain Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.K9Activity',
#   'dispatchTouchEvent(android.view.MotionEvent)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.K9Activity',
#   'setupGestureDetector(com.fsck.k9.activity.misc.SwipeGestureDetector$OnSwipeGestureListener)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.K9Activity',
#   'onCreate(android.os.Bundle)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.K9ActivityCommon',
#   'getThemeBackgroundColor()',
#   'Data Source Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.K9ActivityCommon',
#   'newInstance(android.app.Activity)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.K9ActivityCommon',
#   'setupGestureDetector(com.fsck.k9.activity.misc.SwipeGestureDetector$OnSwipeGestureListener)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.K9ActivityCommon',
#   'preDispatchTouchEvent(android.view.MotionEvent)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.K9ActivityCommon',
#   'setLanguage(android.content.Context,java.lang.String)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.AccountList',
#   'onResume()',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.AccountList',
#   'onItemClick(android.widget.AdapterView,android.view.View,int,long)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.AccountList',
#   'populateListView(java.util.List)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.AccountList',
#   'onCreate(android.os.Bundle)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.LauncherShortcuts',
#   'onCreate(android.os.Bundle)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.Accounts$PasswordPromptDialog',
#   'onTextChanged(java.lang.CharSequence,int,int,int)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.Accounts$PasswordPromptDialog',
#   'afterTextChanged(android.text.Editable)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.Accounts$PasswordPromptDialog',
#   'restore(android.app.Activity)',
#   'Service Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.Accounts$PasswordPromptDialog',
#   'show(com.fsck.k9.activity.Accounts)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.Accounts$PasswordPromptDialog',
#   'retain()',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.Accounts$PasswordPromptDialog',
#   'beforeTextChanged(java.lang.CharSequence,int,int,int)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.Accounts$AccountClickListener',
#   'onClick(android.view.View)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.ColorPickerDialog',
#   'setColor(int)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.ChooseFolder',
#   'onOptionsItemSelected(android.view.MenuItem)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.ChooseFolder',
#   'onCreateOptionsMenu(android.view.Menu)',
# ...
#   'Presentation Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupAccountType',
#   'onCreate(android.os.Bundle)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupOutgoing',
#   'onCheckedChanged(android.widget.CompoundButton,boolean)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupOutgoing',
#   'onSaveInstanceState(android.os.Bundle)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupOutgoing',
#   'onActivityResult(int,int,android.content.Intent)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupOutgoing',
#   'actionOutgoingSettings(android.content.Context,com.fsck.k9.Account,boolean)',
#   'Service Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupOutgoing',
#   'actionEditOutgoingSettings(android.content.Context,com.fsck.k9.Account)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupOutgoing',
#   'onCreate(android.os.Bundle)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupOutgoing',
#   'intentActionEditOutgoingSettings(android.content.Context,com.fsck.k9.Account)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupOutgoing',
#   'onClick(android.view.View)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSettings',
#   'onCreateDialog(int)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSettings',
#   'onPrepareDialog(int,android.app.Dialog)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSettings',
#   'actionSettings(android.content.Context,com.fsck.k9.Account)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSettings',
#   'onChooseLedColor()',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSettings',
#   'onChooseChipColor()',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSettings',
#   'onActivityResult(int,int,android.content.Intent)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSettings',
#   'onChooseAutoExpandFolder()',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSettings',
#   'onCreate(android.os.Bundle)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.SpinnerOption',
#   'toString()',
#   'Domain Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.SpinnerOption',
#   'setSpinnerOptionValue(android.widget.Spinner,java.lang.Object)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.FolderSettings',
#   'onPause()',
#   'Domain Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.FolderSettings',
#   'actionSettings(android.content.Context,com.fsck.k9.Account,java.lang.String)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.FolderSettings',
#   'onCreate(android.os.Bundle)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupCheckSettings',
#   'onDestroy()',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupCheckSettings',
#   'actionCheckSettings(android.app.Activity,com.fsck.k9.Account,com.fsck.k9.activity.setup.AccountSetupCheckSettings$CheckDirection)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupCheckSettings',
#   'onClick(android.view.View)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupCheckSettings',
#   'doPositiveClick(int)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupCheckSettings',
#   'onCreate(android.os.Bundle)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupCheckSettings',
#   'dialogCancelled(int)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupCheckSettings',
#   'onActivityResult(int,int,android.content.Intent)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupCheckSettings',
#   'doNegativeClick(int)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupComposition',
#   'onBackPressed()',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupComposition',
#   'onCreate(android.os.Bundle)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupComposition',
#   'onActivityResult(int,int,android.content.Intent)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupComposition',
#   'onSaveInstanceState(android.os.Bundle)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupComposition',
#   'actionEditCompositionSettings(android.app.Activity,com.fsck.k9.Account)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.ConnectionSecurityAdapter',
#   'get(android.content.Context,com.fsck.k9.mail.ConnectionSecurity[])',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.ConnectionSecurityAdapter',
#   'getConnectionSecurityPosition(com.fsck.k9.mail.ConnectionSecurity)',
#   'Service Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.ConnectionSecurityAdapter',
#   'get(android.content.Context)',
#   'Service Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.WelcomeMessage',
#   'onCreate(android.os.Bundle)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.WelcomeMessage',
#   'onClick(android.view.View)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.WelcomeMessage',
#   'showWelcomeMessage(android.content.Context)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupIncoming',
#   'actionIncomingSettings(android.app.Activity,com.fsck.k9.Account,boolean)',
#   'Service Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupIncoming',
#   'onSaveInstanceState(android.os.Bundle)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupIncoming',
#   'intentActionEditIncomingSettings(android.content.Context,com.fsck.k9.Account)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupIncoming',
#   'onClick(android.view.View)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupIncoming',
#   'actionEditIncomingSettings(android.app.Activity,com.fsck.k9.Account)',
#   'Service Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupIncoming',
#   'onActivityResult(int,int,android.content.Intent)',
#   'Domain Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupIncoming',
#   'onCreate(android.os.Bundle)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.FontSizeSettings',
#   'actionEditSettings(android.content.Context)',
#   'Service Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.FontSizeSettings',
#   'onCreate(android.os.Bundle)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.FontSizeSettings',
#   'onBackPressed()',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupNames',
#   'onClick(android.view.View)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupNames',
#   'onCreate(android.os.Bundle)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupNames',
#   'actionSetNames(android.content.Context,com.fsck.k9.Account)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.SliderPreference',
#   'setValue(float)',
#   'Domain Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.SliderPreference',
#   'getValue()',
#   'Domain Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.SliderPreference',
#   'getSummary()',
#   'Domain Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.SliderPreference',
#   'setSummary(int)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.SliderPreference',
#   'setSummary(java.lang.CharSequence)',
#   'Domain Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.SliderPreference',
#   'setSummary(java.lang.CharSequence[])',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.ConnectionSecurityHolder',
#   'toString()',
#   'Utility Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.Prefs',
#   'actionPrefs(android.content.Context)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.Prefs',
#   'onCreate(android.os.Bundle)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.OpenPgpAppSelectDialog$OpenPgpAppSelectFragment',
#   'onDismiss(android.content.DialogInterface)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.OpenPgpAppSelectDialog$OpenPgpAppSelectFragment',
#   'onCreateDialog(android.os.Bundle)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.OpenPgpAppSelectDialog$OpenPgpAppSelectFragment',
#   'onCreate(android.os.Bundle)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AuthTypeHolder',
#   'toString()',
#   'Domain Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AuthTypeHolder',
#   'setInsecure(boolean)',
#   'Domain Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupBasics',
#   'onSaveInstanceState(android.os.Bundle)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupBasics',
#   'afterTextChanged(android.text.Editable)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupBasics',
#   'onActivityResult(int,int,android.content.Intent)',
#   'Service Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupBasics',
#   'beforeTextChanged(java.lang.CharSequence,int,int,int)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupBasics',
#   'onClick(android.view.View)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupBasics',
#   'onCreate(android.os.Bundle)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupBasics',
#   'onCreateDialog(int)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupBasics',
#   'onTextChanged(java.lang.CharSequence,int,int,int)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupBasics',
#   'actionNewAccount(android.content.Context)',
#   'Presentation Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupBasics',
#   'onClientCertificateChanged(java.lang.String)',
#   'Domain Layer'),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupBasics',
#   'onCheckedChanged(android.widget.CompoundButton,boolean)',
#   'Presentation Layer'),
#  ('com.fsck.k9.autocrypt',
#   'com.fsck.k9.autocrypt.AutocryptHeaderParser',
#   'getInstance()',
#   'Domain Layer'),
#  ('com.fsck.k9.autocrypt',
#   'com.fsck.k9.autocrypt.AutocryptOperations',
#   'addAutocryptPeerUpdateToIntentIfPresent(com.fsck.k9.mail.Message,android.content.Intent)',
#   'Service Layer'),
#  ('com.fsck.k9.autocrypt',
#   'com.fsck.k9.autocrypt.AutocryptOperations',
#   'getInstance()',
#   'Service Layer'),
#  ('com.fsck.k9.autocrypt',
#   'com.fsck.k9.autocrypt.AutocryptOperations',
#   'addAutocryptHeaderToMessage(com.fsck.k9.mail.Message,byte[],java.lang.String,boolean)',
#   'Service Layer'),
#  ('com.fsck.k9.autocrypt',
#   'com.fsck.k9.autocrypt.AutocryptOperations',
#   'hasAutocryptHeader(com.fsck.k9.mail.Message)',
#   'Domain Layer'),
#  ('com.fsck.k9.autocrypt',
#   'com.fsck.k9.autocrypt.AutocryptOpenPgpApiInteractor',
#   'getInstance()',
#   'Domain Layer'),
#  ('com.fsck.k9.autocrypt',
#   'com.fsck.k9.autocrypt.AutocryptOpenPgpApiInteractor',
#   'getKeyMaterialFromApi(org.openintents.openpgp.util.OpenPgpApi,long,java.lang.String)',
#   'Data Source Layer'),
#  ('com.fsck.k9.autocrypt',
#   'com.fsck.k9.autocrypt.AutocryptHeader',
#   'hashCode()',
#   'Domain Layer'),
#  ('com.fsck.k9.autocrypt',
#   'com.fsck.k9.autocrypt.AutocryptHeader',
#   'equals(java.lang.Object)',
#   'Domain Layer'),
#  ('com.fsck.k9.cache',
#   'com.fsck.k9.cache.TemporaryAttachmentStore',
#   'getFileForWriting(android.content.Context,java.lang.String)',
#   'Data Source Layer'),
#  ('com.fsck.k9.cache',
#   'com.fsck.k9.cache.TemporaryAttachmentStore',
#   'getFile(android.content.Context,java.lang.String)',
#   'Data Source Layer'),
#  ('com.fsck.k9.cache',
#   'com.fsck.k9.cache.EmailProviderCacheCursor',
#   'getPosition()',
#   'Domain Layer'),
#  ('com.fsck.k9.cache',
#   'com.fsck.k9.cache.EmailProviderCacheCursor',
#   'moveToNext()',
#   'Data Source Layer'),
#  ('com.fsck.k9.cache',
#   'com.fsck.k9.cache.EmailProviderCacheCursor',
#   'moveToPosition(int)',
#   'Domain Layer'),
#  ('com.fsck.k9.cache',
#   'com.fsck.k9.cache.EmailProviderCacheCursor',
#   'moveToLast()',
#   'Data Source Layer'),
#  ('com.fsck.k9.cache',
#   'com.fsck.k9.cache.EmailProviderCacheCursor',
#   'isLast()',
#   'Domain Layer'),
#  ('com.fsck.k9.cache',
#   'com.fsck.k9.cache.EmailProviderCacheCursor',
#   'getInt(int)',
#   'Domain Layer'),
#  ('com.fsck.k9.cache',
#   'com.fsck.k9.cache.EmailProviderCacheCursor',
#   'moveToFirst()',
#   'Data Source Layer'),
#  ('com.fsck.k9.cache',
#   'com.fsck.k9.cache.EmailProviderCacheCursor',
#   'move(int)',
#   'Domain Layer'),
#  ('com.fsck.k9.cache',
#   'com.fsck.k9.cache.EmailProviderCacheCursor',
#   'moveToPrevious()',
#   'Domain Layer'),
#  ('com.fsck.k9.cache',
#   'com.fsck.k9.cache.EmailProviderCacheCursor',
#   'getCount()',
#   'Domain Layer'),
#  ('com.fsck.k9.cache',
#   'com.fsck.k9.cache.EmailProviderCache',
#   'getCache(java.lang.String,android.content.Context)',
#   'Data Source Layer'),
#  ('com.fsck.k9.cache',
#   'com.fsck.k9.cache.EmailProviderCache',
#   'setValueForThreads(java.util.List,java.lang.String,java.lang.String)',
#   'Service Layer'),
#  ('com.fsck.k9.cache',
#   'com.fsck.k9.cache.EmailProviderCache',
#   'removeValueForThreads(java.util.List,java.lang.String)',
#   'Domain Layer'),
#  ('com.fsck.k9.cache',
#   'com.fsck.k9.cache.EmailProviderCache',
#   'hideMessages(java.util.List)',
#   'Service Layer'),
#  ('com.fsck.k9.cache',
#   'com.fsck.k9.cache.EmailProviderCache',
#   'removeValueForMessages(java.util.List,java.lang.String)',
#   'Domain Layer'),
#  ('com.fsck.k9.cache',
#   'com.fsck.k9.cache.EmailProviderCache',
#   'setValueForMessages(java.util.List,java.lang.String,java.lang.String)',
#   'Service Layer'),
#  ('com.fsck.k9.cache',
#   'com.fsck.k9.cache.EmailProviderCache',
#   'getValueForThread(java.lang.Long,java.lang.String)',
#   'Domain Layer'),
#  ('com.fsck.k9.cache',
#   'com.fsck.k9.cache.EmailProviderCache',
#   'getValueForMessage(java.lang.Long,java.lang.String)',
#   'Domain Layer'),
#  ('com.fsck.k9.cache',
#   'com.fsck.k9.cache.EmailProviderCache',
#   'unhideMessages(java.util.List)',
#   'Domain Layer'),
#  ...]

# %%
header = ("package", "class", "method", "layer")

# %%
import csv

with open(f"layerinator-v2/{project_name}-layers1-{timestr}.csv", mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(header)
    writer.writerows(rows)

# %%
rows = []

for package in results:
	for clss in [c for c in results[package] if c != 'layers']:
		for layer in results[package][clss]['layers']:
			rows.append((package,clss,layer,results[package][clss]['layers'][layer]))

rows
# Out:
# [('com.fsck.k9', 'com.fsck.k9.Throttle$MyTimerTask', 'Service Layer', 1),
#  ('com.fsck.k9', 'com.fsck.k9.Throttle$MyTimerTask', 'Presentation Layer', 1),
#  ('com.fsck.k9', 'com.fsck.k9.Throttle', 'Execution Layer', 1),
#  ('com.fsck.k9', 'com.fsck.k9.Throttle', 'Service Layer', 1),
#  ('com.fsck.k9', 'com.fsck.k9.PRNGFixes', 'Utility Layer', 1),
#  ('com.fsck.k9', 'com.fsck.k9.BaseAccount', 'Domain Layer', 5),
#  ('com.fsck.k9',
#   'com.fsck.k9.Throttle$MyTimerTask$HandlerRunnable',
#   'Service Layer',
#   1),
#  ('com.fsck.k9', 'com.fsck.k9.K9', 'Presentation Layer', 40),
#  ('com.fsck.k9', 'com.fsck.k9.K9', 'Service Layer', 45),
#  ('com.fsck.k9', 'com.fsck.k9.K9', 'Domain Layer', 35),
#  ('com.fsck.k9', 'com.fsck.k9.K9', 'Data Source Layer', 10),
#  ('com.fsck.k9', 'com.fsck.k9.K9', 'Utility Layer', 5),
#  ('com.fsck.k9', 'com.fsck.k9.K9', 'None', 2),
#  ('com.fsck.k9', 'com.fsck.k9.EmailAddressValidator', 'Domain Layer', 3),
#  ('com.fsck.k9', 'com.fsck.k9.Account$SortType', 'Domain Layer', 1),
#  ('com.fsck.k9', 'com.fsck.k9.Account$SortType', 'Presentation Layer', 1),
#  ('com.fsck.k9', 'com.fsck.k9.Globals', 'Utility Layer', 1),
#  ('com.fsck.k9', 'com.fsck.k9.FontSizes', 'Presentation Layer', 5),
#  ('com.fsck.k9', 'com.fsck.k9.FontSizes', 'Domain Layer', 30),
#  ('com.fsck.k9', 'com.fsck.k9.FontSizes', 'Data Source Layer', 2),
#  ('com.fsck.k9', 'com.fsck.k9.NotificationSetting', 'Domain Layer', 13),
#  ('com.fsck.k9', 'com.fsck.k9.NotificationSetting', 'Utility Layer', 1),
#  ('com.fsck.k9', 'com.fsck.k9.NotificationSetting', 'Data Source Layer', 1),
#  ('com.fsck.k9', 'com.fsck.k9.NotificationSetting', 'Presentation Layer', 1),
#  ('com.fsck.k9', 'com.fsck.k9.Preferences', 'Data Source Layer', 4),
#  ('com.fsck.k9', 'com.fsck.k9.Preferences', 'Service Layer', 2),
#  ('com.fsck.k9', 'com.fsck.k9.Preferences', 'Domain Layer', 4),
#  ('com.fsck.k9', 'com.fsck.k9.Clock', 'Utility Layer', 1),
#  ('com.fsck.k9', 'com.fsck.k9.Account', 'Data Source Layer', 10),
#  ('com.fsck.k9', 'com.fsck.k9.Account', 'Domain Layer', 134),
#  ('com.fsck.k9', 'com.fsck.k9.Account', 'Service Layer', 12),
#  ('com.fsck.k9', 'com.fsck.k9.Account', 'Presentation Layer', 1),
#  ('com.fsck.k9', 'com.fsck.k9.K9$ApplicationAware', 'Service Layer', 1),
#  ('com.fsck.k9', 'com.fsck.k9.Identity', 'Domain Layer', 13),
#  ('com.fsck.k9', 'com.fsck.k9.Account$DeletePolicy', 'Domain Layer', 2),
#  ('com.fsck.k9.account',
#   'com.fsck.k9.account.AccountCreator',
#   'Service Layer',
#   2),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.FolderList$FolderListAdapter',
#   'Presentation Layer',
#   6),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.FolderList$FolderListAdapter',
#   'Domain Layer',
#   3),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.FolderList$FolderListAdapter',
#   'Service Layer',
#   1),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.FolderList$FolderListAdapter',
#   'Data Source Layer',
#   4),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.Accounts$AccountsHandler',
#   'Presentation Layer',
#   6),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageCompose',
#   'Presentation Layer',
#   20),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageCompose',
#   'Domain Layer',
#   6),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageCompose',
#   'Service Layer',
#   4),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageInfoHolder',
#   'Domain Layer',
#   2),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.Search',
#   'Presentation Layer',
#   3),
#  ('com.fsck.k9.activity', 'com.fsck.k9.activity.Search', 'Service Layer', 1),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.ColorPickerDialog$OnColorChangedListener',
#   'Presentation Layer',
#   1),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.K9PreferenceActivity',
#   'Presentation Layer',
#   1),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageList$StorageListenerImplementation',
#   'Presentation Layer',
#   1),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageList$StorageListenerImplementation',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.K9Activity',
#   'Presentation Layer',
#   3),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.K9ActivityCommon',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.K9ActivityCommon',
#   'Presentation Layer',
#   4),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.AccountList',
#   'Presentation Layer',
#   4),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.LauncherShortcuts',
#   'Presentation Layer',
#   1),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.Accounts$PasswordPromptDialog',
#   'Presentation Layer',
#   5),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.Accounts$PasswordPromptDialog',
#   'Service Layer',
#   1),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.Accounts$AccountClickListener',
#   'Presentation Layer',
#   1),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.ColorPickerDialog',
#   'Presentation Layer',
#   1),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.ChooseFolder',
#   'Presentation Layer',
#   3),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.EditIdentity',
#   'Presentation Layer',
#   3),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageCompose$Action',
#   'Presentation Layer',
#   1),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.UnreadWidgetConfiguration',
#   'Presentation Layer',
#   4),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.UnreadWidgetConfiguration',
#   'Data Source Layer',
#   2),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.EmailAddressList',
#   'Presentation Layer',
#   2),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.K9PreferenceActivity$PreferenceChangeListener',
#   'Presentation Layer',
#   1),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.Accounts$AccountsAdapter',
#   'Presentation Layer',
#   1),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.AccountList$AccountsAdapter',
#   'Presentation Layer',
#   1),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.FolderList$FolderClickListener',
#   'Presentation Layer',
#   1),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.Accounts',
#   'Presentation Layer',
#   16),
#  ('com.fsck.k9.activity', 'com.fsck.k9.activity.Accounts', 'Service Layer', 3),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageLoaderHelper',
#   'Service Layer',
#   3),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageLoaderHelper',
#   'Presentation Layer',
#   4),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.ConfirmationDialog',
#   'Presentation Layer',
#   3),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.AlternateRecipientAdapter$AlternateRecipientListener',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.AlternateRecipientAdapter$AlternateRecipientListener',
#   'Presentation Layer',
#   1),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.FolderList$FolderListHandler',
#   'Presentation Layer',
#   7),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.K9ListActivity',
#   'Presentation Layer',
#   6),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.ChooseFolder$ChooseFolderHandler',
#   'Presentation Layer',
#   2),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.ChooseFolder$ChooseFolderHandler',
#   'Service Layer',
#   1),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.ActivityListener',
#   'Presentation Layer',
#   5),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.ActivityListener',
#   'Service Layer',
#   12),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.ActivityListener',
#   'Domain Layer',
#   5),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.ActivityListener',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.NotificationDeleteConfirmation',
#   'Presentation Layer',
#   3),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.NotificationDeleteConfirmation',
#   'Service Layer',
#   2),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.ChooseIdentity',
#   'Presentation Layer',
#   2),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.UpgradeDatabases',
#   'Presentation Layer',
#   2),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.UpgradeDatabases',
#   'Service Layer',
#   2),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.Accounts$ImportSelectionDialog',
#   'Presentation Layer',
#   4),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.AlternateRecipientAdapter',
#   'Presentation Layer',
#   6),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.AlternateRecipientAdapter',
#   'Domain Layer',
#   5),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageLoaderHelper$MessageLoaderCallbacks',
#   'Service Layer',
#   5),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageLoaderHelper$MessageLoaderCallbacks',
#   'Presentation Layer',
#   2),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageLoaderHelper$MessageLoaderCallbacks',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.K9ActivityCommon$K9ActivityMagic',
#   'Presentation Layer',
#   1),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.UpgradeDatabases$UpgradeDatabaseBroadcastReceiver',
#   'Presentation Layer',
#   1),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.AlternateRecipientAdapter$RecipientTokenHolder',
#   'Presentation Layer',
#   1),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.FolderList',
#   'Presentation Layer',
#   8),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.FolderList',
#   'Data Source Layer',
#   2),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.FolderList',
#   'Service Layer',
#   3),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.Accounts$SimpleDialog',
#   'Presentation Layer',
#   3),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageReferenceHelper',
#   'Domain Layer',
#   2),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageReference',
#   'Domain Layer',
#   12),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.ManageIdentities',
#   'Presentation Layer',
#   6),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.FolderList$FolderListAdapter$FolderListFilter',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.FolderListFilter',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageList',
#   'Presentation Layer',
#   40),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageList',
#   'Data Source Layer',
#   2),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageList',
#   'Service Layer',
#   9),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageList',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.FolderInfoHolder',
#   'Domain Layer',
#   4),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.FolderInfoHolder',
#   'Service Layer',
#   3),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.PgpEnabledErrorDialog$OnOpenPgpDisableListener',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.RecipientLoader',
#   'Service Layer',
#   1),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.RecipientLoader',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.PgpInlineDialog',
#   'Presentation Layer',
#   2),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.PgpSignOnlyDialog',
#   'Presentation Layer',
#   2),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.AttachmentPresenter$AttachmentMvpView',
#   'Service Layer',
#   2),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.AttachmentPresenter$AttachmentMvpView',
#   'Presentation Layer',
#   7),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.ComposeCryptoStatus',
#   'Service Layer',
#   1),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.ComposeCryptoStatus',
#   'Domain Layer',
#   8),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.IdentityAdapter',
#   'Presentation Layer',
#   6),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.IdentityAdapter',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.IdentityAdapter',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.RecipientPresenter$RecipientsChangedListener',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.PgpEncryptDescriptionDialog',
#   'Presentation Layer',
#   2),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.PgpEnabledErrorDialog',
#   'Service Layer',
#   1),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.PgpEnabledErrorDialog',
#   'Presentation Layer',
#   1),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.RecipientAdapter',
#   'Presentation Layer',
#   6),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.RecipientAdapter',
#   'Domain Layer',
#   3),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.PgpSignOnlyDialog$OnOpenPgpSignOnlyChangeListener',
#   'Service Layer',
#   1),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.ComposeCryptoStatus$ComposeCryptoStatusBuilder',
#   'Domain Layer',
#   7),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.MessageActions',
#   'Presentation Layer',
#   4),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.MessageActions',
#   'Service Layer',
#   2),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.PgpInlineDialog$OnOpenPgpInlineChangeListener',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.RecipientMvpView',
#   'Presentation Layer',
#   43),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.RecipientMvpView',
#   'Domain Layer',
#   6),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.RecipientPresenter',
#   'Presentation Layer',
#   15),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.RecipientPresenter',
#   'Service Layer',
#   11),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.RecipientPresenter',
#   'Domain Layer',
#   7),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.RecipientPresenter',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.AttachmentPresenter',
#   'Service Layer',
#   4),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.AttachmentPresenter',
#   'Presentation Layer',
#   6),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.AttachmentPresenter',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.AttachmentPresenter$AttachmentsChangedListener',
#   'Service Layer',
#   1),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.AttachmentPresenter$AttachmentsChangedListener',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.activity.loader',
#   'com.fsck.k9.activity.loader.AttachmentContentLoader',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.activity.loader',
#   'com.fsck.k9.activity.loader.AttachmentInfoLoader',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.activity.misc',
#   'com.fsck.k9.activity.misc.ContactPictureLoader$FallbackGlideModelLoader',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.activity.misc',
#   'com.fsck.k9.activity.misc.ContactPictureLoader$FallbackGlideBitmapDecoder',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.activity.misc',
#   'com.fsck.k9.activity.misc.ContactPictureLoader$FallbackGlideBitmapDecoder',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.activity.misc',
#   'com.fsck.k9.activity.misc.ContactPictureLoader',
#   'Data Source Layer',
#   2),
#  ('com.fsck.k9.activity.misc',
#   'com.fsck.k9.activity.misc.ContactPictureLoader$FallbackGlideParams',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.activity.misc',
#   'com.fsck.k9.activity.misc.SwipeGestureDetector$OnSwipeGestureListener',
#   'Presentation Layer',
#   2),
#  ('com.fsck.k9.activity.misc',
#   'com.fsck.k9.activity.misc.Attachment',
#   'Domain Layer',
#   4),
#  ('com.fsck.k9.activity.misc',
#   'com.fsck.k9.activity.misc.Attachment',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.activity.misc',
#   'com.fsck.k9.activity.misc.Attachment',
#   'Presentation Layer',
#   1),
#  ('com.fsck.k9.activity.misc',
#   'com.fsck.k9.activity.misc.ExtendedAsyncTask',
#   'Presentation Layer',
#   2),
#  ('com.fsck.k9.activity.misc',
#   'com.fsck.k9.activity.misc.SwipeGestureDetector',
#   'Presentation Layer',
#   2),
#  ('com.fsck.k9.activity.misc',
#   'com.fsck.k9.activity.misc.NonConfigurationInstance',
#   'Service Layer',
#   1),
#  ('com.fsck.k9.activity.misc',
#   'com.fsck.k9.activity.misc.NonConfigurationInstance',
#   'Presentation Layer',
#   1),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.OpenPgpAppSelectDialog',
#   'Presentation Layer',
#   2),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.OpenPgpAppSelectDialog',
#   'Service Layer',
#   1),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.OpenPgpAppSelectDialog$ApgDeprecationDialogFragment',
#   'Presentation Layer',
#   2),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupOptions',
#   'Presentation Layer',
#   3),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AuthTypeAdapter',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AuthTypeAdapter',
#   'Presentation Layer',
#   2),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.OpenPgpAppSelectDialog$OpenPgpProviderEntry',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupAccountType',
#   'Service Layer',
#   1),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupAccountType',
#   'Presentation Layer',
#   2),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupOutgoing',
#   'Presentation Layer',
#   7),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupOutgoing',
#   'Service Layer',
#   1),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSettings',
#   'Presentation Layer',
#   8),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.SpinnerOption',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.SpinnerOption',
#   'Presentation Layer',
#   1),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.FolderSettings',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.FolderSettings',
#   'Presentation Layer',
#   2),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupCheckSettings',
#   'Presentation Layer',
#   8),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupComposition',
#   'Presentation Layer',
#   5),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.ConnectionSecurityAdapter',
#   'Presentation Layer',
#   1),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.ConnectionSecurityAdapter',
#   'Service Layer',
#   2),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.WelcomeMessage',
#   'Presentation Layer',
#   3),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupIncoming',
#   'Service Layer',
#   2),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupIncoming',
#   'Presentation Layer',
#   4),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupIncoming',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.FontSizeSettings',
#   'Service Layer',
#   1),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.FontSizeSettings',
#   'Presentation Layer',
#   2),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupNames',
#   'Presentation Layer',
#   3),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.SliderPreference',
#   'Domain Layer',
#   4),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.SliderPreference',
#   'Presentation Layer',
#   2),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.ConnectionSecurityHolder',
#   'Utility Layer',
#   1),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.Prefs',
#   'Presentation Layer',
#   2),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.OpenPgpAppSelectDialog$OpenPgpAppSelectFragment',
#   'Presentation Layer',
#   3),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AuthTypeHolder',
#   'Domain Layer',
#   2),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupBasics',
#   'Presentation Layer',
#   9),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupBasics',
#   'Service Layer',
#   1),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupBasics',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.autocrypt',
#   'com.fsck.k9.autocrypt.AutocryptHeaderParser',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.autocrypt',
#   'com.fsck.k9.autocrypt.AutocryptOperations',
#   'Service Layer',
#   3),
#  ('com.fsck.k9.autocrypt',
#   'com.fsck.k9.autocrypt.AutocryptOperations',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.autocrypt',
#   'com.fsck.k9.autocrypt.AutocryptOpenPgpApiInteractor',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.autocrypt',
#   'com.fsck.k9.autocrypt.AutocryptOpenPgpApiInteractor',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.autocrypt',
#   'com.fsck.k9.autocrypt.AutocryptHeader',
#   'Domain Layer',
#   2),
#  ('com.fsck.k9.cache',
#   'com.fsck.k9.cache.TemporaryAttachmentStore',
#   'Data Source Layer',
#   2),
#  ('com.fsck.k9.cache',
#   'com.fsck.k9.cache.EmailProviderCacheCursor',
#   'Domain Layer',
#   7),
#  ('com.fsck.k9.cache',
#   'com.fsck.k9.cache.EmailProviderCacheCursor',
#   'Data Source Layer',
#   3),
#  ('com.fsck.k9.cache',
#   'com.fsck.k9.cache.EmailProviderCache',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.cache',
#   'com.fsck.k9.cache.EmailProviderCache',
#   'Service Layer',
#   3),
#  ('com.fsck.k9.cache',
#   'com.fsck.k9.cache.EmailProviderCache',
#   'Domain Layer',
#   6),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.ProgressBodyFactory$ProgressListener',
#   'Service Layer',
#   1),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.MessagingControllerPushReceiver',
#   'Service Layer',
#   8),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.MessagingControllerPushReceiver',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.MessagingControllerPushReceiver',
#   'Presentation Layer',
#   1),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.MemorizingMessagingListener',
#   'Service Layer',
#   5),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.MemorizingMessagingListener',
#   'Domain Layer',
#   7),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.SimpleMessagingListener',
#   'Service Layer',
#   30),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.SimpleMessagingListener',
#   'Domain Layer',
#   10),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.SimpleMessagingListener',
#   'Presentation Layer',
#   1),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.SimpleMessagingListener',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.PendingCommandSerializer',
#   'Service Layer',
#   1),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.PendingCommandSerializer',
#   'Data Source Layer',
#   2),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.MessagingControllerCommands$PendingMoveOrCopy',
#   'Service Layer',
#   3),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.MessagingControllerCommands$PendingMoveOrCopy',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.MessagingControllerCommands$PendingEmptyTrash',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.MessagingControllerCommands$PendingEmptyTrash',
#   'Service Layer',
#   2),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.MessagingControllerCommands$PendingMarkAllAsRead',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.MessagingControllerCommands$PendingMarkAllAsRead',
#   'Service Layer',
#   2),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.MessagingControllerCommands$PendingCommand',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.MessagingControllerCommands$PendingCommand',
#   'Service Layer',
#   1),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.MessagingListener',
#   'Service Layer',
#   26),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.MessagingListener',
#   'Domain Layer',
#   12),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.MessagingListener',
#   'Data Source Layer',
#   3),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.MessagingListener',
#   'Presentation Layer',
#   1),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.MessagingController$MessageActor',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.MessagingControllerCommands$PendingAppend',
#   'Domain Layer',
#   2),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.MessagingControllerCommands$PendingAppend',
#   'Service Layer',
#   1),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.MessagingController$Command',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.UidReverseComparator',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.MessagingController',
#   'Service Layer',
#   56),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.MessagingController',
#   'Domain Layer',
#   8),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.MessagingController',
#   'Presentation Layer',
#   1),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.MessagingController',
#   'Data Source Layer',
#   2),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.MessagingControllerCommands$PendingExpunge',
#   'Service Layer',
#   2),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.MessagingControllerCommands$PendingExpunge',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.MessagingControllerCommands$PendingSetFlag',
#   'Service Layer',
#   3),
#  ('com.fsck.k9.crypto',
#   'com.fsck.k9.crypto.MessageCryptoStructureDetector',
#   'Domain Layer',
#   8),
#  ('com.fsck.k9.crypto',
#   'com.fsck.k9.crypto.MessageCryptoStructureDetector',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.crypto',
#   'com.fsck.k9.crypto.OpenPgpApiHelper',
#   'Service Layer',
#   1),
#  ('com.fsck.k9.fragment',
#   'com.fsck.k9.fragment.MessageListFragment',
#   'Presentation Layer',
#   33),
#  ('com.fsck.k9.fragment',
#   'com.fsck.k9.fragment.MessageListFragment',
#   'Domain Layer',
#   17),
#  ('com.fsck.k9.fragment',
#   'com.fsck.k9.fragment.MessageListFragment',
#   'Service Layer',
#   9),
#  ('com.fsck.k9.fragment',
#   'com.fsck.k9.fragment.MessageListFragment',
#   'Utility Layer',
#   1),
#  ('com.fsck.k9.fragment',
#   'com.fsck.k9.fragment.MessageListFragment',
#   'Data Source Layer',
#   2),
#  ('com.fsck.k9.fragment',
#   'com.fsck.k9.fragment.MessageListFragmentComparators$SenderComparator',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.fragment',
#   'com.fsck.k9.fragment.ProgressDialogFragment',
#   'Presentation Layer',
#   3),
#  ('com.fsck.k9.fragment',
#   'com.fsck.k9.fragment.AttachmentDownloadDialogFragment',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.fragment',
#   'com.fsck.k9.fragment.AttachmentDownloadDialogFragment',
#   'Presentation Layer',
#   3),
#  ('com.fsck.k9.fragment',
#   'com.fsck.k9.fragment.MessageListFragmentComparators$ArrivalComparator',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.fragment',
#   'com.fsck.k9.fragment.ProgressDialogFragment$CancelListener',
#   'Presentation Layer',
#   1),
#  ('com.fsck.k9.fragment',
#   'com.fsck.k9.fragment.MessageListFragment$MessageListActivityListener',
#   'Presentation Layer',
#   9),
#  ('com.fsck.k9.fragment',
#   'com.fsck.k9.fragment.MessageListFragment$MessageListActivityListener',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.fragment',
#   'com.fsck.k9.fragment.MessageListAdapter',
#   'Presentation Layer',
#   2),
#  ('com.fsck.k9.fragment',
#   'com.fsck.k9.fragment.MessageListFragmentComparators$FlaggedComparator',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.fragment',
#   'com.fsck.k9.fragment.MessageListFragmentComparators$SubjectComparator',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.fragment',
#   'com.fsck.k9.fragment.MessageListFragmentComparators$AttachmentComparator',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.fragment',
#   'com.fsck.k9.fragment.MessageListFragmentComparators$UnreadComparator',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.fragment',
#   'com.fsck.k9.fragment.MessageListHandler',
#   'Service Layer',
#   4),
#  ('com.fsck.k9.fragment',
#   'com.fsck.k9.fragment.MessageListHandler',
#   'Presentation Layer',
#   5),
#  ('com.fsck.k9.fragment',
#   'com.fsck.k9.fragment.AttachmentDownloadDialogFragment$AttachmentDownloadCancelListener',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.fragment',
#   'com.fsck.k9.fragment.ConfirmationDialogFragment',
#   'Presentation Layer',
#   6),
#  ('com.fsck.k9.fragment',
#   'com.fsck.k9.fragment.MessageViewHolder',
#   'Presentation Layer',
#   1),
#  ('com.fsck.k9.fragment',
#   'com.fsck.k9.fragment.MessageListFragmentComparators$ComparatorChain',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.fragment',
#   'com.fsck.k9.fragment.ConfirmationDialogFragment$ConfirmationDialogFragmentListener',
#   'Presentation Layer',
#   3),
#  ('com.fsck.k9.fragment',
#   'com.fsck.k9.fragment.MessageListFragmentComparators$DateComparator',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.fragment',
#   'com.fsck.k9.fragment.MessageListFragmentComparators$ReverseIdComparator',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.fragment',
#   'com.fsck.k9.fragment.MessageListFragment$MessageListFragmentListener',
#   'Presentation Layer',
#   5),
#  ('com.fsck.k9.fragment',
#   'com.fsck.k9.fragment.MessageListFragment$MessageListFragmentListener',
#   'Domain Layer',
#   6),
#  ('com.fsck.k9.fragment',
#   'com.fsck.k9.fragment.MessageListFragment$MessageListFragmentListener',
#   'Service Layer',
#   6),
#  ('com.fsck.k9.fragment',
#   'com.fsck.k9.fragment.MessageListFragment$ActionModeCallback',
#   'Presentation Layer',
#   7),
#  ('com.fsck.k9.fragment',
#   'com.fsck.k9.fragment.MessageListFragmentComparators$ReverseComparator',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.MergeCursor',
#   'Data Source Layer',
#   30),
#  ('com.fsck.k9.helper', 'com.fsck.k9.helper.MergeCursor', 'Domain Layer', 9),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.MergeCursor',
#   'Presentation Layer',
#   1),
#  ('com.fsck.k9.helper', 'com.fsck.k9.helper.MergeCursor', 'Service Layer', 1),
#  ('com.fsck.k9.helper', 'com.fsck.k9.helper.EmailHelper', 'Domain Layer', 1),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.IdentityHelper',
#   'Service Layer',
#   1),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.MergeCursorWithUniqueId',
#   'Data Source Layer',
#   3),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.MergeCursorWithUniqueId',
#   'Presentation Layer',
#   1),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.UrlEncodingHelper',
#   'Utility Layer',
#   2),
#  ('com.fsck.k9.helper', 'com.fsck.k9.helper.MessageHelper', 'Domain Layer', 4),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.MessageHelper',
#   'Service Layer',
#   1),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.MessageHelper',
#   'Utility Layer',
#   1),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.FileHelper',
#   'Data Source Layer',
#   4),
#  ('com.fsck.k9.helper', 'com.fsck.k9.helper.FileHelper', 'Utility Layer', 1),
#  ('com.fsck.k9.helper', 'com.fsck.k9.helper.FileHelper', 'Service Layer', 1),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.K9AlarmManager',
#   'Data Source Layer',
#   2),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.K9AlarmManager',
#   'Service Layer',
#   1),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.UnreadWidgetProperties',
#   'Service Layer',
#   2),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.UnreadWidgetProperties',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.UnreadWidgetProperties',
#   'Domain Layer',
#   3),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.SizeFormatter',
#   'Utility Layer',
#   1),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.FileBrowserHelper',
#   'Presentation Layer',
#   2),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.FileBrowserHelper',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.ParcelableUtil',
#   'Data Source Layer',
#   2),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.RetainFragment',
#   'Data Source Layer',
#   4),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.RetainFragment',
#   'Presentation Layer',
#   2),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.RetainFragment',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.FileBrowserHelper$FileBrowserFailOverCallback',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.FileBrowserHelper$FileBrowserFailOverCallback',
#   'Presentation Layer',
#   1),
#  ('com.fsck.k9.helper', 'com.fsck.k9.helper.MailTo', 'Domain Layer', 5),
#  ('com.fsck.k9.helper', 'com.fsck.k9.helper.MailTo', 'Data Source Layer', 1),
#  ('com.fsck.k9.helper', 'com.fsck.k9.helper.MailTo', 'Utility Layer', 1),
#  ('com.fsck.k9.helper', 'com.fsck.k9.helper.Contacts', 'Data Source Layer', 6),
#  ('com.fsck.k9.helper', 'com.fsck.k9.helper.Contacts', 'Domain Layer', 1),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.Contacts',
#   'Presentation Layer',
#   1),
#  ('com.fsck.k9.helper', 'com.fsck.k9.helper.Contacts', 'Service Layer', 1),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.SimpleTextWatcher',
#   'Presentation Layer',
#   3),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.ContactPicture',
#   'Presentation Layer',
#   1),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.ClipboardManager',
#   'Data Source Layer',
#   2),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.MailTo$CaseInsensitiveParamWrapper',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.ReplyToParser',
#   'Service Layer',
#   1),
#  ('com.fsck.k9.helper', 'com.fsck.k9.helper.ReplyToParser', 'Domain Layer', 1),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.ExceptionHelper',
#   'Service Layer',
#   1),
#  ('com.fsck.k9.helper', 'com.fsck.k9.helper.Utility', 'Data Source Layer', 2),
#  ('com.fsck.k9.helper', 'com.fsck.k9.helper.Utility', 'Utility Layer', 8),
#  ('com.fsck.k9.helper', 'com.fsck.k9.helper.Utility', 'Service Layer', 3),
#  ('com.fsck.k9.helper', 'com.fsck.k9.helper.Utility', 'Presentation Layer', 3),
#  ('com.fsck.k9.helper', 'com.fsck.k9.helper.Utility', 'Domain Layer', 4),
#  ('com.fsck.k9.helper', 'com.fsck.k9.helper.Preconditions', 'Domain Layer', 1),
#  ('com.fsck.k9.helper.jsoup',
#   'com.fsck.k9.helper.jsoup.NodeFilter',
#   'Service Layer',
#   2),
#  ('com.fsck.k9.helper.jsoup',
#   'com.fsck.k9.helper.jsoup.AdvancedNodeTraversor',
#   'Service Layer',
#   1),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.StorageManager$SamsungGalaxySStorageProvider',
#   'Presentation Layer',
#   1),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.StorageManager$SamsungGalaxySStorageProvider',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.StorageManager$ExternalStorageProvider',
#   'Data Source Layer',
#   6),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.StorageManager$ExternalStorageProvider',
#   'Service Layer',
#   1),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.StorageManager$ExternalStorageProvider',
#   'Presentation Layer',
#   1),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.LocalStore',
#   'Domain Layer',
#   7),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.LocalStore',
#   'Data Source Layer',
#   17),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.LocalStore',
#   'Service Layer',
#   5),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.LockableDatabase$StorageListener',
#   'Data Source Layer',
#   2),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.LockableDatabase$DbCallback',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.CryptoResultAnnotation',
#   'Domain Layer',
#   16),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.CryptoResultAnnotation',
#   'Utility Layer',
#   1),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.CryptoResultAnnotation',
#   'Service Layer',
#   2),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.CryptoResultAnnotation',
#   'Presentation Layer',
#   2),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.AttachmentViewInfo',
#   'Domain Layer',
#   2),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.DatabasePreviewType',
#   'Service Layer',
#   1),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.DatabasePreviewType',
#   'Data Source Layer',
#   2),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.DatabasePreviewType',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.LocalFolder$MoreMessages',
#   'Data Source Layer',
#   2),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.LocalMimeMessage',
#   'Domain Layer',
#   3),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.StorageManager$HtcIncredibleStorageProvider',
#   'Presentation Layer',
#   1),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.StorageManager$HtcIncredibleStorageProvider',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.MessageHelper',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.MessageHelper',
#   'Utility Layer',
#   1),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.StoreSchemaDefinition$RealMigrationsHelper',
#   'Data Source Layer',
#   5),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.LockableDatabase',
#   'Data Source Layer',
#   2),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.LockableDatabase',
#   'Service Layer',
#   3),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.LockableDatabase',
#   'Domain Layer',
#   2),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.LocalFolder',
#   'Data Source Layer',
#   18),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.LocalFolder',
#   'Domain Layer',
#   38),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.LocalFolder',
#   'Service Layer',
#   20),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.MessageRemovalListener',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.TempFileBody',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.TempFileBody',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.MimePartStreamParser$PartBuilder',
#   'Domain Layer',
#   9),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.MimePartStreamParser$PartBuilder',
#   'Service Layer',
#   2),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.MimePartStreamParser$PartBuilder',
#   'Data Source Layer',
#   2),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.LockableDatabase$SchemaDefinition',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.LockableDatabase$SchemaDefinition',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.MessageViewInfoExtractor',
#   'Service Layer',
#   2),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.StorageManager$InternalStorageProvider',
#   'Data Source Layer',
#   5),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.StorageManager$InternalStorageProvider',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.StorageManager$InternalStorageProvider',
#   'Presentation Layer',
#   1),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.StorageManager$InternalStorageProvider',
#   'Service Layer',
#   1),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.MessageViewInfo',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.AttachmentResolver',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.AttachmentResolver',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.DeferredFileBody',
#   'Domain Layer',
#   4),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.DeferredFileBody',
#   'Data Source Layer',
#   3),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.FileBackedBody',
#   'Data Source Layer',
#   2),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.FileBackedBody',
#   'Domain Layer',
#   3),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.LocalBodyPart',
#   'Domain Layer',
#   4),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.StorageManager$FixedStorageProviderBase',
#   'Data Source Layer',
#   4),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.StorageManager$FixedStorageProviderBase',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.StorageManager$FixedStorageProviderBase',
#   'Service Layer',
#   1),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.StorageManager$StorageProvider',
#   'Service Layer',
#   2),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.StorageManager$StorageProvider',
#   'Data Source Layer',
#   3),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.StorageManager$StorageProvider',
#   'Domain Layer',
#   3),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.LocalMessage',
#   'Domain Layer',
#   22),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.LocalMessage',
#   'Data Source Layer',
#   3),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.LocalMessage',
#   'Service Layer',
#   2),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.MimePartStreamParser',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.StorageManager$StorageListener',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.StorageManager$StorageListener',
#   'Service Layer',
#   1),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.LocalStore$BatchSetSelection',
#   'Domain Layer',
#   2),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.LocalStore$BatchSetSelection',
#   'Data Source Layer',
#   2),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.LocalPart',
#   'Domain Layer',
#   4),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.StorageManager',
#   'Domain Layer',
#   4),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.StorageManager',
#   'Service Layer',
#   4),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.StorageManager',
#   'Data Source Layer',
#   6),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.BinaryAttachmentBody',
#   'Domain Layer',
#   2),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.BinaryAttachmentBody',
#   'Data Source Layer',
#   2),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.StoreSchemaDefinition',
#   'Data Source Layer',
#   2),
#  ('com.fsck.k9.mailstore.migrations',
#   'com.fsck.k9.mailstore.migrations.MigrationTo61',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.mailstore.migrations',
#   'com.fsck.k9.mailstore.migrations.MigrationTo44',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.mailstore.migrations',
#   'com.fsck.k9.mailstore.migrations.MigrationTo54',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.mailstore.migrations',
#   'com.fsck.k9.mailstore.migrations.MigrationTo42',
#   'Service Layer',
#   1),
#  ('com.fsck.k9.mailstore.migrations',
#   'com.fsck.k9.mailstore.migrations.MigrationTo37',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.mailstore.migrations',
#   'com.fsck.k9.mailstore.migrations.MigrationTo60',
#   'Service Layer',
#   1),
#  ('com.fsck.k9.mailstore.migrations',
#   'com.fsck.k9.mailstore.migrations.MigrationTo40',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.mailstore.migrations',
#   'com.fsck.k9.mailstore.migrations.MigrationTo32',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.mailstore.migrations',
#   'com.fsck.k9.mailstore.migrations.MigrationTo52',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.mailstore.migrations',
#   'com.fsck.k9.mailstore.migrations.MigrationTo36',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.mailstore.migrations',
#   'com.fsck.k9.mailstore.migrations.MigrationTo51',
#   'Service Layer',
#   1),
#  ('com.fsck.k9.mailstore.migrations',
#   'com.fsck.k9.mailstore.migrations.MigrationTo35',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.mailstore.migrations',
#   'com.fsck.k9.mailstore.migrations.MigrationTo45',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.mailstore.migrations',
#   'com.fsck.k9.mailstore.migrations.MigrationTo33',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.mailstore.migrations',
#   'com.fsck.k9.mailstore.migrations.MigrationTo43',
#   'Service Layer',
#   1),
#  ('com.fsck.k9.mailstore.migrations',
#   'com.fsck.k9.mailstore.migrations.MigrationTo46',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.mailstore.migrations',
#   'com.fsck.k9.mailstore.migrations.MigrationTo39',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.mailstore.migrations',
#   'com.fsck.k9.mailstore.migrations.MigrationTo51$MimeStructureState',
#   'Domain Layer',
#   5),
#  ('com.fsck.k9.mailstore.migrations',
#   'com.fsck.k9.mailstore.migrations.MigrationsHelper',
#   'Data Source Layer',
#   2),
#  ('com.fsck.k9.mailstore.migrations',
#   'com.fsck.k9.mailstore.migrations.MigrationsHelper',
#   'Presentation Layer',
#   1),
#  ('com.fsck.k9.mailstore.migrations',
#   'com.fsck.k9.mailstore.migrations.MigrationsHelper',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.mailstore.migrations',
#   'com.fsck.k9.mailstore.migrations.MigrationsHelper',
#   'Service Layer',
#   1),
#  ('com.fsck.k9.mailstore.migrations',
#   'com.fsck.k9.mailstore.migrations.MigrationTo48',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.mailstore.migrations',
#   'com.fsck.k9.mailstore.migrations.MigrationTo53',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.mailstore.migrations',
#   'com.fsck.k9.mailstore.migrations.MigrationTo50',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.mailstore.migrations',
#   'com.fsck.k9.mailstore.migrations.MigrationTo41',
#   'Data Source Layer',
#   2),
#  ('com.fsck.k9.mailstore.migrations',
#   'com.fsck.k9.mailstore.migrations.MigrationTo49',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.mailstore.migrations',
#   'com.fsck.k9.mailstore.migrations.Migrations',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.mailstore.migrations',
#   'com.fsck.k9.mailstore.migrations.MigrationTo47',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.mailstore.migrations',
#   'com.fsck.k9.mailstore.migrations.MigrationTo31',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.mailstore.migrations',
#   'com.fsck.k9.mailstore.migrations.MigrationTo30',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.mailstore.migrations',
#   'com.fsck.k9.mailstore.migrations.MigrationTo34',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.mailstore.util',
#   'com.fsck.k9.mailstore.util.DeferredFileOutputStream',
#   'Domain Layer',
#   2),
#  ('com.fsck.k9.mailstore.util',
#   'com.fsck.k9.mailstore.util.FileFactory',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.mailstore.util',
#   'com.fsck.k9.mailstore.util.FlowedMessageUtils',
#   'Service Layer',
#   1),
#  ('com.fsck.k9.mailstore.util',
#   'com.fsck.k9.mailstore.util.FlowedMessageUtils',
#   'Utility Layer',
#   2),
#  ('com.fsck.k9.mailstore.util',
#   'com.fsck.k9.mailstore.util.FlowedMessageUtils',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.message',
#   'com.fsck.k9.message.IdentityHeaderBuilder',
#   'Domain Layer',
#   13),
#  ('com.fsck.k9.message',
#   'com.fsck.k9.message.MessageBuilder$Callback',
#   'Service Layer',
#   2),
#  ('com.fsck.k9.message',
#   'com.fsck.k9.message.MessageBuilder$Callback',
#   'Presentation Layer',
#   1),
#  ('com.fsck.k9.message',
#   'com.fsck.k9.message.MessageBuilder$Callback',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.message',
#   'com.fsck.k9.message.SimpleMessageBuilder',
#   'Service Layer',
#   1),
#  ('com.fsck.k9.message',
#   'com.fsck.k9.message.AutocryptStatusInteractor$RecipientAutocryptStatus',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.message',
#   'com.fsck.k9.message.PgpMessageBuilder',
#   'Service Layer',
#   2),
#  ('com.fsck.k9.message',
#   'com.fsck.k9.message.PgpMessageBuilder',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.message',
#   'com.fsck.k9.message.PgpMessageBuilder',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.message',
#   'com.fsck.k9.message.ComposePgpEnableByDefaultDecider',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.message',
#   'com.fsck.k9.message.ComposePgpInlineDecider',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.message',
#   'com.fsck.k9.message.AutocryptStatusInteractor$RecipientAutocryptStatusType',
#   'Domain Layer',
#   3),
#  ('com.fsck.k9.message',
#   'com.fsck.k9.message.IdentityField',
#   'Domain Layer',
#   2),
#  ('com.fsck.k9.message',
#   'com.fsck.k9.message.TextBodyBuilder',
#   'Domain Layer',
#   7),
#  ('com.fsck.k9.message',
#   'com.fsck.k9.message.TextBodyBuilder',
#   'Service Layer',
#   2),
#  ('com.fsck.k9.message',
#   'com.fsck.k9.message.TextBodyBuilder',
#   'Presentation Layer',
#   1),
#  ('com.fsck.k9.message',
# ...
#   'Service Layer',
#   1),
#  ('com.fsck.k9.provider',
#   'com.fsck.k9.provider.MessageProvider$IdExtractor',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.provider',
#   'com.fsck.k9.provider.AttachmentTempFileProvider$AttachmentTempFileProviderCleanupReceiver',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.provider',
#   'com.fsck.k9.provider.MessageProvider$SenderExtractor',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.provider',
#   'com.fsck.k9.provider.MessageProvider$MonitoredCursor',
#   'Data Source Layer',
#   40),
#  ('com.fsck.k9.provider',
#   'com.fsck.k9.provider.MessageProvider$MonitoredCursor',
#   'Presentation Layer',
#   1),
#  ('com.fsck.k9.provider',
#   'com.fsck.k9.provider.MessageProvider$MonitoredCursor',
#   'Domain Layer',
#   2),
#  ('com.fsck.k9.provider',
#   'com.fsck.k9.provider.MessageProvider$MonitoredCursor',
#   'Service Layer',
#   1),
#  ('com.fsck.k9.provider',
#   'com.fsck.k9.provider.UnreadWidgetProvider',
#   'Presentation Layer',
#   1),
#  ('com.fsck.k9.provider',
#   'com.fsck.k9.provider.UnreadWidgetProvider',
#   'Service Layer',
#   2),
#  ('com.fsck.k9.provider',
#   'com.fsck.k9.provider.UnreadWidgetProvider',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.provider',
#   'com.fsck.k9.provider.MessageProvider$SendDateExtractor',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.provider',
#   'com.fsck.k9.provider.MessageProvider$UriExtractor',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.provider',
#   'com.fsck.k9.provider.EmailProvider$IdTrickeryCursor',
#   'Data Source Layer',
#   2),
#  ('com.fsck.k9.provider',
#   'com.fsck.k9.provider.DecryptedFileProvider$DecryptedFileProviderCleanupReceiver',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.provider',
#   'com.fsck.k9.provider.MessageProvider$UnreadExtractor',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.remotecontrol',
#   'com.fsck.k9.remotecontrol.AccountReceiver',
#   'Service Layer',
#   1),
#  ('com.fsck.k9.remotecontrol',
#   'com.fsck.k9.remotecontrol.K9AccountReceptor',
#   'Service Layer',
#   1),
#  ('com.fsck.k9.remotecontrol',
#   'com.fsck.k9.remotecontrol.K9RemoteControl',
#   'Service Layer',
#   2),
#  ('com.fsck.k9.search', 'com.fsck.k9.search.SearchAccount', 'Domain Layer', 7),
#  ('com.fsck.k9.search',
#   'com.fsck.k9.search.SearchAccount',
#   'Service Layer',
#   2),
#  ('com.fsck.k9.search',
#   'com.fsck.k9.search.SearchSpecification',
#   'Domain Layer',
#   2),
#  ('com.fsck.k9.search',
#   'com.fsck.k9.search.SearchSpecification',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.search', 'com.fsck.k9.search.LocalSearch', 'Domain Layer', 17),
#  ('com.fsck.k9.search',
#   'com.fsck.k9.search.LocalSearch',
#   'Presentation Layer',
#   1),
#  ('com.fsck.k9.search',
#   'com.fsck.k9.search.LocalSearch',
#   'Data Source Layer',
#   2),
#  ('com.fsck.k9.search', 'com.fsck.k9.search.LocalSearch', 'Service Layer', 3),
#  ('com.fsck.k9.search',
#   'com.fsck.k9.search.ConditionsTreeNode',
#   'Presentation Layer',
#   1),
#  ('com.fsck.k9.search',
#   'com.fsck.k9.search.ConditionsTreeNode',
#   'Data Source Layer',
#   2),
#  ('com.fsck.k9.search',
#   'com.fsck.k9.search.ConditionsTreeNode',
#   'Service Layer',
#   1),
#  ('com.fsck.k9.search',
#   'com.fsck.k9.search.ConditionsTreeNode',
#   'Domain Layer',
#   7),
#  ('com.fsck.k9.search',
#   'com.fsck.k9.search.SqlQueryBuilder',
#   'Service Layer',
#   1),
#  ('com.fsck.k9.search',
#   'com.fsck.k9.search.SqlQueryBuilder',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.search',
#   'com.fsck.k9.search.SearchSpecification$SearchCondition',
#   'Domain Layer',
#   4),
#  ('com.fsck.k9.search',
#   'com.fsck.k9.search.SearchSpecification$SearchCondition',
#   'Data Source Layer',
#   2),
#  ('com.fsck.k9.service',
#   'com.fsck.k9.service.RemoteControlReceiver',
#   'Service Layer',
#   1),
#  ('com.fsck.k9.service',
#   'com.fsck.k9.service.RemoteControlService',
#   'Service Layer',
#   2),
#  ('com.fsck.k9.service',
#   'com.fsck.k9.service.ShutdownReceiver',
#   'Service Layer',
#   1),
#  ('com.fsck.k9.service',
#   'com.fsck.k9.service.PollService',
#   'Service Layer',
#   4),
#  ('com.fsck.k9.service',
#   'com.fsck.k9.service.PollService',
#   'Presentation Layer',
#   1),
#  ('com.fsck.k9.service',
#   'com.fsck.k9.service.SleepService',
#   'Service Layer',
#   2),
#  ('com.fsck.k9.service', 'com.fsck.k9.service.MailService', 'Domain Layer', 3),
#  ('com.fsck.k9.service',
#   'com.fsck.k9.service.MailService',
#   'Service Layer',
#   11),
#  ('com.fsck.k9.service',
#   'com.fsck.k9.service.MailService',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.service',
#   'com.fsck.k9.service.MailService',
#   'Presentation Layer',
#   1),
#  ('com.fsck.k9.service',
#   'com.fsck.k9.service.StorageGoneReceiver',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.service',
#   'com.fsck.k9.service.CoreService',
#   'Service Layer',
#   5),
#  ('com.fsck.k9.service',
#   'com.fsck.k9.service.CoreService',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.service',
#   'com.fsck.k9.service.CoreService',
#   'Presentation Layer',
#   1),
#  ('com.fsck.k9.service',
#   'com.fsck.k9.service.CoreReceiver',
#   'Service Layer',
#   3),
#  ('com.fsck.k9.service',
#   'com.fsck.k9.service.PushService',
#   'Service Layer',
#   4),
#  ('com.fsck.k9.service',
#   'com.fsck.k9.service.PushService',
#   'Presentation Layer',
#   1),
#  ('com.fsck.k9.service',
#   'com.fsck.k9.service.StorageReceiver',
#   'Service Layer',
#   1),
#  ('com.fsck.k9.service',
#   'com.fsck.k9.service.PollService$Listener',
#   'Service Layer',
#   4),
#  ('com.fsck.k9.service',
#   'com.fsck.k9.service.PollService$Listener',
#   'Domain Layer',
#   3),
#  ('com.fsck.k9.service',
#   'com.fsck.k9.service.DatabaseUpgradeService',
#   'Service Layer',
#   3),
#  ('com.fsck.k9.service',
#   'com.fsck.k9.service.DatabaseUpgradeService',
#   'Presentation Layer',
#   1),
#  ('com.fsck.k9.service',
#   'com.fsck.k9.service.BootReceiver',
#   'Service Layer',
#   3),
#  ('com.fsck.k9.service',
#   'com.fsck.k9.service.BootReceiver',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.setup',
#   'com.fsck.k9.setup.ServerNameSuggester',
#   'Service Layer',
#   1),
#  ('com.fsck.k9.ui',
#   'com.fsck.k9.ui.EolConvertingEditText',
#   'Presentation Layer',
#   2),
#  ('com.fsck.k9.ui', 'com.fsck.k9.ui.ContactBadge', 'Service Layer', 2),
#  ('com.fsck.k9.ui', 'com.fsck.k9.ui.ContactBadge', 'Presentation Layer', 4),
#  ('com.fsck.k9.ui.compose',
#   'com.fsck.k9.ui.compose.QuotedMessagePresenter',
#   'Presentation Layer',
#   5),
#  ('com.fsck.k9.ui.compose',
#   'com.fsck.k9.ui.compose.QuotedMessagePresenter',
#   'Domain Layer',
#   5),
#  ('com.fsck.k9.ui.compose',
#   'com.fsck.k9.ui.compose.QuotedMessagePresenter',
#   'Service Layer',
#   2),
#  ('com.fsck.k9.ui.compose',
#   'com.fsck.k9.ui.compose.QuotedMessageMvpView',
#   'Domain Layer',
#   2),
#  ('com.fsck.k9.ui.compose',
#   'com.fsck.k9.ui.compose.QuotedMessageMvpView',
#   'Presentation Layer',
#   6),
#  ('com.fsck.k9.ui.compose',
#   'com.fsck.k9.ui.compose.QuotedMessageMvpView',
#   'Service Layer',
#   1),
#  ('com.fsck.k9.ui.crypto',
#   'com.fsck.k9.ui.crypto.MessageCryptoAnnotations',
#   'Domain Layer',
#   4),
#  ('com.fsck.k9.ui.crypto',
#   'com.fsck.k9.ui.crypto.MessageCryptoAnnotations',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.ui.crypto',
#   'com.fsck.k9.ui.crypto.MessageCryptoHelper',
#   'Service Layer',
#   5),
#  ('com.fsck.k9.ui.crypto',
#   'com.fsck.k9.ui.crypto.MessageCryptoCallback',
#   'Service Layer',
#   2),
#  ('com.fsck.k9.ui.crypto',
#   'com.fsck.k9.ui.crypto.MessageCryptoCallback',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.ui.message',
#   'com.fsck.k9.ui.message.LocalMessageExtractorLoader',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.ui.message',
#   'com.fsck.k9.ui.message.LocalMessageExtractorLoader',
#   'Service Layer',
#   1),
#  ('com.fsck.k9.ui.message',
#   'com.fsck.k9.ui.message.LocalMessageExtractorLoader',
#   'Presentation Layer',
#   1),
#  ('com.fsck.k9.ui.message',
#   'com.fsck.k9.ui.message.LocalMessageLoader',
#   'Domain Layer',
#   2),
#  ('com.fsck.k9.ui.message',
#   'com.fsck.k9.ui.message.LocalMessageLoader',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.ui.messageview',
#   'com.fsck.k9.ui.messageview.AttachmentViewCallback',
#   'Domain Layer',
#   3),
#  ('com.fsck.k9.ui.messageview',
#   'com.fsck.k9.ui.messageview.MessageViewFragment',
#   'Presentation Layer',
#   30),
#  ('com.fsck.k9.ui.messageview',
#   'com.fsck.k9.ui.messageview.MessageViewFragment',
#   'Domain Layer',
#   12),
#  ('com.fsck.k9.ui.messageview',
#   'com.fsck.k9.ui.messageview.MessageViewFragment',
#   'Service Layer',
#   9),
#  ('com.fsck.k9.ui.messageview',
#   'com.fsck.k9.ui.messageview.AttachmentController',
#   'Service Layer',
#   1),
#  ('com.fsck.k9.ui.messageview',
#   'com.fsck.k9.ui.messageview.AttachmentController',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.ui.messageview',
#   'com.fsck.k9.ui.messageview.AttachmentController',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.ui.messageview',
#   'com.fsck.k9.ui.messageview.MessageCryptoPresenter$MessageCryptoMvpView',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.ui.messageview',
#   'com.fsck.k9.ui.messageview.MessageCryptoPresenter$MessageCryptoMvpView',
#   'Presentation Layer',
#   4),
#  ('com.fsck.k9.ui.messageview',
#   'com.fsck.k9.ui.messageview.MessageTopView',
#   'Presentation Layer',
#   20),
#  ('com.fsck.k9.ui.messageview',
#   'com.fsck.k9.ui.messageview.MessageContainerView$SavedState',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.ui.messageview',
#   'com.fsck.k9.ui.messageview.CryptoInfoDialog$OnClickShowCryptoKeyListener',
#   'Presentation Layer',
#   2),
#  ('com.fsck.k9.ui.messageview',
#   'com.fsck.k9.ui.messageview.MessageViewFragment$MessageViewFragmentListener',
#   'Presentation Layer',
#   5),
#  ('com.fsck.k9.ui.messageview',
#   'com.fsck.k9.ui.messageview.MessageViewFragment$MessageViewFragmentListener',
#   'Service Layer',
#   3),
#  ('com.fsck.k9.ui.messageview',
#   'com.fsck.k9.ui.messageview.MessageViewFragment$MessageViewFragmentListener',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.ui.messageview',
#   'com.fsck.k9.ui.messageview.LockedAttachmentView',
#   'Presentation Layer',
#   2),
#  ('com.fsck.k9.ui.messageview',
#   'com.fsck.k9.ui.messageview.LockedAttachmentView',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.ui.messageview',
#   'com.fsck.k9.ui.messageview.OnCryptoClickListener',
#   'Presentation Layer',
#   1),
#  ('com.fsck.k9.ui.messageview',
#   'com.fsck.k9.ui.messageview.AttachmentController$IntentAndResolvedActivitiesCount',
#   'Presentation Layer',
#   1),
#  ('com.fsck.k9.ui.messageview',
#   'com.fsck.k9.ui.messageview.AttachmentController$IntentAndResolvedActivitiesCount',
#   'Data Source Layer',
#   2),
#  ('com.fsck.k9.ui.messageview',
#   'com.fsck.k9.ui.messageview.AttachmentController$IntentAndResolvedActivitiesCount',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.ui.messageview',
#   'com.fsck.k9.ui.messageview.MessageContainerView$OnRenderingFinishedListener',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.ui.messageview',
#   'com.fsck.k9.ui.messageview.MessageContainerView',
#   'Domain Layer',
#   2),
#  ('com.fsck.k9.ui.messageview',
#   'com.fsck.k9.ui.messageview.MessageContainerView',
#   'Presentation Layer',
#   15),
#  ('com.fsck.k9.ui.messageview',
#   'com.fsck.k9.ui.messageview.CryptoInfoDialog',
#   'Presentation Layer',
#   2),
#  ('com.fsck.k9.ui.messageview',
#   'com.fsck.k9.ui.messageview.AttachmentView',
#   'Presentation Layer',
#   6),
#  ('com.fsck.k9.ui.messageview',
#   'com.fsck.k9.ui.messageview.AttachmentView',
#   'Domain Layer',
#   2),
#  ('com.fsck.k9.ui.messageview',
#   'com.fsck.k9.ui.messageview.MessageCryptoPresenter',
#   'Presentation Layer',
#   10),
#  ('com.fsck.k9.ui.messageview',
#   'com.fsck.k9.ui.messageview.MessageCryptoPresenter',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.MessageHeader$OnLayoutChangedListener',
#   'Presentation Layer',
#   1),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.HighlightDialogFragment',
#   'Presentation Layer',
#   2),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.CryptoModeSelector$CryptoStatusSelectedListener',
#   'Service Layer',
#   1),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.ViewSwitcher',
#   'Presentation Layer',
#   14),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.NonLockingScrollView',
#   'Presentation Layer',
#   2),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.MessageCryptoDisplayStatus',
#   'Domain Layer',
#   2),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.MessageCryptoDisplayStatus',
#   'Service Layer',
#   1),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.MessageWebView',
#   'Presentation Layer',
#   2),
#  ('com.fsck.k9.view', 'com.fsck.k9.view.MessageWebView', 'Service Layer', 1),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.MessageWebView',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.MessageHeader',
#   'Presentation Layer',
#   16),
#  ('com.fsck.k9.view', 'com.fsck.k9.view.MessageHeader', 'Domain Layer', 1),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.ClientCertificateSpinner',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.ClientCertificateSpinner',
#   'Presentation Layer',
#   2),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.ClientCertificateSpinner',
#   'Service Layer',
#   1),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.K9WebViewClient',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.K9WebViewClient',
#   'Presentation Layer',
#   3),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.MessageWebView$OnPageFinishedListener',
#   'Presentation Layer',
#   1),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.ClientCertificateSpinner$OnClientCertificateChangedListener',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.MessageTitleView',
#   'Presentation Layer',
#   2),
#  ('com.fsck.k9.view', 'com.fsck.k9.view.MessageTitleView', 'Domain Layer', 1),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.K9WebViewClient$LollipopWebViewClient',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.K9WebViewClient$PreLollipopWebViewClient',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.RecipientSelectView$Recipient',
#   'Domain Layer',
#   6),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.RecipientSelectView$Recipient',
#   'Presentation Layer',
#   1),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.RecipientSelectView$Recipient',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.FoldableLinearLayout',
#   'Presentation Layer',
#   1),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.RecipientSelectView$TokenListener',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.ToolableViewAnimator',
#   'Presentation Layer',
#   5),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.ViewSwitcher$OnSwitchCompleteListener',
#   'Presentation Layer',
#   1),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.NonLockingScrollView$HierarchyTreeChangeListener',
#   'Presentation Layer',
#   2),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.MessageCryptoStatusView',
#   'Presentation Layer',
#   1),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.FoldableLinearLayout$SavedState',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.LinearViewAnimator',
#   'Presentation Layer',
#   10),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.MessageHeader$SavedState',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.view', 'com.fsck.k9.view.ThemeUtils', 'Presentation Layer', 2),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.RecipientSelectView',
#   'Presentation Layer',
#   14),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.RecipientSelectView',
#   'Domain Layer',
#   5),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.RecipientSelectView',
#   'Service Layer',
#   2),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.CryptoModeSelector',
#   'Presentation Layer',
#   1),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.CryptoModeSelector',
#   'Domain Layer',
#   1),
#  ('com.fsck.k9.view', 'com.fsck.k9.view.ColorChip', 'Domain Layer', 1),
#  ('com.fsck.k9.widget.list',
#   'com.fsck.k9.widget.list.MessageListWidgetProvider',
#   'Service Layer',
#   2),
#  ('com.fsck.k9.widget.list',
#   'com.fsck.k9.widget.list.MessageListWidgetProvider',
#   'Presentation Layer',
#   1),
#  ('com.fsck.k9.widget.list',
#   'com.fsck.k9.widget.list.MessageListWidgetService',
#   'Service Layer',
#   1),
#  ('com.fsck.k9.widget.list',
#   'com.fsck.k9.widget.list.MessageListRemoteViewFactory',
#   'Presentation Layer',
#   7),
#  ('com.fsck.k9.widget.list',
#   'com.fsck.k9.widget.list.MessageListRemoteViewFactory',
#   'Data Source Layer',
#   1),
#  ('com.fsck.k9.widget.list',
#   'com.fsck.k9.widget.list.MessageListRemoteViewFactory',
#   'Domain Layer',
#   1)]

# %%
header = ("package", "class", "layer", "count")

# %%
import csv

with open(f"layerinator-v2/{project_name}-layers2-{timestr}.csv", mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(header)
    writer.writerows(rows)

# %%
rows = []

for package in results:
	for clss in [c for c in results[package] if c != 'layers']:
		for layer in results[package][clss]['layers']:
			rows.append((package,clss,layer,results[package][clss]['layers'][layer]/sum(results[package][clss]['layers'].values())))

rows
# Out:
# [('com.fsck.k9', 'com.fsck.k9.Throttle$MyTimerTask', 'Service Layer', 0.5),
#  ('com.fsck.k9',
#   'com.fsck.k9.Throttle$MyTimerTask',
#   'Presentation Layer',
#   0.5),
#  ('com.fsck.k9', 'com.fsck.k9.Throttle', 'Execution Layer', 0.5),
#  ('com.fsck.k9', 'com.fsck.k9.Throttle', 'Service Layer', 0.5),
#  ('com.fsck.k9', 'com.fsck.k9.PRNGFixes', 'Utility Layer', 1.0),
#  ('com.fsck.k9', 'com.fsck.k9.BaseAccount', 'Domain Layer', 1.0),
#  ('com.fsck.k9',
#   'com.fsck.k9.Throttle$MyTimerTask$HandlerRunnable',
#   'Service Layer',
#   1.0),
#  ('com.fsck.k9', 'com.fsck.k9.K9', 'Presentation Layer', 0.291970802919708),
#  ('com.fsck.k9', 'com.fsck.k9.K9', 'Service Layer', 0.3284671532846715),
#  ('com.fsck.k9', 'com.fsck.k9.K9', 'Domain Layer', 0.25547445255474455),
#  ('com.fsck.k9', 'com.fsck.k9.K9', 'Data Source Layer', 0.072992700729927),
#  ('com.fsck.k9', 'com.fsck.k9.K9', 'Utility Layer', 0.0364963503649635),
#  ('com.fsck.k9', 'com.fsck.k9.K9', 'None', 0.014598540145985401),
#  ('com.fsck.k9', 'com.fsck.k9.EmailAddressValidator', 'Domain Layer', 1.0),
#  ('com.fsck.k9', 'com.fsck.k9.Account$SortType', 'Domain Layer', 0.5),
#  ('com.fsck.k9', 'com.fsck.k9.Account$SortType', 'Presentation Layer', 0.5),
#  ('com.fsck.k9', 'com.fsck.k9.Globals', 'Utility Layer', 1.0),
#  ('com.fsck.k9',
#   'com.fsck.k9.FontSizes',
#   'Presentation Layer',
#   0.13513513513513514),
#  ('com.fsck.k9', 'com.fsck.k9.FontSizes', 'Domain Layer', 0.8108108108108109),
#  ('com.fsck.k9',
#   'com.fsck.k9.FontSizes',
#   'Data Source Layer',
#   0.05405405405405406),
#  ('com.fsck.k9', 'com.fsck.k9.NotificationSetting', 'Domain Layer', 0.8125),
#  ('com.fsck.k9', 'com.fsck.k9.NotificationSetting', 'Utility Layer', 0.0625),
#  ('com.fsck.k9',
#   'com.fsck.k9.NotificationSetting',
#   'Data Source Layer',
#   0.0625),
#  ('com.fsck.k9',
#   'com.fsck.k9.NotificationSetting',
#   'Presentation Layer',
#   0.0625),
#  ('com.fsck.k9', 'com.fsck.k9.Preferences', 'Data Source Layer', 0.4),
#  ('com.fsck.k9', 'com.fsck.k9.Preferences', 'Service Layer', 0.2),
#  ('com.fsck.k9', 'com.fsck.k9.Preferences', 'Domain Layer', 0.4),
#  ('com.fsck.k9', 'com.fsck.k9.Clock', 'Utility Layer', 1.0),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'Data Source Layer',
#   0.06369426751592357),
#  ('com.fsck.k9', 'com.fsck.k9.Account', 'Domain Layer', 0.8535031847133758),
#  ('com.fsck.k9', 'com.fsck.k9.Account', 'Service Layer', 0.07643312101910828),
#  ('com.fsck.k9',
#   'com.fsck.k9.Account',
#   'Presentation Layer',
#   0.006369426751592357),
#  ('com.fsck.k9', 'com.fsck.k9.K9$ApplicationAware', 'Service Layer', 1.0),
#  ('com.fsck.k9', 'com.fsck.k9.Identity', 'Domain Layer', 1.0),
#  ('com.fsck.k9', 'com.fsck.k9.Account$DeletePolicy', 'Domain Layer', 1.0),
#  ('com.fsck.k9.account',
#   'com.fsck.k9.account.AccountCreator',
#   'Service Layer',
#   1.0),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.FolderList$FolderListAdapter',
#   'Presentation Layer',
#   0.42857142857142855),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.FolderList$FolderListAdapter',
#   'Domain Layer',
#   0.21428571428571427),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.FolderList$FolderListAdapter',
#   'Service Layer',
#   0.07142857142857142),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.FolderList$FolderListAdapter',
#   'Data Source Layer',
#   0.2857142857142857),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.Accounts$AccountsHandler',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageCompose',
#   'Presentation Layer',
#   0.6666666666666666),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageCompose',
#   'Domain Layer',
#   0.2),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageCompose',
#   'Service Layer',
#   0.13333333333333333),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageInfoHolder',
#   'Domain Layer',
#   1.0),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.Search',
#   'Presentation Layer',
#   0.75),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.Search',
#   'Service Layer',
#   0.25),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.ColorPickerDialog$OnColorChangedListener',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.K9PreferenceActivity',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageList$StorageListenerImplementation',
#   'Presentation Layer',
#   0.5),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageList$StorageListenerImplementation',
#   'Domain Layer',
#   0.5),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.K9Activity',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.K9ActivityCommon',
#   'Data Source Layer',
#   0.2),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.K9ActivityCommon',
#   'Presentation Layer',
#   0.8),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.AccountList',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.LauncherShortcuts',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.Accounts$PasswordPromptDialog',
#   'Presentation Layer',
#   0.8333333333333334),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.Accounts$PasswordPromptDialog',
#   'Service Layer',
#   0.16666666666666666),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.Accounts$AccountClickListener',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.ColorPickerDialog',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.ChooseFolder',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.EditIdentity',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageCompose$Action',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.UnreadWidgetConfiguration',
#   'Presentation Layer',
#   0.6666666666666666),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.UnreadWidgetConfiguration',
#   'Data Source Layer',
#   0.3333333333333333),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.EmailAddressList',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.K9PreferenceActivity$PreferenceChangeListener',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.Accounts$AccountsAdapter',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.AccountList$AccountsAdapter',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.FolderList$FolderClickListener',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.Accounts',
#   'Presentation Layer',
#   0.8421052631578947),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.Accounts',
#   'Service Layer',
#   0.15789473684210525),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageLoaderHelper',
#   'Service Layer',
#   0.42857142857142855),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageLoaderHelper',
#   'Presentation Layer',
#   0.5714285714285714),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.ConfirmationDialog',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.AlternateRecipientAdapter$AlternateRecipientListener',
#   'Domain Layer',
#   0.5),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.AlternateRecipientAdapter$AlternateRecipientListener',
#   'Presentation Layer',
#   0.5),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.FolderList$FolderListHandler',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.K9ListActivity',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.ChooseFolder$ChooseFolderHandler',
#   'Presentation Layer',
#   0.6666666666666666),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.ChooseFolder$ChooseFolderHandler',
#   'Service Layer',
#   0.3333333333333333),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.ActivityListener',
#   'Presentation Layer',
#   0.21739130434782608),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.ActivityListener',
#   'Service Layer',
#   0.5217391304347826),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.ActivityListener',
#   'Domain Layer',
#   0.21739130434782608),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.ActivityListener',
#   'Data Source Layer',
#   0.043478260869565216),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.NotificationDeleteConfirmation',
#   'Presentation Layer',
#   0.6),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.NotificationDeleteConfirmation',
#   'Service Layer',
#   0.4),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.ChooseIdentity',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.UpgradeDatabases',
#   'Presentation Layer',
#   0.5),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.UpgradeDatabases',
#   'Service Layer',
#   0.5),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.Accounts$ImportSelectionDialog',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.AlternateRecipientAdapter',
#   'Presentation Layer',
#   0.5454545454545454),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.AlternateRecipientAdapter',
#   'Domain Layer',
#   0.45454545454545453),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageLoaderHelper$MessageLoaderCallbacks',
#   'Service Layer',
#   0.625),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageLoaderHelper$MessageLoaderCallbacks',
#   'Presentation Layer',
#   0.25),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageLoaderHelper$MessageLoaderCallbacks',
#   'Domain Layer',
#   0.125),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.K9ActivityCommon$K9ActivityMagic',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.UpgradeDatabases$UpgradeDatabaseBroadcastReceiver',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.AlternateRecipientAdapter$RecipientTokenHolder',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.FolderList',
#   'Presentation Layer',
#   0.6153846153846154),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.FolderList',
#   'Data Source Layer',
#   0.15384615384615385),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.FolderList',
#   'Service Layer',
#   0.23076923076923078),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.Accounts$SimpleDialog',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageReferenceHelper',
#   'Domain Layer',
#   1.0),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageReference',
#   'Domain Layer',
#   1.0),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.ManageIdentities',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.FolderList$FolderListAdapter$FolderListFilter',
#   'Domain Layer',
#   1.0),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.FolderListFilter',
#   'Domain Layer',
#   1.0),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageList',
#   'Presentation Layer',
#   0.7692307692307693),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageList',
#   'Data Source Layer',
#   0.038461538461538464),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageList',
#   'Service Layer',
#   0.17307692307692307),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.MessageList',
#   'Domain Layer',
#   0.019230769230769232),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.FolderInfoHolder',
#   'Domain Layer',
#   0.5714285714285714),
#  ('com.fsck.k9.activity',
#   'com.fsck.k9.activity.FolderInfoHolder',
#   'Service Layer',
#   0.42857142857142855),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.PgpEnabledErrorDialog$OnOpenPgpDisableListener',
#   'Domain Layer',
#   1.0),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.RecipientLoader',
#   'Service Layer',
#   0.5),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.RecipientLoader',
#   'Data Source Layer',
#   0.5),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.PgpInlineDialog',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.PgpSignOnlyDialog',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.AttachmentPresenter$AttachmentMvpView',
#   'Service Layer',
#   0.2222222222222222),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.AttachmentPresenter$AttachmentMvpView',
#   'Presentation Layer',
#   0.7777777777777778),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.ComposeCryptoStatus',
#   'Service Layer',
#   0.1111111111111111),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.ComposeCryptoStatus',
#   'Domain Layer',
#   0.8888888888888888),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.IdentityAdapter',
#   'Presentation Layer',
#   0.75),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.IdentityAdapter',
#   'Data Source Layer',
#   0.125),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.IdentityAdapter',
#   'Domain Layer',
#   0.125),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.RecipientPresenter$RecipientsChangedListener',
#   'Domain Layer',
#   1.0),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.PgpEncryptDescriptionDialog',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.PgpEnabledErrorDialog',
#   'Service Layer',
#   0.5),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.PgpEnabledErrorDialog',
#   'Presentation Layer',
#   0.5),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.RecipientAdapter',
#   'Presentation Layer',
#   0.6666666666666666),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.RecipientAdapter',
#   'Domain Layer',
#   0.3333333333333333),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.PgpSignOnlyDialog$OnOpenPgpSignOnlyChangeListener',
#   'Service Layer',
#   1.0),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.ComposeCryptoStatus$ComposeCryptoStatusBuilder',
#   'Domain Layer',
#   1.0),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.MessageActions',
#   'Presentation Layer',
#   0.6666666666666666),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.MessageActions',
#   'Service Layer',
#   0.3333333333333333),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.PgpInlineDialog$OnOpenPgpInlineChangeListener',
#   'Domain Layer',
#   1.0),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.RecipientMvpView',
#   'Presentation Layer',
#   0.8775510204081632),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.RecipientMvpView',
#   'Domain Layer',
#   0.12244897959183673),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.RecipientPresenter',
#   'Presentation Layer',
#   0.4411764705882353),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.RecipientPresenter',
#   'Service Layer',
#   0.3235294117647059),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.RecipientPresenter',
#   'Domain Layer',
#   0.20588235294117646),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.RecipientPresenter',
#   'Data Source Layer',
#   0.029411764705882353),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.AttachmentPresenter',
#   'Service Layer',
#   0.36363636363636365),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.AttachmentPresenter',
#   'Presentation Layer',
#   0.5454545454545454),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.AttachmentPresenter',
#   'Domain Layer',
#   0.09090909090909091),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.AttachmentPresenter$AttachmentsChangedListener',
#   'Service Layer',
#   0.5),
#  ('com.fsck.k9.activity.compose',
#   'com.fsck.k9.activity.compose.AttachmentPresenter$AttachmentsChangedListener',
#   'Domain Layer',
#   0.5),
#  ('com.fsck.k9.activity.loader',
#   'com.fsck.k9.activity.loader.AttachmentContentLoader',
#   'Data Source Layer',
#   1.0),
#  ('com.fsck.k9.activity.loader',
#   'com.fsck.k9.activity.loader.AttachmentInfoLoader',
#   'Data Source Layer',
#   1.0),
#  ('com.fsck.k9.activity.misc',
#   'com.fsck.k9.activity.misc.ContactPictureLoader$FallbackGlideModelLoader',
#   'Data Source Layer',
#   1.0),
#  ('com.fsck.k9.activity.misc',
#   'com.fsck.k9.activity.misc.ContactPictureLoader$FallbackGlideBitmapDecoder',
#   'Data Source Layer',
#   0.5),
#  ('com.fsck.k9.activity.misc',
#   'com.fsck.k9.activity.misc.ContactPictureLoader$FallbackGlideBitmapDecoder',
#   'Domain Layer',
#   0.5),
#  ('com.fsck.k9.activity.misc',
#   'com.fsck.k9.activity.misc.ContactPictureLoader',
#   'Data Source Layer',
#   1.0),
#  ('com.fsck.k9.activity.misc',
#   'com.fsck.k9.activity.misc.ContactPictureLoader$FallbackGlideParams',
#   'Domain Layer',
#   1.0),
#  ('com.fsck.k9.activity.misc',
#   'com.fsck.k9.activity.misc.SwipeGestureDetector$OnSwipeGestureListener',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.activity.misc',
#   'com.fsck.k9.activity.misc.Attachment',
#   'Domain Layer',
#   0.6666666666666666),
#  ('com.fsck.k9.activity.misc',
#   'com.fsck.k9.activity.misc.Attachment',
#   'Data Source Layer',
#   0.16666666666666666),
#  ('com.fsck.k9.activity.misc',
#   'com.fsck.k9.activity.misc.Attachment',
#   'Presentation Layer',
#   0.16666666666666666),
#  ('com.fsck.k9.activity.misc',
#   'com.fsck.k9.activity.misc.ExtendedAsyncTask',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.activity.misc',
#   'com.fsck.k9.activity.misc.SwipeGestureDetector',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.activity.misc',
#   'com.fsck.k9.activity.misc.NonConfigurationInstance',
#   'Service Layer',
#   0.5),
#  ('com.fsck.k9.activity.misc',
#   'com.fsck.k9.activity.misc.NonConfigurationInstance',
#   'Presentation Layer',
#   0.5),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.OpenPgpAppSelectDialog',
#   'Presentation Layer',
#   0.6666666666666666),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.OpenPgpAppSelectDialog',
#   'Service Layer',
#   0.3333333333333333),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.OpenPgpAppSelectDialog$ApgDeprecationDialogFragment',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupOptions',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AuthTypeAdapter',
#   'Domain Layer',
#   0.3333333333333333),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AuthTypeAdapter',
#   'Presentation Layer',
#   0.6666666666666666),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.OpenPgpAppSelectDialog$OpenPgpProviderEntry',
#   'Domain Layer',
#   1.0),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupAccountType',
#   'Service Layer',
#   0.3333333333333333),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupAccountType',
#   'Presentation Layer',
#   0.6666666666666666),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupOutgoing',
#   'Presentation Layer',
#   0.875),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupOutgoing',
#   'Service Layer',
#   0.125),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSettings',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.SpinnerOption',
#   'Domain Layer',
#   0.5),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.SpinnerOption',
#   'Presentation Layer',
#   0.5),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.FolderSettings',
#   'Domain Layer',
#   0.3333333333333333),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.FolderSettings',
#   'Presentation Layer',
#   0.6666666666666666),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupCheckSettings',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupComposition',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.ConnectionSecurityAdapter',
#   'Presentation Layer',
#   0.3333333333333333),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.ConnectionSecurityAdapter',
#   'Service Layer',
#   0.6666666666666666),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.WelcomeMessage',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupIncoming',
#   'Service Layer',
#   0.2857142857142857),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupIncoming',
#   'Presentation Layer',
#   0.5714285714285714),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupIncoming',
#   'Domain Layer',
#   0.14285714285714285),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.FontSizeSettings',
#   'Service Layer',
#   0.3333333333333333),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.FontSizeSettings',
#   'Presentation Layer',
#   0.6666666666666666),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupNames',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.SliderPreference',
#   'Domain Layer',
#   0.6666666666666666),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.SliderPreference',
#   'Presentation Layer',
#   0.3333333333333333),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.ConnectionSecurityHolder',
#   'Utility Layer',
#   1.0),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.Prefs',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.OpenPgpAppSelectDialog$OpenPgpAppSelectFragment',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AuthTypeHolder',
#   'Domain Layer',
#   1.0),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupBasics',
#   'Presentation Layer',
#   0.8181818181818182),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupBasics',
#   'Service Layer',
#   0.09090909090909091),
#  ('com.fsck.k9.activity.setup',
#   'com.fsck.k9.activity.setup.AccountSetupBasics',
#   'Domain Layer',
#   0.09090909090909091),
#  ('com.fsck.k9.autocrypt',
#   'com.fsck.k9.autocrypt.AutocryptHeaderParser',
#   'Domain Layer',
#   1.0),
#  ('com.fsck.k9.autocrypt',
#   'com.fsck.k9.autocrypt.AutocryptOperations',
#   'Service Layer',
#   0.75),
#  ('com.fsck.k9.autocrypt',
#   'com.fsck.k9.autocrypt.AutocryptOperations',
#   'Domain Layer',
#   0.25),
#  ('com.fsck.k9.autocrypt',
#   'com.fsck.k9.autocrypt.AutocryptOpenPgpApiInteractor',
#   'Domain Layer',
#   0.5),
#  ('com.fsck.k9.autocrypt',
#   'com.fsck.k9.autocrypt.AutocryptOpenPgpApiInteractor',
#   'Data Source Layer',
#   0.5),
#  ('com.fsck.k9.autocrypt',
#   'com.fsck.k9.autocrypt.AutocryptHeader',
#   'Domain Layer',
#   1.0),
#  ('com.fsck.k9.cache',
#   'com.fsck.k9.cache.TemporaryAttachmentStore',
#   'Data Source Layer',
#   1.0),
#  ('com.fsck.k9.cache',
#   'com.fsck.k9.cache.EmailProviderCacheCursor',
#   'Domain Layer',
#   0.7),
#  ('com.fsck.k9.cache',
#   'com.fsck.k9.cache.EmailProviderCacheCursor',
#   'Data Source Layer',
#   0.3),
#  ('com.fsck.k9.cache',
#   'com.fsck.k9.cache.EmailProviderCache',
#   'Data Source Layer',
#   0.1),
#  ('com.fsck.k9.cache',
#   'com.fsck.k9.cache.EmailProviderCache',
#   'Service Layer',
#   0.3),
#  ('com.fsck.k9.cache',
#   'com.fsck.k9.cache.EmailProviderCache',
#   'Domain Layer',
#   0.6),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.ProgressBodyFactory$ProgressListener',
#   'Service Layer',
#   1.0),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.MessagingControllerPushReceiver',
#   'Service Layer',
#   0.8),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.MessagingControllerPushReceiver',
#   'Data Source Layer',
#   0.1),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.MessagingControllerPushReceiver',
#   'Presentation Layer',
#   0.1),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.MemorizingMessagingListener',
#   'Service Layer',
#   0.4166666666666667),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.MemorizingMessagingListener',
#   'Domain Layer',
#   0.5833333333333334),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.SimpleMessagingListener',
#   'Service Layer',
#   0.7142857142857143),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.SimpleMessagingListener',
#   'Domain Layer',
#   0.23809523809523808),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.SimpleMessagingListener',
#   'Presentation Layer',
#   0.023809523809523808),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.SimpleMessagingListener',
#   'Data Source Layer',
#   0.023809523809523808),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.PendingCommandSerializer',
#   'Service Layer',
#   0.3333333333333333),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.PendingCommandSerializer',
#   'Data Source Layer',
#   0.6666666666666666),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.MessagingControllerCommands$PendingMoveOrCopy',
#   'Service Layer',
#   0.75),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.MessagingControllerCommands$PendingMoveOrCopy',
#   'Domain Layer',
#   0.25),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.MessagingControllerCommands$PendingEmptyTrash',
#   'Domain Layer',
#   0.3333333333333333),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.MessagingControllerCommands$PendingEmptyTrash',
#   'Service Layer',
#   0.6666666666666666),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.MessagingControllerCommands$PendingMarkAllAsRead',
#   'Domain Layer',
#   0.3333333333333333),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.MessagingControllerCommands$PendingMarkAllAsRead',
#   'Service Layer',
#   0.6666666666666666),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.MessagingControllerCommands$PendingCommand',
#   'Domain Layer',
#   0.5),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.MessagingControllerCommands$PendingCommand',
#   'Service Layer',
#   0.5),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.MessagingListener',
#   'Service Layer',
#   0.6190476190476191),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.MessagingListener',
#   'Domain Layer',
#   0.2857142857142857),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.MessagingListener',
#   'Data Source Layer',
#   0.07142857142857142),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.MessagingListener',
#   'Presentation Layer',
#   0.023809523809523808),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.MessagingController$MessageActor',
#   'Domain Layer',
#   1.0),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.MessagingControllerCommands$PendingAppend',
#   'Domain Layer',
#   0.6666666666666666),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.MessagingControllerCommands$PendingAppend',
#   'Service Layer',
#   0.3333333333333333),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.MessagingController$Command',
#   'Domain Layer',
#   1.0),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.UidReverseComparator',
#   'Domain Layer',
#   1.0),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.MessagingController',
#   'Service Layer',
#   0.835820895522388),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.MessagingController',
#   'Domain Layer',
#   0.11940298507462686),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.MessagingController',
#   'Presentation Layer',
#   0.014925373134328358),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.MessagingController',
#   'Data Source Layer',
#   0.029850746268656716),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.MessagingControllerCommands$PendingExpunge',
#   'Service Layer',
#   0.6666666666666666),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.MessagingControllerCommands$PendingExpunge',
#   'Domain Layer',
#   0.3333333333333333),
#  ('com.fsck.k9.controller',
#   'com.fsck.k9.controller.MessagingControllerCommands$PendingSetFlag',
#   'Service Layer',
#   1.0),
#  ('com.fsck.k9.crypto',
#   'com.fsck.k9.crypto.MessageCryptoStructureDetector',
#   'Domain Layer',
#   0.8888888888888888),
#  ('com.fsck.k9.crypto',
#   'com.fsck.k9.crypto.MessageCryptoStructureDetector',
#   'Data Source Layer',
#   0.1111111111111111),
#  ('com.fsck.k9.crypto',
#   'com.fsck.k9.crypto.OpenPgpApiHelper',
#   'Service Layer',
#   1.0),
#  ('com.fsck.k9.fragment',
#   'com.fsck.k9.fragment.MessageListFragment',
#   'Presentation Layer',
#   0.532258064516129),
#  ('com.fsck.k9.fragment',
#   'com.fsck.k9.fragment.MessageListFragment',
#   'Domain Layer',
#   0.27419354838709675),
#  ('com.fsck.k9.fragment',
#   'com.fsck.k9.fragment.MessageListFragment',
#   'Service Layer',
#   0.14516129032258066),
#  ('com.fsck.k9.fragment',
#   'com.fsck.k9.fragment.MessageListFragment',
#   'Utility Layer',
#   0.016129032258064516),
#  ('com.fsck.k9.fragment',
#   'com.fsck.k9.fragment.MessageListFragment',
#   'Data Source Layer',
#   0.03225806451612903),
#  ('com.fsck.k9.fragment',
#   'com.fsck.k9.fragment.MessageListFragmentComparators$SenderComparator',
#   'Data Source Layer',
#   1.0),
#  ('com.fsck.k9.fragment',
#   'com.fsck.k9.fragment.ProgressDialogFragment',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.fragment',
#   'com.fsck.k9.fragment.AttachmentDownloadDialogFragment',
#   'Data Source Layer',
#   0.25),
#  ('com.fsck.k9.fragment',
#   'com.fsck.k9.fragment.AttachmentDownloadDialogFragment',
#   'Presentation Layer',
#   0.75),
#  ('com.fsck.k9.fragment',
#   'com.fsck.k9.fragment.MessageListFragmentComparators$ArrivalComparator',
#   'Data Source Layer',
#   1.0),
#  ('com.fsck.k9.fragment',
#   'com.fsck.k9.fragment.ProgressDialogFragment$CancelListener',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.fragment',
#   'com.fsck.k9.fragment.MessageListFragment$MessageListActivityListener',
#   'Presentation Layer',
#   0.9),
#  ('com.fsck.k9.fragment',
#   'com.fsck.k9.fragment.MessageListFragment$MessageListActivityListener',
#   'Domain Layer',
#   0.1),
#  ('com.fsck.k9.fragment',
#   'com.fsck.k9.fragment.MessageListAdapter',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.fragment',
#   'com.fsck.k9.fragment.MessageListFragmentComparators$FlaggedComparator',
#   'Data Source Layer',
#   1.0),
#  ('com.fsck.k9.fragment',
#   'com.fsck.k9.fragment.MessageListFragmentComparators$SubjectComparator',
#   'Data Source Layer',
#   1.0),
#  ('com.fsck.k9.fragment',
#   'com.fsck.k9.fragment.MessageListFragmentComparators$AttachmentComparator',
#   'Data Source Layer',
#   1.0),
#  ('com.fsck.k9.fragment',
#   'com.fsck.k9.fragment.MessageListFragmentComparators$UnreadComparator',
#   'Data Source Layer',
#   1.0),
#  ('com.fsck.k9.fragment',
#   'com.fsck.k9.fragment.MessageListHandler',
#   'Service Layer',
#   0.4444444444444444),
#  ('com.fsck.k9.fragment',
#   'com.fsck.k9.fragment.MessageListHandler',
#   'Presentation Layer',
#   0.5555555555555556),
#  ('com.fsck.k9.fragment',
#   'com.fsck.k9.fragment.AttachmentDownloadDialogFragment$AttachmentDownloadCancelListener',
#   'Domain Layer',
#   1.0),
#  ('com.fsck.k9.fragment',
#   'com.fsck.k9.fragment.ConfirmationDialogFragment',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.fragment',
#   'com.fsck.k9.fragment.MessageViewHolder',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.fragment',
#   'com.fsck.k9.fragment.MessageListFragmentComparators$ComparatorChain',
#   'Domain Layer',
#   1.0),
#  ('com.fsck.k9.fragment',
#   'com.fsck.k9.fragment.ConfirmationDialogFragment$ConfirmationDialogFragmentListener',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.fragment',
#   'com.fsck.k9.fragment.MessageListFragmentComparators$DateComparator',
#   'Data Source Layer',
#   1.0),
#  ('com.fsck.k9.fragment',
#   'com.fsck.k9.fragment.MessageListFragmentComparators$ReverseIdComparator',
#   'Data Source Layer',
#   1.0),
#  ('com.fsck.k9.fragment',
#   'com.fsck.k9.fragment.MessageListFragment$MessageListFragmentListener',
#   'Presentation Layer',
#   0.29411764705882354),
#  ('com.fsck.k9.fragment',
#   'com.fsck.k9.fragment.MessageListFragment$MessageListFragmentListener',
#   'Domain Layer',
#   0.35294117647058826),
#  ('com.fsck.k9.fragment',
#   'com.fsck.k9.fragment.MessageListFragment$MessageListFragmentListener',
#   'Service Layer',
#   0.35294117647058826),
#  ('com.fsck.k9.fragment',
#   'com.fsck.k9.fragment.MessageListFragment$ActionModeCallback',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.fragment',
#   'com.fsck.k9.fragment.MessageListFragmentComparators$ReverseComparator',
#   'Domain Layer',
#   1.0),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.MergeCursor',
#   'Data Source Layer',
#   0.7317073170731707),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.MergeCursor',
#   'Domain Layer',
#   0.21951219512195122),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.MergeCursor',
#   'Presentation Layer',
#   0.024390243902439025),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.MergeCursor',
#   'Service Layer',
#   0.024390243902439025),
#  ('com.fsck.k9.helper', 'com.fsck.k9.helper.EmailHelper', 'Domain Layer', 1.0),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.IdentityHelper',
#   'Service Layer',
#   1.0),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.MergeCursorWithUniqueId',
#   'Data Source Layer',
#   0.75),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.MergeCursorWithUniqueId',
#   'Presentation Layer',
#   0.25),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.UrlEncodingHelper',
#   'Utility Layer',
#   1.0),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.MessageHelper',
#   'Domain Layer',
#   0.6666666666666666),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.MessageHelper',
#   'Service Layer',
#   0.16666666666666666),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.MessageHelper',
#   'Utility Layer',
#   0.16666666666666666),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.FileHelper',
#   'Data Source Layer',
#   0.6666666666666666),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.FileHelper',
#   'Utility Layer',
#   0.16666666666666666),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.FileHelper',
#   'Service Layer',
#   0.16666666666666666),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.K9AlarmManager',
#   'Data Source Layer',
#   0.6666666666666666),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.K9AlarmManager',
#   'Service Layer',
#   0.3333333333333333),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.UnreadWidgetProperties',
#   'Service Layer',
#   0.3333333333333333),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.UnreadWidgetProperties',
#   'Data Source Layer',
#   0.16666666666666666),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.UnreadWidgetProperties',
#   'Domain Layer',
#   0.5),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.SizeFormatter',
#   'Utility Layer',
#   1.0),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.FileBrowserHelper',
#   'Presentation Layer',
#   0.6666666666666666),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.FileBrowserHelper',
#   'Data Source Layer',
#   0.3333333333333333),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.ParcelableUtil',
#   'Data Source Layer',
#   1.0),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.RetainFragment',
#   'Data Source Layer',
#   0.5714285714285714),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.RetainFragment',
#   'Presentation Layer',
#   0.2857142857142857),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.RetainFragment',
#   'Domain Layer',
#   0.14285714285714285),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.FileBrowserHelper$FileBrowserFailOverCallback',
#   'Domain Layer',
#   0.5),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.FileBrowserHelper$FileBrowserFailOverCallback',
#   'Presentation Layer',
#   0.5),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.MailTo',
#   'Domain Layer',
#   0.7142857142857143),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.MailTo',
#   'Data Source Layer',
#   0.14285714285714285),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.MailTo',
#   'Utility Layer',
#   0.14285714285714285),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.Contacts',
#   'Data Source Layer',
#   0.6666666666666666),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.Contacts',
#   'Domain Layer',
#   0.1111111111111111),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.Contacts',
#   'Presentation Layer',
#   0.1111111111111111),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.Contacts',
#   'Service Layer',
#   0.1111111111111111),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.SimpleTextWatcher',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.ContactPicture',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.ClipboardManager',
#   'Data Source Layer',
#   1.0),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.MailTo$CaseInsensitiveParamWrapper',
#   'Domain Layer',
#   1.0),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.ReplyToParser',
#   'Service Layer',
#   0.5),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.ReplyToParser',
#   'Domain Layer',
#   0.5),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.ExceptionHelper',
#   'Service Layer',
#   1.0),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.Utility',
#   'Data Source Layer',
#   0.1),
#  ('com.fsck.k9.helper', 'com.fsck.k9.helper.Utility', 'Utility Layer', 0.4),
#  ('com.fsck.k9.helper', 'com.fsck.k9.helper.Utility', 'Service Layer', 0.15),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.Utility',
#   'Presentation Layer',
#   0.15),
#  ('com.fsck.k9.helper', 'com.fsck.k9.helper.Utility', 'Domain Layer', 0.2),
#  ('com.fsck.k9.helper',
#   'com.fsck.k9.helper.Preconditions',
#   'Domain Layer',
#   1.0),
#  ('com.fsck.k9.helper.jsoup',
#   'com.fsck.k9.helper.jsoup.NodeFilter',
#   'Service Layer',
#   1.0),
#  ('com.fsck.k9.helper.jsoup',
#   'com.fsck.k9.helper.jsoup.AdvancedNodeTraversor',
#   'Service Layer',
#   1.0),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.StorageManager$SamsungGalaxySStorageProvider',
#   'Presentation Layer',
#   0.5),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.StorageManager$SamsungGalaxySStorageProvider',
#   'Data Source Layer',
#   0.5),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.StorageManager$ExternalStorageProvider',
#   'Data Source Layer',
#   0.75),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.StorageManager$ExternalStorageProvider',
#   'Service Layer',
#   0.125),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.StorageManager$ExternalStorageProvider',
#   'Presentation Layer',
#   0.125),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.LocalStore',
#   'Domain Layer',
#   0.2413793103448276),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.LocalStore',
#   'Data Source Layer',
#   0.5862068965517241),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.LocalStore',
#   'Service Layer',
#   0.1724137931034483),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.LockableDatabase$StorageListener',
#   'Data Source Layer',
#   1.0),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.LockableDatabase$DbCallback',
#   'Data Source Layer',
#   1.0),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.CryptoResultAnnotation',
#   'Domain Layer',
#   0.7619047619047619),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.CryptoResultAnnotation',
#   'Utility Layer',
#   0.047619047619047616),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.CryptoResultAnnotation',
#   'Service Layer',
#   0.09523809523809523),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.CryptoResultAnnotation',
#   'Presentation Layer',
#   0.09523809523809523),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.AttachmentViewInfo',
#   'Domain Layer',
#   1.0),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.DatabasePreviewType',
#   'Service Layer',
#   0.25),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.DatabasePreviewType',
#   'Data Source Layer',
#   0.5),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.DatabasePreviewType',
#   'Domain Layer',
#   0.25),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.LocalFolder$MoreMessages',
#   'Data Source Layer',
#   1.0),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.LocalMimeMessage',
#   'Domain Layer',
#   1.0),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.StorageManager$HtcIncredibleStorageProvider',
#   'Presentation Layer',
#   0.5),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.StorageManager$HtcIncredibleStorageProvider',
#   'Data Source Layer',
#   0.5),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.MessageHelper',
#   'Domain Layer',
#   0.5),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.MessageHelper',
#   'Utility Layer',
#   0.5),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.StoreSchemaDefinition$RealMigrationsHelper',
#   'Data Source Layer',
#   1.0),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.LockableDatabase',
#   'Data Source Layer',
#   0.2857142857142857),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.LockableDatabase',
#   'Service Layer',
#   0.42857142857142855),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.LockableDatabase',
#   'Domain Layer',
#   0.2857142857142857),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.LocalFolder',
#   'Data Source Layer',
#   0.23684210526315788),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.LocalFolder',
#   'Domain Layer',
#   0.5),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.LocalFolder',
#   'Service Layer',
#   0.2631578947368421),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.MessageRemovalListener',
#   'Domain Layer',
#   1.0),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.TempFileBody',
#   'Data Source Layer',
#   0.5),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.TempFileBody',
#   'Domain Layer',
#   0.5),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.MimePartStreamParser$PartBuilder',
#   'Domain Layer',
#   0.6923076923076923),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.MimePartStreamParser$PartBuilder',
#   'Service Layer',
#   0.15384615384615385),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.MimePartStreamParser$PartBuilder',
#   'Data Source Layer',
#   0.15384615384615385),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.LockableDatabase$SchemaDefinition',
#   'Domain Layer',
#   0.5),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.LockableDatabase$SchemaDefinition',
#   'Data Source Layer',
#   0.5),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.MessageViewInfoExtractor',
#   'Service Layer',
#   1.0),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.StorageManager$InternalStorageProvider',
#   'Data Source Layer',
#   0.625),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.StorageManager$InternalStorageProvider',
#   'Domain Layer',
#   0.125),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.StorageManager$InternalStorageProvider',
#   'Presentation Layer',
#   0.125),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.StorageManager$InternalStorageProvider',
#   'Service Layer',
#   0.125),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.MessageViewInfo',
#   'Domain Layer',
#   1.0),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.AttachmentResolver',
#   'Domain Layer',
#   0.5),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.AttachmentResolver',
#   'Data Source Layer',
#   0.5),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.DeferredFileBody',
#   'Domain Layer',
#   0.5714285714285714),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.DeferredFileBody',
#   'Data Source Layer',
#   0.42857142857142855),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.FileBackedBody',
#   'Data Source Layer',
#   0.4),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.FileBackedBody',
#   'Domain Layer',
#   0.6),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.LocalBodyPart',
#   'Domain Layer',
#   1.0),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.StorageManager$FixedStorageProviderBase',
#   'Data Source Layer',
#   0.6666666666666666),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.StorageManager$FixedStorageProviderBase',
#   'Domain Layer',
#   0.16666666666666666),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.StorageManager$FixedStorageProviderBase',
#   'Service Layer',
#   0.16666666666666666),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.StorageManager$StorageProvider',
#   'Service Layer',
#   0.25),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.StorageManager$StorageProvider',
#   'Data Source Layer',
#   0.375),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.StorageManager$StorageProvider',
#   'Domain Layer',
#   0.375),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.LocalMessage',
#   'Domain Layer',
#   0.8148148148148148),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.LocalMessage',
#   'Data Source Layer',
#   0.1111111111111111),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.LocalMessage',
#   'Service Layer',
#   0.07407407407407407),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.MimePartStreamParser',
#   'Data Source Layer',
#   1.0),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.StorageManager$StorageListener',
#   'Data Source Layer',
#   0.5),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.StorageManager$StorageListener',
#   'Service Layer',
#   0.5),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.LocalStore$BatchSetSelection',
#   'Domain Layer',
#   0.5),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.LocalStore$BatchSetSelection',
#   'Data Source Layer',
#   0.5),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.LocalPart',
#   'Domain Layer',
#   1.0),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.StorageManager',
#   'Domain Layer',
#   0.2857142857142857),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.StorageManager',
#   'Service Layer',
#   0.2857142857142857),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.StorageManager',
#   'Data Source Layer',
#   0.42857142857142855),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.BinaryAttachmentBody',
#   'Domain Layer',
#   0.5),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.BinaryAttachmentBody',
#   'Data Source Layer',
#   0.5),
#  ('com.fsck.k9.mailstore',
#   'com.fsck.k9.mailstore.StoreSchemaDefinition',
#   'Data Source Layer',
#   1.0),
#  ('com.fsck.k9.mailstore.migrations',
#   'com.fsck.k9.mailstore.migrations.MigrationTo61',
#   'Data Source Layer',
#   1.0),
#  ('com.fsck.k9.mailstore.migrations',
#   'com.fsck.k9.mailstore.migrations.MigrationTo44',
#   'Data Source Layer',
#   1.0),
#  ('com.fsck.k9.mailstore.migrations',
#   'com.fsck.k9.mailstore.migrations.MigrationTo54',
#   'Data Source Layer',
#   1.0),
#  ('com.fsck.k9.mailstore.migrations',
#   'com.fsck.k9.mailstore.migrations.MigrationTo42',
#   'Service Layer',
#   1.0),
#  ('com.fsck.k9.mailstore.migrations',
#   'com.fsck.k9.mailstore.migrations.MigrationTo37',
#   'Data Source Layer',
#   1.0),
#  ('com.fsck.k9.mailstore.migrations',
#   'com.fsck.k9.mailstore.migrations.MigrationTo60',
#   'Service Layer',
#   1.0),
#  ('com.fsck.k9.mailstore.migrations',
#   'com.fsck.k9.mailstore.migrations.MigrationTo40',
#   'Data Source Layer',
#   1.0),
#  ('com.fsck.k9.mailstore.migrations',
#   'com.fsck.k9.mailstore.migrations.MigrationTo32',
#   'Data Source Layer',
#   1.0),
#  ('com.fsck.k9.mailstore.migrations',
#   'com.fsck.k9.mailstore.migrations.MigrationTo52',
#   'Data Source Layer',
#   1.0),
#  ('com.fsck.k9.mailstore.migrations',
#   'com.fsck.k9.mailstore.migrations.MigrationTo36',
#   'Data Source Layer',
#   1.0),
#  ('com.fsck.k9.mailstore.migrations',
#   'com.fsck.k9.mailstore.migrations.MigrationTo51',
#   'Service Layer',
#   1.0),
#  ('com.fsck.k9.mailstore.migrations',
#   'com.fsck.k9.mailstore.migrations.MigrationTo35',
#   'Data Source Layer',
#   1.0),
#  ('com.fsck.k9.mailstore.migrations',
#   'com.fsck.k9.mailstore.migrations.MigrationTo45',
#   'Data Source Layer',
#   1.0),
#  ('com.fsck.k9.mailstore.migrations',
#   'com.fsck.k9.mailstore.migrations.MigrationTo33',
#   'Data Source Layer',
#   1.0),
#  ('com.fsck.k9.mailstore.migrations',
#   'com.fsck.k9.mailstore.migrations.MigrationTo43',
#   'Service Layer',
#   1.0),
#  ('com.fsck.k9.mailstore.migrations',
#   'com.fsck.k9.mailstore.migrations.MigrationTo46',
#   'Data Source Layer',
#   1.0),
#  ('com.fsck.k9.mailstore.migrations',
#   'com.fsck.k9.mailstore.migrations.MigrationTo39',
#   'Data Source Layer',
#   1.0),
#  ('com.fsck.k9.mailstore.migrations',
#   'com.fsck.k9.mailstore.migrations.MigrationTo51$MimeStructureState',
#   'Domain Layer',
#   1.0),
#  ('com.fsck.k9.mailstore.migrations',
#   'com.fsck.k9.mailstore.migrations.MigrationsHelper',
#   'Data Source Layer',
#   0.4),
#  ('com.fsck.k9.mailstore.migrations',
# ...
#   'Domain Layer',
#   1.0),
#  ('com.fsck.k9.provider',
#   'com.fsck.k9.provider.EmailProvider$IdTrickeryCursor',
#   'Data Source Layer',
#   1.0),
#  ('com.fsck.k9.provider',
#   'com.fsck.k9.provider.DecryptedFileProvider$DecryptedFileProviderCleanupReceiver',
#   'Data Source Layer',
#   1.0),
#  ('com.fsck.k9.provider',
#   'com.fsck.k9.provider.MessageProvider$UnreadExtractor',
#   'Domain Layer',
#   1.0),
#  ('com.fsck.k9.remotecontrol',
#   'com.fsck.k9.remotecontrol.AccountReceiver',
#   'Service Layer',
#   1.0),
#  ('com.fsck.k9.remotecontrol',
#   'com.fsck.k9.remotecontrol.K9AccountReceptor',
#   'Service Layer',
#   1.0),
#  ('com.fsck.k9.remotecontrol',
#   'com.fsck.k9.remotecontrol.K9RemoteControl',
#   'Service Layer',
#   1.0),
#  ('com.fsck.k9.search',
#   'com.fsck.k9.search.SearchAccount',
#   'Domain Layer',
#   0.7777777777777778),
#  ('com.fsck.k9.search',
#   'com.fsck.k9.search.SearchAccount',
#   'Service Layer',
#   0.2222222222222222),
#  ('com.fsck.k9.search',
#   'com.fsck.k9.search.SearchSpecification',
#   'Domain Layer',
#   0.6666666666666666),
#  ('com.fsck.k9.search',
#   'com.fsck.k9.search.SearchSpecification',
#   'Data Source Layer',
#   0.3333333333333333),
#  ('com.fsck.k9.search',
#   'com.fsck.k9.search.LocalSearch',
#   'Domain Layer',
#   0.7391304347826086),
#  ('com.fsck.k9.search',
#   'com.fsck.k9.search.LocalSearch',
#   'Presentation Layer',
#   0.043478260869565216),
#  ('com.fsck.k9.search',
#   'com.fsck.k9.search.LocalSearch',
#   'Data Source Layer',
#   0.08695652173913043),
#  ('com.fsck.k9.search',
#   'com.fsck.k9.search.LocalSearch',
#   'Service Layer',
#   0.13043478260869565),
#  ('com.fsck.k9.search',
#   'com.fsck.k9.search.ConditionsTreeNode',
#   'Presentation Layer',
#   0.09090909090909091),
#  ('com.fsck.k9.search',
#   'com.fsck.k9.search.ConditionsTreeNode',
#   'Data Source Layer',
#   0.18181818181818182),
#  ('com.fsck.k9.search',
#   'com.fsck.k9.search.ConditionsTreeNode',
#   'Service Layer',
#   0.09090909090909091),
#  ('com.fsck.k9.search',
#   'com.fsck.k9.search.ConditionsTreeNode',
#   'Domain Layer',
#   0.6363636363636364),
#  ('com.fsck.k9.search',
#   'com.fsck.k9.search.SqlQueryBuilder',
#   'Service Layer',
#   0.5),
#  ('com.fsck.k9.search',
#   'com.fsck.k9.search.SqlQueryBuilder',
#   'Data Source Layer',
#   0.5),
#  ('com.fsck.k9.search',
#   'com.fsck.k9.search.SearchSpecification$SearchCondition',
#   'Domain Layer',
#   0.6666666666666666),
#  ('com.fsck.k9.search',
#   'com.fsck.k9.search.SearchSpecification$SearchCondition',
#   'Data Source Layer',
#   0.3333333333333333),
#  ('com.fsck.k9.service',
#   'com.fsck.k9.service.RemoteControlReceiver',
#   'Service Layer',
#   1.0),
#  ('com.fsck.k9.service',
#   'com.fsck.k9.service.RemoteControlService',
#   'Service Layer',
#   1.0),
#  ('com.fsck.k9.service',
#   'com.fsck.k9.service.ShutdownReceiver',
#   'Service Layer',
#   1.0),
#  ('com.fsck.k9.service',
#   'com.fsck.k9.service.PollService',
#   'Service Layer',
#   0.8),
#  ('com.fsck.k9.service',
#   'com.fsck.k9.service.PollService',
#   'Presentation Layer',
#   0.2),
#  ('com.fsck.k9.service',
#   'com.fsck.k9.service.SleepService',
#   'Service Layer',
#   1.0),
#  ('com.fsck.k9.service',
#   'com.fsck.k9.service.MailService',
#   'Domain Layer',
#   0.1875),
#  ('com.fsck.k9.service',
#   'com.fsck.k9.service.MailService',
#   'Service Layer',
#   0.6875),
#  ('com.fsck.k9.service',
#   'com.fsck.k9.service.MailService',
#   'Data Source Layer',
#   0.0625),
#  ('com.fsck.k9.service',
#   'com.fsck.k9.service.MailService',
#   'Presentation Layer',
#   0.0625),
#  ('com.fsck.k9.service',
#   'com.fsck.k9.service.StorageGoneReceiver',
#   'Data Source Layer',
#   1.0),
#  ('com.fsck.k9.service',
#   'com.fsck.k9.service.CoreService',
#   'Service Layer',
#   0.7142857142857143),
#  ('com.fsck.k9.service',
#   'com.fsck.k9.service.CoreService',
#   'Data Source Layer',
#   0.14285714285714285),
#  ('com.fsck.k9.service',
#   'com.fsck.k9.service.CoreService',
#   'Presentation Layer',
#   0.14285714285714285),
#  ('com.fsck.k9.service',
#   'com.fsck.k9.service.CoreReceiver',
#   'Service Layer',
#   1.0),
#  ('com.fsck.k9.service',
#   'com.fsck.k9.service.PushService',
#   'Service Layer',
#   0.8),
#  ('com.fsck.k9.service',
#   'com.fsck.k9.service.PushService',
#   'Presentation Layer',
#   0.2),
#  ('com.fsck.k9.service',
#   'com.fsck.k9.service.StorageReceiver',
#   'Service Layer',
#   1.0),
#  ('com.fsck.k9.service',
#   'com.fsck.k9.service.PollService$Listener',
#   'Service Layer',
#   0.5714285714285714),
#  ('com.fsck.k9.service',
#   'com.fsck.k9.service.PollService$Listener',
#   'Domain Layer',
#   0.42857142857142855),
#  ('com.fsck.k9.service',
#   'com.fsck.k9.service.DatabaseUpgradeService',
#   'Service Layer',
#   0.75),
#  ('com.fsck.k9.service',
#   'com.fsck.k9.service.DatabaseUpgradeService',
#   'Presentation Layer',
#   0.25),
#  ('com.fsck.k9.service',
#   'com.fsck.k9.service.BootReceiver',
#   'Service Layer',
#   0.75),
#  ('com.fsck.k9.service',
#   'com.fsck.k9.service.BootReceiver',
#   'Data Source Layer',
#   0.25),
#  ('com.fsck.k9.setup',
#   'com.fsck.k9.setup.ServerNameSuggester',
#   'Service Layer',
#   1.0),
#  ('com.fsck.k9.ui',
#   'com.fsck.k9.ui.EolConvertingEditText',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.ui',
#   'com.fsck.k9.ui.ContactBadge',
#   'Service Layer',
#   0.3333333333333333),
#  ('com.fsck.k9.ui',
#   'com.fsck.k9.ui.ContactBadge',
#   'Presentation Layer',
#   0.6666666666666666),
#  ('com.fsck.k9.ui.compose',
#   'com.fsck.k9.ui.compose.QuotedMessagePresenter',
#   'Presentation Layer',
#   0.4166666666666667),
#  ('com.fsck.k9.ui.compose',
#   'com.fsck.k9.ui.compose.QuotedMessagePresenter',
#   'Domain Layer',
#   0.4166666666666667),
#  ('com.fsck.k9.ui.compose',
#   'com.fsck.k9.ui.compose.QuotedMessagePresenter',
#   'Service Layer',
#   0.16666666666666666),
#  ('com.fsck.k9.ui.compose',
#   'com.fsck.k9.ui.compose.QuotedMessageMvpView',
#   'Domain Layer',
#   0.2222222222222222),
#  ('com.fsck.k9.ui.compose',
#   'com.fsck.k9.ui.compose.QuotedMessageMvpView',
#   'Presentation Layer',
#   0.6666666666666666),
#  ('com.fsck.k9.ui.compose',
#   'com.fsck.k9.ui.compose.QuotedMessageMvpView',
#   'Service Layer',
#   0.1111111111111111),
#  ('com.fsck.k9.ui.crypto',
#   'com.fsck.k9.ui.crypto.MessageCryptoAnnotations',
#   'Domain Layer',
#   0.8),
#  ('com.fsck.k9.ui.crypto',
#   'com.fsck.k9.ui.crypto.MessageCryptoAnnotations',
#   'Data Source Layer',
#   0.2),
#  ('com.fsck.k9.ui.crypto',
#   'com.fsck.k9.ui.crypto.MessageCryptoHelper',
#   'Service Layer',
#   1.0),
#  ('com.fsck.k9.ui.crypto',
#   'com.fsck.k9.ui.crypto.MessageCryptoCallback',
#   'Service Layer',
#   0.6666666666666666),
#  ('com.fsck.k9.ui.crypto',
#   'com.fsck.k9.ui.crypto.MessageCryptoCallback',
#   'Domain Layer',
#   0.3333333333333333),
#  ('com.fsck.k9.ui.message',
#   'com.fsck.k9.ui.message.LocalMessageExtractorLoader',
#   'Domain Layer',
#   0.3333333333333333),
#  ('com.fsck.k9.ui.message',
#   'com.fsck.k9.ui.message.LocalMessageExtractorLoader',
#   'Service Layer',
#   0.3333333333333333),
#  ('com.fsck.k9.ui.message',
#   'com.fsck.k9.ui.message.LocalMessageExtractorLoader',
#   'Presentation Layer',
#   0.3333333333333333),
#  ('com.fsck.k9.ui.message',
#   'com.fsck.k9.ui.message.LocalMessageLoader',
#   'Domain Layer',
#   0.6666666666666666),
#  ('com.fsck.k9.ui.message',
#   'com.fsck.k9.ui.message.LocalMessageLoader',
#   'Data Source Layer',
#   0.3333333333333333),
#  ('com.fsck.k9.ui.messageview',
#   'com.fsck.k9.ui.messageview.AttachmentViewCallback',
#   'Domain Layer',
#   1.0),
#  ('com.fsck.k9.ui.messageview',
#   'com.fsck.k9.ui.messageview.MessageViewFragment',
#   'Presentation Layer',
#   0.5882352941176471),
#  ('com.fsck.k9.ui.messageview',
#   'com.fsck.k9.ui.messageview.MessageViewFragment',
#   'Domain Layer',
#   0.23529411764705882),
#  ('com.fsck.k9.ui.messageview',
#   'com.fsck.k9.ui.messageview.MessageViewFragment',
#   'Service Layer',
#   0.17647058823529413),
#  ('com.fsck.k9.ui.messageview',
#   'com.fsck.k9.ui.messageview.AttachmentController',
#   'Service Layer',
#   0.3333333333333333),
#  ('com.fsck.k9.ui.messageview',
#   'com.fsck.k9.ui.messageview.AttachmentController',
#   'Data Source Layer',
#   0.3333333333333333),
#  ('com.fsck.k9.ui.messageview',
#   'com.fsck.k9.ui.messageview.AttachmentController',
#   'Domain Layer',
#   0.3333333333333333),
#  ('com.fsck.k9.ui.messageview',
#   'com.fsck.k9.ui.messageview.MessageCryptoPresenter$MessageCryptoMvpView',
#   'Domain Layer',
#   0.2),
#  ('com.fsck.k9.ui.messageview',
#   'com.fsck.k9.ui.messageview.MessageCryptoPresenter$MessageCryptoMvpView',
#   'Presentation Layer',
#   0.8),
#  ('com.fsck.k9.ui.messageview',
#   'com.fsck.k9.ui.messageview.MessageTopView',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.ui.messageview',
#   'com.fsck.k9.ui.messageview.MessageContainerView$SavedState',
#   'Data Source Layer',
#   1.0),
#  ('com.fsck.k9.ui.messageview',
#   'com.fsck.k9.ui.messageview.CryptoInfoDialog$OnClickShowCryptoKeyListener',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.ui.messageview',
#   'com.fsck.k9.ui.messageview.MessageViewFragment$MessageViewFragmentListener',
#   'Presentation Layer',
#   0.5555555555555556),
#  ('com.fsck.k9.ui.messageview',
#   'com.fsck.k9.ui.messageview.MessageViewFragment$MessageViewFragmentListener',
#   'Service Layer',
#   0.3333333333333333),
#  ('com.fsck.k9.ui.messageview',
#   'com.fsck.k9.ui.messageview.MessageViewFragment$MessageViewFragmentListener',
#   'Domain Layer',
#   0.1111111111111111),
#  ('com.fsck.k9.ui.messageview',
#   'com.fsck.k9.ui.messageview.LockedAttachmentView',
#   'Presentation Layer',
#   0.6666666666666666),
#  ('com.fsck.k9.ui.messageview',
#   'com.fsck.k9.ui.messageview.LockedAttachmentView',
#   'Domain Layer',
#   0.3333333333333333),
#  ('com.fsck.k9.ui.messageview',
#   'com.fsck.k9.ui.messageview.OnCryptoClickListener',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.ui.messageview',
#   'com.fsck.k9.ui.messageview.AttachmentController$IntentAndResolvedActivitiesCount',
#   'Presentation Layer',
#   0.25),
#  ('com.fsck.k9.ui.messageview',
#   'com.fsck.k9.ui.messageview.AttachmentController$IntentAndResolvedActivitiesCount',
#   'Data Source Layer',
#   0.5),
#  ('com.fsck.k9.ui.messageview',
#   'com.fsck.k9.ui.messageview.AttachmentController$IntentAndResolvedActivitiesCount',
#   'Domain Layer',
#   0.25),
#  ('com.fsck.k9.ui.messageview',
#   'com.fsck.k9.ui.messageview.MessageContainerView$OnRenderingFinishedListener',
#   'Data Source Layer',
#   1.0),
#  ('com.fsck.k9.ui.messageview',
#   'com.fsck.k9.ui.messageview.MessageContainerView',
#   'Domain Layer',
#   0.11764705882352941),
#  ('com.fsck.k9.ui.messageview',
#   'com.fsck.k9.ui.messageview.MessageContainerView',
#   'Presentation Layer',
#   0.8823529411764706),
#  ('com.fsck.k9.ui.messageview',
#   'com.fsck.k9.ui.messageview.CryptoInfoDialog',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.ui.messageview',
#   'com.fsck.k9.ui.messageview.AttachmentView',
#   'Presentation Layer',
#   0.75),
#  ('com.fsck.k9.ui.messageview',
#   'com.fsck.k9.ui.messageview.AttachmentView',
#   'Domain Layer',
#   0.25),
#  ('com.fsck.k9.ui.messageview',
#   'com.fsck.k9.ui.messageview.MessageCryptoPresenter',
#   'Presentation Layer',
#   0.9090909090909091),
#  ('com.fsck.k9.ui.messageview',
#   'com.fsck.k9.ui.messageview.MessageCryptoPresenter',
#   'Domain Layer',
#   0.09090909090909091),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.MessageHeader$OnLayoutChangedListener',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.HighlightDialogFragment',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.CryptoModeSelector$CryptoStatusSelectedListener',
#   'Service Layer',
#   1.0),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.ViewSwitcher',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.NonLockingScrollView',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.MessageCryptoDisplayStatus',
#   'Domain Layer',
#   0.6666666666666666),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.MessageCryptoDisplayStatus',
#   'Service Layer',
#   0.3333333333333333),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.MessageWebView',
#   'Presentation Layer',
#   0.5),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.MessageWebView',
#   'Service Layer',
#   0.25),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.MessageWebView',
#   'Data Source Layer',
#   0.25),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.MessageHeader',
#   'Presentation Layer',
#   0.9411764705882353),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.MessageHeader',
#   'Domain Layer',
#   0.058823529411764705),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.ClientCertificateSpinner',
#   'Domain Layer',
#   0.25),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.ClientCertificateSpinner',
#   'Presentation Layer',
#   0.5),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.ClientCertificateSpinner',
#   'Service Layer',
#   0.25),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.K9WebViewClient',
#   'Data Source Layer',
#   0.25),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.K9WebViewClient',
#   'Presentation Layer',
#   0.75),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.MessageWebView$OnPageFinishedListener',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.ClientCertificateSpinner$OnClientCertificateChangedListener',
#   'Domain Layer',
#   1.0),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.MessageTitleView',
#   'Presentation Layer',
#   0.6666666666666666),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.MessageTitleView',
#   'Domain Layer',
#   0.3333333333333333),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.K9WebViewClient$LollipopWebViewClient',
#   'Data Source Layer',
#   1.0),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.K9WebViewClient$PreLollipopWebViewClient',
#   'Data Source Layer',
#   1.0),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.RecipientSelectView$Recipient',
#   'Domain Layer',
#   0.75),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.RecipientSelectView$Recipient',
#   'Presentation Layer',
#   0.125),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.RecipientSelectView$Recipient',
#   'Data Source Layer',
#   0.125),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.FoldableLinearLayout',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.RecipientSelectView$TokenListener',
#   'Domain Layer',
#   1.0),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.ToolableViewAnimator',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.ViewSwitcher$OnSwitchCompleteListener',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.NonLockingScrollView$HierarchyTreeChangeListener',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.MessageCryptoStatusView',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.FoldableLinearLayout$SavedState',
#   'Domain Layer',
#   1.0),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.LinearViewAnimator',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.MessageHeader$SavedState',
#   'Data Source Layer',
#   1.0),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.ThemeUtils',
#   'Presentation Layer',
#   1.0),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.RecipientSelectView',
#   'Presentation Layer',
#   0.6666666666666666),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.RecipientSelectView',
#   'Domain Layer',
#   0.23809523809523808),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.RecipientSelectView',
#   'Service Layer',
#   0.09523809523809523),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.CryptoModeSelector',
#   'Presentation Layer',
#   0.5),
#  ('com.fsck.k9.view',
#   'com.fsck.k9.view.CryptoModeSelector',
#   'Domain Layer',
#   0.5),
#  ('com.fsck.k9.view', 'com.fsck.k9.view.ColorChip', 'Domain Layer', 1.0),
#  ('com.fsck.k9.widget.list',
#   'com.fsck.k9.widget.list.MessageListWidgetProvider',
#   'Service Layer',
#   0.6666666666666666),
#  ('com.fsck.k9.widget.list',
#   'com.fsck.k9.widget.list.MessageListWidgetProvider',
#   'Presentation Layer',
#   0.3333333333333333),
#  ('com.fsck.k9.widget.list',
#   'com.fsck.k9.widget.list.MessageListWidgetService',
#   'Service Layer',
#   1.0),
#  ('com.fsck.k9.widget.list',
#   'com.fsck.k9.widget.list.MessageListRemoteViewFactory',
#   'Presentation Layer',
#   0.7777777777777778),
#  ('com.fsck.k9.widget.list',
#   'com.fsck.k9.widget.list.MessageListRemoteViewFactory',
#   'Data Source Layer',
#   0.1111111111111111),
#  ('com.fsck.k9.widget.list',
#   'com.fsck.k9.widget.list.MessageListRemoteViewFactory',
#   'Domain Layer',
#   0.1111111111111111)]

# %%
import csv

with open(f"layerinator-v2/{project_name}-layers3-{timestr}.csv", mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(header)
    writer.writerows(rows)
